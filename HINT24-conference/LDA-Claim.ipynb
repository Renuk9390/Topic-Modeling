# %%
import pandas as pd

df_claim = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %% [markdown]
# # preprocessing

# %%
def cleantext(df_claim): 
    
    df_claim['cleaned_Claim_text'] = df_claim['first_claim'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
    
    # convert to lowercase
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].str.lower()
    
    #remove numbers
    df_claim['cleaned_Claim_text'] =df_claim['cleaned_Claim_text'].replace(r'\d+', '', regex = True)
        
    #remove_symbols
    df_claim['cleaned_Claim_text']  = df_claim['cleaned_Claim_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
    
    #remove punctuations 
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
    
    #remove_URL(x):
    df_claim['cleaned_Claim_text']  = df_claim['cleaned_Claim_text'].replace(r'https.*$', "", regex = True)
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace("   ", " ", regex = True)
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace("  ", " ", regex = True)
   
    return df_claim

df_claim = cleantext(df_claim)
df_claim.head()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:181: FutureWarning: Possible nested set at position 1
#   re.compile(obj)
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...

# %%
import nltk
from nltk.corpus import stopwords

# Load the stop words
nltk.download('stopwords')
english_stop_words = set(stopwords.words('english'))

# Define a set of patent-specific stop words 337
patent_stop_words = set([
                        'a', 'an', 'the', 'is', 'are', 'was', 'were', 'will', 'shall', 'may', 'can', 'could',
                        'of', 'in', 'on', 'at', 'by', 'with', 'for', 'to', 'from', 'as', 'and', 'or', 'not',
                        'this', 'that', 'these', 'those', 'such', 'which', 'where', 'when', 'who', 'whom',
                        'what', 'how', 'why', 'be', 'have', 'has', 'having', 'had', 'do', 'does', 'doing',
                        'done', 'but', 'however', 'although', 'unless', 'until', 'since', 'while', 'before',
                        'after', 'during', 'through', 'over', 'under', 'above', 'below', 'between', 'among',
                        'within', 'without', 'against', 'via', 'via', 'due', 'onto', 'per', 'each', 'any',
                        'some', 'many', 'few', 'all', 'most', 'no', 'yes', 'ok', 'okk', 'nope', 'nopes', 'nay',
                        'more', 'less', 'least', 'other', 'another', 'somehow', 'thus', 'therefore',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'therein', 'thereupon', 'therewith', 'thereto', 'wherefore', 'forthwith', 'hereby',
                        'herein', 'hereupon', 'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore',
                        'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore', 'therefrom', 'thereof',
                        'therein', 'thereon', 'thereto', 'whereby', 'thereafter', 'hereafter', 'whenever',
                        'wherever', 'until', 'since', 'whenever', 'wherever', 'until', 'since', 'whereas', 'whilst',
                        'whereas', 'whilst', 'beside', 'beyond', 'during', 'about', 'around', 'above', 'below', 'before',
                        'after', 'without', 'within', 'between', 'among', 'against', 'under', 'over', 'through',
                        'into', 'onto', 'upon', 'am', 'are', 'is', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
                        'had', 'having', 'do', 'does', 'did', 'doing', 'can', 'could', 'will', 'would', 'shall', 'should',
                        'may', 'might', 'must', 'ought', 'need', 'dare', 'used', 'use', 'using', 'uses', 'used', 'put',
                        'puts', 'putting', 'tell', 'tells', 'told', 'telling', 'ask', 'asks', 'asked', 'asking',
                        'make', 'makes', 'made', 'making', 'find', 'finds', 'found', 'finding', 'keep', 'keeps',
                        'kept', 'keeping', 'begin', 'begins', 'began', 'beginning', 'show', 'shows', 'showed',
                        'showing', 'say', 'says', 'said', 'saying', 'says', 'said', 'let', 'lets', 'letting', 'make',
                        'makes', 'made', 'making', 'put', 'puts', 'putting', 'seem', 'seems', 'seemed', 'seeming',
                        'need', 'needs', 'needed', 'needing', 'become', 'becomes', 'became', 'bec'])


# Merge the sets of stop words
stop_words = english_stop_words.union(patent_stop_words)

df_claim['cleaned_Claim_without_Stopwprd'] = df_claim['cleaned_Claim_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
df_claim.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df_claim["Lemmatized-Claim"] = df_claim["cleaned_Claim_without_Stopwprd"].apply(lambda text: lemmatize_words(text))
df_claim.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
first_record = df_claim['Lemmatized-Claim'][1]
first_record
# Out:
# 'claimed data storage retrieval system noncontiguous medical device data system comprising medical device connectable computer network subject occasional gap connectivity computer network configured automatically repeatedly capture status information medical device send message containing status information computer network network connectivity log configured automatically record time medical device connects computer network b time medical device disconnect computer network data store configured automatically store digital medium data medium file provide requested portion stored medium file response provision request wherein provision request includes index relative end medium file corresponds requested portion medium server connectable computer network configured automatically receive message computer network store status information received message data store wherein status information consecutive received message stored contiguously data store notwithstanding occasional gap connectivity medical'

# %%
from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

# Tokenize the abstracts
docs = [doc.split() for doc in df_claim['Lemmatized-Claim']]

# Apply n-gram (1,3) using the Phrases class from Gensim
bigram_phrases = Phrases(docs, min_count=10)  # bigram model
trigram_phrases = Phrases(bigram_phrases[docs], min_count=10)  # trigram model

#quadgram_phraser = Phrases(trigram_phrases[bigram_phrases[docs]])
#docs = [quadgram_phraser[trigram_phrases[bigram_phrases[doc]]] for doc in docs]

docs = [trigram_phrases[bigram_phrases[doc]] for doc in docs]  # apply the trigram model to the tokenized documents

# Create the dictionary and document-term matrix using the Dictionary class from Gensim
id2word = Dictionary(docs)
id2word.filter_extremes(no_below=10, no_above=0.4)  # remove infrequent and very frequent words from the dictionary
corpus = [id2word.doc2bow(doc) for doc in docs]  # convert the tokenized documents to a bag-of-words corpus

# Train the LDA model using the LdaModel class from Gensim
num_topics = 30  # the number of topics to discover
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics, passes=10, random_state=42)

# Transform the corpus to get the topic distribution for each document
lda_output = lda_model[corpus]

# Calculate coherence metrics using the CoherenceModel class from Gensim
cm_cv = CoherenceModel(model=lda_model, corpus=corpus, texts=docs, dictionary=id2word, coherence='c_v')
coherence_cv = cm_cv.get_coherence()  # get the coherence score for the C_v metric

cm_npmi = CoherenceModel(model=lda_model, texts=docs, corpus=corpus, dictionary=id2word, coherence='c_npmi')
coherence_npmi = cm_npmi.get_coherence()  # get the coherence score for the c_npmi metric

cm_umass = CoherenceModel(model=lda_model, corpus=corpus, dictionary=id2word, coherence='u_mass')
coherence_umass = cm_umass.get_coherence()  # get the coherence score for the u_mass metric

# Print the coherence scores
print('C_v coherence:', coherence_cv)
print('c_npmi coherence:', coherence_npmi)
print('u_mass coherence:', coherence_umass)
# Out:
# C_v coherence: 0.38256263268167306
# c_npmi coherence: -0.014029892174474494
# u_mass coherence: -3.964854114233124

# %%
# Print the most significant words for each topic in the model
for topic_num in range(lda_model.num_topics):
    # Get the top 5 words for the current topic
    top_words = lda_model.show_topic(topic_num, topn=10)
    # Join the words into a single string for printing
    word_list = [word for word, _ in top_words]
    topic_words = " ".join(word_list)
    # Print the topic number and its top words
    print(f"Topic #{topic_num}: {topic_words}")
# Out:
# Topic #0: model location object characteristic representation virtual determining physical initial dynamic
# Topic #1: medication type identifier prescription order identification associated member particular receiving
# Topic #2: service digital file request service_provider facility criterion recited_claim voice station
# Topic #3: user health activity input profile processor associated receiving determining device
# Topic #4: healthcare item person product personal platform resource customer recipient card
# Topic #5: point reference position motion body tissue movement area heart brain
# Topic #6: mean medicine compliance pharmaceutical temperature stream center error assistance log
# Topic #7: content component delivery adapted fluid layer clinical_trial phase key flow
# Topic #8: monitoring physiological therapy status condition monitor plan alert change physiological_parameter
# Topic #9: medical set feature training plurality condition candidate input comprises associated
# Topic #10: sensor module configured controller device container wearable comprises sensing dispensing
# Topic #11: first second third component receiving associated portion bed different including
# Topic #12: video setting recording configuration audio environment pressure property channel sound
# Topic #13: image imaging display ultrasound region pixel frame processing processor displaying
# Topic #14: source procedure rule examination medium surgical engine operation usage implant
# Topic #15: subject individual sample step b test c comprises andor cell
# Topic #16: information unit apparatus according display processing configured storage control terminal
# Topic #17: code document collection format text standard human term concept mapping
# Topic #18: score level disease risk determining indicator symptom factor probability prediction
# Topic #19: measurement target region volume node segment scan tag path line
# Topic #20: computing_device exercise program case session subsystem metadata tracking fitness eye
# Topic #21: signal output processor pattern detection biometric response configured circuit detected
# Topic #22: device communication server medical network remote interface mobile message memory
# Topic #23: clinical attribute current task protocol assessment associated receiving template diagnostic
# Topic #24: computer database information user client report receiving application selected display
# Topic #25: patient record information medical electronic care provider health receiving associated
# Topic #26: plurality event drug respective group associated entity corresponding category sequence
# Topic #27: element portion configured light surface material end control optical mode
# Topic #28: treatment dose schedule consumer tool blood therapeutic glucose period administration
# Topic #29: value parameter time according determining function range state amount index

# %%
# Get the most probable topic and its probability for each document
doc_topics = [sorted(lda_model.get_document_topics(doc), key=lambda x: x[1], reverse=True) for doc in lda_output]

# %%
# Create empty columns for topic number and probability
df_claim['topics'] = 0
df_claim['prob'] = 0.0

# Loop through each document and update the corresponding row in the dataframe   
for i, doc in enumerate(doc_topics):
    if len(doc) > 0:
        topic_num, topic_prob = doc[0]
        df_claim.at[i, 'topics'] = topic_num
        df_claim.at[i, 'prob'] = topic_prob

# %%
df_claim
# Out:
#       publication_number country_code kind_code  \
# 0         US2020097067A1           US        A1
# 1         US2020098473A1           US        A1
# 2         US2020098451A1           US        A1
# 3         US2020098458A1           US        A1
# 4         US2020093988A1           US        A1
# ...                  ...          ...       ...
# 31301     US2016253489A1           US        A1
# 31302     US2016253467A1           US        A1
# 31303     US2016253462A1           US        A1
# 31304     US2016249985A1           US        A1
# 31305     US2016253465A1           US        A1
#
#                                                    title  \
# 0      Artificial Intelligence System and Interactive...
# 1      Data Storage and Retrieval System for Non-Cont...
# 2      Hybrid analysis framework for prediction of ou...
# 3      Medical cannabis platform with physician and p...
# 4               Patient day planning systems and methods
# ...                                                  ...
# 31301                         User authentication system
# 31302  Diagnosis support apparatus and method, and no...
# 31303  Novel open-access scheduling system that optim...
# 31304  Interrelated point acquisition for navigated s...
# 31305             Next generation lifestream application
#
#                                                 abstract  \
# 0      A reality interactive responding system, compr...
# 1      A web-based interface enables medical personne...
# 2      A facility for predicting patient outcomes on ...
# 3      Through a physician&#39;s portal, a platform c...
# 4      Infusion systems, infusion devices, and relate...
# ...                                                  ...
# 31301  A user authentication system performs user rec...
# 31302  A diagnosis support apparatus for diagnosis of...
# 31303  A patient appointment schedule is generated fo...
# 31304  The present invention relates to a method for ...
# 31305  A method including a healthcare server of a he...
#
#                                                   claims  publication_date  \
# 0      1 . A reality interactive responding system, c...          20200326
# 1      What is claimed is: \n     \n         1 . A da...          20200326
# 2      1 . A method in a computing system, comprising...          20200326
# 3      What is claimed is: \n     \n         1 . A me...          20200326
# 4      What is claimed is: \n     \n         1 . A me...          20200326
# ...                                                  ...               ...
# 31301  1 . A user authentication system comprising:\n...          20160901
# 31302  What is claimed is: \n     \n         1 . A di...          20160901
# 31303  1 . A medical appointment scheduling system co...          20160901
# 31304  1 . A data processing, comprising a computer h...          20160901
# 31305  1 . A method comprising:\n a healthcare server...          20160901
#
#         ipc_code      cpc_code  \
# 0      G06F9/448     G16H40/67
# 1      G16H40/67   H04L67/1097
# 2      G16H10/20     G16H10/20
# 3      G16H80/00    A61K36/185
# 4      G16H20/17  A61M2230/201
# ...          ...           ...
# 31301  G16H10/60     G06F21/32
# 31302  G16H10/60     A61B5/743
# 31303  G16H40/20    G06F19/327
# 31304  G16H20/40    G06F19/324
# 31305  G16H40/67     G16H50/20
#
#                                              first_claim  claim_lengths  \
# 0      1 . A reality interactive responding system, c...            200
# 1      What is claimed is: 1 . A data storage and ret...            200
# 2      1 . A method in a computing system, comprising...            200
# 3      What is claimed is: 1 . A method for providing...            200
# 4      What is claimed is: 1 . A method of monitoring...            200
# ...                                                  ...            ...
# 31301  1 . A user authentication system comprising: a...            200
# 31302  What is claimed is: 1 . A diagnosis support ap...            200
# 31303  1 . A medical appointment scheduling system co...            200
# 31304  1 . A data processing, comprising a computer h...            200
# 31305  1 . A method comprising: a healthcare server o...            200
#
#                          sub_classes         sub_class  abstract_lengths  \
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']               123
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']               142
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']                81
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']               148
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']               110
# ...                              ...               ...               ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']               151
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']               139
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']               134
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']               200
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']               111
#
#                                       cleaned_Claim_text  \
# 0       a reality interactive responding system compr...
# 1      what is claimed is a data storage and retrieva...
# 2       a method in a computing system comprising obt...
# 3      what is claimed is a method for providing netw...
# 4      what is claimed is a method of monitoring a ph...
# ...                                                  ...
# 31301   a user authentication system comprising a plu...
# 31302  what is claimed is a diagnosis support apparat...
# 31303   a medical appointment scheduling system compr...
# 31304   a data processing comprising a computer havin...
# 31305   a method comprising a healthcare server of a ...
#
#                           cleaned_Claim_without_Stopwprd  \
# 0      reality interactive responding system comprisi...
# 1      claimed data storage retrieval system nonconti...
# 2      method computing system comprising obtaining i...
# 3      claimed method providing networking communicat...
# 4      claimed method monitoring physiological condit...
# ...                                                  ...
# 31301  user authentication system comprising pluralit...
# 31302  claimed diagnosis support apparatus diagnosis ...
# 31303  medical appointment scheduling system comprisi...
# 31304  data processing comprising computer processor ...
# 31305  method comprising healthcare server healthcare...
#
#                                         Lemmatized-Claim  topics      prob
# 0      reality interactive responding system comprisi...      26  0.294128
# 1      claimed data storage retrieval system nonconti...      26  0.462536
# 2      method computing system comprising obtaining i...      24  0.219682
# 3      claimed method providing networking communicat...      26  0.298282
# 4      claimed method monitoring physiological condit...      24  0.292083
# ...                                                  ...     ...       ...
# 31301  user authentication system comprising pluralit...       8  0.492714
# 31302  claimed diagnosis support apparatus diagnosis ...       8  0.345636
# 31303  medical appointment scheduling system comprisi...      26  0.189817
# 31304  data processing comprising computer processor ...      10  0.457962
# 31305  method comprising healthcare server healthcare...      21  0.256824
#
# [31306 rows x 19 columns]

# %%
df_Claim_topic=df_claim[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob"]]
df_Claim_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 1      What is claimed is: 1 . A data storage and ret...
# 2      1 . A method in a computing system, comprising...
# 3      What is claimed is: 1 . A method for providing...
# 4      What is claimed is: 1 . A method of monitoring...
# ...                                                  ...
# 31301  1 . A user authentication system comprising: a...
# 31302  What is claimed is: 1 . A diagnosis support ap...
# 31303  1 . A medical appointment scheduling system co...
# 31304  1 . A data processing, comprising a computer h...
# 31305  1 . A method comprising: a healthcare server o...
#
#                                         Lemmatized-Claim  \
# 0      reality interactive responding system comprisi...
# 1      claimed data storage retrieval system nonconti...
# 2      method computing system comprising obtaining i...
# 3      claimed method providing networking communicat...
# 4      claimed method monitoring physiological condit...
# ...                                                  ...
# 31301  user authentication system comprising pluralit...
# 31302  claimed diagnosis support apparatus diagnosis ...
# 31303  medical appointment scheduling system comprisi...
# 31304  data processing comprising computer processor ...
# 31305  method comprising healthcare server healthcare...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      26  0.294128
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']      26  0.462536
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      24  0.219682
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']      26  0.298282
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      24  0.292083
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']       8  0.492714
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']       8  0.345636
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      26  0.189817
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']      10  0.457962
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']      21  0.256824
#
# [31306 rows x 8 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_Cliam_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_Cliam_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_Cliam_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %% [markdown]
# # list of 10 queries

# %%
num_samples_to_predict = 100
num_of_topics = 5
results = []

# Assuming you have a list of 10 queries in test
queries = df_Cliam_test['first_claim'][:num_samples_to_predict]

for query in queries:
    if isinstance(query, str):  # Check if the value is a string
        query_tokens = trigram_phrases[bigram_phrases[query.split()]]  # Preprocess the query text
        query_bow = id2word.doc2bow(query_tokens)  # Convert to bag of words
        query_topic_dist = lda_model[query_bow]  # Get the topic distribution for the query
        top_topics = sorted(query_topic_dist, key=lambda x: x[1], reverse=True)[:num_of_topics]  # Get the top topics
        results.append(top_topics)
    else:
        results.append([])  # Append an empty list for non-string values

# Now, the 'results' list contains the top topics and their probabilities for each query
# You can access the results for a specific query like this:
for i, top_topics in enumerate(results):
    print(f"Query {i + 1}: Top {num_of_topics} Topics {top_topics}")
# Out:
# Query 1: Top 5 Topics [(27, 0.44132754), (21, 0.27422747), (19, 0.09982033), (7, 0.076217316), (8, 0.041560855)]
# Query 2: Top 5 Topics [(27, 0.72169775), (5, 0.06572825), (22, 0.050713748), (10, 0.044252455), (26, 0.036214855)]
# Query 3: Top 5 Topics [(5, 0.33110124), (25, 0.16941497), (0, 0.13851112), (14, 0.12607163), (13, 0.11857704)]
# Query 4: Top 5 Topics [(7, 0.5665527), (19, 0.08871398), (18, 0.088426836), (16, 0.08838817), (26, 0.08824482)]
# Query 5: Top 5 Topics [(22, 0.27691272), (0, 0.17761587), (24, 0.12198241), (8, 0.121569246), (26, 0.06510305)]
# Query 6: Top 5 Topics [(10, 0.23528697), (24, 0.14775358), (22, 0.12572141), (11, 0.1180997), (16, 0.1011623)]
# Query 7: Top 5 Topics [(10, 0.26557672), (1, 0.2566868), (22, 0.10740168), (25, 0.077250205), (17, 0.07318081)]
# Query 8: Top 5 Topics [(3, 0.30850613), (10, 0.21200706), (5, 0.17465249), (11, 0.15513931), (22, 0.10523008)]
# Query 9: Top 5 Topics [(25, 0.33896887), (14, 0.22263916), (3, 0.1277998), (10, 0.062670775), (23, 0.048956435)]
# Query 10: Top 5 Topics [(11, 0.19381474), (13, 0.18968761), (9, 0.14807008), (26, 0.14706494), (18, 0.09435285)]
# Query 11: Top 5 Topics [(15, 0.38812375), (11, 0.26024124), (19, 0.14694431), (29, 0.12906602), (18, 0.060742382)]
# Query 12: Top 5 Topics [(21, 0.26962838), (3, 0.2358165), (11, 0.13830358), (29, 0.121514864), (10, 0.07834186)]
# Query 13: Top 5 Topics [(27, 0.2526968), (10, 0.22526361), (19, 0.07954049), (11, 0.077143386), (9, 0.07370021)]
# Query 14: Top 5 Topics [(3, 0.5072896), (10, 0.11730039), (5, 0.11507739), (21, 0.07540122), (25, 0.067779765)]
# Query 15: Top 5 Topics [(22, 0.41059375), (21, 0.20596288), (8, 0.100631304), (3, 0.09500468), (16, 0.07675011)]
# Query 16: Top 5 Topics [(21, 0.2224059), (3, 0.13437659), (0, 0.12896131), (11, 0.10056013), (6, 0.08976632)]
# Query 17: Top 5 Topics [(27, 0.36652228), (10, 0.17969653), (11, 0.123544075), (13, 0.09515658), (12, 0.057799112)]
# Query 18: Top 5 Topics [(29, 0.15645805), (28, 0.13479291), (3, 0.120070904), (24, 0.110164866), (18, 0.10937896)]
# Query 19: Top 5 Topics [(29, 0.23722756), (11, 0.13748913), (22, 0.13188829), (28, 0.12486433), (8, 0.11547254)]
# Query 20: Top 5 Topics [(5, 0.18494637), (3, 0.18334101), (25, 0.14219412), (23, 0.09159678), (22, 0.08319142)]
# Query 21: Top 5 Topics [(15, 0.37933373), (26, 0.12855299), (18, 0.11651514), (19, 0.076531135), (10, 0.07224403)]
# Query 22: Top 5 Topics [(27, 0.5068968), (11, 0.12620543), (0, 0.12025961), (18, 0.071417615), (21, 0.053343665)]
# Query 23: Top 5 Topics [(3, 0.74160784), (23, 0.08094059), (9, 0.071355484), (26, 0.06573689), (2, 0.021362571)]
# Query 24: Top 5 Topics [(21, 0.34674153), (5, 0.09173921), (3, 0.088590465), (9, 0.07780989), (10, 0.074852906)]
# Query 25: Top 5 Topics [(23, 0.28408325), (5, 0.2631738), (9, 0.13161947), (29, 0.118334), (17, 0.08908206)]
# Query 26: Top 5 Topics [(0, 0.4231152), (13, 0.16276678), (2, 0.15604395), (21, 0.07175003), (10, 0.047655992)]
# Query 27: Top 5 Topics [(12, 0.31034192), (27, 0.21407418), (11, 0.18641947), (29, 0.107836284), (10, 0.05145516)]
# Query 28: Top 5 Topics [(22, 0.30514538), (25, 0.2151163), (11, 0.21463872), (16, 0.13213575), (26, 0.095159605)]
# Query 29: Top 5 Topics [(15, 0.31939417), (26, 0.20999177), (29, 0.18543875), (5, 0.08823891), (17, 0.07906377)]
# Query 30: Top 5 Topics [(10, 0.53219587), (22, 0.13522993), (11, 0.06969451), (25, 0.05697371), (1, 0.056203153)]
# Query 31: Top 5 Topics [(22, 0.3523052), (26, 0.14950603), (9, 0.12802872), (27, 0.09846588), (2, 0.082706675)]
# Query 32: Top 5 Topics [(27, 0.4649521), (10, 0.16738002), (7, 0.14631797), (19, 0.082057536), (0, 0.053704657)]
# Query 33: Top 5 Topics [(27, 0.5489863), (9, 0.14209254), (11, 0.13266508), (22, 0.1049976), (12, 0.032179486)]
# Query 34: Top 5 Topics [(10, 0.2891684), (22, 0.24280551), (11, 0.117223345), (28, 0.07445728), (5, 0.06875557)]
# Query 35: Top 5 Topics [(22, 0.3369216), (21, 0.23614484), (10, 0.21457522), (14, 0.06991983), (18, 0.039752446)]
# Query 36: Top 5 Topics [(3, 0.20163313), (9, 0.1450286), (16, 0.11958414), (24, 0.07846719), (8, 0.068121)]
# Query 37: Top 5 Topics [(3, 0.40034527), (8, 0.24069902), (29, 0.21110898), (26, 0.10657205)]
# Query 38: Top 5 Topics [(11, 0.28453466), (22, 0.24394408), (18, 0.18848978), (24, 0.12757054), (15, 0.04441592)]
# Query 39: Top 5 Topics [(10, 0.19149655), (12, 0.181662), (22, 0.15819585), (21, 0.12058144), (23, 0.10007599)]
# Query 40: Top 5 Topics [(22, 0.18538432), (24, 0.11851975), (10, 0.114275865), (28, 0.1051582), (5, 0.075581245)]
# Query 41: Top 5 Topics [(24, 0.30701143), (22, 0.2978128), (25, 0.11269387), (12, 0.075640105), (0, 0.06113023)]
# Query 42: Top 5 Topics [(13, 0.28041133), (25, 0.18956909), (27, 0.14099978), (0, 0.11526789), (23, 0.11176191)]
# Query 43: Top 5 Topics [(22, 0.2963852), (11, 0.19645973), (8, 0.14118806), (7, 0.13146046), (16, 0.0860711)]
# Query 44: Top 5 Topics [(5, 0.18936867), (9, 0.14283697), (0, 0.12807025), (8, 0.11059924), (13, 0.091622785)]
# Query 45: Top 5 Topics [(28, 0.25721535), (26, 0.17381349), (24, 0.10460225), (29, 0.07758514), (18, 0.06295139)]
# Query 46: Top 5 Topics [(3, 0.22814807), (24, 0.19805875), (26, 0.1810149), (15, 0.11928602), (29, 0.095720276)]
# Query 47: Top 5 Topics [(10, 0.3151171), (22, 0.13700104), (13, 0.11786838), (28, 0.11173508), (1, 0.085741885)]
# Query 48: Top 5 Topics [(13, 0.18212497), (25, 0.16047211), (19, 0.1117096), (16, 0.08742924), (4, 0.07487278)]
# Query 49: Top 5 Topics [(0, 0.5264005), (26, 0.105991706), (23, 0.10145426), (17, 0.0992012), (12, 0.055404115)]
# Query 50: Top 5 Topics [(19, 0.3140697), (2, 0.23254901), (23, 0.12264127), (21, 0.1213642), (0, 0.07771842)]
# Query 51: Top 5 Topics [(25, 0.29573554), (22, 0.12409829), (4, 0.08343061), (20, 0.08043431), (11, 0.0684973)]
# Query 52: Top 5 Topics [(9, 0.31519067), (15, 0.1654368), (5, 0.12085373), (8, 0.08931457), (18, 0.08533221)]
# Query 53: Top 5 Topics [(9, 0.2918811), (21, 0.22596788), (27, 0.19014494), (3, 0.1568707), (1, 0.04863992)]
# Query 54: Top 5 Topics [(11, 0.17083701), (21, 0.16122353), (5, 0.1304366), (16, 0.1196084), (10, 0.09223863)]
# Query 55: Top 5 Topics [(22, 0.42202613), (11, 0.23527269), (27, 0.22106464), (25, 0.07247056), (14, 0.035273783)]
# Query 56: Top 5 Topics [(3, 0.3280545), (9, 0.21695419), (20, 0.16127355), (7, 0.14939958), (21, 0.11345029)]
# Query 57: Top 5 Topics [(0, 0.40321192), (23, 0.18358132), (5, 0.16990548), (24, 0.06296456), (19, 0.056179)]
# Query 58: Top 5 Topics [(25, 0.39312553), (22, 0.36430594), (8, 0.17537093), (16, 0.052254543)]
# Query 59: Top 5 Topics [(16, 0.21312937), (21, 0.18789889), (26, 0.15996408), (3, 0.11515476), (10, 0.10063642)]
# Query 60: Top 5 Topics [(0, 0.39034194), (5, 0.17413266), (6, 0.10199463), (26, 0.085801534), (14, 0.07466535)]
# Query 61: Top 5 Topics [(3, 0.28871715), (23, 0.19073488), (8, 0.16215494), (22, 0.1519256), (20, 0.1159371)]
# Query 62: Top 5 Topics [(3, 0.3144872), (16, 0.13535781), (20, 0.12768503), (23, 0.101890355), (7, 0.06573736)]
# Query 63: Top 5 Topics [(11, 0.24514343), (10, 0.14302811), (2, 0.14126046), (12, 0.10593133), (6, 0.07736271)]
# Query 64: Top 5 Topics [(21, 0.464573), (8, 0.16997573), (3, 0.12193025), (29, 0.063911386), (9, 0.038855273)]
# Query 65: Top 5 Topics [(10, 0.46376872), (5, 0.15204442), (0, 0.13122685), (17, 0.12114691), (22, 0.10307402)]
# Query 66: Top 5 Topics [(13, 0.21577913), (11, 0.21423467), (10, 0.17847067), (12, 0.16215475), (17, 0.06801348)]
# Query 67: Top 5 Topics []
# Query 68: Top 5 Topics [(29, 0.4089809), (3, 0.333689), (1, 0.06907681), (24, 0.058273792), (20, 0.041321058)]
# Query 69: Top 5 Topics [(21, 0.3525955), (22, 0.17416866), (27, 0.119727604), (7, 0.10799376), (11, 0.07645401)]
# Query 70: Top 5 Topics [(24, 0.3832369), (3, 0.15757741), (10, 0.08865587), (29, 0.07964024), (8, 0.07609932)]
# Query 71: Top 5 Topics [(2, 0.13006599), (16, 0.12248076), (8, 0.121546246), (0, 0.118632786), (26, 0.11713534)]
# Query 72: Top 5 Topics [(10, 0.35941043), (15, 0.201616), (0, 0.06607284), (16, 0.059410878), (17, 0.059363656)]
# Query 73: Top 5 Topics [(3, 0.48062924), (18, 0.23019905), (8, 0.11809279), (24, 0.04845576), (1, 0.048414964)]
# Query 74: Top 5 Topics []
# Query 75: Top 5 Topics [(10, 0.356527), (13, 0.15479891), (26, 0.11231075), (0, 0.071183845), (28, 0.0706305)]
# Query 76: Top 5 Topics [(9, 0.26680836), (16, 0.23497188), (27, 0.21719201), (10, 0.21346569), (13, 0.05493413)]
# Query 77: Top 5 Topics [(10, 0.13872574), (28, 0.10789495), (8, 0.09199606), (21, 0.08706494), (27, 0.08455856)]
# Query 78: Top 5 Topics [(27, 0.22872198), (7, 0.21423359), (21, 0.12036729), (13, 0.09937555), (18, 0.08597678)]
# Query 79: Top 5 Topics [(22, 0.22542511), (28, 0.21037571), (0, 0.10499305), (10, 0.08113184), (3, 0.07915124)]
# Query 80: Top 5 Topics [(22, 0.5077961), (13, 0.2587975)]
# Query 81: Top 5 Topics [(21, 0.23909284), (26, 0.15835992), (11, 0.15133514), (29, 0.1358252), (27, 0.11915261)]
# Query 82: Top 5 Topics [(11, 0.40625545), (5, 0.12559722), (29, 0.12353895), (4, 0.08002061), (18, 0.05458998)]
# Query 83: Top 5 Topics [(27, 0.23235437), (25, 0.18124634), (0, 0.18018822), (5, 0.16402042), (7, 0.15532808)]
# Query 84: Top 5 Topics [(22, 0.35845837), (25, 0.25516903), (3, 0.11405377), (24, 0.070866786), (12, 0.053790133)]
# Query 85: Top 5 Topics [(27, 0.21048795), (21, 0.15502065), (11, 0.14229867), (10, 0.13304497), (16, 0.101005346)]
# Query 86: Top 5 Topics [(3, 0.55688184), (29, 0.08132923), (13, 0.08100571), (20, 0.054360177), (8, 0.054267574)]
# Query 87: Top 5 Topics [(26, 0.31556216), (15, 0.23628414), (27, 0.1294913), (19, 0.11336038), (28, 0.072321415)]
# Query 88: Top 5 Topics [(22, 0.55162585), (1, 0.11374313), (24, 0.11173718), (16, 0.07638406), (4, 0.05984166)]
# Query 89: Top 5 Topics [(10, 0.44866392), (22, 0.101879925), (25, 0.09557462), (1, 0.086671695), (9, 0.043883782)]
# Query 90: Top 5 Topics [(22, 0.5253959), (1, 0.3101536), (9, 0.08116243), (24, 0.055135302), (7, 0.020289043)]
# Query 91: Top 5 Topics [(27, 0.31619775), (13, 0.11833376), (10, 0.10492936), (18, 0.102097824), (5, 0.066614166)]
# Query 92: Top 5 Topics [(13, 0.5442422), (9, 0.39620447), (16, 0.046875637)]
# Query 93: Top 5 Topics [(3, 0.42541227), (23, 0.09714074), (11, 0.08950652), (9, 0.073946506), (18, 0.06556259)]
# Query 94: Top 5 Topics [(8, 0.16632956), (11, 0.15499702), (10, 0.15071824), (3, 0.10125807), (22, 0.085306965)]
# Query 95: Top 5 Topics [(29, 0.18506488), (9, 0.18115789), (21, 0.17421313), (27, 0.1265203), (10, 0.110070035)]
# Query 96: Top 5 Topics [(25, 0.21959934), (24, 0.20451222), (22, 0.16836669), (1, 0.11106432), (4, 0.069546916)]
# Query 97: Top 5 Topics [(22, 0.26697102), (26, 0.25124457), (11, 0.1816238), (1, 0.16982287), (3, 0.10872728)]
# Query 98: Top 5 Topics [(19, 0.26960996), (11, 0.26100343), (24, 0.09263617), (25, 0.0915097), (1, 0.06105806)]
# Query 99: Top 5 Topics [(11, 0.25090268), (26, 0.24945731), (9, 0.115484565), (10, 0.110779434), (21, 0.10840199)]
# Query 100: Top 5 Topics [(24, 0.21438166), (22, 0.14715245), (25, 0.14707512), (11, 0.11311552), (20, 0.11138251)]

# %%
# Create a new DataFrame to store the predicted topics
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Populate the new DataFrame with the predicted topics
for i, top_topics in enumerate(results):
    query_publication_numbers = df_Cliam_test['publication_numbers'].iloc[i]
    query_class_codes = df_Cliam_test['class_codes'].iloc[i]
    query_claim = df_Cliam_test['first_claim'].iloc[i]
    predicted_topics = [topic_id for topic_id, _ in top_topics]
    
    # Append the data to the new DataFrame
    new_row = {'query_publication_numbers': query_publication_numbers,
               'query_class_codes': query_class_codes,
               'query_claim': query_claim,
               'query_predicted_topics': predicted_topics}
    
    result_df_q = pd.concat([result_df_q, pd.DataFrame([new_row])], ignore_index=True)

# Now, predicted_topics_df contains the desired structure of predicted topics for each query
result_df_q
# Out:
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 95           US20230017310A1
# 96           US20230091925A1
# 97           US20230010638A1
# 98           US20230009812A1
# 99           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 95  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 96  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 97  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 98  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 99  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                           query_claim query_predicted_topics
# 0   1. A physiological monitoring device comprisin...     [27, 21, 19, 7, 8]
# 1   1. A monitoring device, comprising:\na band co...    [27, 5, 22, 10, 26]
# 2   1-25. (canceled) 26. A method for guiding a fr...     [5, 25, 0, 14, 13]
# 3   1-184. (canceled) 185. A computer-implemented ...    [7, 19, 18, 16, 26]
# 4   1. (canceled) 2. A community based response sy...     [22, 0, 24, 8, 26]
# ..                                                ...                    ...
# 95  1. A system for storing medical information re...     [25, 24, 22, 1, 4]
# 96  1. A method for event notification in an inter...     [22, 26, 11, 1, 3]
# 97  1.-2. (canceled) 3. A method of managing an in...    [19, 11, 24, 25, 1]
# 98  1. (canceled) 2. A patient monitoring system c...    [11, 26, 9, 10, 21]
# 99  1-27. (canceled) 28. A system to manage record...   [24, 22, 25, 11, 20]
#
# [100 rows x 4 columns]

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'first_claim', 'Lemmatized-Claim', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_claim']
    predicted_topics = row['query_predicted_topics']
    
    rows_to_append = []  # Create a list to store rows to be appended
    
    for topic_id in predicted_topics:
        # Filter 'df_Abstract_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_Claim_topic[df_Claim_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'rows_to_append' list
        for _, doc_row in topic_documents.iterrows():
            new_row = {
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_claim': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'first_claim': doc_row['first_claim'],
                'Lemmatized-Claim': doc_row['Lemmatized-Claim'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }
            rows_to_append.append(new_row)
    
    # Use pd.concat to append rows to result_df
    result_df = pd.concat([result_df, pd.DataFrame(rows_to_append)], ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2022246286A1  Use of audio data for matching patients with h...
# 1        US2021050107A1                       Medical treatment management
# 2        US2022405475A1  System and method for improved feature definit...
# 3        US2002069092A1  Computerized method and system of assessing an...
# 4        US2002062235A1  Computerized method and system for providing c...
# ...                 ...                                                ...
# 3127     US2014206565A1                          Esophageal Cancer Markers
# 3128     US2022351865A1  Methods of biological age evaluation and syste...
# 3129     US2015315652A1  Method for Determining Coronary Artery Disease...
# 3130     US2022180964A1  Systems and methods for karyotyping by sequencing
# 3131     US2021041336A1  Method and system for evaluating fertility of ...
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method comprising: o...
# 1     What is claimed is: 1 . A method comprising: r...
# 2     1 - 28 . (canceled) 29 . A method of classifyi...
# 3     What is claimed is: 1 . A method of estimating...
# 4     What is claimed is: 1 . A method of estimating...
# ...                                                 ...
# 3127  1 . A method of determining presence or predis...
# 3128  We claim: 1 . A method for determining a biolo...
# 3129  1 . A method for determining coronary artery d...
# 3130  What is claimed is: 1 . A method of treating a...
# 3131  1 . A method for evaluating fertility potentia...
#
#                                        Lemmatized-Claim  \
# 0     claimed method comprising obtaining computing ...
# 1     claimed method comprising receiving processor ...
# 2     canceled method classifying speech transcript ...
# 3     claimed method estimating liability accident c...
# 4     claimed method estimating liability accident c...
# ...                                                 ...
# 3127  method determining presence predisposition eso...
# 3128  claim method determining biological age mammal...
# 3129  method determining coronary artery disease ris...
# 3130  claimed method treating subject chromosomal st...
# 3131  method evaluating fertility potential living s...
#
#                      sub_classes         sub_class topics      prob  \
# 0     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# ...                          ...               ...    ...       ...
# 3127  ['G16B25/10', 'G16H70/60']  ['G16B', 'G16H']     11  0.507987
# 3128  ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     11  0.507508
# 3129  ['G16H50/30', 'G06F19/20']  ['G16H', 'G06F']     11  0.507432
# 3130  ['G16H10/40', 'G16B15/20']  ['G16H', 'G16B']     11  0.507175
# 3131  ['G02B21/00', 'G16H50/30']  ['G02B', 'G16H']     11  0.506627
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 3127           US20230138516A1
# 3128           US20230138516A1
# 3129           US20230138516A1
# 3130           US20230138516A1
# 3131           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 3127  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3128  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3129  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3130  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3131  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim query_predicted_topics
# 0     1. A physiological monitoring device comprisin...                   [27]
# 1     1. A physiological monitoring device comprisin...                   [27]
# 2     1. A physiological monitoring device comprisin...                   [27]
# 3     1. A physiological monitoring device comprisin...                   [27]
# 4     1. A physiological monitoring device comprisin...                   [27]
# ...                                                 ...                    ...
# 3127  1-27. (canceled) 28. A system to manage record...                   [11]
# 3128  1-27. (canceled) 28. A system to manage record...                   [11]
# 3129  1-27. (canceled) 28. A system to manage record...                   [11]
# 3130  1-27. (canceled) 28. A system to manage record...                   [11]
# 3131  1-27. (canceled) 28. A system to manage record...                   [11]
#
# [3132 rows x 12 columns]

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2022246286A1  Use of audio data for matching patients with h...
# 1        US2021050107A1                       Medical treatment management
# 2        US2022405475A1  System and method for improved feature definit...
# 3        US2002069092A1  Computerized method and system of assessing an...
# 4        US2002062235A1  Computerized method and system for providing c...
# ...                 ...                                                ...
# 3127     US2014206565A1                          Esophageal Cancer Markers
# 3128     US2022351865A1  Methods of biological age evaluation and syste...
# 3129     US2015315652A1  Method for Determining Coronary Artery Disease...
# 3130     US2022180964A1  Systems and methods for karyotyping by sequencing
# 3131     US2021041336A1  Method and system for evaluating fertility of ...
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method comprising: o...
# 1     What is claimed is: 1 . A method comprising: r...
# 2     1 - 28 . (canceled) 29 . A method of classifyi...
# 3     What is claimed is: 1 . A method of estimating...
# 4     What is claimed is: 1 . A method of estimating...
# ...                                                 ...
# 3127  1 . A method of determining presence or predis...
# 3128  We claim: 1 . A method for determining a biolo...
# 3129  1 . A method for determining coronary artery d...
# 3130  What is claimed is: 1 . A method of treating a...
# 3131  1 . A method for evaluating fertility potentia...
#
#                                        Lemmatized-Claim  \
# 0     claimed method comprising obtaining computing ...
# 1     claimed method comprising receiving processor ...
# 2     canceled method classifying speech transcript ...
# 3     claimed method estimating liability accident c...
# 4     claimed method estimating liability accident c...
# ...                                                 ...
# 3127  method determining presence predisposition eso...
# 3128  claim method determining biological age mammal...
# 3129  method determining coronary artery disease ris...
# 3130  claimed method treating subject chromosomal st...
# 3131  method evaluating fertility potential living s...
#
#                      sub_classes         sub_class topics      prob  \
# 0     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# ...                          ...               ...    ...       ...
# 3127  ['G16B25/10', 'G16H70/60']  ['G16B', 'G16H']     11  0.507987
# 3128  ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     11  0.507508
# 3129  ['G16H50/30', 'G06F19/20']  ['G16H', 'G06F']     11  0.507432
# 3130  ['G16H10/40', 'G16B15/20']  ['G16H', 'G16B']     11  0.507175
# 3131  ['G02B21/00', 'G16H50/30']  ['G02B', 'G16H']     11  0.506627
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 3127           US20230138516A1
# 3128           US20230138516A1
# 3129           US20230138516A1
# 3130           US20230138516A1
# 3131           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 3127  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3128  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3129  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3130  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3131  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 3127  1-27. (canceled) 28. A system to manage record...
# 3128  1-27. (canceled) 28. A system to manage record...
# 3129  1-27. (canceled) 28. A system to manage record...
# 3130  1-27. (canceled) 28. A system to manage record...
# 3131  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [27]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [27]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [27]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [27]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [27]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 3127                   [11]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3128                   [11]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3129                   [11]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3130                   [11]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3131                   [11]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [3132 rows x 13 columns]

# %%
import ast


# Create a new column to store the common code
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Convert the sub_classes string to a list
    sub_classes = ast.literal_eval(sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str
    
    # Debugging statements
    #print(f'Row {index}: sub_classes={sub_classes}, query_codes_G16H={query_codes_G16H}, common_codes={common_codes_str}')

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2022246286A1  Use of audio data for matching patients with h...
# 1        US2021050107A1                       Medical treatment management
# 2        US2022405475A1  System and method for improved feature definit...
# 3        US2002069092A1  Computerized method and system of assessing an...
# 4        US2002062235A1  Computerized method and system for providing c...
# ...                 ...                                                ...
# 3127     US2014206565A1                          Esophageal Cancer Markers
# 3128     US2022351865A1  Methods of biological age evaluation and syste...
# 3129     US2015315652A1  Method for Determining Coronary Artery Disease...
# 3130     US2022180964A1  Systems and methods for karyotyping by sequencing
# 3131     US2021041336A1  Method and system for evaluating fertility of ...
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method comprising: o...
# 1     What is claimed is: 1 . A method comprising: r...
# 2     1 - 28 . (canceled) 29 . A method of classifyi...
# 3     What is claimed is: 1 . A method of estimating...
# 4     What is claimed is: 1 . A method of estimating...
# ...                                                 ...
# 3127  1 . A method of determining presence or predis...
# 3128  We claim: 1 . A method for determining a biolo...
# 3129  1 . A method for determining coronary artery d...
# 3130  What is claimed is: 1 . A method of treating a...
# 3131  1 . A method for evaluating fertility potentia...
#
#                                        Lemmatized-Claim  \
# 0     claimed method comprising obtaining computing ...
# 1     claimed method comprising receiving processor ...
# 2     canceled method classifying speech transcript ...
# 3     claimed method estimating liability accident c...
# 4     claimed method estimating liability accident c...
# ...                                                 ...
# 3127  method determining presence predisposition eso...
# 3128  claim method determining biological age mammal...
# 3129  method determining coronary artery disease ris...
# 3130  claimed method treating subject chromosomal st...
# 3131  method evaluating fertility potential living s...
#
#                      sub_classes         sub_class topics      prob  \
# 0     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# ...                          ...               ...    ...       ...
# 3127  ['G16B25/10', 'G16H70/60']  ['G16B', 'G16H']     11  0.507987
# 3128  ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     11  0.507508
# 3129  ['G16H50/30', 'G06F19/20']  ['G16H', 'G06F']     11  0.507432
# 3130  ['G16H10/40', 'G16B15/20']  ['G16H', 'G16B']     11  0.507175
# 3131  ['G02B21/00', 'G16H50/30']  ['G02B', 'G16H']     11  0.506627
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 3127           US20230138516A1
# 3128           US20230138516A1
# 3129           US20230138516A1
# 3130           US20230138516A1
# 3131           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 3127  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3128  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3129  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3130  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3131  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 3127  1-27. (canceled) 28. A system to manage record...
# 3128  1-27. (canceled) 28. A system to manage record...
# 3129  1-27. (canceled) 28. A system to manage record...
# 3130  1-27. (canceled) 28. A system to manage record...
# 3131  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [27]
# 1                      [27]
# 2                      [27]
# 3                      [27]
# 4                      [27]
# ...                     ...
# 3127                   [11]
# 3128                   [11]
# 3129                   [11]
# 3130                   [11]
# 3131                   [11]
#
#                                        query_codes_G16H exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 3127       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3128       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3129       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3130       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3131       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [3132 rows x 14 columns]

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2022246286A1  Use of audio data for matching patients with h...
# 1        US2021050107A1                       Medical treatment management
# 2        US2022405475A1  System and method for improved feature definit...
# 3        US2002069092A1  Computerized method and system of assessing an...
# 4        US2002062235A1  Computerized method and system for providing c...
# ...                 ...                                                ...
# 3127     US2014206565A1                          Esophageal Cancer Markers
# 3128     US2022351865A1  Methods of biological age evaluation and syste...
# 3129     US2015315652A1  Method for Determining Coronary Artery Disease...
# 3130     US2022180964A1  Systems and methods for karyotyping by sequencing
# 3131     US2021041336A1  Method and system for evaluating fertility of ...
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method comprising: o...
# 1     What is claimed is: 1 . A method comprising: r...
# 2     1 - 28 . (canceled) 29 . A method of classifyi...
# 3     What is claimed is: 1 . A method of estimating...
# 4     What is claimed is: 1 . A method of estimating...
# ...                                                 ...
# 3127  1 . A method of determining presence or predis...
# 3128  We claim: 1 . A method for determining a biolo...
# 3129  1 . A method for determining coronary artery d...
# 3130  What is claimed is: 1 . A method of treating a...
# 3131  1 . A method for evaluating fertility potentia...
#
#                                        Lemmatized-Claim  \
# 0     claimed method comprising obtaining computing ...
# 1     claimed method comprising receiving processor ...
# 2     canceled method classifying speech transcript ...
# 3     claimed method estimating liability accident c...
# 4     claimed method estimating liability accident c...
# ...                                                 ...
# 3127  method determining presence predisposition eso...
# 3128  claim method determining biological age mammal...
# 3129  method determining coronary artery disease ris...
# 3130  claimed method treating subject chromosomal st...
# 3131  method evaluating fertility potential living s...
#
#                      sub_classes         sub_class topics      prob  \
# 0     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# ...                          ...               ...    ...       ...
# 3127  ['G16B25/10', 'G16H70/60']  ['G16B', 'G16H']     11  0.507987
# 3128  ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     11  0.507508
# 3129  ['G16H50/30', 'G06F19/20']  ['G16H', 'G06F']     11  0.507432
# 3130  ['G16H10/40', 'G16B15/20']  ['G16H', 'G16B']     11  0.507175
# 3131  ['G02B21/00', 'G16H50/30']  ['G02B', 'G16H']     11  0.506627
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 3127           US20230138516A1
# 3128           US20230138516A1
# 3129           US20230138516A1
# 3130           US20230138516A1
# 3131           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 3127  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3128  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3129  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3130  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3131  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 3127  1-27. (canceled) 28. A system to manage record...
# 3128  1-27. (canceled) 28. A system to manage record...
# 3129  1-27. (canceled) 28. A system to manage record...
# 3130  1-27. (canceled) 28. A system to manage record...
# 3131  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [27]
# 1                      [27]
# 2                      [27]
# 3                      [27]
# 4                      [27]
# ...                     ...
# 3127                   [11]
# 3128                   [11]
# 3129                   [11]
# 3130                   [11]
# 3131                   [11]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 3127       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3128       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3129       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3130       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3131       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50
# 0                           6
# 1                           6
# 2                           6
# 3                           6
# 4                           6
# ...                       ...
# 3127                        2
# 3128                        2
# 3129                        2
# 3130                        2
# 3131                        2
#
# [3132 rows x 15 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2022246286A1  Use of audio data for matching patients with h...
# 1        US2021050107A1                       Medical treatment management
# 2        US2022405475A1  System and method for improved feature definit...
# 3        US2002069092A1  Computerized method and system of assessing an...
# 4        US2002062235A1  Computerized method and system for providing c...
# ...                 ...                                                ...
# 3127     US2014206565A1                          Esophageal Cancer Markers
# 3128     US2022351865A1  Methods of biological age evaluation and syste...
# 3129     US2015315652A1  Method for Determining Coronary Artery Disease...
# 3130     US2022180964A1  Systems and methods for karyotyping by sequencing
# 3131     US2021041336A1  Method and system for evaluating fertility of ...
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method comprising: o...
# 1     What is claimed is: 1 . A method comprising: r...
# 2     1 - 28 . (canceled) 29 . A method of classifyi...
# 3     What is claimed is: 1 . A method of estimating...
# 4     What is claimed is: 1 . A method of estimating...
# ...                                                 ...
# 3127  1 . A method of determining presence or predis...
# 3128  We claim: 1 . A method for determining a biolo...
# 3129  1 . A method for determining coronary artery d...
# 3130  What is claimed is: 1 . A method of treating a...
# 3131  1 . A method for evaluating fertility potentia...
#
#                                        Lemmatized-Claim  \
# 0     claimed method comprising obtaining computing ...
# 1     claimed method comprising receiving processor ...
# 2     canceled method classifying speech transcript ...
# 3     claimed method estimating liability accident c...
# 4     claimed method estimating liability accident c...
# ...                                                 ...
# 3127  method determining presence predisposition eso...
# 3128  claim method determining biological age mammal...
# 3129  method determining coronary artery disease ris...
# 3130  claimed method treating subject chromosomal st...
# 3131  method evaluating fertility potential living s...
#
#                      sub_classes         sub_class topics      prob  \
# 0     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# ...                          ...               ...    ...       ...
# 3127  ['G16B25/10', 'G16H70/60']  ['G16B', 'G16H']     11  0.507987
# 3128  ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     11  0.507508
# 3129  ['G16H50/30', 'G06F19/20']  ['G16H', 'G06F']     11  0.507432
# 3130  ['G16H10/40', 'G16B15/20']  ['G16H', 'G16B']     11  0.507175
# 3131  ['G02B21/00', 'G16H50/30']  ['G02B', 'G16H']     11  0.506627
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 3127           US20230138516A1
# 3128           US20230138516A1
# 3129           US20230138516A1
# 3130           US20230138516A1
# 3131           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 3127  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3128  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3129  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3130  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 3131  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 3127  1-27. (canceled) 28. A system to manage record...
# 3128  1-27. (canceled) 28. A system to manage record...
# 3129  1-27. (canceled) 28. A system to manage record...
# 3130  1-27. (canceled) 28. A system to manage record...
# 3131  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [27]
# 1                      [27]
# 2                      [27]
# 3                      [27]
# 4                      [27]
# ...                     ...
# 3127                   [11]
# 3128                   [11]
# 3129                   [11]
# 3130                   [11]
# 3131                   [11]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 3127       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3128       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3129       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3130       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 3131       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50  RFR
# 0                           6  4.0
# 1                           6  4.0
# 2                           6  4.0
# 3                           6  4.0
# 4                           6  4.0
# ...                       ...  ...
# 3127                        2  8.0
# 3128                        2  8.0
# 3129                        2  8.0
# 3130                        2  8.0
# 3131                        2  8.0
#
# [3132 rows x 16 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_claim","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2022143460A1  Method and system for dynamically transforming...
# 1       US2022233241A1                      Surgical procedure monitoring
# 2       US2014278543A1  Data collection marketplace for a data registr...
# 3       US2019117812A1        Activity-Based Targeted Disinfection System
# 4       US2015079565A1      Automated intelligent mentoring system (aims)
# ..                 ...                                                ...
# 482     US2022246286A1  Use of audio data for matching patients with h...
# 483     US2021050107A1                       Medical treatment management
# 484     US2022405475A1  System and method for improved feature definit...
# 485     US2002069092A1  Computerized method and system of assessing an...
# 486     US2002062235A1  Computerized method and system for providing c...
#
#                                            first_claim  \
# 0    What is claimed is: 1 . A computing system imp...
# 1    1 . A surgical computing system comprising: a ...
# 2    1 . A system comprising: a processor; a memory...
# 3    What is claimed is: 1 . A disinfection system,...
# 4    What is claimed is: 1 . A computer-implemented...
# ..                                                 ...
# 482  What is claimed is: 1 . A method comprising: o...
# 483  What is claimed is: 1 . A method comprising: r...
# 484  1 - 28 . (canceled) 29 . A method of classifyi...
# 485  What is claimed is: 1 . A method of estimating...
# 486  What is claimed is: 1 . A method of estimating...
#
#                                       Lemmatized-Claim  \
# 0    claimed computing system implemented method co...
# 1    surgical computing system comprising processor...
# 2    system comprising processor memory storing ins...
# 3    claimed disinfection system comprising one sen...
# 4    claimed computerimplemented method evaluating ...
# ..                                                 ...
# 482  claimed method comprising obtaining computing ...
# 483  claimed method comprising receiving processor ...
# 484  canceled method classifying speech transcript ...
# 485  claimed method estimating liability accident c...
# 486  claimed method estimating liability accident c...
#
#                        sub_classes         sub_class topics      prob  \
# 0        ['G06N7/00', 'G16H20/30']  ['G06N', 'G16H']      0  0.479555
# 1    ['G16H20/40', 'A61B2034/252']  ['G16H', 'A61B']      0  0.468093
# 2       ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']      0  0.446191
# 3        ['A61L2/26', 'G16H40/20']  ['A61L', 'G16H']      0  0.437888
# 4       ['G16H50/50', 'A63B69/38']  ['G16H', 'A63B']      0  0.429625
# ..                             ...               ...    ...       ...
# 482     ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 483     ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 484     ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 485     ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 486     ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 482           US20230270344A1
# 483           US20230270344A1
# 484           US20230270344A1
# 485           US20230270344A1
# 486           US20230270344A1
#
#                                            query_claim  \
# 0    1. A continuous glucose monitoring system comp...
# 1    1. A continuous glucose monitoring system comp...
# 2    1. A continuous glucose monitoring system comp...
# 3    1. A continuous glucose monitoring system comp...
# 4    1. A continuous glucose monitoring system comp...
# ..                                                 ...
# 482  1. A monitoring device, comprising:\na band co...
# 483  1. A monitoring device, comprising:\na band co...
# 484  1. A monitoring device, comprising:\na band co...
# 485  1. A monitoring device, comprising:\na band co...
# 486  1. A monitoring device, comprising:\na band co...
#
#                                       query_codes_G16H exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...        G16H50/50
# ..                                                 ...              ...
# 482  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H50/20
# 483  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H20/00
# 484  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H50/20
# 485  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H40/67
# 486  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H40/67
#
#      count_exact_match_top50  count_exact_match_top5
# 0                          6                       1
# 1                          6                       1
# 2                          6                       1
# 3                          6                       1
# 4                          6                       1
# ..                       ...                     ...
# 482                       23                       5
# 483                       23                       5
# 484                       23                       5
# 485                       23                       5
# 486                       23                       5
#
# [487 rows x 14 columns]

# %%
result_df.to_csv('LDA-Claim.csv', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     1.0
# 1            US20230001263A1                     2.0
# 2            US20230005591A1                     1.0
# 3            US20230005611A1                     0.0
# 4            US20230009812A1                     0.0
# ..                       ...                     ...
# 93           US20230255518A1                     1.0
# 94           US20230259481A1                     1.0
# 95           US20230260617A1                     2.0
# 96           US20230264029A1                     0.0
# 97           US20230270344A1                     5.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 1.030612244897959

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                      6.0
# 1            US20230001263A1                     10.0
# 2            US20230005591A1                      5.0
# 3            US20230005611A1                      0.0
# 4            US20230009812A1                      2.0
# ..                       ...                      ...
# 93           US20230255518A1                      8.0
# 94           US20230259481A1                      8.0
# 95           US20230260617A1                     14.0
# 96           US20230264029A1                      4.0
# 97           US20230270344A1                     23.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 6.224489795918367

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1   5.0
# 1            US20230001263A1   1.0
# 2            US20230005591A1   4.0
# 3            US20230005611A1   NaN
# 4            US20230009812A1  31.0
# ..                       ...   ...
# 93           US20230255518A1   5.0
# 94           US20230259481A1   4.0
# 95           US20230260617A1   1.0
# 96           US20230264029A1  15.0
# 97           US20230270344A1   1.0
#
# [98 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 6.0

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230238130A1']
filtered_df
# Out:
#    publication_number                                              title  \
# 0      US2022246286A1  Use of audio data for matching patients with h...
# 1      US2021050107A1                       Medical treatment management
# 2      US2022405475A1  System and method for improved feature definit...
# 3      US2002069092A1  Computerized method and system of assessing an...
# 4      US2002062235A1  Computerized method and system for providing c...
# 5      US2021375430A1  Methods, systems, and devices for generating a...
# 6      US2022028535A1  Method for mitigating disease transmission in ...
# 7      US2020320391A1  Multilayer perceptron based network to identif...
# 8      US2019057760A1  Automated medical note generation system utili...
# 9      US2020167608A1  Generative Adversarial Network Medical Image G...
# 10     US2011190694A1                             Infusion pump assembly
# 11     US2010131471A1  Correlating subjective user states with object...
# 12     US2009076839A1                             Semantic search system
# 13     US2011046980A1  Information security for recovery based social...
# 14     US2020357300A1  Incorporating real world physical activity int...
# 15     US2022160976A1                        Oxygen tank duration of use
# 16     US2012062383A1  Method for determining operator condition, dev...
# 17     US2018204482A1                              Food Content Detector
# 18     US2018274990A1  Thermometer and body temperature measuring app...
# 19     US2019295398A1       Method for supporting a user and user device
# 20     US2016328855A1  Method and System for Whole Body Bone Removal ...
# 21     US2010290693A1  Location-sensitive cursor control and its use ...
# 22     US2019192114A1  System and Method for Ultrasound Spine Shadow ...
# 23     US2015282782A1         System and method for detection of lesions
# 24     US2020352537A1  Automatic on-the-fly positron emission tomogra...
# 25     US2022292737A1  Method for converting mri to ct image based on...
# 26     US2019307428A1  Methods and apparatus for configuring an ultra...
# 27     US2016364856A1              Process for computed tomography image
# 28     US2016133037A1  Method and System for Unsupervised Cross-Modal...
# 29     US2021093417A1  Imaging and display system for guiding medical...
# 30     US2007179434A1  System and method for determining drug adminis...
# 31     US2012066540A1   Information correction support system and method
# 32     US2012226446A1  Systems and methods for monitoring the use of ...
# 33     US2015193585A1   System with breathing apparatus and touch screen
# 34     US2012065915A1  Information processing method, apparatus, and ...
# 35     US2015145690A1  Health improvement system and method and non-t...
# 36     US2019034991A1  Information insight system for providers of pr...
# 37     US2021007678A1        Selection support system and storage medium
# 38     US2008275721A1  Information Terminal and Health Care Assisting...
# 39     US2017076055A1  Medication history management method and medic...
#
#                                           first_claim  \
# 0   What is claimed is: 1 . A method comprising: o...
# 1   What is claimed is: 1 . A method comprising: r...
# 2   1 - 28 . (canceled) 29 . A method of classifyi...
# 3   What is claimed is: 1 . A method of estimating...
# 4   What is claimed is: 1 . A method of estimating...
# 5   What is claimed is: 1 . A system for generatin...
# 6   I claim: 1 . A method for mitigating disease t...
# 7   What is claimed is: 1 . A method for training ...
# 8   We claim: 1 . A computer-implemented system fo...
# 9   1 . A method, in a data processing system comp...
# 10  1 . A wearable infusion pump assembly comprisi...
# 11  1 .- 106 . (canceled) 107 . A computationally-...
# 12  1 . A method for use of an ontology for search...
# 13  What is claimed is: 1 . A system for recovery ...
# 14  What is claimed is: 1 . A system comprising: a...
# 15  What is claimed is: 1 . A computer-implemented...
# 16  We claim: 1 . A method for alarm distribution,...
# 17  1 .- 672 . (canceled) 673 . A system, comprisi...
# 18  What is claimed is: 1 . A thermometer comprisi...
# 19  What is claimed is: 1 . A method for supportin...
# 20  1 . A method for bone removal and vessel visua...
# 21  1 - 27 . (canceled) 28 . A method, comprising:...
# 22  What is claimed is: 1 . A method, comprising: ...
# 23  1 . A method for detecting a lesion in an anat...
# 24  1 . A non-transitory computer-readable medium ...
# 25  What is claimed is: 1 . A method for convertin...
# 26  What is claimed is: 1 . An ultrasound system, ...
# 27  1 . A method of processing a Computed Tomograp...
# 28  1 . A method for unsupervised cross-modal synt...
# 29  What is claimed is: 1 . A system for capturing...
# 30  1 . A system for determining drug administrati...
# 31  What is claimed is: 1 . An information correct...
# 32  1 . A system for monitoring a fluid, comprisin...
# 33  1 . A system comprising: a breathing apparatus...
# 34  What is claimed is: 1 . An information process...
# 35  What is claimed is: 1 . A health improvement s...
# 36  1 . A method, comprising: identifying a first ...
# 37  What is claimed is: 1 . A selection support sy...
# 38  1 : An information terminal having a function ...
# 39  1 . A medication history management method in ...
#
#                                      Lemmatized-Claim  \
# 0   claimed method comprising obtaining computing ...
# 1   claimed method comprising receiving processor ...
# 2   canceled method classifying speech transcript ...
# 3   claimed method estimating liability accident c...
# 4   claimed method estimating liability accident c...
# 5   claimed system generating refreshment instruct...
# 6   claim method mitigating disease transmission f...
# 7   claimed method training baseline risk model co...
# 8   claim computerimplemented system preparing med...
# 9   method data processing system comprising proce...
# 10  wearable infusion pump assembly comprising res...
# 11  canceled computationallyimplemented system com...
# 12  method ontology searching medical document met...
# 13  claimed system recovery based social networkin...
# 14  claimed system comprising virtual world enviro...
# 15  claimed computerimplemented method determining...
# 16  claim method alarm distribution method compris...
# 17  canceled system comprising utensil mean presen...
# 18  claimed thermometer comprising main body exten...
# 19  claimed method supporting user method comprisi...
# 20  method bone removal vessel visualization medic...
# 21  canceled method comprising displaying image on...
# 22  claimed method comprising obtaining processor ...
# 23  method detecting lesion anatomical region inte...
# 24  nontransitory computerreadable medium storing ...
# 25  claimed method converting magnetic resonance i...
# 26  claimed ultrasound system comprising processin...
# 27  method processing computed tomography ct image...
# 28  method unsupervised crossmodal synthesis targe...
# 29  claimed system capturing image target interest...
# 30  system determining drug administration informa...
# 31  claimed information correction support system ...
# 32  system monitoring fluid comprising first fluid...
# 33  system comprising breathing apparatus touch sc...
# 34  claimed information processing method executed...
# 35  claimed health improvement system comprising o...
# 36  method comprising identifying first user enter...
# 37  claimed selection support system comprising on...
# 38  information terminal function collecting biolo...
# 39  medication history management method server ap...
#
#                        sub_classes         sub_class topics      prob  \
# 0       ['G16H50/20', 'G06N3/044']  ['G16H', 'G06N']     27  0.479324
# 1       ['G16H30/20', 'G16H20/00']  ['G16H', 'G16H']     27  0.474824
# 2       ['G16H50/70', 'G16H50/20']  ['G16H', 'G16H']     27  0.473163
# 3       ['G06Q40/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467067
# 4       ['G06Q10/00', 'G16H40/67']  ['G06Q', 'G16H']     27  0.467060
# 5       ['G16H50/20', 'G16H20/60']  ['G16H', 'G16H']     27  0.463687
# 6       ['G16H40/20', 'G06V20/52']  ['G16H', 'G06V']     27  0.461608
# 7        ['G06N3/04', 'G16H50/70']  ['G06N', 'G16H']     27  0.433526
# 8       ['G16H10/60', 'G10L15/26']  ['G16H', 'G10L']     27  0.419944
# 9        ['G06N5/02', 'G16H30/20']  ['G06N', 'G16H']     27  0.383960
# 10    ['G16H20/17', 'A61M5/14216']  ['G16H', 'A61M']     21  0.514581
# 11      ['G06F17/30', 'G16H30/20']  ['G06F', 'G16H']     21  0.514368
# 12      ['G16H70/60', 'G16H70/60']  ['G16H', 'G16H']     21  0.513863
# 13      ['G16H10/20', 'H04L51/52']  ['G16H', 'H04L']     21  0.513510
# 14      ['G09B19/00', 'G16H20/30']  ['G09B', 'G16H']     21  0.513507
# 15  ['G16H40/67', 'A61M2205/3331']  ['G16H', 'A61M']     21  0.513358
# 16      ['G08B23/00', 'G16H40/67']  ['G08B', 'G16H']     21  0.513278
# 17      ['G16H20/60', 'Y02A90/26']  ['G16H', 'Y02A']     21  0.513032
# 18       ['G01V3/08', 'G16H40/67']  ['G01V', 'G16H']     21  0.508235
# 19      ['G08B21/18', 'G16H80/00']  ['G08B', 'G16H']     21  0.508007
# 20      ['G06T15/08', 'G16H30/40']  ['G06T', 'G16H']      7  0.496871
# 21       ['G06K9/00', 'G16H50/30']  ['G06K', 'G16H']      7  0.495496
# 22       ['G06K9/46', 'G16H50/30']  ['G06K', 'G16H']      7  0.494179
# 23       ['A61B8/08', 'G16H50/30']  ['A61B', 'G16H']      7  0.493029
# 24      ['G16H30/20', 'A61B6/582']  ['G16H', 'A61B']      7  0.490865
# 25     ['G16H30/40', 'A61B6/5217']  ['G16H', 'A61B']      7  0.489473
# 26       ['A61B8/08', 'G16H50/30']  ['A61B', 'G16H']      7  0.486618
# 27       ['A61B6/03', 'G16H50/20']  ['A61B', 'G16H']      7  0.486260
# 28       ['G06K9/62', 'G16H30/40']  ['G06K', 'G16H']      7  0.486098
# 29      ['A61B90/20', 'G16H40/63']  ['A61B', 'G16H']      7  0.484747
# 30       ['G16H10/60', 'A61P3/10']  ['G16H', 'A61P']      8  0.514928
# 31      ['G16H10/60', 'G16H10/20']  ['G16H', 'G16H']      8  0.514787
# 32      ['G16H20/17', 'A61M5/168']  ['G16H', 'A61M']      8  0.514775
# 33      ['G06F19/00', 'G16H20/40']  ['G06F', 'G16H']      8  0.514684
# 34      ['G16H40/60', 'G16H20/30']  ['G16H', 'G16H']      8  0.514629
# 35     ['G16H20/70', 'A61B5/0024']  ['G16H', 'A61B']      8  0.514624
# 36      ['G06Q30/06', 'G16H10/60']  ['G06Q', 'G16H']      8  0.514576
# 37     ['G16H30/40', 'A61B5/7435']  ['G16H', 'A61B']      8  0.514412
# 38      ['G16H20/60', 'G16H20/60']  ['G16H', 'G16H']      8  0.514358
# 39     ['G16H10/60', 'G06F19/326']  ['G16H', 'G06F']      8  0.514336
#
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230238130A1
# 2            US20230238130A1
# 3            US20230238130A1
# 4            US20230238130A1
# 5            US20230238130A1
# 6            US20230238130A1
# 7            US20230238130A1
# 8            US20230238130A1
# 9            US20230238130A1
# 10           US20230238130A1
# 11           US20230238130A1
# 12           US20230238130A1
# 13           US20230238130A1
# 14           US20230238130A1
# 15           US20230238130A1
# 16           US20230238130A1
# 17           US20230238130A1
# 18           US20230238130A1
# 19           US20230238130A1
# 20           US20230238130A1
# 21           US20230238130A1
# 22           US20230238130A1
# 23           US20230238130A1
# 24           US20230238130A1
# 25           US20230238130A1
# 26           US20230238130A1
# 27           US20230238130A1
# 28           US20230238130A1
# 29           US20230238130A1
# 30           US20230238130A1
# 31           US20230238130A1
# 32           US20230238130A1
# 33           US20230238130A1
# 34           US20230238130A1
# 35           US20230238130A1
# 36           US20230238130A1
# 37           US20230238130A1
# 38           US20230238130A1
# 39           US20230238130A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 5   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 6   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 7   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 8   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 9   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 10  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 11  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 12  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 13  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 14  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 15  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 16  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 17  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 18  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 19  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 20  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 21  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 22  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 23  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 24  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 25  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 26  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 27  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 28  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 29  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 30  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 31  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 32  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 33  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 34  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 35  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 36  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 37  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 38  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 39  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
#
#                                           query_claim query_predicted_topics  \
# 0   1. A physiological monitoring device comprisin...                   [27]
# 1   1. A physiological monitoring device comprisin...                   [27]
# 2   1. A physiological monitoring device comprisin...                   [27]
# 3   1. A physiological monitoring device comprisin...                   [27]
# 4   1. A physiological monitoring device comprisin...                   [27]
# 5   1. A physiological monitoring device comprisin...                   [27]
# 6   1. A physiological monitoring device comprisin...                   [27]
# 7   1. A physiological monitoring device comprisin...                   [27]
# 8   1. A physiological monitoring device comprisin...                   [27]
# 9   1. A physiological monitoring device comprisin...                   [27]
# 10  1. A physiological monitoring device comprisin...                   [21]
# 11  1. A physiological monitoring device comprisin...                   [21]
# 12  1. A physiological monitoring device comprisin...                   [21]
# 13  1. A physiological monitoring device comprisin...                   [21]
# 14  1. A physiological monitoring device comprisin...                   [21]
# 15  1. A physiological monitoring device comprisin...                   [21]
# 16  1. A physiological monitoring device comprisin...                   [21]
# 17  1. A physiological monitoring device comprisin...                   [21]
# 18  1. A physiological monitoring device comprisin...                   [21]
# 19  1. A physiological monitoring device comprisin...                   [21]
# 20  1. A physiological monitoring device comprisin...                    [7]
# 21  1. A physiological monitoring device comprisin...                    [7]
# 22  1. A physiological monitoring device comprisin...                    [7]
# 23  1. A physiological monitoring device comprisin...                    [7]
# 24  1. A physiological monitoring device comprisin...                    [7]
# 25  1. A physiological monitoring device comprisin...                    [7]
# 26  1. A physiological monitoring device comprisin...                    [7]
# 27  1. A physiological monitoring device comprisin...                    [7]
# 28  1. A physiological monitoring device comprisin...                    [7]
# 29  1. A physiological monitoring device comprisin...                    [7]
# 30  1. A physiological monitoring device comprisin...                    [8]
# 31  1. A physiological monitoring device comprisin...                    [8]
# 32  1. A physiological monitoring device comprisin...                    [8]
# 33  1. A physiological monitoring device comprisin...                    [8]
# 34  1. A physiological monitoring device comprisin...                    [8]
# 35  1. A physiological monitoring device comprisin...                    [8]
# 36  1. A physiological monitoring device comprisin...                    [8]
# 37  1. A physiological monitoring device comprisin...                    [8]
# 38  1. A physiological monitoring device comprisin...                    [8]
# 39  1. A physiological monitoring device comprisin...                    [8]
#
#                                      query_codes_G16H exact_match_code  \
# 0   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 5   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 6   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 7   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 8   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 9   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 10  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 11  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 12  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 13  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 14  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 15  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 16  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 17  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 18  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 19  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 20  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 21  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 22  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 23  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 24  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 25  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 26  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 27  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 28  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 29  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 30  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 31  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 32  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 33  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 34  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/60
# 35  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 36  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 37  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 38  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 39  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
#
#     count_exact_match_top50  RFR
# 0                         6  4.0
# 1                         6  4.0
# 2                         6  4.0
# 3                         6  4.0
# 4                         6  4.0
# 5                         6  4.0
# 6                         6  4.0
# 7                         6  4.0
# 8                         6  4.0
# 9                         6  4.0
# 10                        6  4.0
# 11                        6  4.0
# 12                        6  4.0
# 13                        6  4.0
# 14                        6  4.0
# 15                        6  4.0
# 16                        6  4.0
# 17                        6  4.0
# 18                        6  4.0
# 19                        6  4.0
# 20                        6  4.0
# 21                        6  4.0
# 22                        6  4.0
# 23                        6  4.0
# 24                        6  4.0
# 25                        6  4.0
# 26                        6  4.0
# 27                        6  4.0
# 28                        6  4.0
# 29                        6  4.0
# 30                        6  4.0
# 31                        6  4.0
# 32                        6  4.0
# 33                        6  4.0
# 34                        6  4.0
# 35                        6  4.0
# 36                        6  4.0
# 37                        6  4.0
# 38                        6  4.0
# 39                        6  4.0
