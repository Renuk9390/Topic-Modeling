# %%
import pandas as pd

df_Abstract = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_Abstract.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
len(df_Abstract)
# Out:
# 31306

# %% [markdown]
# # preprocessing

# %%
def cleantext(df_Abstract): 
    
    df_Abstract['cleaned_Abstract_text'] = df_Abstract['abstract'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
    
    # convert to lowercase
    df_Abstract['cleaned_Abstract_text'] = df_Abstract['cleaned_Abstract_text'].str.lower()
    
    #remove numbers
    df_Abstract['cleaned_Abstract_text'] =df_Abstract['cleaned_Abstract_text'].replace(r'\d+', '', regex = True)
        
    #remove_symbols
    df_Abstract['cleaned_Abstract_text']  = df_Abstract['cleaned_Abstract_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
    
    #remove punctuations 
    df_Abstract['cleaned_Abstract_text'] = df_Abstract['cleaned_Abstract_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
    
    #remove_URL(x):
    df_Abstract['cleaned_Abstract_text']  = df_Abstract['cleaned_Abstract_text'].replace(r'https.*$', "", regex = True)
    df_Abstract['cleaned_Abstract_text'] = df_Abstract['cleaned_Abstract_text'].replace("   ", " ", regex = True)
    df_Abstract['cleaned_Abstract_text'] = df_Abstract['cleaned_Abstract_text'].replace("  ", " ", regex = True)
   
    return df_Abstract

df_Abstract = cleantext(df_Abstract)
df_Abstract.head()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:181: FutureWarning: Possible nested set at position 1
#   re.compile(obj)
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                              cleaned_Abstract_text
# 0               123  a reality interactive responding system compri...
# 1               142  a webbased interface enables medical personnel...
# 2                81  a facility for predicting patient outcomes on ...
# 3               148  through a physician s portal a platform calcul...
# 4               110  infusion systems infusion devices and related ...

# %%
import nltk
from nltk.corpus import stopwords

# Load the stop words
nltk.download('stopwords')
english_stop_words = set(stopwords.words('english'))

# Define a set of patent-specific stop words 337
patent_stop_words = set([
                        'a', 'an', 'the', 'is', 'are', 'was', 'were', 'will', 'shall', 'may', 'can', 'could',
                        'of', 'in', 'on', 'at', 'by', 'with', 'for', 'to', 'from', 'as', 'and', 'or', 'not',
                        'this', 'that', 'these', 'those', 'such', 'which', 'where', 'when', 'who', 'whom',
                        'what', 'how', 'why', 'be', 'have', 'has', 'having', 'had', 'do', 'does', 'doing',
                        'done', 'but', 'however', 'although', 'unless', 'until', 'since', 'while', 'before',
                        'after', 'during', 'through', 'over', 'under', 'above', 'below', 'between', 'among',
                        'within', 'without', 'against', 'via', 'via', 'due', 'onto', 'per', 'each', 'any',
                        'some', 'many', 'few', 'all', 'most', 'no', 'yes', 'ok', 'okk', 'nope', 'nopes', 'nay',
                        'more', 'less', 'least', 'other', 'another', 'somehow', 'thus', 'therefore',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'therein', 'thereupon', 'therewith', 'thereto', 'wherefore', 'forthwith', 'hereby',
                        'herein', 'hereupon', 'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore',
                        'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore', 'therefrom', 'thereof',
                        'therein', 'thereon', 'thereto', 'whereby', 'thereafter', 'hereafter', 'whenever',
                        'wherever', 'until', 'since', 'whenever', 'wherever', 'until', 'since', 'whereas', 'whilst',
                        'whereas', 'whilst', 'beside', 'beyond', 'during', 'about', 'around', 'above', 'below', 'before',
                        'after', 'without', 'within', 'between', 'among', 'against', 'under', 'over', 'through',
                        'into', 'onto', 'upon', 'am', 'are', 'is', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
                        'had', 'having', 'do', 'does', 'did', 'doing', 'can', 'could', 'will', 'would', 'shall', 'should',
                        'may', 'might', 'must', 'ought', 'need', 'dare', 'used', 'use', 'using', 'uses', 'used', 'put',
                        'puts', 'putting', 'tell', 'tells', 'told', 'telling', 'ask', 'asks', 'asked', 'asking',
                        'make', 'makes', 'made', 'making', 'find', 'finds', 'found', 'finding', 'keep', 'keeps',
                        'kept', 'keeping', 'begin', 'begins', 'began', 'beginning', 'show', 'shows', 'showed',
                        'showing', 'say', 'says', 'said', 'saying', 'says', 'said', 'let', 'lets', 'letting', 'make',
                        'makes', 'made', 'making', 'put', 'puts', 'putting', 'seem', 'seems', 'seemed', 'seeming',
                        'need', 'needs', 'needed', 'needing', 'become', 'becomes', 'became', 'bec'])


# Merge the sets of stop words
stop_words = english_stop_words.union(patent_stop_words)

df_Abstract['cleaned_Abstract_without_Stopwprd'] = df_Abstract['cleaned_Abstract_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
df_Abstract.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                              cleaned_Abstract_text  \
# 0               123  a reality interactive responding system compri...
# 1               142  a webbased interface enables medical personnel...
# 2                81  a facility for predicting patient outcomes on ...
# 3               148  through a physician s portal a platform calcul...
# 4               110  infusion systems infusion devices and related ...
#
#                    cleaned_Abstract_without_Stopwprd
# 0  reality interactive responding system comprisi...
# 1  webbased interface enables medical personnel r...
# 2  facility predicting patient outcomes basis cli...
# 3  physician portal platform calculates efficacy ...
# 4  infusion systems infusion devices related pati...

# %%
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df_Abstract["Lemmatized-Abstract"] = df_Abstract["cleaned_Abstract_without_Stopwprd"].apply(lambda text: lemmatize_words(text))
df_Abstract.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                              cleaned_Abstract_text  \
# 0               123  a reality interactive responding system compri...
# 1               142  a webbased interface enables medical personnel...
# 2                81  a facility for predicting patient outcomes on ...
# 3               148  through a physician s portal a platform calcul...
# 4               110  infusion systems infusion devices and related ...
#
#                    cleaned_Abstract_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  webbased interface enables medical personnel r...
# 2  facility predicting patient outcomes basis cli...
# 3  physician portal platform calculates efficacy ...
# 4  infusion systems infusion devices related pati...
#
#                                  Lemmatized-Abstract
# 0  reality interactive responding system comprisi...
# 1  webbased interface enables medical personnel r...
# 2  facility predicting patient outcome basis clin...
# 3  physician portal platform calculates efficacy ...
# 4  infusion system infusion device related patien...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you already have a DataFrame df with 'cleaned_Abstract_text' and 'abstract' columns

# Calculate the length of each record in both columns
df_Abstract['Length (cleaned)'] = df_Abstract['Lemmatized-Abstract'].str.len()
df_Abstract['Length (original)'] = df_Abstract['abstract'].str.len()

# Set a custom Seaborn style for a more appealing plot
sns.set_style("whitegrid")

# Create a figure with subplots for better readability
fig, ax = plt.subplots(figsize=(12, 6))

# Create line plots for both text lengths
sns.lineplot(data=df_Abstract[['Length (cleaned)', 'Length (original)']], ax=ax, palette=["red", "green"])
ax.set_xlabel('Record Index', fontsize=12)
ax.set_ylabel('Text Length', fontsize=12)
ax.set_title('Comparison of Text Lengths', fontsize=16)

# Customize the legend
ax.legend(['Length (cleaned_Abstract_text)', 'Length (abstract)'], fontsize=10)

# Add a grid to the plot
sns.despine()
ax.grid(axis='y', linestyle='--', alpha=0.6)

# Display the plot
plt.tight_layout()
plt.show()

# %%
df_Abstract.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                              cleaned_Abstract_text  \
# 0               123  a reality interactive responding system compri...
# 1               142  a webbased interface enables medical personnel...
# 2                81  a facility for predicting patient outcomes on ...
# 3               148  through a physician s portal a platform calcul...
# 4               110  infusion systems infusion devices and related ...
#
#                    cleaned_Abstract_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  webbased interface enables medical personnel r...
# 2  facility predicting patient outcomes basis cli...
# 3  physician portal platform calculates efficacy ...
# 4  infusion systems infusion devices related pati...
#
#                                  Lemmatized-Abstract  Length (cleaned)  \
# 0  reality interactive responding system comprisi...               506
# 1  webbased interface enables medical personnel r...               601
# 2  facility predicting patient outcome basis clin...               434
# 3  physician portal platform calculates efficacy ...               748
# 4  infusion system infusion device related patien...               590
#
#    Length (original)
# 0                699
# 1                881
# 2                560
# 3               1051
# 4                737

# %%
first_record = df_Abstract['Lemmatized-Abstract'][1]
first_record
# Out:
# 'webbased interface enables medical personnel remotely monitor medical device monitoring system record operational data alarm medical device file network connection medical device monitoring system intermittent file contain contiguous stream data medical device file pause recording gap network connectivity system display current data well list alarm medical personnel wish view detail earlier time one alarm system calculates file medical device data recorded calculation account discontiguous nature data system time network connection broken calculate index file corresponds time userselected alarm'

# %%
x = len(df_Abstract['Lemmatized-Abstract'][1])
print(x)
# Out:
# 601

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\admin\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (4.33.2)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (0.15.2)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (0.17.1)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.3.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: sympy in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.3)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from nltk->sentence-transformers) (8.0.4)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
import torch
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sentence_transformers import SentenceTransformer


# Load the Sentence Transformers model
#sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
#sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)
sentence_model = SentenceTransformer("xlm-r-bert-base-nli-stsb-mean-tokens")



# Adjust UMAP hyperparameters
umap_model = UMAP(n_neighbors=3, 
                  n_components=3, 
                  min_dist=0.05, 
                  metric='cosine', 
                  random_state=100)  # Utilize all available CPU cores for UMAP preprocessing

# Adjust HDBSCAN hyperparameters
hdbscan_model = HDBSCAN( min_cluster_size=80,
                        min_samples=40, 
                        metric='euclidean', 
                        cluster_selection_method='eom', 
                        prediction_data=True)

# Adjust CountVectorizer hyperparameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3))


# c-TF-IDF
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Run Model
topic_model = BERTopic(umap_model=umap_model,
                       embedding_model=sentence_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       ctfidf_model=ctfidf_model,
                       verbose=True)

# Replace 'df['first_claim']' with your data source for the first_claim column
topics, probabilities = topic_model.fit_transform(df_Abstract['Lemmatized-Abstract'])
# Out:
# Batches:   0%|          | 0/979 [00:00<?, ?it/s]
# 2023-10-03 20:06:23,871 - BERTopic - Transformed documents to Embeddings
# 2023-10-03 20:06:47,908 - BERTopic - Reduced dimensionality
# 2023-10-03 20:06:49,656 - BERTopic - Clustered reduced embeddings

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document": df_Abstract['Lemmatized-Abstract'],
                          "ID": range(len(df_Abstract['Lemmatized-Abstract'])),
                          "Topic": topics})

documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence_c_nmpi = coherence_model.get_coherence()
print("c_npmi is: ",coherence_c_nmpi)
# Out:
# c_npmi is:  -0.037301606521504584

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['Lemmatized-Abstract'],
                          "ID": range(len(df_Abstract['Lemmatized-Abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_CV= coherence_model.get_coherence()
print("C_V is: ", coherence_CV)
# Out:
# C_V is:  0.45713186531563016

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['Lemmatized-Abstract'],
                          "ID": range(len(df_Abstract['Lemmatized-Abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence_u_mass= coherence_model.get_coherence()
print("u_mass is: ", coherence_u_mass)
# Out:
# u_mass is:  -0.6301416632334653

# %%
 topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   9669                          -1_system_device_user_one
# 1       0   7000         0_medical_patient_medical image_healthcare
# 2       1   1968                           1_user_first_data_second
# 3       2   1501            2_drug_medication_prescription_pharmacy
# 4       3   1492                     3_pressure_blood_heart_cardiac
# 5       4    877             4_wireless_mobile_communication_device
# 6       5    637                       5_food_nutritional_meal_diet
# 7       6    636                    6_image_image data_unit_imaging
# 8       7    541  7_health_health data_health care_health inform...
# 9       8    530              8_glucose_insulin_blood glucose_blood
# 10      9    523                           9_cancer_tumor_gene_cell
# 11     10    513             10_physiological_sensor_emotion_signal
# 12     11    484  11_surgical_surgical procedure_surgical instru...
# 13     12    432     12_invention_present invention_medical_present
# 14     13    395               13_exercise_workout_fitness_training
# 15     14    337  14_ultrasound_ultrasound image_ultrasound imag...
# 16     15    304                  15_dental_tooth_teeth_orthodontic
# 17     16    249                     16_key_secure_encrypted_record
# 18     17    229  17_physiological_sensor_physiological data_phy...
# 19     18    200  18_wireless_wireless communication_communicati...
# 20     19    185     19_temperature_thermal_body temperature_sensor
# 21     20    183        20_sleep_user sleep_sleep stage_sleep state
# 22     21    182   21_radiation_radiation therapy_dose_radiotherapy
# 23     22    180              22_cancer_laser_colorectal_pancreatic
# 24     23    179  23_biological_biological information_biologica...
# 25     24    174                  24_bone_implant_fracture_bone age
# 26     25    160  25_invention_invention provides_invention rela...
# 27     26    159    26_diabetes_glucose_diabetes management_insulin
# 28     27    149                  27_genetic_genome_gene_biological
# 29     28    145  28_nourishment_biological extraction_edible_fu...
# 30     29    143      29_animal_prostate_veterinary_prostate cancer
# 31     30    142                      30_brain_speech_dementia_text
# 32     31    130       31_measure set_alarm_implant_medical implant
# 33     32    130  32_electrode_electrosurgical_stimulation_elect...
# 34     33    126                       33_tissue_organ_image_vessel
# 35     34    122              34_hygiene_hand_hand hygiene_cleaning
# 36     35    112            35_light_radiation_radiation image_xray
# 37     36    108  36_pain_chronic pain_chronic_chronic pain patient
# 38     37     80            37_robot_massage_robotic_remote station
#
#                                        Representation  \
# 0   [system, device, user, one, method, data, info...
# 1   [medical, patient, medical image, healthcare, ...
# 2   [user, first, data, second, processor, one, in...
# 3   [drug, medication, prescription, pharmacy, pha...
# 4   [pressure, blood, heart, cardiac, flow, fluid,...
# 5   [wireless, mobile, communication, device, mobi...
# 6   [food, nutritional, meal, diet, nutrient, diet...
# 7   [image, image data, unit, imaging, object, dis...
# 8   [health, health data, health care, health info...
# 9   [glucose, insulin, blood glucose, blood, gluco...
# 10  [cancer, tumor, gene, cell, expression, sample...
# 11  [physiological, sensor, emotion, signal, stimu...
# 12  [surgical, surgical procedure, surgical instru...
# 13  [invention, present invention, medical, presen...
# 14  [exercise, workout, fitness, training, motion,...
# 15  [ultrasound, ultrasound image, ultrasound imag...
# 16  [dental, tooth, teeth, orthodontic, arch, dent...
# 17  [key, secure, encrypted, record, encryption, p...
# 18  [physiological, sensor, physiological data, ph...
# 19  [wireless, wireless communication, communicati...
# 20  [temperature, thermal, body temperature, senso...
# 21  [sleep, user sleep, sleep stage, sleep state, ...
# 22  [radiation, radiation therapy, dose, radiother...
# 23  [cancer, laser, colorectal, pancreatic, colore...
# 24  [biological, biological information, biologica...
# 25  [bone, implant, fracture, bone age, joint, den...
# 26  [invention, invention provides, invention rela...
# 27  [diabetes, glucose, diabetes management, insul...
# 28  [genetic, genome, gene, biological, sequence, ...
# 29  [nourishment, biological extraction, edible, f...
# 30  [animal, prostate, veterinary, prostate cancer...
# 31  [brain, speech, dementia, text, brain disease,...
# 32  [measure set, alarm, implant, medical implant,...
# 33  [electrode, electrosurgical, stimulation, elec...
# 34  [tissue, organ, image, vessel, region tissue, ...
# 35  [hygiene, hand, hand hygiene, cleaning, dispen...
# 36  [light, radiation, radiation image, xray, opti...
# 37  [pain, chronic pain, chronic, chronic pain pat...
# 38  [robot, massage, robotic, remote station, ment...
#
#                                   Representative_Docs
# 0   [one implementation apparatus estimate body co...
# 1   [computerimplemented method system managing pa...
# 2   [computer system adaptive parsing processing t...
# 3   [disclosed system method processing releasing ...
# 4   [embodiment analyte detection system includes ...
# 5   [method device provide wireless communication ...
# 6   [novel system methodology dietary medical trea...
# 7   [information processing system comprises image...
# 8   [userspecific medical genetic fitness environm...
# 9   [invention discloses method calculating insuli...
# 10  [disclosed method monitoring early treatment r...
# 11  [method system technique providing neurofeedba...
# 12  [system method automatically populating postop...
# 13  [method according one aspect present invention...
# 14  [exercise feedback system receives exercise da...
# 15  [one embodiment directed system generate ortho...
# 16  [present invention relates computer implemente...
# 17  [exemplary embodiment include intelligent secu...
# 18  [apparatus method predict upcoming stage carot...
# 19  [apparatus system method provided measuring an...
# 20  [system creating electronic health journal com...
# 21  [sleep sensing system comprising sensor obtain...
# 22  [present invention directed data processing me...
# 23  [evaluating method includes evaluating step ev...
# 24  [method system providing aggregating bioelectr...
# 25  [invention relates real time radiation treatme...
# 26  [system method medium laboratory benefit servi...
# 27  [method displaying medical data particularly d...
# 28  [method system genetic attribute analysis pres...
# 29  [embodiment system method characterizing mouth...
# 30  [system method computerreadable medium disclos...
# 31  [method diagnosing autism andor autism spectru...
# 32  [system providing feedback individual patient ...
# 33  [monitoring apparatus includes housing configu...
# 34  [automatic data collection system track medica...
# 35  [system provided providing automated washing v...
# 36  [medical camera includes camera head first fir...
# 37  [medical resource chronic pain patient forecas...
# 38  [method system controlling movement proxy robo...

# %%
#adding topics and probs for eachdoc in dataset
df_Abstract['topics'] = topics
df_Abstract['prob'] = probabilities
df_Abstract_topic=df_Abstract[["publication_number","title","abstract", "Lemmatized-Abstract","sub_classes","sub_class","topics","prob"]]
df_Abstract_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                                 abstract  \
# 0      A reality interactive responding system, compr...
# 1      A web-based interface enables medical personne...
# 2      A facility for predicting patient outcomes on ...
# 3      Through a physician&#39;s portal, a platform c...
# 4      Infusion systems, infusion devices, and relate...
# ...                                                  ...
# 31301  A user authentication system performs user rec...
# 31302  A diagnosis support apparatus for diagnosis of...
# 31303  A patient appointment schedule is generated fo...
# 31304  The present invention relates to a method for ...
# 31305  A method including a healthcare server of a he...
#
#                                      Lemmatized-Abstract  \
# 0      reality interactive responding system comprisi...
# 1      webbased interface enables medical personnel r...
# 2      facility predicting patient outcome basis clin...
# 3      physician portal platform calculates efficacy ...
# 4      infusion system infusion device related patien...
# ...                                                  ...
# 31301  user authentication system performs user recog...
# 31302  diagnosis support apparatus diagnosis patient ...
# 31303  patient appointment schedule generated open ac...
# 31304  present invention relates method acquiring pos...
# 31305  method including healthcare server healthcare ...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']       1  1.000000
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']       0  0.907107
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']       0  1.000000
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']       4  0.571649
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      -1  0.000000
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']       6  0.642399
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']       0  1.000000
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']       0  1.000000
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']      11  0.812209
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']       0  0.910783
#
# [31306 rows x 8 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_Abstract_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_Abstract_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_Abstract_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %%
test1 = df_Abstract_test.loc[0, 'abstract']
test1
# Out:
# 'A physiological sensor has light emitting sources, each activated by addressing at least one row and at least one column of an electrical grid. The light emitting sources are capable of transmitting light of multiple wavelengths and a detector is responsive to the transmitted light after attenuation by body tissue.'

# %%
import numpy as np 

# Find topics
num_of_topics = 5
similar_topics, similarity = topic_model.find_topics(test1, top_n=num_of_topics); 

# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')

for idx, topic_idx in enumerate(similar_topics):
    topic = topic_model.get_topic(topic_idx)
    keywords = ' '.join(str(keyword) for keyword in topic[0])
    print(f"Topic {idx+1}: {keywords}")
# Out:
# The top 5 similar topics are [10, 32, 17, 19, 23], and the similarities are [0.75 0.75 0.74 0.73 0.71]
# Topic 1: physiological 0.26583059497700745
# Topic 2: electrode 0.3226637829795911
# Topic 3: physiological 0.27769657363829137
# Topic 4: temperature 0.46054728682099305
# Topic 5: biological 0.5024680903154035

# %%
# # Define the range of topic IDs you want to retrieve documents for
# selected_topic_range =[43, 5, 49, 42, 16]  # Replace with your desired range of topic IDs

# # Create an empty DataFrame to store the top 10 documents
# top_10_documents_test1 = pd.DataFrame()

# # Iterate through the selected topic IDs
# for selected_topic_id in selected_topic_range:
#     # Filter the dataset based on the current topic ID
#     filtered_df = df_Abstract_topic[df_Abstract_topic['topics'] == selected_topic_id]
    
#     # Sort the filtered dataset by similarity scores in descending order
#     sorted_df = filtered_df.sort_values(by='prob', ascending=False)
    
#     # Retrieve the top 10 documents for the current topic
#     top_10_for_topic = sorted_df.head(10)
    
#     # Append the top 10 documents for the current topic to the result DataFrame
#     top_10_documents_test1 = top_10_documents_test1.append(top_10_for_topic)

# # Display the top 10 documents for all selected topics
# top_10_documents_test1

# %%
# num_records = top_10_documents_test1.shape[0]
# num_records

# %%
# # Define a custom function to format the text
# def format_text(text):
#     # Remove brackets and single quotes, split by comma and strip whitespace
#     cleaned_text = ''.join(text).replace('[', '').replace(']', '').replace("'", '').split(',')
#     # Filter out empty strings and strip whitespace
#     cleaned_text = [item.strip() for item in cleaned_text if item.strip()]
#     # Join the cleaned text with commas and spaces
#     formatted_text = ', '.join(cleaned_text)
#     return formatted_text

# # Apply the custom function to the 'sub_classes' and 'sub_class' columns
# top_10_documents_test1['combined_class'] = top_10_documents_test1.apply(lambda x: format_text(x['sub_classes']) + ', ' + format_text(x['sub_class']), axis=1)

# # Display the resulting DataFrame with the 'combined' column
# print(top_10_documents_test1[['sub_classes', 'sub_class', 'combined_class']])

# %%
# # Get the class_codes from the first record of df_Abstract_test and convert it to a string, then split it by comma
# class_codes_value = df_Abstract_test['class_codes'].iloc[0]
# if pd.notna(class_codes_value):
#     target_sub_classes = str(class_codes_value).split(',')
# else:
#     target_sub_classes = []

# # Define a function to check for matching classes
# def has_matching_class(row):
#     # Extract the first 4 letters from each code in class_codes and combined_class
#     target_codes = [code[:4] for code in target_sub_classes]
#     combined_codes = [code[:4] for code in str(row['combined_class']).split(',')]

#     # Check if there are any common codes
#     return any(code in combined_codes for code in target_codes)

# # Apply the function to create a boolean mask
# top_10_documents_test1['has_matching_class'] = top_10_documents_test1.apply(has_matching_class, axis=1)

# top_10_documents_test1

# %%
# top_10_documents_test1.shape[0]

# %% [markdown]
# # list of 100 queries

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Assuming you have a list of 100 queries in test
for query in df_Abstract_test['abstract'][:num_samples_to_predict]:
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))

# Now, the 'results' list contains the similar topics and similarities for each query
# You can access the results for a specific query like this:
for i, (similar_topics, similarity) in enumerate(results):
    print(f"Query {i + 1}: Similar Topics {similar_topics}, Similarity {similarity}")
# Out:
# Query 1: Similar Topics [10, 32, 17, 19, 23], Similarity [0.75190246, 0.7487134, 0.7351851, 0.7337846, 0.7095729]
# Query 2: Similar Topics [35, 32, 14, 10, 6], Similarity [0.7299535, 0.614368, 0.59822834, 0.59126884, 0.58899605]
# Query 3: Similar Topics [11, 25, 12, 36, 31], Similarity [0.7479586, 0.6910677, 0.658131, 0.65803987, 0.6561134]
# Query 4: Similar Topics [17, 33, 3, 0, 22], Similarity [0.7076813, 0.6923408, 0.6894603, 0.67418015, 0.6617454]
# Query 5: Similar Topics [31, -1, 17, 4, 0], Similarity [0.7363275, 0.7272313, 0.71408236, 0.70218253, 0.6991879]
# Query 6: Similar Topics [10, 32, 18, 19, -1], Similarity [0.7795644, 0.77140635, 0.7694025, 0.73807657, 0.7281778]
# Query 7: Similar Topics [13, 1, 10, 28, 37], Similarity [0.7828999, 0.70860016, 0.7071868, 0.695331, 0.6751277]
# Query 8: Similar Topics [13, 37, 10, 36, 32], Similarity [0.8177393, 0.69908965, 0.6782259, 0.6559068, 0.6388289]
# Query 9: Similar Topics [11, 15, 16, 31, 2], Similarity [0.62396127, 0.5533582, 0.5483023, 0.5403067, 0.53922725]
# Query 10: Similar Topics [11, 33, 36, 22, 30], Similarity [0.7629359, 0.7529799, 0.75070137, 0.7503792, 0.73965144]
# Query 11: Similar Topics [9, 22, 25, 27, 33], Similarity [0.7882917, 0.71926224, 0.69459796, 0.6856786, 0.6450305]
# Query 12: Similar Topics [10, 13, 6, 23, 20], Similarity [0.68758595, 0.6794575, 0.6091926, 0.58224666, 0.5816248]
# Query 13: Similar Topics [32, 13, 17, 19, 3], Similarity [0.6839628, 0.66945136, 0.66539955, 0.65117407, 0.64765584]
# Query 14: Similar Topics [20, 34, 10, 36, -1], Similarity [0.7963594, 0.5591221, 0.54619753, 0.54096854, 0.532299]
# Query 15: Similar Topics [1, 10, 37, -1, 31], Similarity [0.7591398, 0.7516835, 0.7240572, 0.719868, 0.70437586]
# Query 16: Similar Topics [26, 28, 8, -1, 17], Similarity [0.8197535, 0.73922104, 0.7281667, 0.69903105, 0.69523877]
# Query 17: Similar Topics [8, 26, 3, 28, 10], Similarity [0.85225445, 0.7749699, 0.76845527, 0.76485103, 0.7648387]
# Query 18: Similar Topics [7, 17, 2, 31, 0], Similarity [0.78537536, 0.78322375, 0.7742542, 0.75293875, 0.7367487]
# Query 19: Similar Topics [10, 32, 30, 34, 1], Similarity [0.6259366, 0.599665, 0.57307124, 0.561563, 0.55891156]
# Query 20: Similar Topics [25, 12, 31, 17, 0], Similarity [0.8494952, 0.83780265, 0.8372881, 0.8211832, 0.8078203]
# Query 21: Similar Topics [9, 27, 22, 25, 33], Similarity [0.7407445, 0.7396785, 0.72748464, 0.72123426, 0.64778435]
# Query 22: Similar Topics [15, 24, 36, 11, 3], Similarity [0.71154904, 0.65674603, 0.607772, 0.58281225, 0.5798869]
# Query 23: Similar Topics [7, 17, 31, 0, 4], Similarity [0.88520557, 0.784577, 0.77062964, 0.7647284, 0.754817]
# Query 24: Similar Topics [3, 17, 10, 33, 21], Similarity [0.76157963, 0.74022734, 0.70249295, 0.695487, 0.68962073]
# Query 25: Similar Topics [36, 17, 31, -1, 0], Similarity [0.8174289, 0.79427075, 0.7738854, 0.7474495, 0.74554706]
# Query 26: Similar Topics [15, 24, 11, 36, 22], Similarity [0.8238323, 0.58595777, 0.56261516, 0.528301, 0.52590346]
# Query 27: Similar Topics [11, 17, 22, 31, 34], Similarity [0.725214, 0.6958682, 0.6768298, 0.67390895, 0.66986597]
# Query 28: Similar Topics [31, 4, 17, 16, -1], Similarity [0.76812077, 0.76566494, 0.75972176, 0.7440052, 0.7427883]
# Query 29: Similar Topics [27, 23, 25, 28, 9], Similarity [0.6708319, 0.6030687, 0.591346, 0.58043456, 0.5791079]
# Query 30: Similar Topics [31, -1, 0, 4, 36], Similarity [0.7386931, 0.73298717, 0.72154135, 0.7144489, 0.71182024]
# Query 31: Similar Topics [0, 11, 31, 12, 16], Similarity [0.78765106, 0.7550409, 0.73717296, 0.73320204, 0.7308552]
# Query 32: Similar Topics [3, 32, 8, 19, 28], Similarity [0.6685344, 0.6418662, 0.5924823, 0.58127767, 0.56077385]
# Query 33: Similar Topics [11, 37, 32, 24, 14], Similarity [0.6277089, 0.611307, 0.60980535, 0.6059184, 0.59910023]
# Query 34: Similar Topics [12, 0, 31, 16, 11], Similarity [0.8373805, 0.82643026, 0.8184128, 0.79776126, 0.79037786]
# Query 35: Similar Topics [18, 4, 10, -1, 32], Similarity [0.7394228, 0.6975813, 0.68679154, 0.67452234, 0.66158956]
# Query 36: Similar Topics [16, 0, 4, 12, 31], Similarity [0.7161371, 0.68656397, 0.6841924, 0.6644852, 0.6607748]
# Query 37: Similar Topics [8, 26, 2, 17, 3], Similarity [0.81540316, 0.7295137, 0.69379926, 0.6861968, 0.6705591]
# Query 38: Similar Topics [8, 26, 28, 7, 17], Similarity [0.82822526, 0.818657, 0.7508881, 0.74709105, 0.7467601]
# Query 39: Similar Topics [19, 17, 3, 28, 23], Similarity [0.74023324, 0.7100494, 0.70590496, 0.69751143, 0.69011354]
# Query 40: Similar Topics [19, 32, 21, 3, 34], Similarity [0.80510485, 0.7742907, 0.737602, 0.7329799, 0.72545695]
# Query 41: Similar Topics [-1, 31, 10, 17, 4], Similarity [0.75589716, 0.74469036, 0.74072516, 0.72484, 0.72331977]
# Query 42: Similar Topics [15, 24, 11, 37, 36], Similarity [0.7948892, 0.57918376, 0.5494146, 0.51048064, 0.50737566]
# Query 43: Similar Topics [18, 4, 37, 1, 28], Similarity [0.68201715, 0.6657635, 0.6553865, 0.6523729, 0.6446192]
# Query 44: Similar Topics [3, 17, 19, 7, 34], Similarity [0.73481447, 0.73321146, 0.6913245, 0.6886604, 0.68605757]
# Query 45: Similar Topics [26, 4, 16, 0, 8], Similarity [0.81738436, 0.71086097, 0.67679155, 0.67479765, 0.6524789]
# Query 46: Similar Topics [17, 31, 0, 11, 36], Similarity [0.8712871, 0.81025815, 0.8007176, 0.7803168, 0.77256477]
# Query 47: Similar Topics [10, 32, 34, 19, -1], Similarity [0.7160895, 0.71321225, 0.6968823, 0.69221354, 0.6712801]
# Query 48: Similar Topics [15, 24, 34, 11, 36], Similarity [0.7828477, 0.52618057, 0.50689995, 0.49038088, 0.4862001]
# Query 49: Similar Topics [15, 24, 11, 36, 25], Similarity [0.8671792, 0.67484534, 0.67281455, 0.6292309, 0.61278605]
# Query 50: Similar Topics [16, 27, 1, -1, 31], Similarity [0.7088667, 0.6290155, 0.6286408, 0.62753475, 0.62078464]
# Query 51: Similar Topics [37, 1, -1, 31, 0], Similarity [0.7022406, 0.6814339, 0.6809422, 0.67092395, 0.6666795]
# Query 52: Similar Topics [23, 27, 9, 29, 28], Similarity [0.79734206, 0.7532078, 0.7333519, 0.7166136, 0.71623623]
# Query 53: Similar Topics [32, 23, 10, 28, 19], Similarity [0.7809341, 0.76665896, 0.73283017, 0.72669196, 0.71364504]
# Query 54: Similar Topics [3, 17, 33, 19, 32], Similarity [0.843608, 0.7610346, 0.743165, 0.73602605, 0.7171966]
# Query 55: Similar Topics [11, 37, 31, 0, 24], Similarity [0.8314001, 0.7494765, 0.67745346, 0.6618282, 0.66113]
# Query 56: Similar Topics [30, 10, 1, 6, 20], Similarity [0.67299676, 0.6249914, 0.6066437, 0.5678198, 0.56062067]
# Query 57: Similar Topics [15, 24, 14, 25, 29], Similarity [0.74067295, 0.57352567, 0.4870552, 0.4852682, 0.48175758]
# Query 58: Similar Topics [4, 31, 17, 0, 7], Similarity [0.7958087, 0.75742155, 0.7510184, 0.73992133, 0.7128172]
# Query 59: Similar Topics [34, 19, 10, 3, 32], Similarity [0.76272035, 0.74237186, 0.7235664, 0.7054734, 0.69249874]
# Query 60: Similar Topics [11, 24, 36, 17, 31], Similarity [0.7944711, 0.7755394, 0.7695091, 0.7527425, 0.72240114]
# Query 61: Similar Topics [13, 5, 10, 19, 8], Similarity [0.62271166, 0.55790234, 0.498236, 0.48848134, 0.47332442]
# Query 62: Similar Topics [7, 17, 13, 34, -1], Similarity [0.7903312, 0.74860126, 0.7269429, 0.72224236, 0.7134595]
# Query 63: Similar Topics [32, 18, 10, 30, 35], Similarity [0.6113964, 0.55982506, 0.55295616, 0.5454335, 0.5165207]
# Query 64: Similar Topics [32, 10, -1, 28, 17], Similarity [0.74685794, 0.73026097, 0.71186244, 0.7000767, 0.69983816]
# Query 65: Similar Topics [18, 1, 4, 32, 28], Similarity [0.55440795, 0.48560014, 0.46342322, 0.461825, 0.45119667]
# Query 66: Similar Topics [18, 4, 10, 35, 6], Similarity [0.67269707, 0.5580663, 0.5554782, 0.5507196, 0.54330546]
# Query 67: Similar Topics [7, 12, 31, 25, -1], Similarity [0.71224654, 0.706215, 0.7016511, 0.6917536, 0.68190163]
# Query 68: Similar Topics [13, 10, 32, 36, 19], Similarity [0.77561164, 0.726552, 0.68442523, 0.6533605, 0.6398486]
# Query 69: Similar Topics [18, 32, 10, 19, 4], Similarity [0.78935015, 0.74608725, 0.71072656, 0.6666738, 0.6640502]
# Query 70: Similar Topics [4, 16, 31, 0, 17], Similarity [0.76517725, 0.7606551, 0.71613646, 0.7136481, 0.70404077]
# Query 71: Similar Topics [3, 17, -1, 31, 10], Similarity [0.7917286, 0.7778779, 0.7698945, 0.7574972, 0.7430831]
# Query 72: Similar Topics [13, 10, 34, 5, 28], Similarity [0.6495883, 0.5984143, 0.59186906, 0.58966017, 0.58531547]
# Query 73: Similar Topics [31, 17, 7, 36, 2], Similarity [0.667066, 0.6350887, 0.6274227, 0.6247836, 0.6183463]
# Query 74: Similar Topics [12, 0, 11, 31, 17], Similarity [0.86400086, 0.85376906, 0.8444047, 0.84194005, 0.8223294]
# Query 75: Similar Topics [36, 17, 31, 0, -1], Similarity [0.8000673, 0.79972, 0.7912271, 0.7749443, 0.7745272]
# Query 76: Similar Topics [25, 12, 22, 29, 23], Similarity [0.7547213, 0.73349, 0.70195323, 0.6881678, 0.6857512]
# Query 77: Similar Topics [21, 3, 17, 32, -1], Similarity [0.78409505, 0.7835301, 0.76963997, 0.7652621, 0.7550832]
# Query 78: Similar Topics [32, 28, 3, -1, 10], Similarity [0.72317004, 0.69775355, 0.68933237, 0.68755364, 0.683698]
# Query 79: Similar Topics [34, 3, 19, 8, 10], Similarity [0.58009094, 0.55421007, 0.54522824, 0.5238025, 0.51434463]
# Query 80: Similar Topics [37, 11, 24, 28, 17], Similarity [0.5914886, 0.57681924, 0.56048465, 0.5496253, 0.54243165]
# Query 81: Similar Topics [17, 31, 0, 36, 3], Similarity [0.6942035, 0.67042637, 0.64221466, 0.63785005, 0.6256267]
# Query 82: Similar Topics [31, 17, 11, 0, 36], Similarity [0.7042519, 0.6849042, 0.68264556, 0.6730422, 0.6302713]
# Query 83: Similar Topics [36, 11, 33, 31, 0], Similarity [0.7290309, 0.72306824, 0.7067922, 0.7019185, 0.69859743]
# Query 84: Similar Topics [4, 16, 31, 0, 7], Similarity [0.72855556, 0.6666713, 0.6362798, 0.6326748, 0.6116214]
# Query 85: Similar Topics [32, 10, 19, 3, 28], Similarity [0.8105091, 0.7069508, 0.65653, 0.63704985, 0.6269327]
# Query 86: Similar Topics [10, 13, 32, 37, 1], Similarity [0.7921412, 0.77626324, 0.7446104, 0.7184518, 0.7135418]
# Query 87: Similar Topics [27, 9, 23, 24, 28], Similarity [0.69174486, 0.60757375, 0.6052147, 0.6008059, 0.56794167]
# Query 88: Similar Topics [16, 4, 0, 31, 12], Similarity [0.81984735, 0.71092665, 0.69246125, 0.67924577, 0.6772753]
# Query 89: Similar Topics [18, 4, 2, 25, 32], Similarity [0.7182087, 0.66857964, 0.534639, 0.53309596, 0.52859527]
# Query 90: Similar Topics [4, 0, 17, 16, -1], Similarity [0.8257948, 0.7916034, 0.7840719, 0.7839552, 0.77003753]
# Query 91: Similar Topics [11, 36, 24, 0, 17], Similarity [0.84923947, 0.8121505, 0.78490597, 0.76493186, 0.758446]
# Query 92: Similar Topics [36, 25, -1, 30, 22], Similarity [0.7566389, 0.7410482, 0.73395336, 0.7279319, 0.7255217]
# Query 93: Similar Topics [13, 31, -1, 36, 10], Similarity [0.7378192, 0.73383373, 0.73062783, 0.7263893, 0.71562946]
# Query 94: Similar Topics [10, 19, 32, 8, 17], Similarity [0.71254784, 0.68464017, 0.6657927, 0.65755045, 0.6567344]
# Query 95: Similar Topics [3, 17, 32, 10, 33], Similarity [0.85769653, 0.7921103, 0.79023826, 0.7897736, 0.7844275]
# Query 96: Similar Topics [16, 4, 0, -1, 31], Similarity [0.77383214, 0.76906073, 0.7676605, 0.72785866, 0.7265898]
# Query 97: Similar Topics [16, 0, -1, 31, 12], Similarity [0.77028835, 0.7406081, 0.7255821, 0.71135557, 0.70438945]
# Query 98: Similar Topics [2, -1, 3, 17, 31], Similarity [0.7353784, 0.72461313, 0.7185105, 0.7132062, 0.71039724]
# Query 99: Similar Topics [17, 36, 28, 31, -1], Similarity [0.8067336, 0.7994504, 0.77301997, 0.7590828, 0.75886524]
# Query 100: Similar Topics [0, 16, 31, 11, 2], Similarity [0.75804794, 0.7338047, 0.7263957, 0.7019777, 0.6721066]

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Create an empty DataFrame to store the results
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Assuming you have a list of 100 queries in 'df_Abstract_test'
for i, (query, publication_number, abstract, class_codes) in enumerate(zip(df_Abstract_test['abstract'][:num_samples_to_predict], 
                                                    df_Abstract_test['publication_numbers'][:num_samples_to_predict],
                                                    df_Abstract_test['abstract'][:num_samples_to_predict],
                                                    df_Abstract_test['class_codes'][:num_samples_to_predict])):
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))
    
    # Store the results in the DataFrame
    result_df_q = result_df_q.append({
        'query_abstract': query,
        'query_predicted_topics': similar_topics,
        'query_publication_numbers': publication_number,
        'query_class_codes': class_codes
    }, ignore_index=True)
    
result_df_q
# Out:
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 95           US20230017310A1
# 96           US20230091925A1
# 97           US20230010638A1
# 98           US20230009812A1
# 99           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 95  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 96  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 97  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 98  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 99  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                        query_abstract query_predicted_topics
# 0   A physiological sensor has light emitting sour...   [10, 32, 17, 19, 23]
# 1   A wearable monitoring device includes a band c...    [35, 32, 14, 10, 6]
# 2   A number of improvements are provided relating...   [11, 25, 12, 36, 31]
# 3   Embodiments include a system for determining c...     [17, 33, 3, 0, 22]
# 4   A community based response system for providin...     [31, -1, 17, 4, 0]
# ..                                                ...                    ...
# 95  Features are disclosed for remote storage of m...     [16, 4, 0, -1, 31]
# 96  Some of the embodiments herein provide a seaml...    [16, 0, -1, 31, 12]
# 97  A method and system is disclosed for operating...     [2, -1, 3, 17, 31]
# 98  A patient monitor including a physiological me...   [17, 36, 28, 31, -1]
# 99  A system to manage records in a healthcare pra...     [0, 16, 31, 11, 2]
#
# [100 rows x 4 columns]

# %%
# Check if the 'query_publication_numbers' field is unique
is_unique = result_df_q['query_publication_numbers'].nunique() == len(result_df_q)

if is_unique:
    print("The 'query_publication_numbers' field is unique.")
else:
    print("The 'query_publication_numbers' field is not unique.")
# Out:
# The 'query_publication_numbers' field is unique.

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'abstract', 'Lemmatized-Abstract', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_abstract']
    predicted_topics = row['query_predicted_topics']
    
    for topic_id in predicted_topics:
        # Filter 'df_Abstract_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_Abstract_topic[df_Abstract_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'result_df' DataFrame
        for _, doc_row in topic_documents.iterrows():
            result_df = result_df.append({
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_abstract': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'abstract': doc_row['abstract'],
                'Lemmatized-Abstract': doc_row['Lemmatized-Abstract'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }, ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 1        US2017339255A1              Dynamic feedback for wearable devices
# 2        US2014316287A1  System and method for displaying fluid respons...
# 3        US2013217350A1  System and method for communicating presence s...
# 4        US2013018592A1  Systems and Methods for Inter-Population Neuro...
# ...                 ...                                                ...
# 4995     US2009065522A1  Unit dose compliance monitoring and reporting ...
# 4996     US2009063195A1  Medical service support system, medical servic...
# 4997     US2009051560A1                   Drug dispenser/container display
# 4998     US2009048868A1        Medication Related Task Notification System
# 4999     US2009048863A1  Method and apparatus for medication prescripti...
#
#                                                abstract  \
# 0     A tissue stimulation system that generates an ...
# 1     Various embodiments disclosed herein relate to...
# 2     Embodiments provide systems and methods for di...
# 3     A method and system are provided for computing...
# 4     Systems and methods for inter-population asses...
# ...                                                 ...
# 4995  A unit dose medication compliance monitoring a...
# 4996  In the embodiment of the present invention, wh...
# 4997  A display for use on medical dispensing equipm...
# 4998  A task management system for informing a clini...
# 4999  A method and apparatus of providing a pharmace...
#
#                                     Lemmatized-Abstract  \
# 0     tissue stimulation system generates electrical...
# 1     various embodiment disclosed relate wearable d...
# 2     embodiment provide system method displaying fl...
# 3     method system provided computing physiological...
# 4     system method interpopulation assessment neuro...
# ...                                                 ...
# 4995  unit dose medication compliance monitoring rep...
# 4996  embodiment present invention identification in...
# 4997  display medical dispensing equipment resulting...
# 4998  task management system informing clinician med...
# 4999  method apparatus providing pharmaceutical cons...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 1      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 2     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 4      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06F17/00', 'G16H15/00']  ['G06F', 'G16H']      2   1.0
# 4996   ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']      2   1.0
# 4997    ['G09G3/34', 'G16H20/17']  ['G09G', 'G16H']      2   1.0
# 4998   ['G16H20/10', 'G16Z99/00']  ['G16H', 'G16Z']      2   1.0
# 4999   ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']      2   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract query_predicted_topics
# 0     A physiological sensor has light emitting sour...                   [10]
# 1     A physiological sensor has light emitting sour...                   [10]
# 2     A physiological sensor has light emitting sour...                   [10]
# 3     A physiological sensor has light emitting sour...                   [10]
# 4     A physiological sensor has light emitting sour...                   [10]
# ...                                                 ...                    ...
# 4995  A system to manage records in a healthcare pra...                    [2]
# 4996  A system to manage records in a healthcare pra...                    [2]
# 4997  A system to manage records in a healthcare pra...                    [2]
# 4998  A system to manage records in a healthcare pra...                    [2]
# 4999  A system to manage records in a healthcare pra...                    [2]
#
# [5000 rows x 12 columns]

# %%
result_df['query_class_codes'][0]
# Out:
# 'A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/7221,A61B5/14532,G16H40/00,A61B5/14546,G16H40/60,A61B5/68,A61B2562/08,H,A61B1/00,A61B2562/221,A61B5/7475,A61B2562/18,A61B5/746,A61B5/7405,H05K,G16H40/67,A61B,Y10,A61B5/6813,Y,A61B2562/185,G16H10/40,A61B5/6826,A61B5/02,A61B5/0002,A61B5/1455,A61B5/6832,A,A61B5/7235,A61B5/6801,A61B5/7278,G16H,A61B5/026,A61B5/742,A61B2562/22,A61B5/024,G16,A61B5/02416,A61B5/683,A61B5/0015,A61B5/6825,Y10S,A61B5/1495,A61B5/72,A61B5/0261,A61B2562/085,A61B2562/222,A61B5/7275,A61B5/00,A61B5/145,A61B5/74,G16H10/00,H05K999/99,A61B5/7246,Y10S439/909,A61B5/14552,A61B5/6838,A61B5/6815,A61B5/7271,H05K999/00,A61B5/02427,A61B5/0205,Y10S439/00,A61B5/0022,A61B5/6814,A61B2562/00,H05'

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 1        US2017339255A1              Dynamic feedback for wearable devices
# 2        US2014316287A1  System and method for displaying fluid respons...
# 3        US2013217350A1  System and method for communicating presence s...
# 4        US2013018592A1  Systems and Methods for Inter-Population Neuro...
# ...                 ...                                                ...
# 4995     US2009065522A1  Unit dose compliance monitoring and reporting ...
# 4996     US2009063195A1  Medical service support system, medical servic...
# 4997     US2009051560A1                   Drug dispenser/container display
# 4998     US2009048868A1        Medication Related Task Notification System
# 4999     US2009048863A1  Method and apparatus for medication prescripti...
#
#                                                abstract  \
# 0     A tissue stimulation system that generates an ...
# 1     Various embodiments disclosed herein relate to...
# 2     Embodiments provide systems and methods for di...
# 3     A method and system are provided for computing...
# 4     Systems and methods for inter-population asses...
# ...                                                 ...
# 4995  A unit dose medication compliance monitoring a...
# 4996  In the embodiment of the present invention, wh...
# 4997  A display for use on medical dispensing equipm...
# 4998  A task management system for informing a clini...
# 4999  A method and apparatus of providing a pharmace...
#
#                                     Lemmatized-Abstract  \
# 0     tissue stimulation system generates electrical...
# 1     various embodiment disclosed relate wearable d...
# 2     embodiment provide system method displaying fl...
# 3     method system provided computing physiological...
# 4     system method interpopulation assessment neuro...
# ...                                                 ...
# 4995  unit dose medication compliance monitoring rep...
# 4996  embodiment present invention identification in...
# 4997  display medical dispensing equipment resulting...
# 4998  task management system informing clinician med...
# 4999  method apparatus providing pharmaceutical cons...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 1      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 2     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 4      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06F17/00', 'G16H15/00']  ['G06F', 'G16H']      2   1.0
# 4996   ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']      2   1.0
# 4997    ['G09G3/34', 'G16H20/17']  ['G09G', 'G16H']      2   1.0
# 4998   ['G16H20/10', 'G16Z99/00']  ['G16H', 'G16Z']      2   1.0
# 4999   ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']      2   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [10]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [10]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [10]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [10]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [10]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 4995                    [2]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996                    [2]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997                    [2]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998                    [2]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999                    [2]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [5000 rows x 13 columns]

# %%
# Create a new column to store the common code
import re
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Custom extraction of values from sub_classes_str
    sub_classes = re.findall(r"'([^']*)'", sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 1        US2017339255A1              Dynamic feedback for wearable devices
# 2        US2014316287A1  System and method for displaying fluid respons...
# 3        US2013217350A1  System and method for communicating presence s...
# 4        US2013018592A1  Systems and Methods for Inter-Population Neuro...
# ...                 ...                                                ...
# 4995     US2009065522A1  Unit dose compliance monitoring and reporting ...
# 4996     US2009063195A1  Medical service support system, medical servic...
# 4997     US2009051560A1                   Drug dispenser/container display
# 4998     US2009048868A1        Medication Related Task Notification System
# 4999     US2009048863A1  Method and apparatus for medication prescripti...
#
#                                                abstract  \
# 0     A tissue stimulation system that generates an ...
# 1     Various embodiments disclosed herein relate to...
# 2     Embodiments provide systems and methods for di...
# 3     A method and system are provided for computing...
# 4     Systems and methods for inter-population asses...
# ...                                                 ...
# 4995  A unit dose medication compliance monitoring a...
# 4996  In the embodiment of the present invention, wh...
# 4997  A display for use on medical dispensing equipm...
# 4998  A task management system for informing a clini...
# 4999  A method and apparatus of providing a pharmace...
#
#                                     Lemmatized-Abstract  \
# 0     tissue stimulation system generates electrical...
# 1     various embodiment disclosed relate wearable d...
# 2     embodiment provide system method displaying fl...
# 3     method system provided computing physiological...
# 4     system method interpopulation assessment neuro...
# ...                                                 ...
# 4995  unit dose medication compliance monitoring rep...
# 4996  embodiment present invention identification in...
# 4997  display medical dispensing equipment resulting...
# 4998  task management system informing clinician med...
# 4999  method apparatus providing pharmaceutical cons...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 1      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 2     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 4      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06F17/00', 'G16H15/00']  ['G06F', 'G16H']      2   1.0
# 4996   ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']      2   1.0
# 4997    ['G09G3/34', 'G16H20/17']  ['G09G', 'G16H']      2   1.0
# 4998   ['G16H20/10', 'G16Z99/00']  ['G16H', 'G16Z']      2   1.0
# 4999   ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']      2   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [10]
# 1                      [10]
# 2                      [10]
# 3                      [10]
# 4                      [10]
# ...                     ...
# 4995                    [2]
# 4996                    [2]
# 4997                    [2]
# 4998                    [2]
# 4999                    [2]
#
#                                        query_codes_G16H exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H40/20
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [5000 rows x 14 columns]

# %%
# result_df.sample(n=100)

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 1        US2017339255A1              Dynamic feedback for wearable devices
# 2        US2014316287A1  System and method for displaying fluid respons...
# 3        US2013217350A1  System and method for communicating presence s...
# 4        US2013018592A1  Systems and Methods for Inter-Population Neuro...
# ...                 ...                                                ...
# 4995     US2009065522A1  Unit dose compliance monitoring and reporting ...
# 4996     US2009063195A1  Medical service support system, medical servic...
# 4997     US2009051560A1                   Drug dispenser/container display
# 4998     US2009048868A1        Medication Related Task Notification System
# 4999     US2009048863A1  Method and apparatus for medication prescripti...
#
#                                                abstract  \
# 0     A tissue stimulation system that generates an ...
# 1     Various embodiments disclosed herein relate to...
# 2     Embodiments provide systems and methods for di...
# 3     A method and system are provided for computing...
# 4     Systems and methods for inter-population asses...
# ...                                                 ...
# 4995  A unit dose medication compliance monitoring a...
# 4996  In the embodiment of the present invention, wh...
# 4997  A display for use on medical dispensing equipm...
# 4998  A task management system for informing a clini...
# 4999  A method and apparatus of providing a pharmace...
#
#                                     Lemmatized-Abstract  \
# 0     tissue stimulation system generates electrical...
# 1     various embodiment disclosed relate wearable d...
# 2     embodiment provide system method displaying fl...
# 3     method system provided computing physiological...
# 4     system method interpopulation assessment neuro...
# ...                                                 ...
# 4995  unit dose medication compliance monitoring rep...
# 4996  embodiment present invention identification in...
# 4997  display medical dispensing equipment resulting...
# 4998  task management system informing clinician med...
# 4999  method apparatus providing pharmaceutical cons...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 1      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 2     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 4      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06F17/00', 'G16H15/00']  ['G06F', 'G16H']      2   1.0
# 4996   ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']      2   1.0
# 4997    ['G09G3/34', 'G16H20/17']  ['G09G', 'G16H']      2   1.0
# 4998   ['G16H20/10', 'G16Z99/00']  ['G16H', 'G16Z']      2   1.0
# 4999   ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']      2   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [10]
# 1                      [10]
# 2                      [10]
# 3                      [10]
# 4                      [10]
# ...                     ...
# 4995                    [2]
# 4996                    [2]
# 4997                    [2]
# 4998                    [2]
# 4999                    [2]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H40/20
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50
# 0                          13
# 1                          13
# 2                          13
# 3                          13
# 4                          13
# ...                       ...
# 4995                       18
# 4996                       18
# 4997                       18
# 4998                       18
# 4999                       18
#
# [5000 rows x 15 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 1        US2017339255A1              Dynamic feedback for wearable devices
# 2        US2014316287A1  System and method for displaying fluid respons...
# 3        US2013217350A1  System and method for communicating presence s...
# 4        US2013018592A1  Systems and Methods for Inter-Population Neuro...
# ...                 ...                                                ...
# 4995     US2009065522A1  Unit dose compliance monitoring and reporting ...
# 4996     US2009063195A1  Medical service support system, medical servic...
# 4997     US2009051560A1                   Drug dispenser/container display
# 4998     US2009048868A1        Medication Related Task Notification System
# 4999     US2009048863A1  Method and apparatus for medication prescripti...
#
#                                                abstract  \
# 0     A tissue stimulation system that generates an ...
# 1     Various embodiments disclosed herein relate to...
# 2     Embodiments provide systems and methods for di...
# 3     A method and system are provided for computing...
# 4     Systems and methods for inter-population asses...
# ...                                                 ...
# 4995  A unit dose medication compliance monitoring a...
# 4996  In the embodiment of the present invention, wh...
# 4997  A display for use on medical dispensing equipm...
# 4998  A task management system for informing a clini...
# 4999  A method and apparatus of providing a pharmace...
#
#                                     Lemmatized-Abstract  \
# 0     tissue stimulation system generates electrical...
# 1     various embodiment disclosed relate wearable d...
# 2     embodiment provide system method displaying fl...
# 3     method system provided computing physiological...
# 4     system method interpopulation assessment neuro...
# ...                                                 ...
# 4995  unit dose medication compliance monitoring rep...
# 4996  embodiment present invention identification in...
# 4997  display medical dispensing equipment resulting...
# 4998  task management system informing clinician med...
# 4999  method apparatus providing pharmaceutical cons...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 1      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 2     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 4      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06F17/00', 'G16H15/00']  ['G06F', 'G16H']      2   1.0
# 4996   ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']      2   1.0
# 4997    ['G09G3/34', 'G16H20/17']  ['G09G', 'G16H']      2   1.0
# 4998   ['G16H20/10', 'G16Z99/00']  ['G16H', 'G16Z']      2   1.0
# 4999   ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']      2   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [10]
# 1                      [10]
# 2                      [10]
# 3                      [10]
# 4                      [10]
# ...                     ...
# 4995                    [2]
# 4996                    [2]
# 4997                    [2]
# 4998                    [2]
# 4999                    [2]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H40/20
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50  RFR
# 0                          13  4.0
# 1                          13  4.0
# 2                          13  4.0
# 3                          13  4.0
# 4                          13  4.0
# ...                       ...  ...
# 4995                       18  3.0
# 4996                       18  3.0
# 4997                       18  3.0
# 4998                       18  3.0
# 4999                       18  3.0
#
# [5000 rows x 16 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","abstract", "Lemmatized-Abstract","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_abstract","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2020135321A1  System, methods, &amp; device for managing a p...
# 1       US2008103636A1  Automated Washing System With Compliance Verif...
# 2       US2022198596A1  Care support apparatus, care support method an...
# 3       US2010326472A1  Automated washing system with compliance verif...
# 4       US2010332022A1               Hygiene compliance monitoring system
# ..                 ...                                                ...
# 495     US2020134351A1                Handheld arthropod detection device
# 496     US2022030199A1  Endoscope system, information provision method...
# 497     US2013336552A1    Region-selective fluoroscopic image compression
# 498     US2019162679A1  Apparatus and method of processing data acquir...
# 499     US2019133544A1          Systems and methods for image acquisition
#
#                                               abstract  \
# 0    A dose management system receives a product ch...
# 1    A system is provided for providing automated w...
# 2    A caregiving assistance device comprises: an e...
# 3    A system is provided for providing automated w...
# 4    A hygiene compliance monitoring system provide...
# ..                                                 ...
# 495  Various embodiments include systems and method...
# 496  A connection detection unit detects that a rec...
# 497  A method for displaying a sequence of fluorosc...
# 498  In a data processing apparatus, image data are...
# 499  The present disclosure relates to a method and...
#
#                                    Lemmatized-Abstract  \
# 0    dose management system receives product charac...
# 1    system provided providing automated washing ve...
# 2    caregiving assistance device comprises excreti...
# 3    system provided providing automated washing ve...
# 4    hygiene compliance monitoring system provides ...
# ..                                                 ...
# 495  various embodiment include system method arthr...
# 496  connection detection unit detects receiver con...
# 497  method displaying sequence fluoroscopic image ...
# 498  data processing apparatus image data calculate...
# 499  present disclosure relates method system reduc...
#
#                     sub_classes         sub_class topics  prob  \
# 0     ['G16H20/13', 'A61J7/04']  ['G16H', 'A61J']     34   1.0
# 1    ['G16H20/40', 'G16H20/40']  ['G16H', 'G16H']     34   1.0
# 2    ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']     34   1.0
# 3    ['G16H20/40', 'G16H20/40']  ['G16H', 'G16H']     34   1.0
# 4     ['H04K1/00', 'G16H40/20']  ['H04K', 'G16H']     34   1.0
# ..                          ...               ...    ...   ...
# 495  ['G16H30/40', 'G16H40/63']  ['G16H', 'G16H']     35   1.0
# 496   ['H04N7/18', 'G16H30/20']  ['H04N', 'G16H']     35   1.0
# 497  ['G16H30/40', 'G16H30/40']  ['G16H', 'G16H']     35   1.0
# 498   ['A61B6/00', 'G16H50/30']  ['A61B', 'G16H']     35   1.0
# 499   ['A61B6/00', 'G16H50/20']  ['A61B', 'G16H']     35   1.0
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 495           US20230270344A1
# 496           US20230270344A1
# 497           US20230270344A1
# 498           US20230270344A1
# 499           US20230270344A1
#
#                                         query_abstract  \
# 0    Methods and systems for delaying alarms that i...
# 1    Methods and systems for delaying alarms that i...
# 2    Methods and systems for delaying alarms that i...
# 3    Methods and systems for delaying alarms that i...
# 4    Methods and systems for delaying alarms that i...
# ..                                                 ...
# 495  A wearable monitoring device includes a band c...
# 496  A wearable monitoring device includes a band c...
# 497  A wearable monitoring device includes a band c...
# 498  A wearable monitoring device includes a band c...
# 499  A wearable monitoring device includes a band c...
#
#                                       query_codes_G16H     exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# ..                                                 ...                  ...
# 495  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...  G16H30/40,G16H40/63
# 496  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 497  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...  G16H30/40,G16H30/40
# 498  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 499  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H50/20
#
#      count_exact_match_top50  count_exact_match_top5
# 0                         18                       0
# 1                         18                       0
# 2                         18                       0
# 3                         18                       0
# 4                         18                       0
# ..                       ...                     ...
# 495                       29                       3
# 496                       29                       3
# 497                       29                       3
# 498                       29                       3
# 499                       29                       3
#
# [500 rows x 14 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230001090A1']
filtered_df
# Out:
#      publication_number                                              title  \
# 3900     US2020135321A1  System, methods, &amp; device for managing a p...
# 3901     US2008103636A1  Automated Washing System With Compliance Verif...
# 3902     US2022198596A1  Care support apparatus, care support method an...
# 3903     US2010326472A1  Automated washing system with compliance verif...
# 3904     US2010332022A1               Hygiene compliance monitoring system
# 3905     US2010328076A1            Wireless Hand Hygiene Monitoring System
# 3906     US2010315244A1                 Hand hygiene compliance monitoring
# 3907     US2010231385A1           Hand Washing Compliance Detection System
# 3908     US2010073168A1    System and Method for Reporting Status of a Bed
# 3909     US2010032486A1  Tubular container enabling individual identifi...
# 3910     US2020094061A1   Capture in ventricle-from-atrium cardiac therapy
# 3911     US2018310823A1  Medical monitoring device having multiple conf...
# 3912     US2013281852A1  Method for correcting blood pressure estimatio...
# 3913     US2019184119A1  Multiple control interface for medical ventilator
# 3914     US2019175038A1  Method And System For Non-Invasive Management ...
# 3915     US2019159766A1                    Treatment of appendage openings
# 3916     US2019150776A1  Insertable cardiac monitor for use in performi...
# 3917     US2019150827A1  Wearable device capable of recognizing doze-of...
# 3918     US2019156956A1      Treatment selection support system and method
# 3919     US2019154026A1   System, Method, and Apparatus for Infusing Fluid
# 3920     US2016249826A1  Method And System For Monitoring Physiological...
# 3921     US2021204819A1  Patch type thermometer-based body temperature ...
# 3922     US2013110063A1  Absorbent Article with Sensor Array for Body E...
# 3923     US2012265103A1  Systems and Methods for Treating Gastroesophag...
# 3924     US2022305209A1                      Smart vial adapter and method
# 3925     US2021358621A1       Autobot Securtiy Portal and Mobile Sanitizer
# 3926     US2021350929A1  Visual identification based access control of ...
# 3927     US2021267502A1  Wearable device for detecting salinity in pers...
# 3928     US2021257089A1  Methods and systems for managing the temperatu...
# 3929     US2021236326A1                             Patient warming system
# 3930     US2022044808A1  Predictive monitoring of the glucose-insulin e...
# 3931     US2022361779A1  Systems for Determining Similarity of Sequence...
# 3932     US2011071365A1  Method and apparatus for providing blood gluco...
# 3933     US2022369960A1  Process for managing or assisting in the monit...
# 3934     US2013338629A1  Diabetes therapy management system for recomme...
# 3935     US2021038163A1  Machine learning-based system for estimating g...
# 3936     US2013338630A1  Diabetes therapy management system for recomme...
# 3937     US2021059602A1  Systems, devices and methods for estimating bl...
# 3938     US2021068723A1  Intelligent prediction-based glucose alarm dev...
# 3939     US2014005633A1  Method and system to handle manual boluses or ...
# 3940     US2009030476A1  Methods and Apparatus for Electrical Stimulati...
# 3941     US2017339255A1              Dynamic feedback for wearable devices
# 3942     US2014316287A1  System and method for displaying fluid respons...
# 3943     US2013217350A1  System and method for communicating presence s...
# 3944     US2013018592A1  Systems and Methods for Inter-Population Neuro...
# 3945     US2021316089A1          Single dose inhaler monitoring attachment
# 3946     US2014379273A1  System For Improved Interpretation of Physiolo...
# 3947     US2019183450A1  Monitoring body sounds and detecting health co...
# 3948     US2015105633A1  Methods for Generating Data Output Containing ...
# 3949     US2018228447A1  Physiological state determination device and p...
#
#                                                abstract  \
# 3900  A dose management system receives a product ch...
# 3901  A system is provided for providing automated w...
# 3902  A caregiving assistance device comprises: an e...
# 3903  A system is provided for providing automated w...
# 3904  A hygiene compliance monitoring system provide...
# 3905  A method and mobile electronic device for moni...
# 3906  A system and associated processes monitor hand...
# 3907  Systems and methods are provided for monitorin...
# 3908  A method and system of reporting the status of...
# 3909  A tubular container enabling individual identi...
# 3910  Ventricle-from-atrium (VfA) cardiac therapy ma...
# 3911  A patient monitoring device can be configured ...
# 3912  As different artery blood pressure combination...
# 3913  Examples described herein include multiple con...
# 3914  The present invention describes a method and s...
# 3915  A method is provided for measuring an opening ...
# 3916  Long-term electrocardiographic and physiologic...
# 3917  A wearable device capable of recognizing doze-...
# 3918  It is provided a treatment selection support s...
# 3919  A peristaltic pump, and related system method ...
# 3920  The present invention is directed to systems a...
# 3921  A patch type thermometer-based body temperatur...
# 3922  An absorbent article incorporating a non-conta...
# 3923  Systems and methods for treating gastroesophag...
# 3924  A smart vial adapter is capable of measuring t...
# 3925  A security portal has a body having sidewalls ...
# 3926  Systems, and method and computer readable medi...
# 3927  A wearable device for determining risk of an u...
# 3928  A computer-implemented process useful for impl...
# 3929  A patient warming system includes a control un...
# 3930  There is a need for more effective and efficie...
# 3931  In implementations of systems for determining ...
# 3932  An apparatus and method of providing blood glu...
# 3933  A method for assisting in the control of a blo...
# 3934  An electronic computing device as presented he...
# 3935  A method for estimating glucose values of a us...
# 3936  A method of managing use of an insulin infusio...
# 3937  Disclosed are systems, devices and methods for...
# 3938  Glucose-related alarms may be generated based ...
# 3939  Described and illustrated is a diabetes manage...
# 3940  A tissue stimulation system that generates an ...
# 3941  Various embodiments disclosed herein relate to...
# 3942  Embodiments provide systems and methods for di...
# 3943  A method and system are provided for computing...
# 3944  Systems and methods for inter-population asses...
# 3945  A medicament device sensor (Sensor) comprises ...
# 3946  Systems, devices and methods for managing a ph...
# 3947  A method of monitoring body sounds using a sen...
# 3948  A method of generating a data string containin...
# 3949  A physiological state determination system inc...
#
#                                     Lemmatized-Abstract  \
# 3900  dose management system receives product charac...
# 3901  system provided providing automated washing ve...
# 3902  caregiving assistance device comprises excreti...
# 3903  system provided providing automated washing ve...
# 3904  hygiene compliance monitoring system provides ...
# 3905  method mobile electronic device monitoring han...
# 3906  system associated process monitor hand hygiene...
# 3907  system method provided monitoring hand washing...
# 3908  method system reporting status bed whose occup...
# 3909  tubular container enabling individual identifi...
# 3910  ventriclefromatrium vfa cardiac therapy utiliz...
# 3911  patient monitoring device configured provide f...
# 3912  different artery blood pressure combination me...
# 3913  example described include multiple control sys...
# 3914  present invention describes method system noni...
# 3915  method provided measuring opening appendage at...
# 3916  longterm electrocardiographic physiological mo...
# 3917  wearable device capable recognizing dozeoff st...
# 3918  provided treatment selection support system co...
# 3919  peristaltic pump related system method provide...
# 3920  present invention directed system method monit...
# 3921  patch type thermometerbased body temperature m...
# 3922  absorbent article incorporating noncontact ele...
# 3923  system method treating gastroesophageal reflux...
# 3924  smart vial adapter capable measuring dose drug...
# 3925  security portal body sidewall top floor entran...
# 3926  system method computer readable medium store i...
# 3927  wearable device determining risk underlying he...
# 3928  computerimplemented process useful implementin...
# 3929  patient warming system includes control unit c...
# 3930  effective efficient predictive data analysis e...
# 3931  implementation system determining similarity s...
# 3932  apparatus method providing blood glucose manag...
# 3933  method assisting control blood glucosetype phy...
# 3934  electronic computing device presented includes...
# 3935  method estimating glucose value user insulin i...
# 3936  method managing insulin infusion device provid...
# 3937  disclosed system device method estimating bloo...
# 3938  glucoserelated alarm generated based glucose p...
# 3939  described illustrated diabetes management syst...
# 3940  tissue stimulation system generates electrical...
# 3941  various embodiment disclosed relate wearable d...
# 3942  embodiment provide system method displaying fl...
# 3943  method system provided computing physiological...
# 3944  system method interpopulation assessment neuro...
# 3945  medicament device sensor sensor comprises body...
# 3946  system device method managing physiological co...
# 3947  method monitoring body sound sensor including ...
# 3948  method generating data string containing physi...
# 3949  physiological state determination system inclu...
#
#                          sub_classes         sub_class topics  prob  \
# 3900       ['G16H20/13', 'A61J7/04']  ['G16H', 'A61J']     34   1.0
# 3901      ['G16H20/40', 'G16H20/40']  ['G16H', 'G16H']     34   1.0
# 3902      ['G06Q50/22', 'G16H40/20']  ['G06Q', 'G16H']     34   1.0
# 3903      ['G16H20/40', 'G16H20/40']  ['G16H', 'G16H']     34   1.0
# 3904       ['H04K1/00', 'G16H40/20']  ['H04K', 'G16H']     34   1.0
# 3905      ['G08B23/00', 'G16H40/67']  ['G08B', 'G16H']     34   1.0
# 3906      ['G08B21/00', 'G16H40/20']  ['G08B', 'G16H']     34   1.0
# 3907      ['G08B21/00', 'G16H40/20']  ['G08B', 'G16H']     34   1.0
# 3908      ['G08B23/00', 'G16H40/20']  ['G08B', 'G16H']     34   1.0
# 3909      ['G06K19/07', 'G16H10/40']  ['G06K', 'G16H']     34   1.0
# 3910       ['A61N1/37', 'G16H50/20']  ['A61N', 'G16H']      3   1.0
# 3911       ['A61B5/02', 'G16H40/60']  ['A61B', 'G16H']      3   1.0
# 3912       ['A61B8/08', 'G16H50/30']  ['A61B', 'G16H']      3   1.0
# 3913      ['G16H40/67', 'G16H20/40']  ['G16H', 'G16H']      3   1.0
# 3914     ['A61B5/0476', 'G16H40/67']  ['A61B', 'G16H']      3   1.0
# 3915      ['A61B17/34', 'G16H30/40']  ['A61B', 'G16H']      3   1.0
# 3916       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']      3   1.0
# 3917      ['A61B5/024', 'G16H50/70']  ['A61B', 'G16H']      3   1.0
# 3918      ['G16H50/50', 'G16H50/50']  ['G16H', 'G16H']      3   1.0
# 3919      ['G16H20/17', 'G16H40/63']  ['G16H', 'G16H']      3   1.0
# 3920     ['G16H20/30', 'A61B5/1118']  ['G16H', 'A61B']     19   1.0
# 3921       ['A61B5/01', 'G16H40/63']  ['A61B', 'G16H']     19   1.0
# 3922      ['A61F13/42', 'G16H40/67']  ['A61F', 'G16H']     19   1.0
# 3923      ['G16H20/40', 'G16H20/60']  ['G16H', 'G16H']     19   1.0
# 3924  ['G16H40/63', 'A61M2205/3569']  ['G16H', 'A61M']     19   1.0
# 3925     ['G16H50/20', 'A61B5/1172']  ['G16H', 'A61B']     19   1.0
# 3926       ['G06K9/00', 'G16H50/20']  ['G06K', 'G16H']     19   1.0
# 3927      ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']     19   1.0
# 3928       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     19   1.0
# 3929       ['A61F7/00', 'G16H20/30']  ['A61F', 'G16H']     19   1.0
# 3930      ['G16H20/10', 'G06N3/045']  ['G16H', 'G06N']      8   1.0
# 3931       ['A61B5/00', 'G16H40/63']  ['A61B', 'G16H']      8   1.0
# 3932       ['A61B5/00', 'G16H20/00']  ['A61B', 'G16H']      8   1.0
# 3933      ['A61B5/145', 'G16H20/60']  ['A61B', 'G16H']      8   1.0
# 3934      ['A61M5/172', 'G16H40/63']  ['A61M', 'G16H']      8   1.0
# 3935      ['G16H50/20', 'G16H20/17']  ['G16H', 'G16H']      8   1.0
# 3936      ['A61M5/172', 'G16H40/63']  ['A61M', 'G16H']      8   1.0
# 3937      ['A61B5/145', 'G16H40/67']  ['A61B', 'G16H']      8   1.0
# 3938     ['G16H20/17', 'A61B5/7275']  ['G16H', 'A61B']      8   1.0
# 3939      ['A61M5/168', 'G16H20/17']  ['A61M', 'G16H']      8   1.0
# 3940      ['G06Q50/00', 'G16H40/63']  ['G06Q', 'G16H']     10   1.0
# 3941      ['G16H40/63', 'A61B5/742']  ['G16H', 'A61B']     10   1.0
# 3942     ['A61B5/0295', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3943      ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10   1.0
# 3944      ['G16Z99/00', 'G16H50/50']  ['G16Z', 'G16H']     10   1.0
# 3945  ['G16H20/13', 'A61M2205/3375']  ['G16H', 'A61M']     10   1.0
# 3946       ['A61B5/00', 'G16H50/30']  ['A61B', 'G16H']     10   1.0
# 3947       ['H04R1/40', 'G16H40/63']  ['H04R', 'G16H']     10   1.0
# 3948       ['A61B5/11', 'G16H40/67']  ['A61B', 'G16H']     10   1.0
# 3949       ['G06T7/00', 'G16H50/30']  ['G06T', 'G16H']     10   1.0
#
#      query_publication_numbers  \
# 3900           US20230001090A1
# 3901           US20230001090A1
# 3902           US20230001090A1
# 3903           US20230001090A1
# 3904           US20230001090A1
# 3905           US20230001090A1
# 3906           US20230001090A1
# 3907           US20230001090A1
# 3908           US20230001090A1
# 3909           US20230001090A1
# 3910           US20230001090A1
# 3911           US20230001090A1
# 3912           US20230001090A1
# 3913           US20230001090A1
# 3914           US20230001090A1
# 3915           US20230001090A1
# 3916           US20230001090A1
# 3917           US20230001090A1
# 3918           US20230001090A1
# 3919           US20230001090A1
# 3920           US20230001090A1
# 3921           US20230001090A1
# 3922           US20230001090A1
# 3923           US20230001090A1
# 3924           US20230001090A1
# 3925           US20230001090A1
# 3926           US20230001090A1
# 3927           US20230001090A1
# 3928           US20230001090A1
# 3929           US20230001090A1
# 3930           US20230001090A1
# 3931           US20230001090A1
# 3932           US20230001090A1
# 3933           US20230001090A1
# 3934           US20230001090A1
# 3935           US20230001090A1
# 3936           US20230001090A1
# 3937           US20230001090A1
# 3938           US20230001090A1
# 3939           US20230001090A1
# 3940           US20230001090A1
# 3941           US20230001090A1
# 3942           US20230001090A1
# 3943           US20230001090A1
# 3944           US20230001090A1
# 3945           US20230001090A1
# 3946           US20230001090A1
# 3947           US20230001090A1
# 3948           US20230001090A1
# 3949           US20230001090A1
#
#                                       query_class_codes  \
# 3900  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3901  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3902  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3903  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3904  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3905  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3906  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3907  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3908  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3909  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3910  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3911  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3912  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3913  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3914  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3915  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3916  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3917  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3918  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3919  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3920  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3921  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3922  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3923  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3924  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3925  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3926  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3927  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3928  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3929  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3930  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3931  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3932  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3933  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3934  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3935  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3936  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3937  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3938  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3939  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3940  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3941  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3942  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3943  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3944  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3945  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3946  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3947  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3948  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3949  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
#
#                                          query_abstract  \
# 3900  Methods and systems for delaying alarms that i...
# 3901  Methods and systems for delaying alarms that i...
# 3902  Methods and systems for delaying alarms that i...
# 3903  Methods and systems for delaying alarms that i...
# 3904  Methods and systems for delaying alarms that i...
# 3905  Methods and systems for delaying alarms that i...
# 3906  Methods and systems for delaying alarms that i...
# 3907  Methods and systems for delaying alarms that i...
# 3908  Methods and systems for delaying alarms that i...
# 3909  Methods and systems for delaying alarms that i...
# 3910  Methods and systems for delaying alarms that i...
# 3911  Methods and systems for delaying alarms that i...
# 3912  Methods and systems for delaying alarms that i...
# 3913  Methods and systems for delaying alarms that i...
# 3914  Methods and systems for delaying alarms that i...
# 3915  Methods and systems for delaying alarms that i...
# 3916  Methods and systems for delaying alarms that i...
# 3917  Methods and systems for delaying alarms that i...
# 3918  Methods and systems for delaying alarms that i...
# 3919  Methods and systems for delaying alarms that i...
# 3920  Methods and systems for delaying alarms that i...
# 3921  Methods and systems for delaying alarms that i...
# 3922  Methods and systems for delaying alarms that i...
# 3923  Methods and systems for delaying alarms that i...
# 3924  Methods and systems for delaying alarms that i...
# 3925  Methods and systems for delaying alarms that i...
# 3926  Methods and systems for delaying alarms that i...
# 3927  Methods and systems for delaying alarms that i...
# 3928  Methods and systems for delaying alarms that i...
# 3929  Methods and systems for delaying alarms that i...
# 3930  Methods and systems for delaying alarms that i...
# 3931  Methods and systems for delaying alarms that i...
# 3932  Methods and systems for delaying alarms that i...
# 3933  Methods and systems for delaying alarms that i...
# 3934  Methods and systems for delaying alarms that i...
# 3935  Methods and systems for delaying alarms that i...
# 3936  Methods and systems for delaying alarms that i...
# 3937  Methods and systems for delaying alarms that i...
# 3938  Methods and systems for delaying alarms that i...
# 3939  Methods and systems for delaying alarms that i...
# 3940  Methods and systems for delaying alarms that i...
# 3941  Methods and systems for delaying alarms that i...
# 3942  Methods and systems for delaying alarms that i...
# 3943  Methods and systems for delaying alarms that i...
# 3944  Methods and systems for delaying alarms that i...
# 3945  Methods and systems for delaying alarms that i...
# 3946  Methods and systems for delaying alarms that i...
# 3947  Methods and systems for delaying alarms that i...
# 3948  Methods and systems for delaying alarms that i...
# 3949  Methods and systems for delaying alarms that i...
#
#      query_predicted_topics  \
# 3900                   [34]
# 3901                   [34]
# 3902                   [34]
# 3903                   [34]
# 3904                   [34]
# 3905                   [34]
# 3906                   [34]
# 3907                   [34]
# 3908                   [34]
# 3909                   [34]
# 3910                    [3]
# 3911                    [3]
# 3912                    [3]
# 3913                    [3]
# 3914                    [3]
# 3915                    [3]
# 3916                    [3]
# 3917                    [3]
# 3918                    [3]
# 3919                    [3]
# 3920                   [19]
# 3921                   [19]
# 3922                   [19]
# 3923                   [19]
# 3924                   [19]
# 3925                   [19]
# 3926                   [19]
# 3927                   [19]
# 3928                   [19]
# 3929                   [19]
# 3930                    [8]
# 3931                    [8]
# 3932                    [8]
# 3933                    [8]
# 3934                    [8]
# 3935                    [8]
# 3936                    [8]
# 3937                    [8]
# 3938                    [8]
# 3939                    [8]
# 3940                   [10]
# 3941                   [10]
# 3942                   [10]
# 3943                   [10]
# 3944                   [10]
# 3945                   [10]
# 3946                   [10]
# 3947                   [10]
# 3948                   [10]
# 3949                   [10]
#
#                                        query_codes_G16H     exact_match_code  \
# 3900  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3901  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3902  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3903  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3904  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3905  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3906  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3907  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3908  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3909  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3910  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3911  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/60
# 3912  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3913  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3914  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3915  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3916  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3917  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3918  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H50/50,G16H50/50
# 3919  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3920  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3921  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3922  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3923  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3924  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3925  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3926  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3927  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3928  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3929  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3930  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/10
# 3931  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3932  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/00
# 3933  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3934  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3935  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3936  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3937  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3938  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3939  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3940  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3941  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3942  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3943  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3944  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H50/50
# 3945  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3946  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3947  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3948  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3949  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
#
#       count_exact_match_top50  RFR
# 3900                       18  6.0
# 3901                       18  6.0
# 3902                       18  6.0
# 3903                       18  6.0
# 3904                       18  6.0
# 3905                       18  6.0
# 3906                       18  6.0
# 3907                       18  6.0
# 3908                       18  6.0
# 3909                       18  6.0
# 3910                       18  6.0
# 3911                       18  6.0
# 3912                       18  6.0
# 3913                       18  6.0
# 3914                       18  6.0
# 3915                       18  6.0
# 3916                       18  6.0
# 3917                       18  6.0
# 3918                       18  6.0
# 3919                       18  6.0
# 3920                       18  6.0
# 3921                       18  6.0
# 3922                       18  6.0
# 3923                       18  6.0
# 3924                       18  6.0
# 3925                       18  6.0
# 3926                       18  6.0
# 3927                       18  6.0
# 3928                       18  6.0
# 3929                       18  6.0
# 3930                       18  6.0
# 3931                       18  6.0
# 3932                       18  6.0
# 3933                       18  6.0
# 3934                       18  6.0
# 3935                       18  6.0
# 3936                       18  6.0
# 3937                       18  6.0
# 3938                       18  6.0
# 3939                       18  6.0
# 3940                       18  6.0
# 3941                       18  6.0
# 3942                       18  6.0
# 3943                       18  6.0
# 3944                       18  6.0
# 3945                       18  6.0
# 3946                       18  6.0
# 3947                       18  6.0
# 3948                       18  6.0
# 3949                       18  6.0

# %%
result_df.to_csv('BERTopic-Preprocessing-Abstract-Tuning-SentenceTransformers.csv', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     0.0
# 1            US20230001263A1                     5.0
# 2            US20230005591A1                     5.0
# 3            US20230005611A1                     0.0
# 4            US20230009812A1                     0.0
# ..                       ...                     ...
# 95           US20230255518A1                     0.0
# 96           US20230259481A1                     1.0
# 97           US20230260617A1                     3.0
# 98           US20230264029A1                     0.0
# 99           US20230270344A1                     3.0
#
# [100 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 1.81

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                     18.0
# 1            US20230001263A1                     21.0
# 2            US20230005591A1                     22.0
# 3            US20230005611A1                      5.0
# 4            US20230009812A1                      7.0
# ..                       ...                      ...
# 95           US20230255518A1                     11.0
# 96           US20230259481A1                     14.0
# 97           US20230260617A1                     25.0
# 98           US20230264029A1                      1.0
# 99           US20230270344A1                     29.0
#
# [100 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 13.79

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1   6.0
# 1            US20230001263A1   1.0
# 2            US20230005591A1   1.0
# 3            US20230005611A1   7.0
# 4            US20230009812A1  11.0
# ..                       ...   ...
# 95           US20230255518A1  10.0
# 96           US20230259481A1   5.0
# 97           US20230260617A1   1.0
# 98           US20230264029A1  23.0
# 99           US20230270344A1   1.0
#
# [100 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 5.091836734693878
