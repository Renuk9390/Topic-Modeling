# %%
import pandas as pd

df_claim = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
len(df_claim)
# Out:
# 31306

# %%
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
first_record = df_claim['first_claim'][1]
first_record
# Out:
# 'What is claimed is: 1 . A data storage and retrieval system for non-contiguous medical device data, the system comprising: a medical device, connectable to a computer network, subject to occasional gaps in connectivity to the computer network, and configured to automatically repeatedly capture status information about the medical device and send messages containing the status information via the computer network; a network connectivity log configured to automatically record: (a) times at which the medical device connects to the computer network and (b) times at which the medical device disconnects from the computer network; a data store configured to automatically: store digital media data in a media file; and provide a requested portion, less than all, of the stored media file in response to a provision request, wherein the provision request includes an index, relative to an end of the media file, that corresponds to the requested portion; a media server, connectable to the computer network and configured to automatically: receive the messages via the computer network; store status information from received messages into the data store, wherein status information from consecutive received messages is stored contiguously in the data store, notwithstanding the occasional gaps in connectivity between the medical'

# %%
x = len(df_claim['first_claim'][1])
print(x)
# Out:
# 1331

# %%
# Check for NaN or null values in 'first_claim' column
has_nan_or_null = df_claim['first_claim'].isna().any()

if has_nan_or_null:
    print("The 'first_claim' column contains NaN or null values.")
else:
    print("The 'first_claim' column does not contain NaN or null values.")
# Out:
# The 'first_claim' column does not contain NaN or null values.

# %%
# Calculate the length of strings in the 'first_claim' column and find the minimum length
min_length = df_claim['first_claim'].str.len().min()

print(f"The shortest length in the 'first_claim' column is: {min_length}")
# Out:
# The shortest length in the 'first_claim' column is: 67

# %%
import torch
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer

# Check if GPU is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the Sentence Transformers model
sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
#sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)

# Adjust UMAP hyperparameters
umap_model = UMAP(n_neighbors=3, 
                  n_components=3, 
                  min_dist=0.05, 
                  metric='cosine', 
                  random_state=100,
                  n_jobs=-1)  # Utilize all available CPU cores for UMAP preprocessing

# Adjust HDBSCAN hyperparameters
hdbscan_model = HDBSCAN( min_cluster_size=80,
                        min_samples=40, 
                        metric='euclidean', 
                        cluster_selection_method='eom', 
                        prediction_data=True)

# Adjust CountVectorizer hyperparameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3))


# c-TF-IDF
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Run Model
topic_model = BERTopic(umap_model=umap_model,
                       embedding_model=sentence_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       ctfidf_model=ctfidf_model,
                       verbose=True)

# Replace 'df['first_claim']' with your data source for the first_claim column
topics, probabilities = topic_model.fit_transform(df_claim['first_claim'])
# Out:
# Batches:   0%|          | 0/979 [00:00<?, ?it/s]
# 2023-09-29 15:37:06,203 - BERTopic - Transformed documents to Embeddings
# 2023-09-29 15:38:21,297 - BERTopic - Reduced dimensionality
# 2023-09-29 15:38:24,817 - BERTopic - Clustered reduced embeddings

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document": df_claim['first_claim'],
                          "ID": range(len(df_claim['first_claim'])),
                          "Topic": topics})

documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence_c_nmpi = coherence_model.get_coherence()
print("c_npmi is: ",coherence_c_nmpi)
# Out:
# c_npmi is:  -0.15064908026131865

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_claim['first_claim'],
                          "ID": range(len(df_claim['first_claim'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_CV= coherence_model.get_coherence()
print("C_V is: ", coherence_CV)
# Out:
# C_V is:  0.36835536593182094

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_claim['first_claim'],
                          "ID": range(len(df_claim['first_claim'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence_u_mass= coherence_model.get_coherence()
print("u_mass is: ", coherence_u_mass)
# Out:
# u_mass is:  -0.4814320980853131

# %%
 topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  12235                                -1_of the_for_in_or
# 1       0   5409               0_configured_configured to_system_is
# 2       1   1388  1_method of claim_method of_the method of_the ...
# 3       2   1208   2_method of claim_method of_health_the method of
# 4       3    794              3_image_images_method_method of claim
# 5       4    751                      4_image_imaging_images_method
# 6       5    693  5_system of claim_system of_the system_the sys...
# 7       6    467                 6_21_canceled_claim 21_of claim 21
# 8       7    465                    7_cancer_sample_gene_expression
# 9       8    404              8_glucose_insulin_blood glucose_blood
# 10      9    391  9_apparatus_the apparatus_apparatus of_apparat...
# 11     10    387  10_patient_healthcare_claimed is method_is method
# 12     11    353  11_prescription_medication_pharmacy_the prescr...
# 13     12    322                 12_health_health care_patient_care
# 14     13    291              13_image_imaging_images_medical image
# 15     14    286              14_image_medical image_unit_apparatus
# 16     15    270                         15_bone_image_3d_resonance
# 17     16    262     16_device of claim_device of_device_the device
# 18     17    255                   17_genetic_cardiac_sample_method
# 19     18    234  18_prescription_pharmaceutical_the prescriptio...
# 20     19    220                               19_16_15_canceled_17
# 21     20    220           20_glucose_insulin_blood glucose_analyte
# 22     21    219                  21_dental_tooth_teeth_orthodontic
# 23     22    194       22_medium_medium of claim_medium of_readable
# 24     23    192  23_claim method_prescription_claim method for_...
# 25     24    184                     24_server_care_terminal_health
# 26     25    183  25_physiological_monitoring_the physiological_...
# 27     26    183  26_infusion_transitory computer readable_non t...
# 28     27    180  27_ultrasound_the ultrasound_an ultrasound_ult...
# 29     28    157           28_exercise_fitness_activity_performance
# 30     29    152  29_invention_the invention_invention claimed_t...
# 31     30    150          30_exercise_the exercise_fitness_the user
# 32     31    149      31_stimulation_eeg_neuromodulation_electrical
# 33     32    147  32_treatment_system according_clinical_system ...
# 34     33    146  33_data components_implemented method_cognitiv...
# 35     34    136                     34_coronary_flow_artery_vessel
# 36     35    134      35_media of_media_media of claim_the media of
# 37     36    134                   36_risk_disease_score_risk score
# 38     37    129                       37_cardiac_heart_signal_beat
# 39     38    118               38_infusion_pump_infusion pump_fluid
# 40     39    116      39_remote_monitoring_monitoring system_system
# 41     40    104  40_information processing_the information proc...
# 42     41     96                   41_food_nutritional_meal_dietary
# 43     42     96  42_massage_health condition_patient health con...
# 44     43     95          43_we claim_we_we claim method_transplant
# 45     44     90           44_claim as_invention_said_our invention
# 46     45     89               45_food_of food_nutritional_the food
# 47     46     88  46_radiation_the radiation_radiation image_rad...
# 48     47     87  47_physiological_the physiological_physiologic...
# 49     48     86  48_content_of data_rehabilitation_semantics re...
# 50     49     84      49_media of claim_media of_media_the media of
# 51     50     83  50_medication_dispensing_the medication_compar...
#
#                                        Representation  \
# 0   [of the, for, in, or, at, an, wherein, method,...
# 1   [configured, configured to, system, is, the sy...
# 2   [method of claim, method of, the method of, th...
# 3   [method of claim, method of, health, the metho...
# 4   [image, images, method, method of claim, the m...
# 5   [image, imaging, images, method, image data, t...
# 6   [system of claim, system of, the system, the s...
# 7   [21, canceled, claim 21, of claim 21, 20, 22, ...
# 8   [cancer, sample, gene, expression, dna, geneti...
# 9   [glucose, insulin, blood glucose, blood, gluco...
# 10  [apparatus, the apparatus, apparatus of, appar...
# 11  [patient, healthcare, claimed is method, is me...
# 12  [prescription, medication, pharmacy, the presc...
# 13  [health, health care, patient, care, data, com...
# 14  [image, imaging, images, medical image, system...
# 15  [image, medical image, unit, apparatus, image ...
# 16  [bone, image, 3d, resonance, magnetic, magneti...
# 17  [device of claim, device of, device, the devic...
# 18  [genetic, cardiac, sample, method, biological,...
# 19  [prescription, pharmaceutical, the prescriptio...
# 20  [16, 15, canceled, 17, claim 16, claim 16 wher...
# 21  [glucose, insulin, blood glucose, analyte, bas...
# 22  [dental, tooth, teeth, orthodontic, the dental...
# 23  [medium, medium of claim, medium of, readable,...
# 24  [claim method, prescription, claim method for,...
# 25  [server, care, terminal, health, di, system, i...
# 26  [physiological, monitoring, the physiological,...
# 27  [infusion, transitory computer readable, non t...
# 28  [ultrasound, the ultrasound, an ultrasound, ul...
# 29  [exercise, fitness, activity, performance, phy...
# 30  [invention, the invention, invention claimed, ...
# 31  [exercise, the exercise, fitness, the user, ac...
# 32  [stimulation, eeg, neuromodulation, electrical...
# 33  [treatment, system according, clinical, system...
# 34  [data components, implemented method, cognitiv...
# 35  [coronary, flow, artery, vessel, blood, corona...
# 36  [media of, media, media of claim, the media of...
# 37  [risk, disease, score, risk score, geographic,...
# 38  [cardiac, heart, signal, beat, ecg, the heart,...
# 39  [infusion, pump, infusion pump, fluid, the inf...
# 40  [remote, monitoring, monitoring system, system...
# 41  [information processing, the information proce...
# 42  [food, nutritional, meal, dietary, recipe, ite...
# 43  [massage, health condition, patient health con...
# 44  [we claim, we, we claim method, transplant, cl...
# 45  [claim as, invention, said, our invention, our...
# 46  [food, of food, nutritional, the food, food it...
# 47  [radiation, the radiation, radiation image, ra...
# 48  [physiological, the physiological, physiologic...
# 49  [content, of data, rehabilitation, semantics r...
# 50  [media of claim, media of, media, the media of...
# 51  [medication, dispensing, the medication, compa...
#
#                                   Representative_Docs
# 0   [What is claimed is: 1 . A system comprising: ...
# 1   [What is claimed is: 1 . A system for identify...
# 2   [1 . A computer-implemented method for providi...
# 3   [What is claimed is: 1 . A computer implemente...
# 4   [What is claimed is: 1 . A method for determin...
# 5   [1 . A method of detecting the presence or abs...
# 6   [1 . A system, comprising: at least one memory...
# 7   [1 - 20 . (canceled) 21 . A non-transitory com...
# 8   [What is claimed is: 1 . A method of assessing...
# 9   [1 . A method comprising: receiving previous i...
# 10  [1 . A medical apparatus, comprising: (a) a pa...
# 11  [What is claimed is: 1 . A computerized method...
# 12  [1 . A method for management and distribution ...
# 13  [1 . A computer-implemented method performed a...
# 14  [1 . A system for generating a key-image from ...
# 15  [1 . An image display apparatus, comprising: a...
# 16  [1 . A method for automatically processing 3D ...
# 17  [1 . A data communication module for use with ...
# 18  [What is claimed is: 1 . An evaluating method ...
# 19  [What is claimed is: 1 . A method for validati...
# 20  [1 - 12 . (canceled) 13 . A system for recordi...
# 21  [1 . A device for treatment of a subject, wher...
# 22  [What is claimed is: 1 . A three-dimensionally...
# 23  [1 . A non-transitory computer-readable storag...
# 24  [I claim: 1 . A non-transitory software based ...
# 25  [1 . A computer server or servers for assistin...
# 26  [1 . A method for determining one or more phys...
# 27  [What is claimed is: 1 . A non-transitory comp...
# 28  [What is claimed is: 1 . An ultrasound diagnos...
# 29  [1 - 47 . (canceled) 48 . A method comprising:...
# 30  [The invention is claimed as follows: 1 . A ho...
# 31  [What is claimed is: 1 . A computer-system-imp...
# 32  [What is claimed is: 1 . A method of providing...
# 33  [1 . A treatment decision support system, comp...
# 34  [1 . A computer-system-implemented method of d...
# 35  [1 . A method for multi-component heart modeli...
# 36  [What is claimed is: 1 . One or more computer ...
# 37  [What is claimed is: 1 . A method for monitori...
# 38  [What is claimed is: 1 . A method comprising: ...
# 39  [1 . A system for delivering a fluid to a pati...
# 40  [1 . A patient monitoring system, comprising: ...
# 41  [1 . An information processing device comprisi...
# 42  [1 . A method for providing food products for ...
# 43  [1 - 28 . (canceled) 29 . A method for managin...
# 44  [We claim: 1 . A method of providing a reward ...
# 45  [We claim as our invention: 1 . A medical syst...
# 46  [We claim: 1 . A computer-implemented method o...
# 47  [What is claimed is: 1 . An imaging control ap...
# 48  [What is claimed is: 1 . A method of monitorin...
# 49  [What is claimed is: 1 . A method for monitori...
# 50  [1 . One or more non-transitory computer-stora...
# 51  [What is claimed is: 1 . A patient kiosk for c...

# %%
#adding topics and probs for eachdoc in dataset
df_claim['topics'] = topics
df_claim['prob'] = probabilities
df_claim_topic=df_claim[["publication_number","title","first_claim","sub_classes","sub_class","topics","prob"]]
df_claim_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 1      What is claimed is: 1 . A data storage and ret...
# 2      1 . A method in a computing system, comprising...
# 3      What is claimed is: 1 . A method for providing...
# 4      What is claimed is: 1 . A method of monitoring...
# ...                                                  ...
# 31301  1 . A user authentication system comprising: a...
# 31302  What is claimed is: 1 . A diagnosis support ap...
# 31303  1 . A medical appointment scheduling system co...
# 31304  1 . A data processing, comprising a computer h...
# 31305  1 . A method comprising: a healthcare server o...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      -1  0.000000
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']       0  1.000000
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      -1  0.000000
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']      -1  0.000000
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      47  1.000000
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']       5  0.900515
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']       0  1.000000
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      -1  0.000000
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']       4  0.996585
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']      -1  0.000000
#
# [31306 rows x 7 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_claim_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_claim_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_claim_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %%
test1 = df_claim_test.loc[0, 'first_claim']
test1
# Out:
# '1. A physiological monitoring device comprising:\nat least two LEDs, the at least two LEDs configured to emit light of at least two different wavelengths; at least one detector configured to detect at least a portion of the light emitted from the at least two LEDs after at least a portion of the light has been attenuated by tissue, the at least one detector configured to output at least one signal responsive to the detected light; a light block surrounding the at least one detector, the light block forming a cavity, the light block comprising a light-absorbing material, the light block including only one circular opening through which light is configured to pass, an area of the circular opening being smaller than a surface area of a facing surface of the at least one detector; and a processor configured to receive and process one or more signals responsive to the outputted at least one signal and determine a physiological parameter of a user responsive to the one or more signals. at least two LEDs, the at least two LEDs configured to emit light of at least two different wavelengths; at least one detector configured to detect at least a portion of the light emitted from the at least two LEDs after at least a portion of the light has been attenuated by tissue, the at least one detector configured to output at least one signal responsive to the detected light; a light block surrounding the at least one detector, the light block forming a cavity, the light block comprising a light-absorbing material, the light block including only one circular opening through which light is configured to pass, an area of the circular opening being smaller than a surface area of a facing surface of the at least one detector; and a processor configured to receive and process one or more signals responsive to the outputted at least one signal and determine a physiological parameter of a user responsive to the one or more signals.'

# %%
import numpy as np 

# Find topics
num_of_topics = 5
similar_topics, similarity = topic_model.find_topics(test1, top_n=num_of_topics); 

# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')

for idx, topic_idx in enumerate(similar_topics):
    topic = topic_model.get_topic(topic_idx)
    keywords = ' '.join(str(keyword) for keyword in topic[0])
    print(f"Topic {idx+1}: {keywords}")
# Out:
# The top 5 similar topics are [16, 25, 9, -1, 39], and the similarities are [0.79 0.79 0.79 0.78 0.77]
# Topic 1: device of claim 0.24216003429920463
# Topic 2: physiological 0.21760096774303064
# Topic 3: apparatus 0.29467071838283376
# Topic 4: of the 0.11350084110138159
# Topic 5: remote 0.23686951413504426

# %%
# filter_topics_filter = df_claim_topic[df_claim_topic['topics'] == 43]
# filter_topics_filter = filter_topics_filter.sort_values('prob', ascending=False)
# filter_topics_filter

# %%
# Define the range of topic IDs you want to retrieve documents for
selected_topic_range =[-1, 8, 0, 3, 6]  # Replace with your desired range of topic IDs

# Create an empty DataFrame to store the top 10 documents
top_10_documents_test1 = pd.DataFrame()

# Iterate through the selected topic IDs
for selected_topic_id in selected_topic_range:
    # Filter the dataset based on the current topic ID
    filtered_df = df_claim_topic[df_claim_topic['topics'] == selected_topic_id]
    
    # Sort the filtered dataset by similarity scores in descending order
    sorted_df = filtered_df.sort_values(by='prob', ascending=False)
    
    # Retrieve the top 10 documents for the current topic
    top_10_for_topic = sorted_df.head(10)
    
    # Append the top 10 documents for the current topic to the result DataFrame
    top_10_documents_test1 = top_10_documents_test1.append(top_10_for_topic)

# Display the top 10 documents for all selected topics
top_10_documents_test1
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 20543     US2019160247A1  Process and system for generating personalized...
# 20525     US2019159733A1  Method and System for Monitoring Physiological...
# 20529     US2019159713A1  System and method for evaluating mental diseas...
# 20530     US2019159744A1  Computed tomography perfusion (ctp) method and...
# 20531     US2019164651A1              Health task generation and population
# 20532     US2019164019A1    Ultrasound Analytics for Actionable Information
# 20533     US2019161784A1  Precision therapeutic biomarker screening for ...
# 20534     US2019164643A1  Method for controlling an evaluation device fo...
# 20535     US2019159700A1  Systems, apparatus, and methods for using a we...
# 18120     US2022059206A1  Medical device with dose helper functionality ...
# 21233     US2014066892A1  Insulin on board compensation for a closed-loo...
# 21457     US2014121635A1      Variable Rate Closed Loop Control and Methods
# 12838     US2021313036A1  Method and system for the safety, analysis and...
# 12628     US2021283332A1  Integrated user-defined input into a closed-lo...
# 21545     US2014142535A1  Pump controller that checks operational state ...
# 12552     US2021268199A1                    Insulin-dosage detection device
# 12532     US2021268174A1                Operating a portable medical device
# 12289     US2021241879A1            Activity monitoring systems and methods
# 21781     US2014200559A1  Daily periodic target-zone modulation in the m...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 20536     US2019164650A1  Polydynamic integrated healthcare information ...
# 20393     US2019133888A1  System, method, and module for integrated medi...
# 20391     US2019141418A1  A system and method for generating one or more...
# 20389     US2019138505A1  Management Method and System For Implementatio...
# 20388     US2019139632A1  System, method and apparatus for cognitive ora...
# 20366     US2019131013A1  Pharmaceutical waste sorting assistance system...
# 20361     US2019131003A1  Process for carrying out a change in an assign...
# 20351     US2019130072A1                             Virtual consult record
# 20345     US2019131009A1  System and method for auto-regulating drug adm...
# 19142     US2018260954A1  Method and apparatus for providing medical inf...
# 11775     US2021174503A1  Method, system and storage medium with a progr...
# 11069     US2018130202A1  Kind of dr radiography lung contour extraction...
# 132       US2020107787A1  Image Processing of Streptococcal Infection in...
# 10839     US2018061077A1  Determination of result data on the basis of m...
# 27238     US2019333218A1  Automatically linking a description of patholo...
# 18850     US2022138941A1  Method and computer program product and appara...
# 8025      US2004184644A1  Display for computer-aided evaluation of medic...
# 18962     US2022151490A1  Detecting avascular and signal reduction areas...
# 21742     US2014188513A1  Multi-Modality Selective Archiving System and ...
# 31297     US2016253522A1  User targeted medical imaging and informaton p...
# 13270     US2021361273A1  Force-indicating retractor device and methods ...
# 21297     US2014085063A1        Distributed healthcare communication system
# 7829      US2021133509A1  Model optimization and data analysis using mac...
# 7597      US2021093240A1       Systems and methods for reaction measurement
# 7512      US2021085236A1  System and method for calculation of an index ...
# 22407     US2009304547A1                         Portable analytical device
# 7446      US2021068768A1  System for determining confidence in respirato...
# 22626     US2010057161A1  Methods of Treating Medical Conditions by Neur...
# 6991      US2021020309A1  Decreased latency wireless communication for u...
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 20543  1 . A process for constructing a personalized ...
# 20525  1 . A system adapted for at least one health-r...
# 20529  What is claimed is: 1 . A system for evaluatin...
# 20530  1 . A method of using computed tomography perf...
# 20531  We claim: 1 . A method of providing one or mor...
# 20532  What is claimed is: 1 . A monitoring system th...
# 20533  What is claimed: 1 . A method of identifying a...
# 20534  What is claimed is: 1 . A method for controlli...
# 20535  What is claimed is: 1 . A computer-implemented...
# 18120  What is claimed is: 1 . A medical device for s...
# 21233  What is claimed is: 1 . An electronic device c...
# 21457  What is claimed is: 1 . A method, comprising: ...
# 12838  What is claimed is: 1 . A method for detecting...
# 12628  What is claimed is: 1 . A controller for use i...
# 21545  What is claimed is: 1 . A computer-implemented...
# 12552  What is claimed is: 1 . An insulin-dosage dete...
# 12532  What is claimed is: 1 . A method of operating ...
# 12289  What is claimed is: 1 . An activity monitoring...
# 21781  What is claimed is: 1 . A controller for an ar...
# 1      What is claimed is: 1 . A data storage and ret...
# 20536  What is claimed is: 1 . A computerized integra...
# 20393  What is claimed is: 1 . A method for providing...
# 20391  What is claimed is: 1 . A system for generatin...
# 20389  What is claimed is: 1 . A method to perform a ...
# 20388  What is claimed is: 1 . A computer-implemented...
# 20366  We claim: 1 . A sorting assistance system for ...
# 20361  What is claimed is: 1 . A process for carrying...
# 20351  What is claimed is: 1 . A system for creating ...
# 20345  What is claimed is: 1 . An automatic regulatio...
# 19142  What is claimed is: 1 . A method for providing...
# 11775  What is claimed is: 1 . A method for the autom...
# 11069  1 . A DR radiography lung contour extraction m...
# 132    What is claimed is: 1 . A method comprising: a...
# 10839  What is claimed is: 1 . A method for determini...
# 27238  What is claimed is: 1 . A method for automatic...
# 18850  What is claimed is: 1 . A method for remotely ...
# 8025   What is claimed is: 1 . A method for providing...
# 18962  1 - 7 . (canceled) 8 . A method, comprising: i...
# 21742  What is claimed is: 1 . A method of selectivel...
# 31297  1 - 19 . (canceled) 20 . A system, comprising:...
# 13270  1 - 20 . (canceled) 21 . A joint distraction d...
# 21297  1 .- 20 . (canceled) 21 . A healthcare communi...
# 7829   1 .- 20 . (canceled) 21 . A device for assessi...
# 7597   1 - 20 . (canceled) 21 . A system for measurin...
# 7512   1 - 21 . (canceled) 22 . A system for calculat...
# 22407  1 - 22 . (canceled) 23 . A Portable, patient-o...
# 7446   1 - 20 . (canceled) 21 . A patient monitoring ...
# 22626  1 - 19 . (canceled) 20 . A system for improvin...
# 6991   1 - 17 . (canceled) 18 . A computer-implemente...
#
#                            sub_classes         sub_class  topics  prob
# 0           ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      -1   0.0
# 20543       ['G06T19/20', 'G16H10/60']  ['G06T', 'G16H']      -1   0.0
# 20525      ['A61B5/0205', 'G16H40/63']  ['A61B', 'G16H']      -1   0.0
# 20529       ['A61B5/024', 'G16H50/30']  ['A61B', 'G16H']      -1   0.0
# 20530        ['G06K9/20', 'G16H50/30']  ['G06K', 'G16H']      -1   0.0
# 20531       ['G16H50/30', 'G16H10/60']  ['G16H', 'G16H']      -1   0.0
# 20532       ['B64C39/02', 'G16H50/70']  ['B64C', 'G16H']      -1   0.0
# 20533       ['G16H10/40', 'G16H10/40']  ['G16H', 'G16H']      -1   0.0
# 20534        ['G16H30/40', 'G06T7/33']  ['G16H', 'G06T']      -1   0.0
# 20535     ['G16H40/67', 'G06F2218/00']  ['G16H', 'G06F']      -1   0.0
# 18120       ['G16H10/60', 'G16H20/10']  ['G16H', 'G16H']       8   1.0
# 22407       ['G01N33/00', 'G16H10/40']  ['G01N', 'G16H']       6   1.0
# 7446       ['A61B5/0205', 'G16H40/67']  ['A61B', 'G16H']       6   1.0
# 22626        ['A61N1/36', 'G16H20/40']  ['A61N', 'G16H']       6   1.0
# 6991        ['G16H40/40', 'G16H20/13']  ['G16H', 'G16H']       6   1.0

# %%
num_records = top_10_documents_test1.shape[0]
num_records
# Out:
# 50

# %%
# # Define a custom function to format the text
# def format_text(text):
#     # Remove brackets and single quotes, split by comma and strip whitespace
#     cleaned_text = ''.join(text).replace('[', '').replace(']', '').replace("'", '').split(',')
#     # Filter out empty strings and strip whitespace
#     cleaned_text = [item.strip() for item in cleaned_text if item.strip()]
#     # Join the cleaned text with commas and spaces
#     formatted_text = ', '.join(cleaned_text)
#     return formatted_text

# # Apply the custom function to the 'sub_classes' and 'sub_class' columns
# top_10_documents_test1['combined_class'] = top_10_documents_test1.apply(lambda x: format_text(x['sub_classes']) + ', ' + format_text(x['sub_class']), axis=1)

# # Display the resulting DataFrame with the 'combined' column
# print(top_10_documents_test1[['sub_classes', 'sub_class', 'combined_class']])

# %%
# # Get the class_codes from the first record of df_Abstract_test and convert it to a string, then split it by comma
# class_codes_value = df_Abstract_test['class_codes'].iloc[0]
# if pd.notna(class_codes_value):
#     target_sub_classes = str(class_codes_value).split(',')
# else:
#     target_sub_classes = []

# # Define a function to check for matching classes
# def has_matching_class(row):
#     # Extract the first 4 letters from each code in class_codes and combined_class
#     target_codes = [code[:4] for code in target_sub_classes]
#     combined_codes = [code[:4] for code in str(row['combined_class']).split(',')]

#     # Check if there are any common codes
#     return any(code in combined_codes for code in target_codes)

# # Apply the function to create a boolean mask
# top_10_documents_test1['has_matching_class'] = top_10_documents_test1.apply(has_matching_class, axis=1)

# top_10_documents_test1

# %%
# top_10_documents_test1.shape[0]

# %% [markdown]
# # list of 100 queries

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_claim_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Assuming you have a list of 100 queries in test
for query in df_claim_test['first_claim'][:num_samples_to_predict]:
    if isinstance(query, str):  # Check if the query is a string
        similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
        results.append((similar_topics, similarity))
    else:
        # Handle cases where 'query' is not a string (e.g., it's a float)
        print(f"Skipping non-string query: {query}")

# Now, the 'results' list contains the similar topics and similarities for each query
# You can access the results for a specific query like this:
for i, (similar_topics, similarity) in enumerate(results):
    print(f"Query {i + 1}: Similar Topics {similar_topics}, Similarity {similarity}")
# Out:
# Skipping non-string query: nan
# Skipping non-string query: nan
# Query 1: Similar Topics [16, 25, 9, -1, 39], Similarity [0.7918744, 0.79018235, 0.7878056, 0.778339, 0.76860034]
# Query 2: Similar Topics [16, 25, 22, 39, 40], Similarity [0.7235428, 0.71160823, 0.69949853, 0.68764395, 0.68443054]
# Query 3: Similar Topics [6, 42, 19, 15, 21], Similarity [0.7082089, 0.69748014, 0.6785549, 0.6728228, 0.6512108]
# Query 96: Similar Topics [38, 19, 6, 42, 24], Similarity [0.76865995, 0.6972545, 0.68962705, 0.684732, 0.6720605]
# Query 97: Similar Topics [42, 32, 19, -1, 6], Similarity [0.7872604, 0.7807087, 0.78043, 0.77734256, 0.7698184]
# Query 98: Similar Topics [42, 6, 19, 24, 32], Similarity [0.87026894, 0.8373989, 0.80398834, 0.78871846, 0.7779737]

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Create an empty DataFrame to store the results
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Assuming you have a list of 100 queries in 'df_Abstract_test'
for i, (query, publication_number, first_claim, class_codes) in enumerate(zip(df_claim_test['first_claim'][:num_samples_to_predict], 
                                                    df_claim_test['publication_numbers'][:num_samples_to_predict],
                                                    df_claim_test['first_claim'][:num_samples_to_predict],
                                                    df_claim_test['class_codes'][:num_samples_to_predict])):
    # Check if the 'first_claim' is a string before processing
    if isinstance(query, str):
        similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
        results.append((similar_topics, similarity))
        
        # Store the results in the DataFrame
        result_df_q = result_df_q.append({
            'query_claim': query,
            'query_predicted_topics': similar_topics,
            'query_publication_numbers': publication_number,
            'query_class_codes': class_codes
        }, ignore_index=True)
    else:
        # Handle cases where 'query' is not a string (e.g., it's a nan value)
        print(f"Skipping non-string query: {query}")

result_df_q
# Out:
# Skipping non-string query: nan
# Skipping non-string query: nan
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 93           US20230017310A1
# 94           US20230091925A1
# 95           US20230010638A1
# 96           US20230009812A1
# 97           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 93  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 94  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 95  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 96  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 97  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                           query_claim query_predicted_topics
# 0   1. A physiological monitoring device comprisin...    [16, 25, 9, -1, 39]
# 1   1. A monitoring device, comprising:\na band co...   [16, 25, 22, 39, 40]
# 2   1-25. (canceled) 26. A method for guiding a fr...    [6, 42, 19, 15, 21]
# 3   1-184. (canceled) 185. A computer-implemented ...    [19, 6, 34, 38, 17]
# 4   1. (canceled) 2. A community based response sy...    [42, 24, 19, -1, 6]
# ..                                                ...                    ...
# 93  1. A system for storing medical information re...   [24, 13, 22, 32, 16]
# 94  1. A method for event notification in an inter...   [33, 12, 25, 40, -1]
# 95  1.-2. (canceled) 3. A method of managing an in...    [38, 19, 6, 42, 24]
# 96  1. (canceled) 2. A patient monitoring system c...    [42, 32, 19, -1, 6]
# 97  1-27. (canceled) 28. A system to manage record...    [42, 6, 19, 24, 32]
#
# [98 rows x 4 columns]

# %%
# Check if the 'query_publication_numbers' field is unique
is_unique = result_df_q['query_publication_numbers'].nunique() == len(result_df_q)

if is_unique:
    print("The 'query_publication_numbers' field is unique.")
else:
    print("The 'query_publication_numbers' field is not unique.")
# Out:
# The 'query_publication_numbers' field is unique.

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'first_claim', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_claim']
    predicted_topics = row['query_predicted_topics']
    
    for topic_id in predicted_topics:
        # Filter 'df_claim_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_claim_topic[df_claim_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'result_df' DataFrame
        for _, doc_row in topic_documents.iterrows():
            result_df = result_df.append({
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_claim': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'first_claim': doc_row['first_claim'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }, ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2008198033A1  Device for Communicating with a Voice-Disabled...
# 1        US2007118397A1                   Monitoring of medical conditions
# 2        US2012303331A1      Adapter between scale and vital signs monitor
# 3        US2012286959A1                           Automated Allergy Alerts
# 4        US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# ...                 ...                                                ...
# 4895     US2018068076A1  Systems and methods for semantic search and ex...
# 4896     US2007055543A1  Medical resource estimation and simulation system
# 4897     US2007055545A1  System and user interface for processing patie...
# 4898     US2006271556A1  System and method for integration of medical i...
# 4899     US2006241978A1                   Electronic clinical chart system
#
#                                             first_claim  \
# 0     1 . A hand-held communication device comprisin...
# 1     1 . A device for use in the provision of a med...
# 2     1 . A method comprising: receiving, at an adap...
# 3     1 . A wireless communication device comprising...
# 4     1 . A customizable, portable identification an...
# ...                                                 ...
# 4895  1 . A system that facilitates using user-enter...
# 4896  1 . A healthcare decision support system for s...
# 4897  1 . A system for use in processing patient cli...
# 4898  1 . A system for integrating medical informati...
# 4899  1 . An electronic clinical chart system compri...
#
#                         sub_classes         sub_class topics  prob  \
# 0        ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 1         ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 2        ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 3       ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 4        ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
# ...                             ...               ...    ...   ...
# 4895  ['G16H50/20', 'G06F16/90344']  ['G16H', 'G06F']     32   1.0
# 4896     ['G16H10/60', 'G16Z99/00']  ['G16H', 'G16Z']     32   1.0
# 4897     ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     32   1.0
# 4898     ['G06F17/30', 'G16H70/00']  ['G06F', 'G16H']     32   1.0
# 4899     ['G16H50/70', 'G16B25/00']  ['G16H', 'G16B']     32   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim query_predicted_topics
# 0     1. A physiological monitoring device comprisin...                   [16]
# 1     1. A physiological monitoring device comprisin...                   [16]
# 2     1. A physiological monitoring device comprisin...                   [16]
# 3     1. A physiological monitoring device comprisin...                   [16]
# 4     1. A physiological monitoring device comprisin...                   [16]
# ...                                                 ...                    ...
# 4895  1-27. (canceled) 28. A system to manage record...                   [32]
# 4896  1-27. (canceled) 28. A system to manage record...                   [32]
# 4897  1-27. (canceled) 28. A system to manage record...                   [32]
# 4898  1-27. (canceled) 28. A system to manage record...                   [32]
# 4899  1-27. (canceled) 28. A system to manage record...                   [32]
#
# [4900 rows x 11 columns]

# %%
result_df['query_class_codes'][0]
# Out:
# 'A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/7221,A61B5/14532,G16H40/00,A61B5/14546,G16H40/60,A61B5/68,A61B2562/08,H,A61B1/00,A61B2562/221,A61B5/7475,A61B2562/18,A61B5/746,A61B5/7405,H05K,G16H40/67,A61B,Y10,A61B5/6813,Y,A61B2562/185,G16H10/40,A61B5/6826,A61B5/02,A61B5/0002,A61B5/1455,A61B5/6832,A,A61B5/7235,A61B5/6801,A61B5/7278,G16H,A61B5/026,A61B5/742,A61B2562/22,A61B5/024,G16,A61B5/02416,A61B5/683,A61B5/0015,A61B5/6825,Y10S,A61B5/1495,A61B5/72,A61B5/0261,A61B2562/085,A61B2562/222,A61B5/7275,A61B5/00,A61B5/145,A61B5/74,G16H10/00,H05K999/99,A61B5/7246,Y10S439/909,A61B5/14552,A61B5/6838,A61B5/6815,A61B5/7271,H05K999/00,A61B5/02427,A61B5/0205,Y10S439/00,A61B5/0022,A61B5/6814,A61B2562/00,H05'

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2008198033A1  Device for Communicating with a Voice-Disabled...
# 1        US2007118397A1                   Monitoring of medical conditions
# 2        US2012303331A1      Adapter between scale and vital signs monitor
# 3        US2012286959A1                           Automated Allergy Alerts
# 4        US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# ...                 ...                                                ...
# 4895     US2018068076A1  Systems and methods for semantic search and ex...
# 4896     US2007055543A1  Medical resource estimation and simulation system
# 4897     US2007055545A1  System and user interface for processing patie...
# 4898     US2006271556A1  System and method for integration of medical i...
# 4899     US2006241978A1                   Electronic clinical chart system
#
#                                             first_claim  \
# 0     1 . A hand-held communication device comprisin...
# 1     1 . A device for use in the provision of a med...
# 2     1 . A method comprising: receiving, at an adap...
# 3     1 . A wireless communication device comprising...
# 4     1 . A customizable, portable identification an...
# ...                                                 ...
# 4895  1 . A system that facilitates using user-enter...
# 4896  1 . A healthcare decision support system for s...
# 4897  1 . A system for use in processing patient cli...
# 4898  1 . A system for integrating medical informati...
# 4899  1 . An electronic clinical chart system compri...
#
#                         sub_classes         sub_class topics  prob  \
# 0        ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 1         ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 2        ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 3       ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 4        ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
# ...                             ...               ...    ...   ...
# 4895  ['G16H50/20', 'G06F16/90344']  ['G16H', 'G06F']     32   1.0
# 4896     ['G16H10/60', 'G16Z99/00']  ['G16H', 'G16Z']     32   1.0
# 4897     ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     32   1.0
# 4898     ['G06F17/30', 'G16H70/00']  ['G06F', 'G16H']     32   1.0
# 4899     ['G16H50/70', 'G16B25/00']  ['G16H', 'G16B']     32   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [16]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [16]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [16]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [16]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [16]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 4895                   [32]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896                   [32]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4897                   [32]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898                   [32]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4899                   [32]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [4900 rows x 12 columns]

# %%
# Create a new column to store the common code
import re 
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Custom extraction of values from sub_classes_str
    sub_classes = re.findall(r"'([^']*)'", sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2008198033A1  Device for Communicating with a Voice-Disabled...
# 1        US2007118397A1                   Monitoring of medical conditions
# 2        US2012303331A1      Adapter between scale and vital signs monitor
# 3        US2012286959A1                           Automated Allergy Alerts
# 4        US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# ...                 ...                                                ...
# 4895     US2018068076A1  Systems and methods for semantic search and ex...
# 4896     US2007055543A1  Medical resource estimation and simulation system
# 4897     US2007055545A1  System and user interface for processing patie...
# 4898     US2006271556A1  System and method for integration of medical i...
# 4899     US2006241978A1                   Electronic clinical chart system
#
#                                             first_claim  \
# 0     1 . A hand-held communication device comprisin...
# 1     1 . A device for use in the provision of a med...
# 2     1 . A method comprising: receiving, at an adap...
# 3     1 . A wireless communication device comprising...
# 4     1 . A customizable, portable identification an...
# ...                                                 ...
# 4895  1 . A system that facilitates using user-enter...
# 4896  1 . A healthcare decision support system for s...
# 4897  1 . A system for use in processing patient cli...
# 4898  1 . A system for integrating medical informati...
# 4899  1 . An electronic clinical chart system compri...
#
#                         sub_classes         sub_class topics  prob  \
# 0        ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 1         ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 2        ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 3       ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 4        ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
# ...                             ...               ...    ...   ...
# 4895  ['G16H50/20', 'G06F16/90344']  ['G16H', 'G06F']     32   1.0
# 4896     ['G16H10/60', 'G16Z99/00']  ['G16H', 'G16Z']     32   1.0
# 4897     ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     32   1.0
# 4898     ['G06F17/30', 'G16H70/00']  ['G06F', 'G16H']     32   1.0
# 4899     ['G16H50/70', 'G16B25/00']  ['G16H', 'G16B']     32   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [16]
# 1                      [16]
# 2                      [16]
# 3                      [16]
# 4                      [16]
# ...                     ...
# 4895                   [32]
# 4896                   [32]
# 4897                   [32]
# 4898                   [32]
# 4899                   [32]
#
#                                        query_codes_G16H exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [4900 rows x 13 columns]

# %%
# result_df.sample(n=100)

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2008198033A1  Device for Communicating with a Voice-Disabled...
# 1        US2007118397A1                   Monitoring of medical conditions
# 2        US2012303331A1      Adapter between scale and vital signs monitor
# 3        US2012286959A1                           Automated Allergy Alerts
# 4        US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# ...                 ...                                                ...
# 4895     US2018068076A1  Systems and methods for semantic search and ex...
# 4896     US2007055543A1  Medical resource estimation and simulation system
# 4897     US2007055545A1  System and user interface for processing patie...
# 4898     US2006271556A1  System and method for integration of medical i...
# 4899     US2006241978A1                   Electronic clinical chart system
#
#                                             first_claim  \
# 0     1 . A hand-held communication device comprisin...
# 1     1 . A device for use in the provision of a med...
# 2     1 . A method comprising: receiving, at an adap...
# 3     1 . A wireless communication device comprising...
# 4     1 . A customizable, portable identification an...
# ...                                                 ...
# 4895  1 . A system that facilitates using user-enter...
# 4896  1 . A healthcare decision support system for s...
# 4897  1 . A system for use in processing patient cli...
# 4898  1 . A system for integrating medical informati...
# 4899  1 . An electronic clinical chart system compri...
#
#                         sub_classes         sub_class topics  prob  \
# 0        ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 1         ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 2        ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 3       ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 4        ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
# ...                             ...               ...    ...   ...
# 4895  ['G16H50/20', 'G06F16/90344']  ['G16H', 'G06F']     32   1.0
# 4896     ['G16H10/60', 'G16Z99/00']  ['G16H', 'G16Z']     32   1.0
# 4897     ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     32   1.0
# 4898     ['G06F17/30', 'G16H70/00']  ['G06F', 'G16H']     32   1.0
# 4899     ['G16H50/70', 'G16B25/00']  ['G16H', 'G16B']     32   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [16]
# 1                      [16]
# 2                      [16]
# 3                      [16]
# 4                      [16]
# ...                     ...
# 4895                   [32]
# 4896                   [32]
# 4897                   [32]
# 4898                   [32]
# 4899                   [32]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50
# 0                          12
# 1                          12
# 2                          12
# 3                          12
# 4                          12
# ...                       ...
# 4895                       16
# 4896                       16
# 4897                       16
# 4898                       16
# 4899                       16
#
# [4900 rows x 14 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2008198033A1  Device for Communicating with a Voice-Disabled...
# 1        US2007118397A1                   Monitoring of medical conditions
# 2        US2012303331A1      Adapter between scale and vital signs monitor
# 3        US2012286959A1                           Automated Allergy Alerts
# 4        US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# ...                 ...                                                ...
# 4895     US2018068076A1  Systems and methods for semantic search and ex...
# 4896     US2007055543A1  Medical resource estimation and simulation system
# 4897     US2007055545A1  System and user interface for processing patie...
# 4898     US2006271556A1  System and method for integration of medical i...
# 4899     US2006241978A1                   Electronic clinical chart system
#
#                                             first_claim  \
# 0     1 . A hand-held communication device comprisin...
# 1     1 . A device for use in the provision of a med...
# 2     1 . A method comprising: receiving, at an adap...
# 3     1 . A wireless communication device comprising...
# 4     1 . A customizable, portable identification an...
# ...                                                 ...
# 4895  1 . A system that facilitates using user-enter...
# 4896  1 . A healthcare decision support system for s...
# 4897  1 . A system for use in processing patient cli...
# 4898  1 . A system for integrating medical informati...
# 4899  1 . An electronic clinical chart system compri...
#
#                         sub_classes         sub_class topics  prob  \
# 0        ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 1         ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 2        ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 3       ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 4        ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
# ...                             ...               ...    ...   ...
# 4895  ['G16H50/20', 'G06F16/90344']  ['G16H', 'G06F']     32   1.0
# 4896     ['G16H10/60', 'G16Z99/00']  ['G16H', 'G16Z']     32   1.0
# 4897     ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     32   1.0
# 4898     ['G06F17/30', 'G16H70/00']  ['G06F', 'G16H']     32   1.0
# 4899     ['G16H50/70', 'G16B25/00']  ['G16H', 'G16B']     32   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [16]
# 1                      [16]
# 2                      [16]
# 3                      [16]
# 4                      [16]
# ...                     ...
# 4895                   [32]
# 4896                   [32]
# 4897                   [32]
# 4898                   [32]
# 4899                   [32]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...              ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60        G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50  RFR
# 0                          12  6.0
# 1                          12  6.0
# 2                          12  6.0
# 3                          12  6.0
# 4                          12  6.0
# ...                       ...  ...
# 4895                       16  1.0
# 4896                       16  1.0
# 4897                       16  1.0
# 4898                       16  1.0
# 4899                       16  1.0
#
# [4900 rows x 15 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","first_claim","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_claim","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2020185105A1  Monitoring quality of pharmaceutical manufactu...
# 1       US2005097200A1  System and method for aggregating sensor devic...
# 2       US2009240193A1  Systems and methods for customizing delivery o...
# 3       US2009216460A1  Method to determine the degree and stability o...
# 4       US2014073892A1  Glucose predictor based on regularization netw...
# ..                 ...                                                ...
# 485     US2008198033A1  Device for Communicating with a Voice-Disabled...
# 486     US2007118397A1                   Monitoring of medical conditions
# 487     US2012303331A1      Adapter between scale and vital signs monitor
# 488     US2012286959A1                           Automated Allergy Alerts
# 489     US2012280049A1  Personal Health Record (PHR) ID card claiming ...
#
#                                            first_claim  \
# 0    We claim: 1 . A level meter measuring the qual...
# 1    1 . A method for network communication of sens...
# 2    1 . A method for processing sensor data from a...
# 3    1 . A method for determining a stability of a ...
# 4    1 . A glucose prediction device comprising: In...
# ..                                                 ...
# 485  1 . A hand-held communication device comprisin...
# 486  1 . A device for use in the provision of a med...
# 487  1 . A method comprising: receiving, at an adap...
# 488  1 . A wireless communication device comprising...
# 489  1 . A customizable, portable identification an...
#
#                        sub_classes         sub_class topics  prob  \
# 0    ['G16H40/20', 'G06Q10/06393']  ['G16H', 'G06Q']     20   1.0
# 1     ['G16H40/67', 'H04L65/1104']  ['G16H', 'H04L']     20   1.0
# 2       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     20   1.0
# 3       ['G16H20/17', 'G16H20/17']  ['G16H', 'G16H']     20   1.0
# 4       ['A61B5/145', 'G16H50/50']  ['A61B', 'G16H']     20   1.0
# ..                             ...               ...    ...   ...
# 485     ['G09B21/00', 'G16H40/63']  ['G09B', 'G16H']     16   1.0
# 486      ['G16H10/20', 'A61B5/24']  ['G16H', 'A61B']     16   1.0
# 487     ['G06F15/00', 'G16H40/63']  ['G06F', 'G16H']     16   1.0
# 488    ['G16H10/60', 'G08B21/043']  ['G16H', 'G08B']     16   1.0
# 489     ['G06K19/06', 'G16H10/65']  ['G06K', 'G16H']     16   1.0
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 485           US20230270344A1
# 486           US20230270344A1
# 487           US20230270344A1
# 488           US20230270344A1
# 489           US20230270344A1
#
#                                            query_claim  \
# 0    1. A continuous glucose monitoring system comp...
# 1    1. A continuous glucose monitoring system comp...
# 2    1. A continuous glucose monitoring system comp...
# 3    1. A continuous glucose monitoring system comp...
# 4    1. A continuous glucose monitoring system comp...
# ..                                                 ...
# 485  1. A monitoring device, comprising:\na band co...
# 486  1. A monitoring device, comprising:\na band co...
# 487  1. A monitoring device, comprising:\na band co...
# 488  1. A monitoring device, comprising:\na band co...
# 489  1. A monitoring device, comprising:\na band co...
#
#                                       query_codes_G16H     exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H40/67,G16H40/67
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H20/17,G16H20/17
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H50/50
# ..                                                 ...                  ...
# 485  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H40/63
# 486  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 487  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H40/63
# 488  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 489  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
#
#      count_exact_match_top50  count_exact_match_top5
# 0                         21                       4
# 1                         21                       4
# 2                         21                       4
# 3                         21                       4
# 4                         21                       4
# ..                       ...                     ...
# 485                       22                       2
# 486                       22                       2
# 487                       22                       2
# 488                       22                       2
# 489                       22                       2
#
# [490 rows x 13 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230001090A1']
filtered_df
# Out:
#      publication_number                                              title  \
# 3800     US2020185105A1  Monitoring quality of pharmaceutical manufactu...
# 3801     US2005097200A1  System and method for aggregating sensor devic...
# 3802     US2009240193A1  Systems and methods for customizing delivery o...
# 3803     US2009216460A1  Method to determine the degree and stability o...
# 3804     US2014073892A1  Glucose predictor based on regularization netw...
# 3805     US2018303389A1  Multi-function analyte monitor device and meth...
# 3806     US2009171589A1  Method, System and Computer Program Product fo...
# 3807     US2009156923A1             Meter Having Post-Meal Test-Time Alarm
# 3808     US2009105573A1  Medical device for predicting a user&#39;s fut...
# 3809     US2009105570A1    Analyte monitoring devices and methods therefor
# 3810     US2022059206A1  Medical device with dose helper functionality ...
# 3811     US2014066892A1  Insulin on board compensation for a closed-loo...
# 3812     US2014121635A1      Variable Rate Closed Loop Control and Methods
# 3813     US2021313036A1  Method and system for the safety, analysis and...
# 3814     US2021283332A1  Integrated user-defined input into a closed-lo...
# 3815     US2014142535A1  Pump controller that checks operational state ...
# 3816     US2021268199A1                    Insulin-dosage detection device
# 3817     US2021268174A1                Operating a portable medical device
# 3818     US2021241879A1            Activity monitoring systems and methods
# 3819     US2014200559A1  Daily periodic target-zone modulation in the m...
# 3820     US2020105422A1         Patient care system for a home environment
# 3821     US2008228041A1  Method and System for Remote Diagnosis and Sup...
# 3822     US2009125327A1  Systems And Methods For Voice Driven Health Da...
# 3823     US2009112626A1  Remote wireless monitoring, processing, and co...
# 3824     US2009103735A1                                 Telemedical system
# 3825     US2009088605A1  System and method for interference mitigation ...
# 3826     US2009088815A1  Proactive interactive limits override for impl...
# 3827     US2009076346A1  Tracking and Security for Adherent Patient Mon...
# 3828     US2009073991A1  Dynamic Pairing of Patients to Data Collection...
# 3829     US2009024002A1  Monitoring device for patient and monitoring s...
# 3830     US2008198033A1  Device for Communicating with a Voice-Disabled...
# 3831     US2007118397A1                   Monitoring of medical conditions
# 3832     US2012303331A1      Adapter between scale and vital signs monitor
# 3833     US2012286959A1                           Automated Allergy Alerts
# 3834     US2012280049A1  Personal Health Record (PHR) ID card claiming ...
# 3835     US2012265556A1  Method and device for remote controlled applic...
# 3836     US2012239705A1          Mobile information system for 12-lead ecg
# 3837     US2010217803A1  Interface device for communication between a m...
# 3838     US2010253509A1  Personal environmental monitoring method and s...
# 3839     US2010283601A1  Medication usage monitoring and reminding devi...
# 3840     US2020118654A1  System and Method for Optimizing Nuclear Imagi...
# 3841     US2021350893A1  Mobile terminal for controlling a medical prod...
# 3842     US2019108918A1  Remote diagnostic aid system, remote diagnosti...
# 3843     US2019043606A1     Patient-provider healthcare recommender system
# 3844     US2018358126A1     Skilled nursing facility patient triage system
# 3845     US2018357701A1  System and method for predictive recreational ...
# 3846     US2022059233A1  Assessing the functional performance of an ind...
# 3847     US2009076848A1  System and Method for Delivering Medical Exami...
# 3848     US2008215627A1                       Standardized health data hub
# 3849     US2007168464A1  System for Configuring a Data Exchange and For...
#
#                                             first_claim  \
# 3800  We claim: 1 . A level meter measuring the qual...
# 3801  1 . A method for network communication of sens...
# 3802  1 . A method for processing sensor data from a...
# 3803  1 . A method for determining a stability of a ...
# 3804  1 . A glucose prediction device comprising: In...
# 3805  1 . A device, comprising: a housing; a process...
# 3806  1 . A method for measuring blood glucose varia...
# 3807  1 . A meter adapted to determine an analyte co...
# 3808  1 . A medical device for predicting a user&#39...
# 3809  1 . An apparatus including a glucose meter, co...
# 3810  What is claimed is: 1 . A medical device for s...
# 3811  What is claimed is: 1 . An electronic device c...
# 3812  What is claimed is: 1 . A method, comprising: ...
# 3813  What is claimed is: 1 . A method for detecting...
# 3814  What is claimed is: 1 . A controller for use i...
# 3815  What is claimed is: 1 . A computer-implemented...
# 3816  What is claimed is: 1 . An insulin-dosage dete...
# 3817  What is claimed is: 1 . A method of operating ...
# 3818  What is claimed is: 1 . An activity monitoring...
# 3819  What is claimed is: 1 . A controller for an ar...
# 3820  1 . A patient care system, comprising: a deplo...
# 3821  1 . A system for remote diagnosis comprising: ...
# 3822  1 . A health data tracker system, the system c...
# 3823  1 . A system for remote wireless monitoring of...
# 3824  1 . A telemedical system comprising: a first a...
# 3825  1 . A wireless patient monitoring system compr...
# 3826  1 . A system comprising an external device inc...
# 3827  1 . A patient monitoring system, comprising: a...
# 3828  1 . A system for monitoring a patient, the sys...
# 3829  1 . A monitoring system comprising: a mobile c...
# 3830  1 . A hand-held communication device comprisin...
# 3831  1 . A device for use in the provision of a med...
# 3832  1 . A method comprising: receiving, at an adap...
# 3833  1 . A wireless communication device comprising...
# 3834  1 . A customizable, portable identification an...
# 3835  55 . A device useful for monitoring of patient...
# 3836  1 . A 12-leads electrocardiograph mobile infor...
# 3837  1 . A wireless interface device for communicat...
# 3838  1 . A portable personal environmental monitor,...
# 3839  1 ) A device for monitoring medication usage, ...
# 3840  1 . (canceled) 2 . A healthcare management sys...
# 3841  1 . A mobile controlling terminal comprising a...
# 3842  1 . A remote diagnostic aid system being a net...
# 3843  1 . A healthcare recommender system for matchi...
# 3844  1 . A system configured to facilitate computer...
# 3845  1 . A system for predictive recreational canna...
# 3846  1 . A system for assessing functional performa...
# 3847  1 . A system for delivering medical examinatio...
# 3848  1 . A method a managing health-related data co...
# 3849  1 . A system for automatically configuring a d...
#
#                           sub_classes         sub_class topics  prob  \
# 3800    ['G16H40/20', 'G06Q10/06393']  ['G16H', 'G06Q']     20   1.0
# 3801     ['G16H40/67', 'H04L65/1104']  ['G16H', 'H04L']     20   1.0
# 3802       ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     20   1.0
# 3803       ['G16H20/17', 'G16H20/17']  ['G16H', 'G16H']     20   1.0
# 3804       ['A61B5/145', 'G16H50/50']  ['A61B', 'G16H']     20   1.0
# 3805  ['G16H40/63', 'A61M2005/14208']  ['G16H', 'A61M']     20   1.0
# 3806       ['G06F19/00', 'G16H50/20']  ['G06F', 'G16H']     20   1.0
# 3807      ['G16H40/63', 'A61B5/7475']  ['G16H', 'A61B']     20   1.0
# 3808      ['G16H50/30', 'A61B5/7264']  ['G16H', 'A61B']     20   1.0
# 3809    ['G16H10/60', 'G01N33/48785']  ['G16H', 'G01N']     20   1.0
# 3810       ['G16H10/60', 'G16H20/10']  ['G16H', 'G16H']      8   1.0
# 3811       ['A61M5/172', 'G16H10/40']  ['A61M', 'G16H']      8   1.0
# 3812      ['G16H50/50', 'A61B5/6849']  ['G16H', 'A61B']      8   1.0
# 3813       ['A61M5/168', 'G16H50/20']  ['A61M', 'G16H']      8   1.0
# 3814       ['G16H20/10', 'G16H20/10']  ['G16H', 'G16H']      8   1.0
# 3815       ['G16H20/17', 'A61M5/142']  ['G16H', 'A61M']      8   1.0
# 3816     ['G16H20/17', 'A61M5/31546']  ['G16H', 'A61M']      8   1.0
# 3817  ['G16H20/17', 'A61M2005/31518']  ['G16H', 'A61M']      8   1.0
# 3818      ['G16H10/60', 'A61B5/1118']  ['G16H', 'A61B']      8   1.0
# 3835  1. A continuous glucose monitoring system comp...
# 3836  1. A continuous glucose monitoring system comp...
# 3837  1. A continuous glucose monitoring system comp...
# 3838  1. A continuous glucose monitoring system comp...
# 3839  1. A continuous glucose monitoring system comp...
# 3840  1. A continuous glucose monitoring system comp...
# 3841  1. A continuous glucose monitoring system comp...
# 3842  1. A continuous glucose monitoring system comp...
# 3843  1. A continuous glucose monitoring system comp...
# 3844  1. A continuous glucose monitoring system comp...
# 3845  1. A continuous glucose monitoring system comp...
# 3846  1. A continuous glucose monitoring system comp...
# 3847  1. A continuous glucose monitoring system comp...
# 3848  1. A continuous glucose monitoring system comp...
# 3849  1. A continuous glucose monitoring system comp...
#
#      query_predicted_topics  \
# 3800                   [20]
# 3801                   [20]
# 3802                   [20]
# 3803                   [20]
# 3804                   [20]
# 3805                   [20]
# 3806                   [20]
# 3807                   [20]
# 3808                   [20]
# 3809                   [20]
# 3810                    [8]
# 3811                    [8]
# 3812                    [8]
# 3813                    [8]
# 3814                    [8]
# 3815                    [8]
# 3816                    [8]
# 3817                    [8]
# 3818                    [8]
# 3819                    [8]
# 3820                   [39]
# 3821                   [39]
# 3822                   [39]
# 3823                   [39]
# 3824                   [39]
# 3825                   [39]
# 3826                   [39]
# 3827                   [39]
# 3828                   [39]
# 3829                   [39]
# 3830                   [16]
# 3831                   [16]
# 3832                   [16]
# 3833                   [16]
# 3834                   [16]
# 3835                   [16]
# 3836                   [16]
# 3837                   [16]
# 3838                   [16]
# 3839                   [16]
# 3840                   [24]
# 3841                   [24]
# 3842                   [24]
# 3843                   [24]
# 3844                   [24]
# 3845                   [24]
# 3846                   [24]
# 3847                   [24]
# 3848                   [24]
# 3849                   [24]
#
#                                        query_codes_G16H     exact_match_code  \
# 3800  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3801  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3802  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H40/67,G16H40/67
# 3803  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H20/17,G16H20/17
# 3804  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H50/50
# 3805  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3806  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3807  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3808  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3809  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3810  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/10
# 3811  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3812  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H50/50
# 3813  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3814  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H20/10,G16H20/10
# 3815  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3816  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3817  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3818  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3819  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3820  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3821  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3822  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3823  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3824  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3825  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3826  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3827  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3828  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3829  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3830  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3831  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3832  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3833  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3834  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3835  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3836  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3837  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H40/67,G16H40/67
# 3838  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3839  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3840  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3841  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3842  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H20/00,G16H20/00
# 3843  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3844  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3845  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3846  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3847  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3848  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3849  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
#
#       count_exact_match_top50  RFR
# 3800                       21  2.0
# 3801                       21  2.0
# 3802                       21  2.0
# 3803                       21  2.0
# 3804                       21  2.0
# 3805                       21  2.0
# 3806                       21  2.0
# 3807                       21  2.0
# 3808                       21  2.0
# 3809                       21  2.0
# 3810                       21  2.0
# 3811                       21  2.0
# 3812                       21  2.0
# 3813                       21  2.0
# 3814                       21  2.0
# 3815                       21  2.0
# 3816                       21  2.0
# 3817                       21  2.0
# 3818                       21  2.0
# 3819                       21  2.0
# 3820                       21  2.0
# 3821                       21  2.0
# 3822                       21  2.0
# 3823                       21  2.0
# 3824                       21  2.0
# 3825                       21  2.0
# 3826                       21  2.0
# 3827                       21  2.0
# 3828                       21  2.0
# 3829                       21  2.0
# 3830                       21  2.0
# 3831                       21  2.0
# 3832                       21  2.0
# 3833                       21  2.0
# 3834                       21  2.0
# 3835                       21  2.0
# 3836                       21  2.0
# 3837                       21  2.0
# 3838                       21  2.0
# 3839                       21  2.0
# 3840                       21  2.0
# 3841                       21  2.0
# 3842                       21  2.0
# 3843                       21  2.0
# 3844                       21  2.0
# 3845                       21  2.0
# 3846                       21  2.0
# 3847                       21  2.0
# 3848                       21  2.0
# 3849                       21  2.0

# %%
result_df.to_csv('BERTopic-without-Preprocessing.Claim.csv', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     4.0
# 1            US20230001263A1                     1.0
# 2            US20230005591A1                     0.0
# 3            US20230005611A1                     1.0
# 4            US20230009812A1                     0.0
# ..                       ...                     ...
# 93           US20230255518A1                     1.0
# 94           US20230259481A1                     2.0
# 95           US20230260617A1                     1.0
# 96           US20230264029A1                     1.0
# 97           US20230270344A1                     2.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 1.4489795918367347

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                     21.0
# 1            US20230001263A1                     10.0
# 2            US20230005591A1                      6.0
# 3            US20230005611A1                      5.0
# 4            US20230009812A1                      4.0
# ..                       ...                      ...
# 93           US20230255518A1                      7.0
# 94           US20230259481A1                     13.0
# 95           US20230260617A1                     11.0
# 96           US20230264029A1                      2.0
# 97           US20230270344A1                     22.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 11.510204081632653

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1   2.0
# 1            US20230001263A1   4.0
# 2            US20230005591A1  17.0
# 3            US20230005611A1   2.0
# 4            US20230009812A1  16.0
# ..                       ...   ...
# 93           US20230255518A1   4.0
# 94           US20230259481A1   3.0
# 95           US20230260617A1   5.0
# 96           US20230264029A1   4.0
# 97           US20230270344A1   1.0
#
# [98 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 5.270833333333333
