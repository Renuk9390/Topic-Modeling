# %%
import pandas as pd

df_Abstract = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_Abstract.head()

len(df_Abstract)
# Out:
# 31306

# %%
df_Abstract.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
first_record = df_Abstract['abstract'][1]
first_record
# Out:
# 'A web-based interface enables medical personnel to remotely monitor medical devices. A monitoring system records operational data and alarms from the medical devices in a file. However, since network connections between the medical devices and the monitoring system are intermittent, the file does not contain a contiguous stream of data for each medical device. The file pauses recording during gaps in network connectivity. The system displays current data, as well as a list of alarms. If medical personnel wish to view more detail about an earlier time or one of the alarms, the system calculates where in the file the medical device data was recorded. This calculation accounts for the discontiguous nature of the data. The system uses times the network connection is made and broken to calculate an index into the file that corresponds to the time of the user-selected alarm.'

# %%
import torch
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer



# Load the Sentence Transformers model
sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
#sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)

# Adjust UMAP hyperparameters
umap_model = UMAP(n_neighbors=3, 
                  n_components=3, 
                  min_dist=0.05, 
                  metric='cosine', 
                  random_state=100)  # Utilize all available CPU cores for UMAP preprocessing

# Adjust HDBSCAN hyperparameters
hdbscan_model = HDBSCAN( min_cluster_size=80,
                        min_samples=40, 
                        metric='euclidean', 
                        cluster_selection_method='eom', 
                        prediction_data=True)

# Adjust CountVectorizer hyperparameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=10, max_df=0.5)


# c-TF-IDF
#ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

# Run Model
topic_model = BERTopic(umap_model=umap_model,
                       embedding_model=sentence_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       ctfidf_model=ctfidf_model,
                       verbose=True)

# Replace 'df['first_claim']' with your data source for the first_claim column
topics, probabilities = topic_model.fit_transform(df_Abstract['abstract'])
# Out:
# Batches:   0%|          | 0/979 [00:00<?, ?it/s]
# 2023-10-03 19:20:04,003 - BERTopic - Transformed documents to Embeddings
# 2023-10-03 19:20:12,451 - BERTopic - Reduced dimensionality
# 2023-10-03 19:20:14,190 - BERTopic - Clustered reduced embeddings

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document": df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})

documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence_c_nmpi = coherence_model.get_coherence()
print("c_npmi is: ",coherence_c_nmpi)
# Out:
# c_npmi is:  -0.1921969735818733

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_CV= coherence_model.get_coherence()
print("C_V is: ", coherence_CV)
# Out:
# C_V is:  0.3445794195598435

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_Abstract['abstract'],
                          "ID": range(len(df_Abstract['abstract'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence_u_mass= coherence_model.get_coherence()
print("u_mass is: ", coherence_u_mass)
# Out:
# u_mass is:  -0.6258166391734031

# %%
 topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  17053                        -1_sleep_anatomical_3d_skin
# 1       0   1593  0_disclosed are_the disclosure_disclosure prov...
# 2       1   1589  1_invention relates_invention relates to_prese...
# 3       2    862   2_pharmacy_dispensing_the prescription_container
# 4       3    758               3_ecg_cardiac_blood pressure_the ecg
# 5       4    576  4_the medical image_image processing_medical i...
# 6       5    525        5_exercise_fitness_the exercise_an exercise
# 7       6    482  6_certain embodiments_invention provide_presen...
# 8       7    391      7_glucose_insulin_blood glucose_glucose level
# 9       8    364  8_ultrasound_an ultrasound_the ultrasound_ultr...
# 10      9    364                   9_food_nutritional_meal_the food
# 11     10    299  10_medical images_deep_deep learning_the medic...
# 12     11    272  11_referral_medical service_service provider_i...
# 13     12    265               12_cancer_expression_biomarkers_gene
# 14     13    230  13_and health care_adherence_health and_health...
# 15     14    222  14_concepts_treatment option_the medical condi...
# 16     15    210  15_information processing_processing apparatus...
# 17     16    208               16_card_encrypted_the portable_drive
# 18     17    199  17_the care_personal health_care management_pr...
# 19     18    191  18_medical equipment_information management_th...
# 20     19    186             19_infusion_pump_the fluid_an infusion
# 21     20    186           20_provided is_is method_is system_mixed
# 22     21    184      21_chronic_knowledge graph_unstructured_class
# 23     22    176  22_the apparatus includes_apparatus is provide...
# 24     23    168             23_vessel_blood flow_vascular_coronary
# 25     24    165  24_display image_guideline_subgroup_display pr...
# 26     25    162       25_radiation_radiotherapy_beam_defibrillator
# 27     26    159     26_respiratory_respiration_pulmonary_breathing
# 28     27    158  27_present invention relates_invention relates...
# 29     28    157  28_consumer_hcp_interrogation_the healthcare p...
# 30     29    155  29_wearable device_the wearable_the wearable d...
# 31     30    148     30_referral_the referral_service provider_host
# 32     31    144  31_clinical trial_trials_the clinical trial_cl...
# 33     32    140  32_clock_alarm_medical monitoring_monitoring d...
# 34     33    132                       33_dental_teeth_3d_appliance
# 35     34    132    34_vital sign_sign_patient monitoring_the vital
# 36     35    128  35_wellness_and wellness_health and_psychological
# 37     36    127          36_glucose_analyte_blood glucose_diabetes
# 38     37    111                    37_the surgical_hub_robotic_arm
# 39     38    110            38_stress_emotion_pairing_personal data
# 40     39    107   39_electronic processor_of images_radiology_pain
# 41     40    102               40_stimulation_gui_the gui_electrode
# 42     41    100              41_alarm_an alarm_the alarm_the alert
# 43     42     95  42_orders_health profile_health care service_note
# 44     43     94  43_processing circuitry_the processing circuit...
# 45     44     93  44_wearable device_the wearable_the wearable d...
# 46     45     91  45_guideline_clinical information_coding_timeline
# 47     46     90                        46_cancer_acid_genetic_lung
# 48     47     89              47_style_guideline_sensory_anatomical
# 49     48     88  48_anatomy_surgical procedure_surgeon_the surg...
# 50     49     88        49_mr_resonance_magnetic resonance_magnetic
# 51     50     87  50_one medical device_relay_least one medical_...
# 52     51     86  51_rfid_rfid tag_collection device_radio frequ...
# 53     52     85  52_physiological parameters_physiological para...
# 54     53     84  53_dashboard_stage_disease progression_medical...
# 55     54     83  54_emotion_biological information_acquisition ...
# 56     55     82               55_dicom_archiving_picture_radiology
# 57     56     81             56_rfid_inventory_articles_the product
#
#                                        Representation  \
# 0   [sleep, anatomical, 3d, skin, pump, radiation,...
# 1   [disclosed are, the disclosure, disclosure pro...
# 2   [invention relates, invention relates to, pres...
# 3   [pharmacy, dispensing, the prescription, conta...
# 4   [ecg, cardiac, blood pressure, the ecg, pulse,...
# 5   [the medical image, image processing, medical ...
# 6   [exercise, fitness, the exercise, an exercise,...
# 7   [certain embodiments, invention provide, prese...
# 8   [glucose, insulin, blood glucose, glucose leve...
# 9   [ultrasound, an ultrasound, the ultrasound, ul...
# 10  [food, nutritional, meal, the food, diet, of f...
# 11  [medical images, deep, deep learning, the medi...
# 12  [referral, medical service, service provider, ...
# 13  [cancer, expression, biomarkers, gene, immune,...
# 14  [and health care, adherence, health and, healt...
# 15  [concepts, treatment option, the medical condi...
# 16  [information processing, processing apparatus,...
# 17  [card, encrypted, the portable, drive, persona...
# 18  [the care, personal health, care management, p...
# 19  [medical equipment, information management, th...
# 20  [infusion, pump, the fluid, an infusion, injec...
# 21  [provided is, is method, is system, mixed, is ...
# 22  [chronic, knowledge graph, unstructured, class...
# 23  [the apparatus includes, apparatus is provided...
# 24  [vessel, blood flow, vascular, coronary, blood...
# 25  [display image, guideline, subgroup, display p...
# 26  [radiation, radiotherapy, beam, defibrillator,...
# 27  [respiratory, respiration, pulmonary, breathin...
# 28  [present invention relates, invention relates,...
# 29  [consumer, hcp, interrogation, the healthcare ...
# 30  [wearable device, the wearable, the wearable d...
# 31  [referral, the referral, service provider, hos...
# 32  [clinical trial, trials, the clinical trial, c...
# 33  [clock, alarm, medical monitoring, monitoring ...
# 34  [dental, teeth, 3d, appliance, implant, 3d mod...
# 35  [vital sign, sign, patient monitoring, the vit...
# 36  [wellness, and wellness, health and, psycholog...
# 37  [glucose, analyte, blood glucose, diabetes, in...
# 38  [the surgical, hub, robotic, arm, force, surgi...
# 39  [stress, emotion, pairing, personal data, call...
# 40  [electronic processor, of images, radiology, p...
# 41  [stimulation, gui, the gui, electrode, electro...
# 42  [alarm, an alarm, the alarm, the alert, gas, t...
# 43  [orders, health profile, health care service, ...
# 44  [processing circuitry, the processing circuitr...
# 45  [wearable device, the wearable, the wearable d...
# 46  [guideline, clinical information, coding, time...
# 47  [cancer, acid, genetic, lung, concentration, g...
# 48  [style, guideline, sensory, anatomical, manage...
# 49  [anatomy, surgical procedure, surgeon, the sur...
# 50  [mr, resonance, magnetic resonance, magnetic, ...
# 51  [one medical device, relay, least one medical,...
# 52  [rfid, rfid tag, collection device, radio freq...
# 53  [physiological parameters, physiological param...
# 54  [dashboard, stage, disease progression, medica...
# 55  [emotion, biological information, acquisition ...
# 56  [dicom, archiving, picture, radiology, and com...
# 57  [rfid, inventory, articles, the product, artic...
#
#                                   Representative_Docs
# 0   [The invention relates to a method and a devic...
# 1   [Disclosed are methods and apparatus for deter...
# 2   [The invention relates to a telepresence syste...
# 3   [Automated pill dispensing apparatus for filin...
# 4   [A device for graphically reconstructing infor...
# 5   [An image management apparatus capable of rece...
# 6   [A multiple exercise activity recording system...
# 7   [Certain embodiments of the present invention ...
# 8   [Techniques and devices for determining and ge...
# 9   [Provided are an ultrasound diagnosis apparatu...
# 10  [A method for assisting a person create a reco...
# 11  [The invention relates to a medical image data...
# 12  [Methods, computer systems, and computer-reada...
# 13  [The present invention relates to methods, sys...
# 14  [A method of managing health and health-care d...
# 15  [A system and method for generating statements...
# 16  [The present invention discloses an informatio...
# 17  [A medical personal data card system utilizes ...
# 18  [Systems and methods for managing the care of ...
# 19  [A medical information system processes inform...
# 20  [The current subject matter describes generati...
# 21  [Provided is a system and method for educating...
# 22  [A medical triage assistance system helps to s...
# 23  [An apparatus is provided for retrieving infor...
# 24  [A method for acquiring a blood flow volume an...
# 25  [A system for use by a portable processing dev...
# 26  [Generating a three-dimensional radiation dose...
# 27  [A heart failure patient management system inc...
# 28  [The present invention relates to a method and...
# 29  [Apparatuses, computer media, and methods for ...
# 30  [A system and method including a disposable we...
# 31  [A healthcare referral system and methods for ...
# 32  [An automated method is provided for generatin...
# 33  [A system for providing feedback to an individ...
# 34  [Methods and apparatuses for 3D imaging (inclu...
# 35  [A vital sign monitoring system that can be us...
# 36  [A system and computer program product for ana...
# 37  [An internal temperature sensor for measuring ...
# 38  [Various surgical hubs are disclosed. A surgic...
# 39  [In particular embodiments, a method includes ...
# 40  [Methods and systems for automatically determi...
# 41  [Systems and methods for adaptively controllin...
# 42  [A controlling device ( 110 ) is configured fo...
# 43  [An electronic physician&#39;s orders system t...
# 44  [According to one embodiment, a medical inform...
# 45  [A wearable device to assist a sufferer of cog...
# 46  [User interfaces for proactive and interactive...
# 47  [According to the method of evaluating prostat...
# 48  [This disclosure describes systems, devices, a...
# 49  [A surgical planning system for use in surgica...
# 50  [In a method and apparatus for identifying an ...
# 51  [A remote monitoring system for monitoring a p...
# 52  [One aspect of the disclosure is to provide a ...
# 53  [A health monitoring method, including: acquir...
# 54  [A computerized system and method for planning...
# 55  [An emotion estimating system includes a learn...
# 56  [A method for transferring and rendering a med...
# 57  [An automatic data collection system tracks me...

# %%
#adding topics and probs for eachdoc in dataset
df_Abstract['topics'] = topics
df_Abstract['prob'] = probabilities
df_Abstract_topic=df_Abstract[["publication_number","title","abstract","sub_classes","sub_class","topics","prob"]]
df_Abstract_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                                 abstract  \
# 0      A reality interactive responding system, compr...
# 1      A web-based interface enables medical personne...
# 2      A facility for predicting patient outcomes on ...
# 3      Through a physician&#39;s portal, a platform c...
# 4      Infusion systems, infusion devices, and relate...
# ...                                                  ...
# 31301  A user authentication system performs user rec...
# 31302  A diagnosis support apparatus for diagnosis of...
# 31303  A patient appointment schedule is generated fo...
# 31304  The present invention relates to a method for ...
# 31305  A method including a healthcare server of a he...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      -1  0.000000
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']      32  1.000000
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      -1  0.000000
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']      -1  0.000000
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      -1  0.000000
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']      51  1.000000
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']      -1  0.000000
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      -1  0.000000
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']       1  0.893985
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']      28  1.000000
#
# [31306 rows x 7 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_Abstract_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_Abstract_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_Abstract_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %%
test1 = df_Abstract_test.loc[0, 'abstract']
test1
# Out:
# 'A physiological sensor has light emitting sources, each activated by addressing at least one row and at least one column of an electrical grid. The light emitting sources are capable of transmitting light of multiple wavelengths and a detector is responsive to the transmitted light after attenuation by body tissue.'

# %%
import numpy as np 

# Find topics
num_of_topics = 5
similar_topics, similarity = topic_model.find_topics(test1, top_n=num_of_topics); 

# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')

for idx, topic_idx in enumerate(similar_topics):
    topic = topic_model.get_topic(topic_idx)
    keywords = ' '.join(str(keyword) for keyword in topic[0])
    print(f"Topic {idx+1}: {keywords}")
# Out:
# The top 5 similar topics are [34, 44, 3, 41, 32], and the similarities are [0.67 0.66 0.64 0.64 0.64]
# Topic 1: vital sign 0.05143725764421457
# Topic 2: wearable device 0.041425610176207606
# Topic 3: ecg 0.04761030111462619
# Topic 4: alarm 0.1034350669712211
# Topic 5: clock 0.027062087341974385

# %%
filter_topics_filter = df_Abstract_topic[df_Abstract_topic['topics'] == 43]
filter_topics_filter = filter_topics_filter.sort_values('prob', ascending=False)
filter_topics_filter
# Out:
#       publication_number                                              title  \
# 30        US2020097651A1  Systems and methods to achieve robustness and ...
# 18309     US2022076842A1   Medical information processing system and method
# 22830     US2010106518A1  System And Method For Providing Optimized Pati...
# 20695     US2013290010A1  Medication service terminal and method of moni...
# 19467     US2018330822A1  Medical information processing device and medi...
# ...                  ...                                                ...
# 4419      US2004034289A1  System for monitoring health, wellness and fit...
# 23621     US2010332443A1                     Cyclical Behavior Modification
# 21998     US2014243684A1  System and method for creating, processing, an...
# 24561     US2022248965A1                   Self-calibrating glucose monitor
# 18274     US2022071567A1  Information processing apparatus, information ...
#
#                                                 abstract  \
# 30     According to some embodiments, a system, metho...
# 18309  According to one embodiment, a medical informa...
# 22830  In particular embodiments, method, apparatus a...
# 20695  The inventive concept herein relates to medica...
# 19467  A medical information processing apparatus acc...
# ...                                                  ...
# 4419   An apparatus for monitoring human status param...
# 23621  Embodiments treat cyclical behaviors based on ...
# 21998  A system and method for creating and processin...
# 24561  A medical system including processing circuitr...
# 18274  A controller comprising at least one processor...
#
#                           sub_classes         sub_class  topics      prob
# 30      ['G16H40/63', 'G06F2221/034']  ['G16H', 'G06F']      43  1.000000
# 18309      ['G16H50/70', 'G06F18/23']  ['G16H', 'G06F']      43  1.000000
# 22830      ['G16H40/20', 'G16H20/40']  ['G16H', 'G16H']      43  1.000000
# 20695      ['G16H20/10', 'G16H70/40']  ['G16H', 'G16H']      43  1.000000
# 19467      ['G16H50/20', 'G16H50/70']  ['G16H', 'G16H']      43  1.000000
# ...                               ...               ...     ...       ...
# 4419       ['G16H40/67', 'A61B5/369']  ['G16H', 'A61B']      43  0.963390
# 23621      ['G16H20/70', 'G16H40/67']  ['G16H', 'G16H']      43  0.950257
# 21998       ['A61B5/00', 'G16H30/20']  ['A61B', 'G16H']      43  0.948861
# 24561     ['A61B5/1455', 'G16H40/40']  ['A61B', 'G16H']      43  0.940127
# 18274  ['G16H10/60', 'A61B2560/0242']  ['G16H', 'A61B']      43  0.934484
#
# [94 rows x 7 columns]

# %%
# Define the range of topic IDs you want to retrieve documents for
selected_topic_range =[43, 5, 49, 42, 16]  # Replace with your desired range of topic IDs

# Create an empty DataFrame to store the top 10 documents
top_10_documents_test1 = pd.DataFrame()

# Iterate through the selected topic IDs
for selected_topic_id in selected_topic_range:
    # Filter the dataset based on the current topic ID
    filtered_df = df_Abstract_topic[df_Abstract_topic['topics'] == selected_topic_id]
    
    # Sort the filtered dataset by similarity scores in descending order
    sorted_df = filtered_df.sort_values(by='prob', ascending=False)
    
    # Retrieve the top 10 documents for the current topic
    top_10_for_topic = sorted_df.head(10)
    
    # Append the top 10 documents for the current topic to the result DataFrame
    top_10_documents_test1 = top_10_documents_test1.append(top_10_for_topic)

# Display the top 10 documents for all selected topics
top_10_documents_test1
# Out:
#       publication_number                                              title  \
# 30        US2020097651A1  Systems and methods to achieve robustness and ...
# 18309     US2022076842A1   Medical information processing system and method
# 22830     US2010106518A1  System And Method For Providing Optimized Pati...
# 20695     US2013290010A1  Medication service terminal and method of moni...
# 19467     US2018330822A1  Medical information processing device and medi...
# 19406     US2018310885A1  Method of managing disease, and apparatuses op...
# 19181     US2018264258A1      Detection of noise signals in cardiac signals
# 18950     US2022157412A1                  Clinical trial matching apparatus
# 18776     US2022130554A1  Method for an ai powered automated analyzer fo...
# 18739     US2022130556A1  Health management apparatus and health managem...
# 31286     US2016250518A1  Online coaching method enabling online communi...
# 4346      US2004010420A1  System for developing implementing and monitor...
# 5038      US2011179068A1  Computer implemented process for creating an o...
# 22369     US2009292178A1  System and method of monitoring users during a...
# 22581     US2010035726A1  Cardio-fitness station with virtual-reality ca...
# 22794     US2010092935A1       Web-based physical fitness monitoring system
# 22851     US2010112536A1                   Group coaching system and method
# 8287      US2005046576A1  Adjustable training system for athletics and p...
# 8372      US2005076301A1  Apparatus, system, and method for managing fit...
# 4409      US2004029684A1  Anatomically-based personal fitness advisor me...
# 147       US2020107725A1  Systems and methods for generating an elastogr...
# 24074     US2022196770A1  Method for executing at least one application ...
# 23302     US2010237863A1  Method and device for controlling acquisition ...
# 21635     US2014163892A1  Method for determining if an implantable medic...
# 20476     US2019150781A1  Spectral bin un-aliasing for reduced field-of-...
# 20384     US2019139274A1  Method and apparatus for generating magnetic r...
# 20306     US2019117073A1  Global Longitudinal Strain from Cine Magnetic ...
# 20127     US2019087688A1  Magnetic resonance image analysis method and m...
# 20109     US2019086501A1  Method and magnetic resonance apparatus for im...
# 20063     US2019076049A1  Magnetic resonance imaging device, magnetic re...
# 51        US2020097910A1  A system for generating a record of community-...
# 21714     US2014180718A1                   Remote access management systems
# 21468     US2014122129A1  System and Method for Automated Patient Histor...
# 18984     US2022157420A1                                  Integrated Report
# 18220     US2022068447A1         Personal care management system and method
# 17970     US2022036762A1             System for exercise program management
# 17124     US2009150439A1             Common extensible data exchange format
# 16792     US2009070147A1  Personalized information discovery and present...
# 16721     US2009048872A1             Mental health expert system and method
# 16050     US2008189133A1                      Health care education systems
# 23768     US2011040578A1  Device, system and method of displaying and im...
# 8996      US2006036471A1  Computerized automation of physician-patient i...
# 8930      US2006010012A1                Portable medical information device
# 8822      US2005251422A1  System and method for near real-time coding of...
# 8671      US2005197859A1  Portable electronic data storage and retreival...
# 22557     US2010023349A1  Computer software program for mental health pr...
# 8519      US2005128091A1  Apparatus and method for storing, transporting...
# 8460      US2005108059A1                        Portable health data system
# 8453      US2005108056A1  Patient identification card and method for HIP...
# 16684     US2009039153A1  Deactivatable/reactivatable smart card recordi...
#
#                                                 abstract  \
# 30     According to some embodiments, a system, metho...
# 18309  According to one embodiment, a medical informa...
# 22830  In particular embodiments, method, apparatus a...
# 20695  The inventive concept herein relates to medica...
# 19467  A medical information processing apparatus acc...
# 19406  A disease management method and apparatuses pe...
# 19181  Medical device systems include processing circ...
# 18950  A clinical trial matching apparatus according ...
# 18776  Method for an AI Powered Automated Analyzer fo...
# 18739  A health management apparatus according to an ...
# 31286  An online coaching method includes: acquiring ...
# 4346   The method and system includes an integrated s...
# 5038   A total fitness system uses a virtual trainer ...
# 22369  A game system is disclosed and may include an ...
# 22581  In one embodiment, a stationary exercise stati...
# 22794  A computer-implemented system and method for m...
# 22851  Group coaching system, comprising at least a f...
# 8287   A system and method of monitoring the position...
# 8372   An apparatus, system and method manage fitness...
# 4409   An Anatomically-based Personal Fitness Advisor...
# 147    Methods, systems, and devices for mechanically...
# 24074  In a method for executing at least one applica...
# 23302  In a method and a device to control the workfl...
# 21635  A method for determining if an implantable med...
# 20476  A magnetic resonance imaging (MRI) system can ...
# 20384  A magnetic resonance imaging method and a magn...
# 20306  A method for computing global longitudinal str...
# 20127  The present disclosure provides a magnetic res...
# 20109  In a method and magnetic resonance (MR) appara...
# 20063  Accuracy degradation due to a signal loss is r...
# 51     A system for enabling the delivery of healthca...
# 21714  Computer systems and methods relating to opera...
# 21468  A system of automated patient history intake i...
# 18984  Systems, methods, and storage media useful in ...
# 18220  A system and method are provided to coordinate...
# 17970  A computerized system for health management is...
# 17124  A medical data system wherein data is exchange...
# 16792  A personalized health information discovery an...
# 16721  An electronic solution which may be integrated...
# 16050  A computer program product for managing health...
# 23768  A method, system and device for storing and di...
# 8996   Systems and methods are provided for automatin...
# 8930   The present invention provides a system and me...
# 8822   A method for real time communications between ...
# 8671   Methods and apparatus for providing and using ...
# 22557  A computer software program that will allow me...
# 8519   A method and an apparatus for carrying medical...
# 8460   A portable health storage device to be carried...
# 8453   A HIPAA compliant for patient check-in at an o...
# 16684  An automated system with one or more memory-ca...
#
#                          sub_classes         sub_class  topics  prob
# 30     ['G16H40/63', 'G06F2221/034']  ['G16H', 'G06F']      43   1.0
# 18309     ['G16H50/70', 'G06F18/23']  ['G16H', 'G06F']      43   1.0
# 22830     ['G16H40/20', 'G16H20/40']  ['G16H', 'G16H']      43   1.0
# 20695     ['G16H20/10', 'G16H70/40']  ['G16H', 'G16H']      43   1.0
# 19467     ['G16H50/20', 'G16H50/70']  ['G16H', 'G16H']      43   1.0
# 19406      ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']      43   1.0
# 19181     ['A61N1/365', 'G16H50/20']  ['A61N', 'G16H']      43   1.0
# 18950     ['G16B40/00', 'G16H70/40']  ['G16B', 'G16H']      43   1.0
# 18776     ['G16H15/00', 'G16H50/70']  ['G16H', 'G16H']      43   1.0
# 18739    ['G16H50/80', 'A61B5/7275']  ['G16H', 'A61B']      43   1.0
# 31286     ['A63B24/00', 'G16H20/30']  ['A63B', 'G16H']       5   1.0
# 4346      ['G16H50/20', 'G16H40/67']  ['G16H', 'G16H']       5   1.0
# 5038      ['G06F17/30', 'G16H10/60']  ['G06F', 'G16H']       5   1.0
# 22369     ['G16H20/30', 'A63B69/36']  ['G16H', 'A63B']       5   1.0
# 22581  ['G16H20/30', 'A63B2024/009']  ['G16H', 'A63B']       5   1.0
# 22794      ['G16H40/67', 'G09B7/02']  ['G16H', 'G09B']       5   1.0
# 22851     ['G06F19/00', 'G16H20/30']  ['G06F', 'G16H']       5   1.0
# 8287      ['G06F19/00', 'G16H20/30']  ['G06F', 'G16H']       5   1.0
# 8372      ['G06F17/00', 'G16H30/20']  ['G06F', 'G16H']       5   1.0
# 4409      ['G06F19/00', 'G16H20/60']  ['G06F', 'G16H']       5   1.0
# 147        ['A61B8/08', 'G16H30/40']  ['A61B', 'G16H']      49   1.0
# 24074     ['G01R33/54', 'G16H40/63']  ['G01R', 'G16H']      49   1.0
# 23302    ['G16H30/40', 'G01R33/546']  ['G16H', 'G01R']      49   1.0
# 21635     ['G01R33/20', 'G16H40/63']  ['G01R', 'G16H']      49   1.0
# 20476    ['G01R33/565', 'G16H50/70']  ['G01R', 'G16H']      49   1.0
# 20384    ['G01R33/561', 'G16H30/40']  ['G01R', 'G16H']      49   1.0
# 20306      ['G06T7/13', 'G16H30/40']  ['G06T', 'G16H']      49   1.0
# 20127     ['G06T7/168', 'G16H50/20']  ['G06T', 'G16H']      49   1.0
# 20109     ['G01R33/56', 'G16H30/40']  ['G01R', 'G16H']      49   1.0
# 20063     ['G01R33/56', 'G16H30/40']  ['G01R', 'G16H']      49   1.0
# 51        ['G16H80/00', 'G16H40/63']  ['G16H', 'G16H']      42   1.0
# 21714     ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']      42   1.0
# 21468     ['G16H10/60', 'G06Q10/06']  ['G16H', 'G06Q']      42   1.0
# 18984    ['G06F40/186', 'G16H50/20']  ['G06F', 'G16H']      42   1.0
# 18220     ['G16H20/10', 'G16H80/00']  ['G16H', 'G16H']      42   1.0
# 17970     ['G06Q20/08', 'G16H20/60']  ['G06Q', 'G16H']      42   1.0
# 17124     ['G06F17/30', 'G16H10/60']  ['G06F', 'G16H']      42   1.0
# 16792     ['G06Q50/00', 'G16H20/00']  ['G06Q', 'G16H']      42   1.0
# 16721     ['G06Q50/00', 'G16H20/70']  ['G06Q', 'G16H']      42   1.0
# 16050     ['G16H50/30', 'G06Q10/06']  ['G16H', 'G06Q']      42   1.0
# 23768     ['G06Q10/00', 'G16H10/65']  ['G06Q', 'G16H']      16   1.0
# 8996      ['G16H40/20', 'G16H40/20']  ['G16H', 'G16H']      16   1.0
# 8930      ['G16H10/60', 'G16H10/65']  ['G16H', 'G16H']      16   1.0
# 8822      ['G16H10/60', 'G06Q10/10']  ['G16H', 'G06Q']      16   1.0
# 8671      ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']      16   1.0
# 22557     ['G16H20/70', 'G06Q10/10']  ['G16H', 'G06Q']      16   1.0
# 8519      ['G08B25/01', 'G16H10/60']  ['G08B', 'G16H']      16   1.0
# 8460      ['G16H40/67', 'G16H10/65']  ['G16H', 'G16H']      16   1.0
# 8453              [nan, 'G16H15/00']      ['', 'G16H']      16   1.0
# 16684     ['G16H10/60', 'G16H40/63']  ['G16H', 'G16H']      16   1.0

# %%
num_records = top_10_documents_test1.shape[0]
num_records
# Out:
# 50

# %%
# # Define a custom function to format the text
# def format_text(text):
#     # Remove brackets and single quotes, split by comma and strip whitespace
#     cleaned_text = ''.join(text).replace('[', '').replace(']', '').replace("'", '').split(',')
#     # Filter out empty strings and strip whitespace
#     cleaned_text = [item.strip() for item in cleaned_text if item.strip()]
#     # Join the cleaned text with commas and spaces
#     formatted_text = ', '.join(cleaned_text)
#     return formatted_text

# # Apply the custom function to the 'sub_classes' and 'sub_class' columns
# top_10_documents_test1['combined_class'] = top_10_documents_test1.apply(lambda x: format_text(x['sub_classes']) + ', ' + format_text(x['sub_class']), axis=1)

# # Display the resulting DataFrame with the 'combined' column
# print(top_10_documents_test1[['sub_classes', 'sub_class', 'combined_class']])

# %%
# # Get the class_codes from the first record of df_Abstract_test and convert it to a string, then split it by comma
# class_codes_value = df_Abstract_test['class_codes'].iloc[0]
# if pd.notna(class_codes_value):
#     target_sub_classes = str(class_codes_value).split(',')
# else:
#     target_sub_classes = []

# # Define a function to check for matching classes
# def has_matching_class(row):
#     # Extract the first 4 letters from each code in class_codes and combined_class
#     target_codes = [code[:4] for code in target_sub_classes]
#     combined_codes = [code[:4] for code in str(row['combined_class']).split(',')]

#     # Check if there are any common codes
#     return any(code in combined_codes for code in target_codes)

# # Apply the function to create a boolean mask
# top_10_documents_test1['has_matching_class'] = top_10_documents_test1.apply(has_matching_class, axis=1)

# top_10_documents_test1

# %%
# top_10_documents_test1.shape[0]

# %% [markdown]
# # list of 100 queries

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Assuming you have a list of 100 queries in test
for query in df_Abstract_test['abstract'][:num_samples_to_predict]:
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))

# Now, the 'results' list contains the similar topics and similarities for each query
# You can access the results for a specific query like this:
for i, (similar_topics, similarity) in enumerate(results):
    print(f"Query {i + 1}: Similar Topics {similar_topics}, Similarity {similarity}")
# Out:
# Query 1: Similar Topics [34, 44, 3, 41, 32], Similarity [0.6707194, 0.66445553, 0.64145833, 0.6402898, 0.63622487]
# Query 2: Similar Topics [44, 34, 29, 51, 56], Similarity [0.66972625, 0.6250118, 0.61390185, 0.5831846, 0.57547414]
# Query 3: Similar Topics [48, 37, 45, 40, 53], Similarity [0.65560573, 0.6495347, 0.643225, 0.62408566, 0.62396574]
# Query 4: Similar Topics [23, 6, 3, 26, 40], Similarity [0.8103322, 0.787099, 0.7512642, 0.7457191, 0.74056697]
# Query 5: Similar Topics [41, 26, 34, 30, 3], Similarity [0.6394714, 0.625569, 0.62008077, 0.6158669, 0.61405635]
# Query 6: Similar Topics [36, 32, 34, 44, -1], Similarity [0.74751335, 0.70330185, 0.70124954, 0.67774254, 0.67121464]
# Query 7: Similar Topics [5, 44, 29, 35, 3], Similarity [0.7631782, 0.70626724, 0.7045376, 0.67319113, 0.6695421]
# Query 8: Similar Topics [5, 29, 44, 32, 22], Similarity [0.7967857, 0.6920734, 0.686291, 0.6781874, 0.665908]
# Query 9: Similar Topics [48, 37, 2, -1, 56], Similarity [0.6860242, 0.6817516, 0.6791699, 0.672005, 0.6579201]
# Query 10: Similar Topics [10, 48, 39, 8, 40], Similarity [0.7343269, 0.70568573, 0.6938963, 0.68326914, 0.6788986]
# Query 11: Similar Topics [12, 46, 47, 6, -1], Similarity [0.7579597, 0.73608816, 0.6537973, 0.63747, 0.60962796]
# Query 12: Similar Topics [43, 41, 26, 38, 54], Similarity [0.6042737, 0.5944425, 0.59025663, 0.5847276, 0.5801211]
# Query 13: Similar Topics [29, 34, 44, 52, 32], Similarity [0.77164847, 0.7535223, 0.7492034, 0.7302094, 0.7146972]
# Query 14: Similar Topics [29, 34, 32, 41, 52], Similarity [0.7378435, 0.72340715, 0.7232686, 0.7151061, 0.7091602]
# Query 15: Similar Topics [38, 32, 34, 41, -1], Similarity [0.7111175, 0.6941328, 0.68362725, 0.6832408, 0.68277997]
# Query 16: Similar Topics [7, 36, 32, -1, 34], Similarity [0.757391, 0.73230016, 0.64874226, 0.6412313, 0.63241553]
# Query 17: Similar Topics [36, 7, 19, 29, 32], Similarity [0.7597918, 0.7288449, 0.67833364, 0.6636379, 0.658695]
# Query 18: Similar Topics [13, 17, 45, 35, 14], Similarity [0.7200316, 0.7164597, 0.7131854, 0.70808446, 0.70382327]
# Query 19: Similar Topics [41, 44, 29, 38, 0], Similarity [0.6674947, 0.6643115, 0.6291034, 0.6281055, 0.6242777]
# Query 20: Similar Topics [1, 27, -1, 24, 14], Similarity [0.8127401, 0.7389244, 0.717517, 0.7110861, 0.7042107]
# Query 21: Similar Topics [12, 27, 46, 1, 8], Similarity [0.7031259, 0.62195826, 0.6179892, 0.61642194, 0.595297]
# Query 22: Similar Topics [33, 37, 48, 22, 4], Similarity [0.66794866, 0.58135027, 0.54896617, 0.532377, 0.51606464]
# Query 23: Similar Topics [35, 13, 14, 28, 53], Similarity [0.8045126, 0.8023982, 0.77485794, 0.7659688, 0.75776875]
# Query 24: Similar Topics [52, 3, 26, 34, 41], Similarity [0.7052205, 0.682683, 0.65121305, 0.6271396, 0.6264252]
# Query 25: Similar Topics [26, 14, -1, 53, 40], Similarity [0.69785875, 0.6945565, 0.6869123, 0.6834574, 0.682311]
# Query 26: Similar Topics [33, 48, 25, 10, -1], Similarity [0.8060382, 0.698979, 0.69344306, 0.68675196, 0.68192375]
# Query 27: Similar Topics [37, 48, 32, 26, 19], Similarity [0.65254766, 0.59995896, 0.5915785, 0.5913557, 0.5847405]
# Query 28: Similar Topics [32, 30, 34, 51, -1], Similarity [0.8161075, 0.81006604, 0.80773824, 0.79957676, 0.7991786]
# Query 29: Similar Topics [46, 12, 38, 14, 31], Similarity [0.5967712, 0.55760354, 0.5178795, 0.51488984, 0.5036193]
# Query 30: Similar Topics [50, 32, 30, 22, 34], Similarity [0.74643934, 0.7340317, 0.7283002, 0.7254738, 0.7237609]
# Query 31: Similar Topics [21, 18, 53, 43, 28], Similarity [0.6995182, 0.69484055, 0.694255, 0.69356835, 0.6890396]
# Query 32: Similar Topics [19, 23, 22, 37, 36], Similarity [0.6865046, 0.5609831, 0.54814744, 0.5457669, 0.5447309]
# Query 33: Similar Topics [37, 48, 33, 8, 40], Similarity [0.7105843, 0.65749323, 0.6250157, 0.58523613, 0.57779026]
# Query 34: Similar Topics [0, 47, 16, 1, 30], Similarity [0.7906911, 0.78018576, 0.744702, 0.73840845, 0.72929513]
# Query 35: Similar Topics [15, 54, 18, 22, -1], Similarity [0.610601, 0.6097669, 0.5898597, 0.5827538, 0.57751286]
# Query 36: Similar Topics [42, 16, 30, 29, 44], Similarity [0.7203264, 0.71987534, 0.7155369, 0.70812035, 0.7047958]
# Query 37: Similar Topics [7, 36, 19, 12, 3], Similarity [0.7727473, 0.6953584, 0.6753738, 0.61345243, 0.60838306]
# Query 38: Similar Topics [36, 34, 18, 32, 7], Similarity [0.80583465, 0.7364464, 0.73520446, 0.7316859, 0.7276176]
# Query 39: Similar Topics [52, 34, 41, 32, 3], Similarity [0.76702195, 0.76068735, 0.7566804, 0.75659406, 0.75331503]
# Query 40: Similar Topics [25, 19, 40, -1, 37], Similarity [0.69622743, 0.6575122, 0.654729, 0.65011156, 0.6482066]
# Query 41: Similar Topics [51, 30, 34, 50, 40], Similarity [0.6554607, 0.6327079, 0.6270604, 0.62433755, 0.6191273]
# Query 42: Similar Topics [33, 48, 10, 11, 25], Similarity [0.75095415, 0.6897143, 0.6456845, 0.6455244, 0.64293957]
# Query 43: Similar Topics [1, 27, 44, 6, 51], Similarity [0.7147763, 0.65856034, 0.647876, 0.6298381, 0.62201405]
# Query 44: Similar Topics [26, 3, -1, 23, 52], Similarity [0.6620286, 0.6376691, 0.62062216, 0.6199583, 0.6126231]
# Query 45: Similar Topics [30, 50, 36, 18, 16], Similarity [0.6634911, 0.6632286, 0.6582595, 0.64618415, 0.6427736]
# Query 46: Similar Topics [26, 54, -1, 43, 53], Similarity [0.7447753, 0.7408618, 0.73628855, 0.7354918, 0.7354615]
# Query 47: Similar Topics [36, 7, 52, 32, 41], Similarity [0.7752015, 0.7379447, 0.71837676, 0.7126571, 0.71255994]
# Query 48: Similar Topics [33, 39, 48, 10, 4], Similarity [0.75506485, 0.6655174, 0.6590762, 0.6583127, 0.65826505]
# Query 49: Similar Topics [33, 48, 25, 31, 21], Similarity [0.7687182, 0.6750163, 0.6492324, 0.6236365, 0.61186874]
# Query 50: Similar Topics [0, 47, 46, -1, 53], Similarity [0.71938634, 0.69681823, 0.6678256, 0.6564163, 0.6488182]
# Query 51: Similar Topics [1, 27, 30, 6, -1], Similarity [0.7559621, 0.71456623, 0.66742694, 0.6602111, 0.6555225]
# Query 52: Similar Topics [10, 39, 46, 54, -1], Similarity [0.6716059, 0.65654767, 0.64404774, 0.63436425, 0.6316731]
# Query 53: Similar Topics [38, -1, 54, 3, 44], Similarity [0.7337169, 0.73145974, 0.71528584, 0.71223414, 0.7108847]
# Query 54: Similar Topics [3, 26, 8, 43, 34], Similarity [0.8015033, 0.76558346, 0.7203382, 0.71980155, 0.7160897]
# Query 55: Similar Topics [37, 48, 4, 34, 18], Similarity [0.82530427, 0.68396986, 0.6385182, 0.6358417, 0.6350428]
# Query 56: Similar Topics [0, 47, 38, -1, 28], Similarity [0.7602788, 0.7082457, 0.7000988, 0.689595, 0.67813873]
# Query 57: Similar Topics [33, 37, 48, -1, 40], Similarity [0.7230886, 0.5843012, 0.57666606, 0.5564907, 0.5542309]
# Query 58: Similar Topics [32, 34, 30, 18, 50], Similarity [0.8104359, 0.796254, 0.7951652, 0.7897745, 0.7799605]
# Query 59: Similar Topics [36, 3, 26, 19, 41], Similarity [0.6818092, 0.67410713, 0.66539127, 0.65030575, 0.64712733]
# Query 60: Similar Topics [48, 33, 23, 10, -1], Similarity [0.75980675, 0.7300051, 0.68521047, 0.68034315, 0.6704301]
# Query 61: Similar Topics [5, 9, 29, 35, 44], Similarity [0.66675866, 0.6092221, 0.598262, 0.57675666, 0.57341254]
# Query 62: Similar Topics [5, 35, 52, 29, -1], Similarity [0.7627599, 0.75443923, 0.72466594, 0.72435653, 0.71010405]
# Query 63: Similar Topics [44, 37, 22, 34, 38], Similarity [0.6249899, 0.6192828, 0.6021042, 0.5971669, 0.5946554]
# Query 64: Similar Topics [44, 3, 29, 34, 41], Similarity [0.7161794, 0.7096925, 0.7085102, 0.69573843, 0.6618655]
# Query 65: Similar Topics [44, 15, 34, 51, 54], Similarity [0.563846, 0.562808, 0.52414614, 0.5231174, 0.5169226]
# Query 66: Similar Topics [44, 51, 34, 29, 55], Similarity [0.61140454, 0.5892796, 0.5852924, 0.5833064, 0.55361533]
# Query 67: Similar Topics [21, 28, 31, -1, 1], Similarity [0.65856946, 0.6255295, 0.61832494, 0.61619294, 0.6109629]
# Query 68: Similar Topics [5, 0, 47, 44, 29], Similarity [0.7377776, 0.72374177, 0.7097342, 0.69958323, 0.69898844]
# Query 69: Similar Topics [36, 38, 56, 34, -1], Similarity [0.66784245, 0.6387278, 0.63549715, 0.63490003, 0.62795866]
# Query 70: Similar Topics [32, 34, 13, -1, 1], Similarity [0.7496488, 0.7373976, 0.7320466, 0.7206886, 0.71382535]
# Query 71: Similar Topics [41, 3, 34, 26, 32], Similarity [0.6679995, 0.64360416, 0.63937026, 0.6283406, 0.62379473]
# Query 72: Similar Topics [44, 29, 5, 56, 9], Similarity [0.7345951, 0.67596394, 0.6684631, 0.6445169, 0.6367006]
# Query 73: Similar Topics [41, 7, 29, 36, 9], Similarity [0.659686, 0.64051676, 0.6050301, 0.6014608, 0.5833882]
# Query 74: Similar Topics [35, 29, 28, 17, 13], Similarity [0.66144544, 0.6544105, 0.6525285, 0.65130305, 0.64454913]
# Query 75: Similar Topics [18, 17, 30, -1, 50], Similarity [0.76067823, 0.7585551, 0.7508744, 0.7491727, 0.74517345]
# Query 76: Similar Topics [1, 27, 22, -1, 44], Similarity [0.7691866, 0.7670413, 0.7311363, 0.7126987, 0.70357895]
# Query 77: Similar Topics [19, 40, 25, 2, -1], Similarity [0.7638792, 0.7126101, 0.70592135, 0.69810605, 0.69664234]
# Query 78: Similar Topics [19, 34, 3, 26, 36], Similarity [0.65971917, 0.64939594, 0.64801466, 0.63256085, 0.63113284]
# Query 79: Similar Topics [41, 36, 26, 3, 32], Similarity [0.6890884, 0.5825225, 0.5634255, 0.56330454, 0.5624219]
# Query 80: Similar Topics [44, 34, 37, -1, 43], Similarity [0.68858284, 0.659886, 0.6561909, 0.653127, 0.651224]
# Query 81: Similar Topics [52, 3, 34, 26, 41], Similarity [0.68131477, 0.67927045, 0.6670119, 0.64731395, 0.6320207]
# Query 82: Similar Topics [32, 52, 13, 41, 34], Similarity [0.75746834, 0.737524, 0.73727787, 0.73511976, 0.7264534]
# Query 83: Similar Topics [48, 33, 10, -1, 23], Similarity [0.6885232, 0.66607773, 0.66555285, 0.6475593, 0.64335907]
# Query 84: Similar Topics [30, 50, 32, 42, 13], Similarity [0.7745531, 0.75086415, 0.7389504, 0.7373969, 0.73136353]
# Query 85: Similar Topics [22, 15, 43, 44, -1], Similarity [0.62256074, 0.60555106, 0.6038236, 0.5983724, 0.5981957]
# Query 86: Similar Topics [44, 29, 5, 34, 32], Similarity [0.7684177, 0.7578392, 0.74275696, 0.70122355, 0.67583156]
# Query 87: Similar Topics [46, 12, 47, 0, 31], Similarity [0.60795045, 0.5980382, 0.5338763, 0.5292773, 0.5256568]
# Query 88: Similar Topics [16, 51, 42, 30, 18], Similarity [0.79391223, 0.69036126, 0.6868837, 0.6770982, 0.6697682]
# Query 89: Similar Topics [1, 2, 27, 56, 36], Similarity [0.7435527, 0.6614419, 0.65146476, 0.64490783, 0.63097286]
# Query 90: Similar Topics [6, 19, 18, 30, -1], Similarity [0.7811284, 0.76621217, 0.7163354, 0.71194184, 0.70721084]
# Query 91: Similar Topics [48, 37, 40, 22, 18], Similarity [0.7720845, 0.75882304, 0.75675964, 0.7438477, 0.74060905]
# Query 92: Similar Topics [10, 49, 48, 4, 39], Similarity [0.721083, 0.6934068, 0.66851926, 0.66733027, 0.6611129]
# Query 93: Similar Topics [29, 13, 32, 41, 14], Similarity [0.7797649, 0.74613464, 0.74101377, 0.7286035, 0.7276778]
# Query 94: Similar Topics [52, 3, 29, 26, 41], Similarity [0.72640926, 0.70859146, 0.6934592, 0.6923847, 0.68665636]
# Query 95: Similar Topics [3, 26, 23, 52, -1], Similarity [0.79646385, 0.7534435, 0.7299446, 0.72373605, 0.7213857]
# Query 96: Similar Topics [16, 55, 30, 17, 18], Similarity [0.71595883, 0.7001051, 0.6961172, 0.68603635, 0.68251026]
# Query 97: Similar Topics [6, 47, 55, -1, 40], Similarity [0.75039494, 0.7186656, 0.6231932, 0.6221276, 0.6211581]
# Query 98: Similar Topics [19, 0, 36, 1, -1], Similarity [0.7182129, 0.690433, 0.6600162, 0.6550752, 0.65405506]
# Query 99: Similar Topics [52, 34, 43, 26, 3], Similarity [0.7324102, 0.7273395, 0.7263522, 0.7260101, 0.71425366]
# Query 100: Similar Topics [42, 30, 17, 18, 50], Similarity [0.7828075, 0.77815616, 0.77429926, 0.7709037, 0.7679759]

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Create an empty DataFrame to store the results
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Assuming you have a list of 100 queries in 'df_Abstract_test'
for i, (query, publication_number, abstract, class_codes) in enumerate(zip(df_Abstract_test['abstract'][:num_samples_to_predict], 
                                                    df_Abstract_test['publication_numbers'][:num_samples_to_predict],
                                                    df_Abstract_test['abstract'][:num_samples_to_predict],
                                                    df_Abstract_test['class_codes'][:num_samples_to_predict])):
    similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
    results.append((similar_topics, similarity))
    
    # Store the results in the DataFrame
    result_df_q = result_df_q.append({
        'query_abstract': query,
        'query_predicted_topics': similar_topics,
        'query_publication_numbers': publication_number,
        'query_class_codes': class_codes
    }, ignore_index=True)
    
result_df_q
# Out:
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 95           US20230017310A1
# 96           US20230091925A1
# 97           US20230010638A1
# 98           US20230009812A1
# 99           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 95  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 96  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 97  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 98  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 99  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                        query_abstract query_predicted_topics
# 0   A physiological sensor has light emitting sour...    [34, 44, 3, 41, 32]
# 1   A wearable monitoring device includes a band c...   [44, 34, 29, 51, 56]
# 2   A number of improvements are provided relating...   [48, 37, 45, 40, 53]
# 3   Embodiments include a system for determining c...     [23, 6, 3, 26, 40]
# 4   A community based response system for providin...    [41, 26, 34, 30, 3]
# ..                                                ...                    ...
# 95  Features are disclosed for remote storage of m...   [16, 55, 30, 17, 18]
# 96  Some of the embodiments herein provide a seaml...    [6, 47, 55, -1, 40]
# 97  A method and system is disclosed for operating...     [19, 0, 36, 1, -1]
# 98  A patient monitor including a physiological me...    [52, 34, 43, 26, 3]
# 99  A system to manage records in a healthcare pra...   [42, 30, 17, 18, 50]
#
# [100 rows x 4 columns]

# %%
# Check if the 'query_publication_numbers' field is unique
is_unique = result_df_q['query_publication_numbers'].nunique() == len(result_df_q)

if is_unique:
    print("The 'query_publication_numbers' field is unique.")
else:
    print("The 'query_publication_numbers' field is not unique.")
# Out:
# The 'query_publication_numbers' field is unique.

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'abstract', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_abstract', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_abstract']
    predicted_topics = row['query_predicted_topics']
    
    for topic_id in predicted_topics:
        # Filter 'df_Abstract_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_Abstract_topic[df_Abstract_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'result_df' DataFrame
        for _, doc_row in topic_documents.iterrows():
            result_df = result_df.append({
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_abstract': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'abstract': doc_row['abstract'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }, ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020185085A1  Predictive maintenance for large medical imagi...
# 1        US2009163832A1   Data managing device for a diagnostic instrument
# 2        US2014247153A1  Patient monitoring systems and messages that s...
# 3        US2014206950A1                                  Ward cloud system
# 4        US2013303863A1                       Patient Monitoring Apparatus
# ...                 ...                                                ...
# 4995     US2010240980A1  Wan-Based Remote Mobile Monitoring Method And ...
# 4996     US2010185711A1  Online monitoring of patient for routine checkups
# 4997     US2010076275A1  System and Method for Remote Healthcare Monito...
# 4998     US2010049543A1  Health data integration system and the method ...
# 4999     US2009292552A1  Integrated and interactive health-management s...
#
#                                                abstract  \
# 0     A predictive maintenance alerting device ( 40 ...
# 1     A data managing device for connection to a dia...
# 2     A system for is provided for using telemetry d...
# 3     A ward cloud system comprises an intelligent c...
# 4     A patient monitoring system including a sensin...
# ...                                                 ...
# 4995  A WAN-based remote mobile monitoring method an...
# 4996  A method, system, and computer program product...
# 4997  A system and method for remote health monitori...
# 4998  A health data integration system and the metho...
# 4999  An integrated and interactive health-managemen...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G16H30/40', 'G06N20/00']  ['G16H', 'G06N']     34   1.0
# 1       ['A61B5/20', 'G16H40/63']  ['A61B', 'G16H']     34   1.0
# 2      ['H04W4/029', 'G16H50/30']  ['H04W', 'G16H']     34   1.0
# 3     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     34   1.0
# 4       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     34   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06Q50/22', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
# 4996  ['G16H70/40', 'G06F16/258']  ['G16H', 'G06F']     50   1.0
# 4997   ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     50   1.0
# 4998   ['G06Q50/00', 'G16H50/20']  ['G06Q', 'G16H']     50   1.0
# 4999   ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract query_predicted_topics
# 0     A physiological sensor has light emitting sour...                   [34]
# 1     A physiological sensor has light emitting sour...                   [34]
# 2     A physiological sensor has light emitting sour...                   [34]
# 3     A physiological sensor has light emitting sour...                   [34]
# 4     A physiological sensor has light emitting sour...                   [34]
# ...                                                 ...                    ...
# 4995  A system to manage records in a healthcare pra...                   [50]
# 4996  A system to manage records in a healthcare pra...                   [50]
# 4997  A system to manage records in a healthcare pra...                   [50]
# 4998  A system to manage records in a healthcare pra...                   [50]
# 4999  A system to manage records in a healthcare pra...                   [50]
#
# [5000 rows x 11 columns]

# %%
result_df['query_class_codes'][0]
# Out:
# 'A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/7221,A61B5/14532,G16H40/00,A61B5/14546,G16H40/60,A61B5/68,A61B2562/08,H,A61B1/00,A61B2562/221,A61B5/7475,A61B2562/18,A61B5/746,A61B5/7405,H05K,G16H40/67,A61B,Y10,A61B5/6813,Y,A61B2562/185,G16H10/40,A61B5/6826,A61B5/02,A61B5/0002,A61B5/1455,A61B5/6832,A,A61B5/7235,A61B5/6801,A61B5/7278,G16H,A61B5/026,A61B5/742,A61B2562/22,A61B5/024,G16,A61B5/02416,A61B5/683,A61B5/0015,A61B5/6825,Y10S,A61B5/1495,A61B5/72,A61B5/0261,A61B2562/085,A61B2562/222,A61B5/7275,A61B5/00,A61B5/145,A61B5/74,G16H10/00,H05K999/99,A61B5/7246,Y10S439/909,A61B5/14552,A61B5/6838,A61B5/6815,A61B5/7271,H05K999/00,A61B5/02427,A61B5/0205,Y10S439/00,A61B5/0022,A61B5/6814,A61B2562/00,H05'

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020185085A1  Predictive maintenance for large medical imagi...
# 1        US2009163832A1   Data managing device for a diagnostic instrument
# 2        US2014247153A1  Patient monitoring systems and messages that s...
# 3        US2014206950A1                                  Ward cloud system
# 4        US2013303863A1                       Patient Monitoring Apparatus
# ...                 ...                                                ...
# 4995     US2010240980A1  Wan-Based Remote Mobile Monitoring Method And ...
# 4996     US2010185711A1  Online monitoring of patient for routine checkups
# 4997     US2010076275A1  System and Method for Remote Healthcare Monito...
# 4998     US2010049543A1  Health data integration system and the method ...
# 4999     US2009292552A1  Integrated and interactive health-management s...
#
#                                                abstract  \
# 0     A predictive maintenance alerting device ( 40 ...
# 1     A data managing device for connection to a dia...
# 2     A system for is provided for using telemetry d...
# 3     A ward cloud system comprises an intelligent c...
# 4     A patient monitoring system including a sensin...
# ...                                                 ...
# 4995  A WAN-based remote mobile monitoring method an...
# 4996  A method, system, and computer program product...
# 4997  A system and method for remote health monitori...
# 4998  A health data integration system and the metho...
# 4999  An integrated and interactive health-managemen...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G16H30/40', 'G06N20/00']  ['G16H', 'G06N']     34   1.0
# 1       ['A61B5/20', 'G16H40/63']  ['A61B', 'G16H']     34   1.0
# 2      ['H04W4/029', 'G16H50/30']  ['H04W', 'G16H']     34   1.0
# 3     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     34   1.0
# 4       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     34   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06Q50/22', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
# 4996  ['G16H70/40', 'G06F16/258']  ['G16H', 'G06F']     50   1.0
# 4997   ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     50   1.0
# 4998   ['G06Q50/00', 'G16H50/20']  ['G06Q', 'G16H']     50   1.0
# 4999   ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [34]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [34]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [34]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [34]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [34]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 4995                   [50]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996                   [50]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997                   [50]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998                   [50]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999                   [50]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [5000 rows x 12 columns]

# %%
# Create a new column to store the common code
import re
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Custom extraction of values from sub_classes_str
    sub_classes = re.findall(r"'([^']*)'", sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020185085A1  Predictive maintenance for large medical imagi...
# 1        US2009163832A1   Data managing device for a diagnostic instrument
# 2        US2014247153A1  Patient monitoring systems and messages that s...
# 3        US2014206950A1                                  Ward cloud system
# 4        US2013303863A1                       Patient Monitoring Apparatus
# ...                 ...                                                ...
# 4995     US2010240980A1  Wan-Based Remote Mobile Monitoring Method And ...
# 4996     US2010185711A1  Online monitoring of patient for routine checkups
# 4997     US2010076275A1  System and Method for Remote Healthcare Monito...
# 4998     US2010049543A1  Health data integration system and the method ...
# 4999     US2009292552A1  Integrated and interactive health-management s...
#
#                                                abstract  \
# 0     A predictive maintenance alerting device ( 40 ...
# 1     A data managing device for connection to a dia...
# 2     A system for is provided for using telemetry d...
# 3     A ward cloud system comprises an intelligent c...
# 4     A patient monitoring system including a sensin...
# ...                                                 ...
# 4995  A WAN-based remote mobile monitoring method an...
# 4996  A method, system, and computer program product...
# 4997  A system and method for remote health monitori...
# 4998  A health data integration system and the metho...
# 4999  An integrated and interactive health-managemen...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G16H30/40', 'G06N20/00']  ['G16H', 'G06N']     34   1.0
# 1       ['A61B5/20', 'G16H40/63']  ['A61B', 'G16H']     34   1.0
# 2      ['H04W4/029', 'G16H50/30']  ['H04W', 'G16H']     34   1.0
# 3     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     34   1.0
# 4       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     34   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06Q50/22', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
# 4996  ['G16H70/40', 'G06F16/258']  ['G16H', 'G06F']     50   1.0
# 4997   ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     50   1.0
# 4998   ['G06Q50/00', 'G16H50/20']  ['G06Q', 'G16H']     50   1.0
# 4999   ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [34]
# 1                      [34]
# 2                      [34]
# 3                      [34]
# 4                      [34]
# ...                     ...
# 4995                   [50]
# 4996                   [50]
# 4997                   [50]
# 4998                   [50]
# 4999                   [50]
#
#                                        query_codes_G16H exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [5000 rows x 13 columns]

# %%
# result_df.sample(n=100)

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020185085A1  Predictive maintenance for large medical imagi...
# 1        US2009163832A1   Data managing device for a diagnostic instrument
# 2        US2014247153A1  Patient monitoring systems and messages that s...
# 3        US2014206950A1                                  Ward cloud system
# 4        US2013303863A1                       Patient Monitoring Apparatus
# ...                 ...                                                ...
# 4995     US2010240980A1  Wan-Based Remote Mobile Monitoring Method And ...
# 4996     US2010185711A1  Online monitoring of patient for routine checkups
# 4997     US2010076275A1  System and Method for Remote Healthcare Monito...
# 4998     US2010049543A1  Health data integration system and the method ...
# 4999     US2009292552A1  Integrated and interactive health-management s...
#
#                                                abstract  \
# 0     A predictive maintenance alerting device ( 40 ...
# 1     A data managing device for connection to a dia...
# 2     A system for is provided for using telemetry d...
# 3     A ward cloud system comprises an intelligent c...
# 4     A patient monitoring system including a sensin...
# ...                                                 ...
# 4995  A WAN-based remote mobile monitoring method an...
# 4996  A method, system, and computer program product...
# 4997  A system and method for remote health monitori...
# 4998  A health data integration system and the metho...
# 4999  An integrated and interactive health-managemen...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G16H30/40', 'G06N20/00']  ['G16H', 'G06N']     34   1.0
# 1       ['A61B5/20', 'G16H40/63']  ['A61B', 'G16H']     34   1.0
# 2      ['H04W4/029', 'G16H50/30']  ['H04W', 'G16H']     34   1.0
# 3     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     34   1.0
# 4       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     34   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06Q50/22', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
# 4996  ['G16H70/40', 'G06F16/258']  ['G16H', 'G06F']     50   1.0
# 4997   ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     50   1.0
# 4998   ['G06Q50/00', 'G16H50/20']  ['G06Q', 'G16H']     50   1.0
# 4999   ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [34]
# 1                      [34]
# 2                      [34]
# 3                      [34]
# 4                      [34]
# ...                     ...
# 4995                   [50]
# 4996                   [50]
# 4997                   [50]
# 4998                   [50]
# 4999                   [50]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50
# 0                          14
# 1                          14
# 2                          14
# 3                          14
# 4                          14
# ...                       ...
# 4995                       20
# 4996                       20
# 4997                       20
# 4998                       20
# 4999                       20
#
# [5000 rows x 14 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020185085A1  Predictive maintenance for large medical imagi...
# 1        US2009163832A1   Data managing device for a diagnostic instrument
# 2        US2014247153A1  Patient monitoring systems and messages that s...
# 3        US2014206950A1                                  Ward cloud system
# 4        US2013303863A1                       Patient Monitoring Apparatus
# ...                 ...                                                ...
# 4995     US2010240980A1  Wan-Based Remote Mobile Monitoring Method And ...
# 4996     US2010185711A1  Online monitoring of patient for routine checkups
# 4997     US2010076275A1  System and Method for Remote Healthcare Monito...
# 4998     US2010049543A1  Health data integration system and the method ...
# 4999     US2009292552A1  Integrated and interactive health-management s...
#
#                                                abstract  \
# 0     A predictive maintenance alerting device ( 40 ...
# 1     A data managing device for connection to a dia...
# 2     A system for is provided for using telemetry d...
# 3     A ward cloud system comprises an intelligent c...
# 4     A patient monitoring system including a sensin...
# ...                                                 ...
# 4995  A WAN-based remote mobile monitoring method an...
# 4996  A method, system, and computer program product...
# 4997  A system and method for remote health monitori...
# 4998  A health data integration system and the metho...
# 4999  An integrated and interactive health-managemen...
#
#                       sub_classes         sub_class topics  prob  \
# 0      ['G16H30/40', 'G06N20/00']  ['G16H', 'G06N']     34   1.0
# 1       ['A61B5/20', 'G16H40/63']  ['A61B', 'G16H']     34   1.0
# 2      ['H04W4/029', 'G16H50/30']  ['H04W', 'G16H']     34   1.0
# 3     ['G16H10/60', 'A61B5/7285']  ['G16H', 'A61B']     34   1.0
# 4       ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     34   1.0
# ...                           ...               ...    ...   ...
# 4995   ['G06Q50/22', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
# 4996  ['G16H70/40', 'G06F16/258']  ['G16H', 'G06F']     50   1.0
# 4997   ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     50   1.0
# 4998   ['G06Q50/00', 'G16H50/20']  ['G06Q', 'G16H']     50   1.0
# 4999   ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']     50   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4995           US20230138516A1
# 4996           US20230138516A1
# 4997           US20230138516A1
# 4998           US20230138516A1
# 4999           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4995  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4996  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4997  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4998  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4999  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                          query_abstract  \
# 0     A physiological sensor has light emitting sour...
# 1     A physiological sensor has light emitting sour...
# 2     A physiological sensor has light emitting sour...
# 3     A physiological sensor has light emitting sour...
# 4     A physiological sensor has light emitting sour...
# ...                                                 ...
# 4995  A system to manage records in a healthcare pra...
# 4996  A system to manage records in a healthcare pra...
# 4997  A system to manage records in a healthcare pra...
# 4998  A system to manage records in a healthcare pra...
# 4999  A system to manage records in a healthcare pra...
#
#      query_predicted_topics  \
# 0                      [34]
# 1                      [34]
# 2                      [34]
# 3                      [34]
# 4                      [34]
# ...                     ...
# 4995                   [50]
# 4996                   [50]
# 4997                   [50]
# 4998                   [50]
# 4999                   [50]
#
#                                        query_codes_G16H exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# ...                                                 ...              ...
# 4995       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4996       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4997       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4998       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4999       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
#       count_exact_match_top50  RFR
# 0                          14  5.0
# 1                          14  5.0
# 2                          14  5.0
# 3                          14  5.0
# 4                          14  5.0
# ...                       ...  ...
# 4995                       20  3.0
# 4996                       20  3.0
# 4997                       20  3.0
# 4998                       20  3.0
# 4999                       20  3.0
#
# [5000 rows x 15 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","abstract","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_abstract","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2020160993A1         Artificial Intelligence Based Alert System
# 1       US2012303085A1  Methods and apapratus for manually suspending ...
# 2       US2019180592A1                       Closed loop alarm management
# 3       US2019156937A1       Priority alerts based on medical information
# 4       US2019130730A1                                   Alarm Management
# ..                 ...                                                ...
# 495     US2020194106A1  System and device for non-invasive detection o...
# 496     US2018261329A1  Personalized Health-Information Based on Genet...
# 497     US2014052405A1      Concussion detection and communication system
# 498     US2014018945A1  Method and apparatus for determining effect of...
# 499     US2019159700A1  Systems, apparatus, and methods for using a we...
#
#                                               abstract  \
# 0    A mechanism is provided to implement an artifi...
# 1    The capability to suspend a patient alert rela...
# 2    Methods, systems, and devices for patient moni...
# 3    A method and apparatus are disclosed herein fo...
# 4    Methods, systems, and devices for patient moni...
# ..                                                 ...
# 495  Wearable device has at least one sensor operab...
# 496  This disclosure relates to technologies for ev...
# 497  A concussion detection and communication syste...
# 498  The present disclosure concerns determining ph...
# 499  A wearable device includes at least one sensor...
#
#                       sub_classes         sub_class topics  prob  \
# 0     ['G16H15/00', 'G06T7/0012']  ['G16H', 'G06T']     41   1.0
# 1      ['A61N1/365', 'G16H40/63']  ['A61N', 'G16H']     41   1.0
# 2      ['G16H40/63', 'G08B29/10']  ['G16H', 'G08B']     41   1.0
# 3      ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']     41   1.0
# 4     ['G16H40/67', 'A61B5/0022']  ['G16H', 'A61B']     41   1.0
# ..                            ...               ...    ...   ...
# 495    ['G16H40/67', 'G16H20/30']  ['G16H', 'G16H']     44   1.0
# 496   ['C12Q1/6827', 'G16H50/30']  ['C12Q', 'G16H']     44   1.0
# 497    ['G16H20/70', 'G16H40/67']  ['G16H', 'G16H']     44   1.0
# 498    ['A63B24/00', 'G16H20/30']  ['A63B', 'G16H']     44   1.0
# 499  ['G16H40/67', 'G06F2218/00']  ['G16H', 'G06F']     44   1.0
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 495           US20230270344A1
# 496           US20230270344A1
# 497           US20230270344A1
# 498           US20230270344A1
# 499           US20230270344A1
#
#                                         query_abstract  \
# 0    Methods and systems for delaying alarms that i...
# 1    Methods and systems for delaying alarms that i...
# 2    Methods and systems for delaying alarms that i...
# 3    Methods and systems for delaying alarms that i...
# 4    Methods and systems for delaying alarms that i...
# ..                                                 ...
# 495  A wearable monitoring device includes a band c...
# 496  A wearable monitoring device includes a band c...
# 497  A wearable monitoring device includes a band c...
# 498  A wearable monitoring device includes a band c...
# 499  A wearable monitoring device includes a band c...
#
#                                       query_codes_G16H     exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# ..                                                 ...                  ...
# 495  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...  G16H40/67,G16H20/30
# 496  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 497  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H40/67
# 498  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H20/30
# 499  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...            G16H40/67
#
#      count_exact_match_top50  count_exact_match_top5
# 0                         17                       1
# 1                         17                       1
# 2                         17                       1
# 3                         17                       1
# 4                         17                       1
# ..                       ...                     ...
# 495                       25                       4
# 496                       25                       4
# 497                       25                       4
# 498                       25                       4
# 499                       25                       4
#
# [500 rows x 13 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230001090A1']
filtered_df
# Out:
#      publication_number                                              title  \
# 3900     US2020160993A1         Artificial Intelligence Based Alert System
# 3901     US2012303085A1  Methods and apapratus for manually suspending ...
# 3902     US2019180592A1                       Closed loop alarm management
# 3903     US2019156937A1       Priority alerts based on medical information
# 3904     US2019130730A1                                   Alarm Management
# 3905     US2019131014A1  Process, control unit, computer program produc...
# 3906     US2019051383A1                           Intelligent sepsis alert
# 3907     US2019035493A1  Methods of analyte monitoring, and devices and...
# 3908     US2019008384A1  Systems and methods for managing patient-trigg...
# 3909     US2018271454A1  System and method for the identification and s...
# 3910     US2020113436A1  Physiological information transmission system,...
# 3911     US2012289803A1  Systems and methods for handling unacceptable ...
# 3912     US2014012509A1  Methods and systems for synchronization and di...
# 3913     US2013332196A1             Diabetes Monitoring Using Smart Device
# 3914     US2013285807A1                     Blood glucose measuring device
# 3915     US2019156956A1      Treatment selection support system and method
# 3916     US2018292383A1  Portable insulin resistance diagnosis device a...
# 3917     US2018286507A1  Diabetes management systems, methods and appar...
# 3918     US2022142521A1  Methods and apparatus for predicting whether a...
# 3919     US2022148720A1                A projection and measurement system
# 3920     US2020098384A1  System and method for pulmonary condition moni...
# 3921     US2018286518A1  Enhanced acute care management combining imagi...
# 3922     US2014031643A1              Heart failure patients stratification
# 3923     US2014019059A1            Mapping Cognitive to Functional Ability
# 3924     US2014006041A1  Tracking ventilator information for reporting ...
# 3925     US2019184119A1  Multiple control interface for medical ventilator
# 3926     US2019125212A1  Pulmonary function measurement device, pulmona...
# 3927     US2019125214A1  Measuring respiratory parameters from an ecg d...
# 3928     US2018344212A1  Systems and methods for managing heart failure...
# 3929     US2018330813A1       Patient Treatment Status Notification System
# 3930     US2016242664A1  An apparatus and method for evaluating multich...
# 3931     US2015366483A1  Computer-Aided Localization of Site of Origin ...
# 3932     US2015342486A1  Systems and methods for displaying physiologic...
# 3933     US2022084676A1  Systems and methods for noninvasive detection ...
# 3934     US2022071495A1  Blood pressure-related information display dev...
# 3935     US2022068479A1  Separating abnormal heart activities into diff...
# 3936     US2022061797A1                    Medical decision support system
# 3937     US2022068489A1  Computer modeling and evaluation of insurance ...
# 3938     US2022054070A1  Computer implemented method and system for aid...
# 3939     US2022047215A1  Electronic device and method for measuring vit...
# 3940     US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 3941     US2011004277A1  System and Method for Managing Locally-Initiat...
# 3942     US2013218588A1  Method, apparatus, and operating system for re...
# 3943     US2011030034A1        Urgent access medication dispensing station
# 3944     US2013024213A1  Method and system for guided, efficient treatment
# 3945     US2022180991A1  Systems and methods for creating personalized ...
# 3946     US2012271654A1  Method and System for Wound Care and Managemen...
# 3947     US2021358619A1  Health Sticker:  A Modular Adhesive Platform M...
# 3948     US2021327577A1     System and method for monitoring patient state
# 3949     US2022230715A1  Systems and methods for managing, monitoring, ...
#
#                                                abstract  \
# 3900  A mechanism is provided to implement an artifi...
# 3901  The capability to suspend a patient alert rela...
# 3902  Methods, systems, and devices for patient moni...
# 3903  A method and apparatus are disclosed herein fo...
# 3904  Methods, systems, and devices for patient moni...
# 3905  A process for providing failure safety for a p...
# 3906  A system for determining a likelihood of curre...
# 3907  Methods, devices, and systems are provided tha...
# 3908  Systems and methods for managing machine-gener...
# 3909  The system and method described herein represe...
# 3910  A physiological information transmission metho...
# 3911  Embodiments of methods of querying a diabetic ...
# 3912  Methods and systems are disclosed including re...
# 3913  A method for communicating diabetes informatio...
# 3914  A blood glucose measuring instrument is config...
# 3915  It is provided a treatment selection support s...
# 3916  A portable insulin resistance diagnosis device...
# 3917  Systems, methods, and apparatus for diabetes m...
# 3918  A method of predicting an analyte concentratio...
# 3919  A projection and measurement system ( 100 ) co...
# 3920  A method for pulmonary condition monitoring in...
# 3921  A patient monitoring device includes at least ...
# 3922  A system, apparatus and method are provided to...
# 3923  Methods, systems, and apparatus, including med...
# 3924  A method for tracking ventilator information f...
# 3925  Examples described herein include multiple con...
# 3926  A pulmonary function measurement device, a pul...
# 3927  Methods, systems, and devices for measuring re...
# 3928  Systems and methods for monitoring and treatin...
# 3929  A patient treatment status notification system...
# 3930  An evaluating method for ECG signals is provid...
# 3931  A method for quantifying, during pacemapping, ...
# 3932  A method is disclosed for displaying patient E...
# 3933  Heart forcing functions are detected non-invas...
# 3934  A blood pressure-related information display d...
# 3935  A method that is executed by a determination e...
# 3936  At least one swing value is determined respons...
# 3937  Systems, methods and computer-readable media a...
# 3938  A computer implemented method and system are d...
# 3939  Methods and apparatuses are provided for measu...
# 3940  A web-based interface enables medical personne...
# 3941  A system and method for managing locally-initi...
# 3942  A medical monitoring device, operating system,...
# 3943  A medical supply station is disclosed. The med...
# 3944  A system and method is provided in which medic...
# 3945  Systems and methods for creating personalized ...
# 3946  A method and system for use by professionals i...
# 3947  Systems and methods for medical monitoring dev...
# 3948  A patient state monitoring system and a method...
# 3949  Systems, devices, user interfaces, and methods...
#
#                         sub_classes         sub_class topics  prob  \
# 3900    ['G16H15/00', 'G06T7/0012']  ['G16H', 'G06T']     41   1.0
# 3901     ['A61N1/365', 'G16H40/63']  ['A61N', 'G16H']     41   1.0
# 3902     ['G16H40/63', 'G08B29/10']  ['G16H', 'G08B']     41   1.0
# 3903     ['G16H50/20', 'G16H50/30']  ['G16H', 'G16H']     41   1.0
# 3904    ['G16H40/67', 'A61B5/0022']  ['G16H', 'A61B']     41   1.0
# 3905     ['G16H80/00', 'G16H10/60']  ['G16H', 'G16H']     41   1.0
# 3906     ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     41   1.0
# 3907     ['G16H15/00', 'G16H50/20']  ['G16H', 'G16H']     41   1.0
# 3908      ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     41   1.0
# 3909     ['G16H10/60', 'A61B5/024']  ['G16H', 'A61B']     41   1.0
# 3910    ['G16H40/67', 'A61B5/0006']  ['G16H', 'A61B']     36   1.0
# 3911     ['G16H20/17', 'G16H10/20']  ['G16H', 'G16H']     36   1.0
# 3912     ['G06F19/00', 'G16H50/80']  ['G06F', 'G16H']     36   1.0
# 3913     ['G06F19/00', 'G16H40/63']  ['G06F', 'G16H']     36   1.0
# 3914     ['G16H40/63', 'G16H40/63']  ['G16H', 'G16H']     36   1.0
# 3915     ['G16H50/50', 'G16H50/50']  ['G16H', 'G16H']     36   1.0
# 3916    ['G16H50/20', 'G01N33/492']  ['G16H', 'G01N']     36   1.0
# 3917    ['G06F3/0485', 'G16H20/17']  ['G06F', 'G16H']     36   1.0
# 3918     ['A61B5/145', 'G16H50/20']  ['A61B', 'G16H']     36   1.0
# 3919     ['G16H40/60', 'G16H40/60']  ['G16H', 'G16H']     36   1.0
# 3920     ['G10L25/66', 'G16H50/70']  ['G10L', 'G16H']     26   1.0
# 3921      ['A61B5/11', 'G16H50/50']  ['A61B', 'G16H']     26   1.0
# 3922     ['A61B5/366', 'G16H50/30']  ['A61B', 'G16H']     26   1.0
# 3923      ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     26   1.0
# 3924  ['G16H40/60', 'A61M2205/609']  ['G16H', 'A61M']     26   1.0
# 3925     ['G16H40/67', 'G16H20/40']  ['G16H', 'G16H']     26   1.0
# 3926      ['A61B5/00', 'G16H50/30']  ['A61B', 'G16H']     26   1.0
# 3927      ['A61B5/00', 'G16H10/60']  ['A61B', 'G16H']     26   1.0
# 3928    ['A61B5/0205', 'G16H40/67']  ['A61B', 'G16H']     26   1.0
# 3929      ['G16H40/20', 'G08B5/36']  ['G16H', 'G08B']     26   1.0
# 3930    ['G16H50/20', 'A61B5/7267']  ['G16H', 'A61B']      3   1.0
# 3931     ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']      3   1.0
# 3932      ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']      3   1.0
# 3933      ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']      3   1.0
# 3934      ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']      3   1.0
# 3935     ['G16H50/20', 'A61B5/287']  ['G16H', 'A61B']      3   1.0
# 3936    ['A61B5/0245', 'G16H50/20']  ['A61B', 'G16H']      3   1.0
# 3937     ['G16H50/30', 'G16H50/30']  ['G16H', 'G16H']      3   1.0
# 3938     ['G16H50/20', 'A61B5/364']  ['G16H', 'A61B']      3   1.0
# 3939      ['A61B5/00', 'G16H50/30']  ['A61B', 'G16H']      3   1.0
# 3940   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']     32   1.0
# 3941     ['G16H40/67', 'G16H40/67']  ['G16H', 'G16H']     32   1.0
# 3942     ['G16H40/67', 'A61B5/021']  ['G16H', 'A61B']     32   1.0
# 3943     ['G16H10/60', 'H04N5/147']  ['G16H', 'H04N']     32   1.0
# 3944     ['G16H10/60', 'G16H30/20']  ['G16H', 'G16H']     32   1.0
# 3945     ['G16H20/10', 'G06N3/045']  ['G16H', 'G06N']     32   1.0
# 3946     ['G16H10/60', 'G16H30/40']  ['G16H', 'G16H']     32   1.0
# 3947      ['G16H10/60', 'A61B5/16']  ['G16H', 'A61B']     32   1.0
# 3948     ['G16H40/40', 'G16H40/20']  ['G16H', 'G16H']     32   1.0
# 3949     ['G16H10/60', 'G16H40/67']  ['G16H', 'G16H']     32   1.0
#
#      query_publication_numbers  \
# 3900           US20230001090A1
# 3901           US20230001090A1
# 3902           US20230001090A1
# 3903           US20230001090A1
# 3904           US20230001090A1
# 3905           US20230001090A1
# 3906           US20230001090A1
# 3907           US20230001090A1
# 3908           US20230001090A1
# 3909           US20230001090A1
# 3910           US20230001090A1
# 3911           US20230001090A1
# 3912           US20230001090A1
# 3913           US20230001090A1
# 3914           US20230001090A1
# 3915           US20230001090A1
# 3916           US20230001090A1
# 3917           US20230001090A1
# 3918           US20230001090A1
# 3919           US20230001090A1
# 3920           US20230001090A1
# 3921           US20230001090A1
# 3922           US20230001090A1
# 3923           US20230001090A1
# 3924           US20230001090A1
# 3925           US20230001090A1
# 3926           US20230001090A1
# 3927           US20230001090A1
# 3928           US20230001090A1
# 3929           US20230001090A1
# 3930           US20230001090A1
# 3931           US20230001090A1
# 3932           US20230001090A1
# 3933           US20230001090A1
# 3934           US20230001090A1
# 3935           US20230001090A1
# 3936           US20230001090A1
# 3937           US20230001090A1
# 3938           US20230001090A1
# 3939           US20230001090A1
# 3940           US20230001090A1
# 3941           US20230001090A1
# 3942           US20230001090A1
# 3943           US20230001090A1
# 3944           US20230001090A1
# 3945           US20230001090A1
# 3946           US20230001090A1
# 3947           US20230001090A1
# 3948           US20230001090A1
# 3949           US20230001090A1
#
#                                       query_class_codes  \
# 3900  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3901  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3902  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3903  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3904  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3905  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3906  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3907  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3908  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3909  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3910  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3911  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3912  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3913  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3914  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3915  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3916  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3917  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3918  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3919  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3920  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3921  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3922  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3923  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3924  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3925  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3926  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3927  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3928  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3929  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3930  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3931  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3932  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3933  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3934  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3935  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3936  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3937  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3938  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3939  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3940  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3941  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3942  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3943  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3944  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3945  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3946  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3947  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3948  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3949  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
#
#                                          query_abstract  \
# 3900  Methods and systems for delaying alarms that i...
# 3901  Methods and systems for delaying alarms that i...
# 3902  Methods and systems for delaying alarms that i...
# 3903  Methods and systems for delaying alarms that i...
# 3904  Methods and systems for delaying alarms that i...
# 3905  Methods and systems for delaying alarms that i...
# 3906  Methods and systems for delaying alarms that i...
# 3907  Methods and systems for delaying alarms that i...
# 3908  Methods and systems for delaying alarms that i...
# 3909  Methods and systems for delaying alarms that i...
# 3910  Methods and systems for delaying alarms that i...
# 3911  Methods and systems for delaying alarms that i...
# 3912  Methods and systems for delaying alarms that i...
# 3913  Methods and systems for delaying alarms that i...
# 3914  Methods and systems for delaying alarms that i...
# 3915  Methods and systems for delaying alarms that i...
# 3916  Methods and systems for delaying alarms that i...
# 3917  Methods and systems for delaying alarms that i...
# 3918  Methods and systems for delaying alarms that i...
# 3919  Methods and systems for delaying alarms that i...
# 3920  Methods and systems for delaying alarms that i...
# 3921  Methods and systems for delaying alarms that i...
# 3922  Methods and systems for delaying alarms that i...
# 3923  Methods and systems for delaying alarms that i...
# 3924  Methods and systems for delaying alarms that i...
# 3925  Methods and systems for delaying alarms that i...
# 3926  Methods and systems for delaying alarms that i...
# 3927  Methods and systems for delaying alarms that i...
# 3928  Methods and systems for delaying alarms that i...
# 3929  Methods and systems for delaying alarms that i...
# 3930  Methods and systems for delaying alarms that i...
# 3931  Methods and systems for delaying alarms that i...
# 3932  Methods and systems for delaying alarms that i...
# 3933  Methods and systems for delaying alarms that i...
# 3934  Methods and systems for delaying alarms that i...
# 3935  Methods and systems for delaying alarms that i...
# 3936  Methods and systems for delaying alarms that i...
# 3937  Methods and systems for delaying alarms that i...
# 3938  Methods and systems for delaying alarms that i...
# 3939  Methods and systems for delaying alarms that i...
# 3940  Methods and systems for delaying alarms that i...
# 3941  Methods and systems for delaying alarms that i...
# 3942  Methods and systems for delaying alarms that i...
# 3943  Methods and systems for delaying alarms that i...
# 3944  Methods and systems for delaying alarms that i...
# 3945  Methods and systems for delaying alarms that i...
# 3946  Methods and systems for delaying alarms that i...
# 3947  Methods and systems for delaying alarms that i...
# 3948  Methods and systems for delaying alarms that i...
# 3949  Methods and systems for delaying alarms that i...
#
#      query_predicted_topics  \
# 3900                   [41]
# 3901                   [41]
# 3902                   [41]
# 3903                   [41]
# 3904                   [41]
# 3905                   [41]
# 3906                   [41]
# 3907                   [41]
# 3908                   [41]
# 3909                   [41]
# 3910                   [36]
# 3911                   [36]
# 3912                   [36]
# 3913                   [36]
# 3914                   [36]
# 3915                   [36]
# 3916                   [36]
# 3917                   [36]
# 3918                   [36]
# 3919                   [36]
# 3920                   [26]
# 3921                   [26]
# 3922                   [26]
# 3923                   [26]
# 3924                   [26]
# 3925                   [26]
# 3926                   [26]
# 3927                   [26]
# 3928                   [26]
# 3929                   [26]
# 3930                    [3]
# 3931                    [3]
# 3932                    [3]
# 3933                    [3]
# 3934                    [3]
# 3935                    [3]
# 3936                    [3]
# 3937                    [3]
# 3938                    [3]
# 3939                    [3]
# 3940                   [32]
# 3941                   [32]
# 3942                   [32]
# 3943                   [32]
# 3944                   [32]
# 3945                   [32]
# 3946                   [32]
# 3947                   [32]
# 3948                   [32]
# 3949                   [32]
#
#                                        query_codes_G16H     exact_match_code  \
# 3900  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3901  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3902  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3903  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3904  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3905  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3906  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3907  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3908  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3909  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3910  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3911  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3912  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3913  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3914  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3915  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H50/50,G16H50/50
# 3916  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3917  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3918  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3919  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H40/60,G16H40/60
# 3920  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3921  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H50/50
# 3922  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3923  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3924  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/60
# 3925  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3926  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3927  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3928  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3929  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3930  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3931  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3932  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3933  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3934  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3935  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3936  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3937  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3938  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3939  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3940  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3941  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H40/67,G16H40/67
# 3942  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3943  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3944  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3945  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/10
# 3946  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3947  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3948  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3949  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
#
#       count_exact_match_top50  RFR
# 3900                       17  5.0
# 3901                       17  5.0
# 3902                       17  5.0
# 3903                       17  5.0
# 3904                       17  5.0
# 3905                       17  5.0
# 3906                       17  5.0
# 3907                       17  5.0
# 3908                       17  5.0
# 3909                       17  5.0
# 3910                       17  5.0
# 3911                       17  5.0
# 3912                       17  5.0
# 3913                       17  5.0
# 3914                       17  5.0
# 3915                       17  5.0
# 3916                       17  5.0
# 3917                       17  5.0
# 3918                       17  5.0
# 3919                       17  5.0
# 3920                       17  5.0
# 3921                       17  5.0
# 3922                       17  5.0
# 3923                       17  5.0
# 3924                       17  5.0
# 3925                       17  5.0
# 3926                       17  5.0
# 3927                       17  5.0
# 3928                       17  5.0
# 3929                       17  5.0
# 3930                       17  5.0
# 3931                       17  5.0
# 3932                       17  5.0
# 3933                       17  5.0
# 3934                       17  5.0
# 3935                       17  5.0
# 3936                       17  5.0
# 3937                       17  5.0
# 3938                       17  5.0
# 3939                       17  5.0
# 3940                       17  5.0
# 3941                       17  5.0
# 3942                       17  5.0
# 3943                       17  5.0
# 3944                       17  5.0
# 3945                       17  5.0
# 3946                       17  5.0
# 3947                       17  5.0
# 3948                       17  5.0
# 3949                       17  5.0

# %%
result_df.to_csv('BERTopic-without-Preprocessing-Abstract-BM25', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     1.0
# 1            US20230001263A1                     3.0
# 2            US20230005591A1                     4.0
# 3            US20230005611A1                     0.0
# 4            US20230009812A1                     2.0
# ..                       ...                     ...
# 95           US20230255518A1                     3.0
# 96           US20230259481A1                     2.0
# 97           US20230260617A1                     5.0
# 98           US20230264029A1                     1.0
# 99           US20230270344A1                     4.0
#
# [100 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 1.85

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                     17.0
# 1            US20230001263A1                     12.0
# 2            US20230005591A1                     25.0
# 3            US20230005611A1                      7.0
# 4            US20230009812A1                     11.0
# ..                       ...                      ...
# 95           US20230255518A1                     10.0
# 96           US20230259481A1                     13.0
# 97           US20230260617A1                     13.0
# 98           US20230264029A1                      9.0
# 99           US20230270344A1                     25.0
#
# [100 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 15.19

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1   5.0
# 1            US20230001263A1   1.0
# 2            US20230005591A1   1.0
# 3            US20230005611A1  16.0
# 4            US20230009812A1   1.0
# ..                       ...   ...
# 95           US20230255518A1   2.0
# 96           US20230259481A1   2.0
# 97           US20230260617A1   1.0
# 98           US20230264029A1   5.0
# 99           US20230270344A1   1.0
#
# [100 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 4.8979591836734695
