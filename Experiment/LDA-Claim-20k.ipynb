# %%
# Read uspto dataset
import pandas as pd
import numpy as np
import nltk


df = pd.read_csv('./dataset/df-claim-A.csv')
df_claim=df[["ID","Title","Claim","cpc_subclass"]]
df_claim= df_claim.dropna()
df_claim = df_claim.reset_index(drop=True)
df_claim.head()
# Out:
#         ID                                              Title  \
# 0  8927300  Method and compositions for the detection of p...
# 1  8930992                      TV social network advertising
# 2  8929358  Call flow system and method for use in a legac...
# 3  8925531                   Spark plug degradation detection
# 4  8927955                           Resistance change memory
#
#                                                Claim              cpc_subclass
# 0  1. A compound of the formula: wherein R is a s...  C07H,C07K,C12N,C12Q,G01N
# 1  1. An advertising method, comprising: displayi...                 G06Q,H04N
# 2  1. A method, comprising: receiving, from a mob...  H04L,H04M,H04Q,H04W,H05K
# 3  1. A method of controlling an engine cylinder ...            F02D,F02P,Y02T
# 4  1. A resistance change memory comprising: a fi...            B82Y,G11C,H01L

# %%
len(df_claim)
# Out:
# 1428600

# %%
#filter base on the section H
df_claim_uspto = df_claim[df_claim['cpc_subclass'].str.contains(r'\bH[\w]*|,[\s]*H[\w]*')]
df_claim_uspto
# Out:
#                ID                                              Title  \
# 1         8930992                      TV social network advertising
# 2         8929358  Call flow system and method for use in a legac...
# 4         8927955                           Resistance change memory
# 6         8928653  Information processing system, information pro...
# 7         8930595     Memory switch for interconnecting server nodes
# ...           ...                                                ...
# 1428585  10367288       Electric contact and connector terminal pair
# 1428587  10368332  Enhanced location determination of wireless de...
# 1428588  10367624  Uplink multi-bits acknowledgement for self con...
# 1428590  10367054                        Semiconductor memory device
# 1428592  10367250  Antenna structure and electronic device includ...
#
#                                                      Claim  \
# 1        1. An advertising method, comprising: displayi...
# 2        1. A method, comprising: receiving, from a mob...
# 4        1. A resistance change memory comprising: a fi...
# 6        1. An information processing system comprising...
# 7        1. A computer-implemented method for transferr...
# ...                                                    ...
# 1428585  1. An electric contact comprising: a first con...
# 1428587  1. A device, the device comprising memory and ...
# 1428588  1. A method for communicating feedback in wire...
# 1428590  1. A semiconductor memory device, comprising: ...
# 1428592  1. An electronic device comprising: a housing ...
#
#                      cpc_subclass
# 1                       G06Q,H04N
# 2        H04L,H04M,H04Q,H04W,H05K
# 4                  B82Y,G11C,H01L
# 6                  A63F,G06F,H04N
# 7                       G06F,H04L
# ...                           ...
# 1428585                 C25D,H01R
# 1428587                      H04W
# 1428588                 H04L,H04W
# 1428590                      H01L
# 1428592                      H01Q
#
# [570658 rows x 4 columns]

# %%
#df_claim=df_claim[["grant_id","patent_title","claims_text","abstract", "main_classification"]]
df_claim_uspto["Claim"]= df_claim_uspto["Claim"].dropna()
df_claim_uspto = df_claim_uspto.reset_index(drop=True)
df_claim_uspto
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/844082689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto["Claim"]= df_claim_uspto["Claim"].dropna()
#               ID                                              Title  \
# 0        8930992                      TV social network advertising
# 1        8929358  Call flow system and method for use in a legac...
# 2        8927955                           Resistance change memory
# 3        8928653  Information processing system, information pro...
# 4        8930595     Memory switch for interconnecting server nodes
# ...          ...                                                ...
# 570653  10367288       Electric contact and connector terminal pair
# 570654  10368332  Enhanced location determination of wireless de...
# 570655  10367624  Uplink multi-bits acknowledgement for self con...
# 570656  10367054                        Semiconductor memory device
# 570657  10367250  Antenna structure and electronic device includ...
#
#                                                     Claim  \
# 0       1. An advertising method, comprising: displayi...
# 1       1. A method, comprising: receiving, from a mob...
# 2       1. A resistance change memory comprising: a fi...
# 3       1. An information processing system comprising...
# 4       1. A computer-implemented method for transferr...
# ...                                                   ...
# 570653  1. An electric contact comprising: a first con...
# 570654  1. A device, the device comprising memory and ...
# 570655  1. A method for communicating feedback in wire...
# 570656  1. A semiconductor memory device, comprising: ...
# 570657  1. An electronic device comprising: a housing ...
#
#                     cpc_subclass
# 0                      G06Q,H04N
# 1       H04L,H04M,H04Q,H04W,H05K
# 2                 B82Y,G11C,H01L
# 3                 A63F,G06F,H04N
# 4                      G06F,H04L
# ...                          ...
# 570653                 C25D,H01R
# 570654                      H04W
# 570655                 H04L,H04W
# 570656                      H01L
# 570657                      H01Q
#
# [570658 rows x 4 columns]

# %%
df_claim_uspto=df_claim_uspto[:60000]
df_claim_uspto
# Out:
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 59995  9083179                Load circuit disconnection detector
# 59996  9081267                Light emitting device and projector
# 59997  9083330           Output driver with slew rate calibration
# 59998  9082598  Segmented planar calibration for correction of...
# 59999  9083514  Distributed single sign on technologies includ...
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 59995  1. A load circuit disconnection detector which...
# 59996  1. A light emitting device comprising: a first...
# 59997  1. A driver for driving a data output signal t...
# 59998  1. An ion detector system for a mass spectrome...
# 59999  1. A method performed on a computing device th...
#
#                    cpc_subclass
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 59995            G01R,H02H,Y02E
# 59996            G02B,G03B,H01L
# 59997                 H03K,H04L
# 59998                      H01J
# 59999                      H04L
#
# [60000 rows x 4 columns]

# %% [markdown]
# # preprocessing

# %%
def cleantext(df_claim_uspto):
    
    # Replace certain characters with empty string
    df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['Claim'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
    
    # Convert all text to lowercase
    df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].str.lower()
    
    # Remove all numbers
    df_claim_uspto['cleaned_claims_text'] =df_claim_uspto['cleaned_claims_text'].replace(r'\d+', '', regex = True)
        
    # Remove all symbols except alphabets and numbers
    df_claim_uspto['cleaned_claims_text']  = df_claim_uspto['cleaned_claims_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
    
    # Remove all punctuations
    df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
    
    # Remove all URLs
    df_claim_uspto['cleaned_claims_text']  = df_claim_uspto['cleaned_claims_text'].replace(r'https.*$', "", regex = True)
    
    # Remove multiple spaces and replace with a single space
    df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace("   ", " ", regex = True)
    df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace("  ", " ", regex = True)
   
    # Return the cleaned dataframe
    return df_claim_uspto

# Call the function to clean the dataframe and save the result in df_claim_uspto
df_claim_uspto = cleantext(df_claim_uspto)

# Print the cleaned dataframe
df_claim_uspto
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['Claim'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].str.lower()
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] =df_claim_uspto['cleaned_claims_text'].replace(r'\d+', '', regex = True)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text']  = df_claim_uspto['cleaned_claims_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
# C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\inference.py:181: FutureWarning: Possible nested set at position 1
#   re.compile(obj)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text']  = df_claim_uspto['cleaned_claims_text'].replace(r'https.*$', "", regex = True)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace("   ", " ", regex = True)
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3384947362.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claims_text'] = df_claim_uspto['cleaned_claims_text'].replace("  ", " ", regex = True)
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 59995  9083179                Load circuit disconnection detector
# 59996  9081267                Light emitting device and projector
# 59997  9083330           Output driver with slew rate calibration
# 59998  9082598  Segmented planar calibration for correction of...
# 59999  9083514  Distributed single sign on technologies includ...
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 59995  1. A load circuit disconnection detector which...
# 59996  1. A light emitting device comprising: a first...
# 59997  1. A driver for driving a data output signal t...
# 59998  1. An ion detector system for a mass spectrome...
# 59999  1. A method performed on a computing device th...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 59995            G01R,H02H,Y02E
# 59996            G02B,G03B,H01L
# 59997                 H03K,H04L
# 59998                      H01J
# 59999                      H04L
#
#                                      cleaned_claims_text
# 0       an advertising method comprising displaying a...
# 1       a method comprising receiving from a mobile s...
# 2       a resistance change memory comprising a first...
# 3       an information processing system comprising a...
# 4       a computerimplemented method for transferring...
# ...                                                  ...
# 59995   a load circuit disconnection detector which b...
# 59996   a light emitting device comprising a first la...
# 59997   a driver for driving a data output signal thr...
# 59998   an ion detector system for a mass spectromete...
# 59999   a method performed on a computing device that...
#
# [60000 rows x 5 columns]

# %%
import nltk
from nltk.corpus import stopwords

# Load the stop words
nltk.download('stopwords')
english_stop_words = set(stopwords.words('english'))

# Define a set of patent-specific stop words
patent_stop_words = set(["invention", "apparatus", "method", "system", "device",
                         "means", "comprising", "having", "including", "wherein",
                         "according", "configured", "configured to", "configured for",
                         "one or more", "plurality", "at least", "said", "and/or",
                         "thereof", "thereto", "herein", "hereby", "hereof", "hereunder",
                         "hereto", "herewith", "respectively", "corresponding",
                         "respectively corresponding", "substantially", "generally",
                         "typically", "usually", "often", "frequently", "commonly",
                         "normally", "conventional", "traditional", "known", "prior",
                         "art", "field", "related", "disclosed", "described", "illustrated",
                         "embodiment", "example", "figure", "graph", "chart", "data",
                         "information", "section", "portion", "aspect", "aspect of",
                         "part", "feature", "detail", "particular", "certain", "some",
                         "many", "various", "multiple", "different", "differentiate",
                         "similar", "corresponding", "correspondingly", "also",
                         "in addition", "furthermore", "moreover", "additionally",
                         "especially", "particular", "particularity", "specific",
                         "specifically", "example", "exemplary", "illustrative",
                         "such as", "include", "includes", "including", "included",
                         "contain", "contains", "containing", "contained", "shown"])

# Merge the sets of stop words
stop_words = english_stop_words.union(patent_stop_words)

df_claim_uspto['cleaned_claim_text_without_Stopwprd'] = df_claim_uspto['cleaned_claims_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
df_claim_uspto
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/3001502917.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['cleaned_claim_text_without_Stopwprd'] = df_claim_uspto['cleaned_claims_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 59995  9083179                Load circuit disconnection detector
# 59996  9081267                Light emitting device and projector
# 59997  9083330           Output driver with slew rate calibration
# 59998  9082598  Segmented planar calibration for correction of...
# 59999  9083514  Distributed single sign on technologies includ...
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 59995  1. A load circuit disconnection detector which...
# 59996  1. A light emitting device comprising: a first...
# 59997  1. A driver for driving a data output signal t...
# 59998  1. An ion detector system for a mass spectrome...
# 59999  1. A method performed on a computing device th...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 59995            G01R,H02H,Y02E
# 59996            G02B,G03B,H01L
# 59997                 H03K,H04L
# 59998                      H01J
# 59999                      H04L
#
#                                      cleaned_claims_text  \
# 0       an advertising method comprising displaying a...
# 1       a method comprising receiving from a mobile s...
# 2       a resistance change memory comprising a first...
# 3       an information processing system comprising a...
# 4       a computerimplemented method for transferring...
# ...                                                  ...
# 59995   a load circuit disconnection detector which b...
# 59996   a light emitting device comprising a first la...
# 59997   a driver for driving a data output signal thr...
# 59998   an ion detector system for a mass spectromete...
# 59999   a method performed on a computing device that...
#
#                      cleaned_claim_text_without_Stopwprd
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 59995  load circuit disconnection detector breaks loa...
# 59996  light emitting first layer generates light inj...
# 59997  driver driving output signal output pad pulldo...
# 59998  ion detector mass spectrometer ion detector co...
# 59999  performed computing least one processor memory...
#
# [60000 rows x 6 columns]

# %%
# Import the necessary library
from nltk.stem import WordNetLemmatizer

# Create an instance of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Define a function to lemmatize each word in a given text
def lemmatize_words(text):
    # Split the text into individual words
    words = text.split()
    # Apply lemmatization to each word and join them back into a string
    return " ".join([lemmatizer.lemmatize(word) for word in words])

# Apply the lemmatize_words function to the 'cleaned_claim_text_without_Stopwprd' column of the dataframe
df_claim_uspto["Lemmatized-Claim"] = df_claim_uspto["cleaned_claim_text_without_Stopwprd"].apply(lambda text: lemmatize_words(text))

# Print the resulting dataframe with the added 'Lemmatized-Cliam' column
df_claim_uspto
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/423572630.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto["Lemmatized-Claim"] = df_claim_uspto["cleaned_claim_text_without_Stopwprd"].apply(lambda text: lemmatize_words(text))
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 59995  9083179                Load circuit disconnection detector
# 59996  9081267                Light emitting device and projector
# 59997  9083330           Output driver with slew rate calibration
# 59998  9082598  Segmented planar calibration for correction of...
# 59999  9083514  Distributed single sign on technologies includ...
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 59995  1. A load circuit disconnection detector which...
# 59996  1. A light emitting device comprising: a first...
# 59997  1. A driver for driving a data output signal t...
# 59998  1. An ion detector system for a mass spectrome...
# 59999  1. A method performed on a computing device th...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 59995            G01R,H02H,Y02E
# 59996            G02B,G03B,H01L
# 59997                 H03K,H04L
# 59998                      H01J
# 59999                      H04L
#
#                                      cleaned_claims_text  \
# 0       an advertising method comprising displaying a...
# 1       a method comprising receiving from a mobile s...
# 2       a resistance change memory comprising a first...
# 3       an information processing system comprising a...
# 4       a computerimplemented method for transferring...
# ...                                                  ...
# 59995   a load circuit disconnection detector which b...
# 59996   a light emitting device comprising a first la...
# 59997   a driver for driving a data output signal thr...
# 59998   an ion detector system for a mass spectromete...
# 59999   a method performed on a computing device that...
#
#                      cleaned_claim_text_without_Stopwprd  \
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 59995  load circuit disconnection detector breaks loa...
# 59996  light emitting first layer generates light inj...
# 59997  driver driving output signal output pad pulldo...
# 59998  ion detector mass spectrometer ion detector co...
# 59999  performed computing least one processor memory...
#
#                                         Lemmatized-Claim
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 59995  load circuit disconnection detector break load...
# 59996  light emitting first layer generates light inj...
# 59997  driver driving output signal output pad pulldo...
# 59998  ion detector mass spectrometer ion detector co...
# 59999  performed computing least one processor memory...
#
# [60000 rows x 7 columns]

# %%
#tokenize corpus
nltk.download('punkt')

#tokenize a string into words
def tokenize_text(text):
    tokens = nltk.word_tokenize(text)
    return tokens

# Apply the tokenization function to each row of the 'Lemmatized-Claim' column
df_claim_uspto['Claim_tokens'] = df_claim_uspto["Lemmatized-Claim"].apply(tokenize_text)
df_claim_uspto
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/2856393971.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_uspto['Claim_tokens'] = df_claim_uspto["Lemmatized-Claim"].apply(tokenize_text)
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 59995  9083179                Load circuit disconnection detector
# 59996  9081267                Light emitting device and projector
# 59997  9083330           Output driver with slew rate calibration
# 59998  9082598  Segmented planar calibration for correction of...
# 59999  9083514  Distributed single sign on technologies includ...
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 59995  1. A load circuit disconnection detector which...
# 59996  1. A light emitting device comprising: a first...
# 59997  1. A driver for driving a data output signal t...
# 59998  1. An ion detector system for a mass spectrome...
# 59999  1. A method performed on a computing device th...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 59995            G01R,H02H,Y02E
# 59996            G02B,G03B,H01L
# 59997                 H03K,H04L
# 59998                      H01J
# 59999                      H04L
#
#                                      cleaned_claims_text  \
# 0       an advertising method comprising displaying a...
# 1       a method comprising receiving from a mobile s...
# 2       a resistance change memory comprising a first...
# 3       an information processing system comprising a...
# 4       a computerimplemented method for transferring...
# ...                                                  ...
# 59995   a load circuit disconnection detector which b...
# 59996   a light emitting device comprising a first la...
# 59997   a driver for driving a data output signal thr...
# 59998   an ion detector system for a mass spectromete...
# 59999   a method performed on a computing device that...
#
#                      cleaned_claim_text_without_Stopwprd  \
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 59995  load circuit disconnection detector breaks loa...
# 59996  light emitting first layer generates light inj...
# 59997  driver driving output signal output pad pulldo...
# 59998  ion detector mass spectrometer ion detector co...
# 59999  performed computing least one processor memory...
#
#                                         Lemmatized-Claim  \
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 59995  load circuit disconnection detector break load...
# 59996  light emitting first layer generates light inj...
# 59997  driver driving output signal output pad pulldo...
# 59998  ion detector mass spectrometer ion detector co...
# 59999  performed computing least one processor memory...
#
#                                             Claim_tokens
# 0      [advertising, displaying, television, program,...
# 1      [receiving, mobile, switching, network, carrie...
# 2      [resistance, change, memory, first, interconne...
# 3      [processing, first, processing, second, proces...
# 4      [computerimplemented, transferring, electronic...
# ...                                                  ...
# 59995  [load, circuit, disconnection, detector, break...
# 59996  [light, emitting, first, layer, generates, lig...
# 59997  [driver, driving, output, signal, output, pad,...
# 59998  [ion, detector, mass, spectrometer, ion, detec...
# 59999  [performed, computing, least, one, processor, ...
#
# [60000 rows x 8 columns]

# %% [markdown]
# # divide the dataset

# %%
#Divide the dataset into different size
df_claim_20K=df_claim_uspto[:20000]
df_claim_20K
# Out:
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 19995  8975813                              Light emitting device
# 19996  8975173  Semiconductor device with buried gate and meth...
# 19997  8976859  Processing a video for spatial and temporal ma...
# 19998  8977244                       Extensible phone application
# 19999  8977979                Social network relationship mapping
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 19995  1. A display device comprising: a first substr...
# 19996  1. A method for fabricating a semiconductor de...
# 19997  1. A method for increasing a resolution of a v...
# 19998  1. A mobile communication device, comprising: ...
# 19999  1. A method for determining and displaying rel...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 19995                 H01L,Y10S
# 19996                      H01L
# 19997                 G06T,H04N
# 19998                      H04M
# 19999                 G06F,H04L
#
#                                      cleaned_claims_text  \
# 0       an advertising method comprising displaying a...
# 1       a method comprising receiving from a mobile s...
# 2       a resistance change memory comprising a first...
# 3       an information processing system comprising a...
# 4       a computerimplemented method for transferring...
# ...                                                  ...
# 19995   a display device comprising a first substrate...
# 19996   a method for fabricating a semiconductor devi...
# 19997   a method for increasing a resolution of a vid...
# 19998   a mobile communication device comprising a me...
# 19999   a method for determining and displaying relat...
#
#                      cleaned_claim_text_without_Stopwprd  \
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 19995  display first substrate first pixel first subs...
# 19996  fabricating semiconductor forming first layer ...
# 19997  increasing resolution video receiving image fr...
# 19998  mobile communication memory encoded computerex...
# 19999  determining displaying relationships social ne...
#
#                                         Lemmatized-Claim  \
# 0      advertising displaying television program vide...
# 1      receiving mobile switching network carrier gat...
# 2      resistance change memory first interconnect li...
# 3      processing first processing second processing ...
# 4      computerimplemented transferring electronic de...
# ...                                                  ...
# 19995  display first substrate first pixel first subs...
# 19996  fabricating semiconductor forming first layer ...
# 19997  increasing resolution video receiving image fr...
# 19998  mobile communication memory encoded computerex...
# 19999  determining displaying relationship social net...
#
#                                             Claim_tokens
# 0      [advertising, displaying, television, program,...
# 1      [receiving, mobile, switching, network, carrie...
# 2      [resistance, change, memory, first, interconne...
# 3      [processing, first, processing, second, proces...
# 4      [computerimplemented, transferring, electronic...
# ...                                                  ...
# 19995  [display, first, substrate, first, pixel, firs...
# 19996  [fabricating, semiconductor, forming, first, l...
# 19997  [increasing, resolution, video, receiving, ima...
# 19998  [mobile, communication, memory, encoded, compu...
# 19999  [determining, displaying, relationship, social...
#
# [20000 rows x 8 columns]

# %%
New_Sample = df_claim_uspto.iloc[59394:59395, :]
New_Sample
# Out:
#             ID                                             Title  \
# 59394  9083591  Communication apparatus and communication method
#
#                                                    Claim cpc_subclass  \
# 59394  1. A communication apparatus for communicating...         H04L
#
#                                      cleaned_claims_text  \
# 59394   a communication apparatus for communicating w...
#
#                      cleaned_claim_text_without_Stopwprd  \
# 59394  communication communicating another orthogonal...
#
#                                         Lemmatized-Claim  \
# 59394  communication communicating another orthogonal...
#
#                                             Claim_tokens
# 59394  [communication, communicating, another, orthog...

# %%
new_claim = str(New_Sample["Lemmatized-Claim"].iloc[0])
new_claim
# Out:
# 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'

# %% [markdown]
# # LDA on 20K patent

# %%
from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

# Tokenize the abstracts
docs = [doc.split() for doc in df_claim_20K['Lemmatized-Claim']]

# Apply n-gram (1,3) using the Phrases class from Gensim
bigram_phrases = Phrases(docs, min_count=10)  # bigram model
trigram_phrases = Phrases(bigram_phrases[docs], min_count=10)  # trigram model

#quadgram_phraser = Phrases(trigram_phrases[bigram_phrases[docs]])
#docs = [quadgram_phraser[trigram_phrases[bigram_phrases[doc]]] for doc in docs]

docs = [trigram_phrases[bigram_phrases[doc]] for doc in docs]  # apply the trigram model to the tokenized documents

# Create the dictionary and document-term matrix using the Dictionary class from Gensim
id2word = Dictionary(docs)
id2word.filter_extremes(no_below=10, no_above=0.4)  # remove infrequent and very frequent words from the dictionary
corpus = [id2word.doc2bow(doc) for doc in docs]  # convert the tokenized documents to a bag-of-words corpus

# Train the LDA model using the LdaModel class from Gensim
num_topics = 70  # the number of topics to discover
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics, passes=10, random_state=42)

# Transform the corpus to get the topic distribution for each document
lda_output = lda_model[corpus]

# Calculate coherence metrics using the CoherenceModel class from Gensim
cm_cv = CoherenceModel(model=lda_model, corpus=corpus, texts=docs, dictionary=id2word, coherence='c_v')
coherence_cv = cm_cv.get_coherence()  # get the coherence score for the C_v metric

cm_npmi = CoherenceModel(model=lda_model, texts=docs, corpus=corpus, dictionary=id2word, coherence='c_npmi')
coherence_npmi = cm_npmi.get_coherence()  # get the coherence score for the c_npmi metric

cm_umass = CoherenceModel(model=lda_model, corpus=corpus, dictionary=id2word, coherence='u_mass')
coherence_umass = cm_umass.get_coherence()  # get the coherence score for the u_mass metric

# Print the coherence scores
print('C_v coherence:', coherence_cv)
print('c_npmi coherence:', coherence_npmi)
print('u_mass coherence:', coherence_umass)
# Out:
# C_v coherence: 0.48261153251985583
# c_npmi coherence: -0.11532409454951423
# u_mass coherence: -8.371539604147335

# %%
# Print the most significant words for each topic in the model
for topic_num in range(lda_model.num_topics):
    # Get the top 5 words for the current topic
    top_words = lda_model.show_topic(topic_num, topn=10)
    # Join the words into a single string for printing
    word_list = [word for word, _ in top_words]
    topic_words = " ".join(word_list)
    # Print the topic number and its top words
    print(f"Topic #{topic_num}: {topic_words}")
# Out:
# Topic #0: substrate pattern forming surface form mask opening silicon removing formed
# Topic #1: anode cathode organic range coating oxide emission solar_cell light_emitting concentration
# Topic #2: sensor receiver transmitter characteristic received quality band broadcast representation scanning
# Topic #3: cell motor pressure token capacity valve reverse fuel termination analog_signal
# Topic #4: processor memory flow coupled operable station variable machine generator instruction
# Topic #5: pair energy rate cable time_period semiconductor_chip mirror cylindrical curved cylinder
# Topic #6: third transistor gate fourth container resistor drain cluster coupled scan
# Topic #7: image position point camera imaging distance based processing object screen
# Topic #8: transfer table supply electric status back fuel_cell fluid emitter transferring
# Topic #9: light chip internal panel light_source holder section microphone receiving elongated
# Topic #10: external active bit rf transceiver low volume site high job
# Topic #11: least_one mode stream command least selected one recipient advertisement receiving
# Topic #12: source function host distribution designated mesh public touch combined powered
# Topic #13: port authentication virtual physical piece vector logic given tube queue
# Topic #14: region semiconductor conductor gate_electrode semiconductor_substrate formed disposed conductivity_type source well
# Topic #15: mobile location address test vehicle new initial potential determining collection
# Topic #16: connection connected driving ground driver resistance positive memory_cell discharge negative
# Topic #17: structure coil magnetic sheet case shaft height magnet alignment force
# Topic #18: filter pad face domain peripheral account part email passivation_layer design
# Topic #19: channel computing resource code identity available spectrum communication_session least requested
# Topic #20: forming trench dielectric_layer sidewall stack top_surface top bottom fin structure
# Topic #21: signal output input frequency phase generate circuit receive control digital
# Topic #22: set type object one associated based event identifying determining subset
# Topic #23: ring interference linear estimate noise desired estimated decision represents socket
# Topic #24: content sequence selected selection list receiving user_interface response selecting presentation
# Topic #25: process symbol read document reading auxiliary rotation tray calculation multilayer
# Topic #26: value time number predetermined determining based threshold period measurement amount
# Topic #27: electrode line wiring pixel disposed insulating provided formed protrusion electrically_connected
# Topic #28: device medium audio digital remote page one communication_link single via
# Topic #29: pixel block reference value color error using correction difference picture
# Topic #30: main drive coupling intermediate sound lighting adjustment mechanism transaction calibration
# Topic #31: state operation cavity clock transition change cycle stop starting wave
# Topic #32: direction arranged inner length outer along ion width shape package
# Topic #33: terminal sensing connected logical extended photovoltaic intermediary conference_call spacing mixed
# Topic #34: element view actuator detector arm illumination reflection least_one binary appliance
# Topic #35: group pin row extension three speaker plural enclosure l brightness
# Topic #36: step b c compound polymer resin composition bonding selected_group_consisting applying
# Topic #37: slot circuit_board dielectric open dimension seal bridge tool track system
# Topic #38: user associated profile based one medium_content activity equipment word providing
# Topic #39: target temperature chamber gas beam heat cooling air heating liquid
# Topic #40: plate lens plane vertical subsystem tab horizontal sealing rail inner_surface
# Topic #41: area flexible release lead_frame overlap piezoelectric tuning trace alternating exhaust
# Topic #42: interface configuration carrier die window boundary arrangement waveguide virtual_machine party
# Topic #43: n array circuitry integrated_circuit b r e x relay c
# Topic #44: member base lower least_two upper bus column ceramic attachment upper_surface
# Topic #45: current zone led membrane string branch peak intensity k payload
# Topic #46: server request message application client computer receiving response identifier associated
# Topic #47: optical additional wavelength laser radiation printed_circuit_board quantity text log fiber
# Topic #48: housing position opening hole cover space mounting mounted movable fixed
# Topic #49: frame base_station core ue version subframe allocation allocated electrolyte transmitting
# Topic #50: material film doped protection source_drain cap oxide_layer formed diffusion backside
# Topic #51: body contact electronic connector assembly wire individual feed spring loop
# Topic #52: communication transmission control component power transmitting transmit transmitted radio receiving
# Topic #53: layer conductive metal semiconductor formed surface insulating_layer wafer disposed substrate
# Topic #54: mobile_communication indicator trigger instance scheduling delivery option authorized joint q
# Topic #55: electrical aperture positioning least_one electrically_conductive electronic_component continuous least electrical_contact electrical_connection
# Topic #56: controller parameter operating condition detection controlling impedance factor grid video_content
# Topic #57: network service access call link via protocol communication message gateway
# Topic #58: circuit voltage switch control power switching load coupled battery output
# Topic #59: display segment displaying displayed input display_panel report image_pickup managed display_screen
# Topic #60: packet primary traffic destination subscriber routing route secondary router dynamic
# Topic #61: central agent customer card engine platform usage bar web web_page
# Topic #62: video encoded encoding recording header modulation conducting name recorded video_stream
# Topic #63: node antenna wireless_communication local user_equipment receiving transmitting mobile_terminal uplink access_point
# Topic #64: one module respective path processing two item plug voice hardware
# Topic #65: center angle depth plasma series degree pole resonator normal shield
# Topic #66: unit processing control setting predetermined reception detection master performs perform
# Topic #67: surface side end portion edge support extending wall disposed groove
# Topic #68: storage key file stored program storing store using encrypted format
# Topic #69: wireless level common buffer interval enabled lamp mobility ribbon hot

# %%
import networkx as nx
from collections import Counter
import matplotlib.pyplot as plt

# Get all the topic words
all_topic_words = " ".join([word for topic in lda_model.show_topics(num_topics=70, formatted=False) for word, _ in topic[1]])

# Create a list of the most frequent words
most_frequent_words = [word for word, count in Counter(all_topic_words.split()).most_common(30)]

# Create an empty graph object
G = nx.Graph()

# Add the nodes (topics) to the graph
for i in range(70):
    G.add_node(i)

# Add the edges (terms) to the graph
for i in range(70):
    topic_words = lda_model.show_topic(i, topn=10)
    for word, prob in topic_words:
        if word in most_frequent_words:
            j = most_frequent_words.index(word)
            G.add_edge(i, j, weight=prob)

# Draw the graph
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=True, node_color="skyblue", node_size=1500, font_size=10, font_weight="bold")
nx.draw_networkx_edge_labels(G, pos, edge_labels={(i, j): "{:.2f}".format(d["weight"]) for i, j, d in G.edges(data=True)})
plt.gcf().set_size_inches(15, 15)
plt.title("LDA Network Graph for 20K Patent Claim",fontsize=20)
plt.show()

# %%
#Get the topic and probability for each document

# %%
# Get the most probable topic and its probability for each document
doc_topics = [sorted(lda_model.get_document_topics(doc), key=lambda x: x[1], reverse=True) for doc in lda_output]

# Print the most probable topic and its probability for each document
# for i, doc in enumerate(doc_topics):
#     print(f"Document {i+1}:")
#     for topic, prob in doc:
#         print(f"Topic {topic}: {prob:.4f}")
#     print()

# %%
# Create empty columns for topic number and probability
df_claim_20K['LDA_topics'] = 0
df_claim_20K['LDA_prob'] = 0.0

# Loop through each document and update the corresponding row in the dataframe
for i, doc in enumerate(doc_topics):
    topic_num, topic_prob = doc[0]
    df_claim_20K.at[i, 'LDA_topics'] = topic_num
    df_claim_20K.at[i, 'LDA_prob'] = topic_prob
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/2074810121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_20K['LDA_topics'] = 0
# C:\Users\admin\AppData\Local\Temp/ipykernel_9396/2074810121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_claim_20K['LDA_prob'] = 0.0

# %%
df_Claim_20K_topic=df_claim_20K[["ID","Title","Claim","cpc_subclass","Lemmatized-Claim", "LDA_topics", "LDA_prob"]]
df_Claim_20K_topic
# Out:
#             ID                                              Title  \
# 0      8930992                      TV social network advertising
# 1      8929358  Call flow system and method for use in a legac...
# 2      8927955                           Resistance change memory
# 3      8928653  Information processing system, information pro...
# 4      8930595     Memory switch for interconnecting server nodes
# ...        ...                                                ...
# 19995  8975813                              Light emitting device
# 19996  8975173  Semiconductor device with buried gate and meth...
# 19997  8976859  Processing a video for spatial and temporal ma...
# 19998  8977244                       Extensible phone application
# 19999  8977979                Social network relationship mapping
#
#                                                    Claim  \
# 0      1. An advertising method, comprising: displayi...
# 1      1. A method, comprising: receiving, from a mob...
# 2      1. A resistance change memory comprising: a fi...
# 3      1. An information processing system comprising...
# 4      1. A computer-implemented method for transferr...
# ...                                                  ...
# 19995  1. A display device comprising: a first substr...
# 19996  1. A method for fabricating a semiconductor de...
# 19997  1. A method for increasing a resolution of a v...
# 19998  1. A mobile communication device, comprising: ...
# 19999  1. A method for determining and displaying rel...
#
#                    cpc_subclass  \
# 0                     G06Q,H04N
# 1      H04L,H04M,H04Q,H04W,H05K
# 2                B82Y,G11C,H01L
# 3                A63F,G06F,H04N
# 4                     G06F,H04L
# ...                         ...
# 19995                 H01L,Y10S
# 19996                      H01L
# 19997                 G06T,H04N
# 19998                      H04M
# 19999                 G06F,H04L
#
#                                         Lemmatized-Claim  LDA_topics  LDA_prob
# 0      advertising displaying television program vide...          22  0.285236
# 1      receiving mobile switching network carrier gat...          57  0.315694
# 2      resistance change memory first interconnect li...          15  0.301497
# 3      processing first processing second processing ...          46  0.214217
# 4      computerimplemented transferring electronic de...          59  0.259928
# ...                                                  ...         ...       ...
# 19995  display first substrate first pixel first subs...          11  0.209496
# 19996  fabricating semiconductor forming first layer ...          11  0.330709
# 19997  increasing resolution video receiving image fr...          11  0.246703
# 19998  mobile communication memory encoded computerex...          15  0.219278
# 19999  determining displaying relationship social net...          11  0.209896
#
# [20000 rows x 7 columns]

# %%
#prediction

# %%
new_claim = str(New_Sample["Lemmatized-Claim"].iloc[0])
new_claim
# Out:
# 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'

# %%
#query_tokens = quadgram_phraser[trigram_phrases[bigram_phrases[new_Abstract.split()]]]

# Tokenize the new claim and apply n-gram (1,3)
query_tokens = trigram_phrases[bigram_phrases[new_claim.split()]]

# Create a bag of words representation of the query
query_bow = id2word.doc2bow(query_tokens)

# Get the topic distribution for the query using the trained LDA model
query_lda = lda_model[query_bow]

# Print the topic distribution for the query
print(query_lda)
# Out:
# [(1, 0.036274824), (2, 0.01085747), (7, 0.04192288), (9, 0.024576506), (10, 0.010119548), (21, 0.30123734), (22, 0.023720015), (23, 0.016955495), (25, 0.013633607), (26, 0.0472929), (29, 0.04294408), (30, 0.010503833), (32, 0.043631762), (34, 0.041666992), (35, 0.026371282), (36, 0.014101436), (46, 0.012581556), (47, 0.027795324), (49, 0.020779526), (52, 0.050792117), (58, 0.044666894), (62, 0.020419573), (63, 0.030394722), (65, 0.06273677)]

# %%
# Print the most probable topic for the query
most_probable_topic = max(query_lda, key=lambda item: item[1])[0]
print(f"Most probable topic: {most_probable_topic}")
# Out:
# Most probable topic: 21

# %%
# Sort the list of topics in descending order based on their prob
sorted_topics = sorted(query_lda, key=lambda item: item[1], reverse=True)

# Select the top 3 topics from the sorted list
top_topics = [topic[0] for topic in sorted_topics[:3]]

# Print the 3 most probable topics
print(f"3 most probable topics: {top_topics}")
# Out:
# 3 most probable topics: [21, 65, 52]

# %%
# Print the most significant words for the topic
top_words = lda_model.show_topic(52, topn=10)
print(f"Most probable topic for the query: {' '.join(word for word, _ in top_words)}")
# Out:
# Most probable topic for the query: communication transmission control component power transmitting transmit transmitted radio receiving

# %%
# filter the documents that have a predicted topic (for example here predicted topi for query is 21)

# %%
filter_topics_lda=df_Claim_20K_topic[df_Claim_20K_topic['LDA_topics'] == 52]
filter_topics_lda = filter_topics_lda.sort_values('LDA_prob', ascending=False)
filter_topics_lda = filter_topics_lda.reset_index().rename(columns={'index': 'new_index'})
filter_topics_lda
# Out:
#     new_index       ID                                              Title  \
# 0        2529  8934755  System and method for managing multiple indepe...
# 1        7480  8947595  Fingerprinting to match videos having varying ...
# 2        1310  8930998  Method and system for providing a program guid...
# 3        6667  8942541  Recording medium and recording method reducing...
# 4        8854  8947493  System and method for alerting a participant i...
# 5       14762  8964036  System and method for capturing, storing, anal...
# 6        3147  8933961  Video processing system generating corrected g...
# 7       15203  8964981  Method and system for transmitting signaling i...
# 8        5106  8938009                Layered encoded bitstream structure
# 9         270  8929712                    Display for displaying progress
# 10        252  8929709  Automatic digital curation and tagging of acti...
# 11       4782  8937997  Scalable video coding/multiplexing compatible ...
# 12       5020  8938791  System and method to control display of a real...
# 13      16814  8970654  System and method for selecting portions of vi...
# 14      18747  8974690  Compositions containing chlorfluoroolefins or ...
# 15       2730  8934759   Video editing apparatus and video editing method
# 16       2065  8930795  Methods for slicing dynamically modulated symbols
# 17       1507  8929433  Systems, methods, and apparatus for improving ...
# 18        702  8929720  Apparatus and method for identifying insertion...
# 19       5734  8942293  Picture-in-picture processing for video telephony
# 20      12563  8958440  System and method for identifying upper layer ...
# 21      19474  8976872  Picture-in-picture processing for video telephony
# 22      18700  8977100  Video server and controlling method for video ...
# 23      19383  8977106  Methods and apparatus for filtering content in...
# 24       9722  8953019  Method and apparatus for generating stream and...
# 25      17097  8970666             Low scale production system and method
# 26      13808  8964835                    Feature-based video compression
# 27      15567  8965124             Spatio-temporal segmentation for video
# 28       3660  8934536  Transcoding system using encoding history info...
# 29       1513  8929400  Apparatus and method for support of communicat...
# 30       7241  8947503         Method and system for processing 3-D video
# 31      18851  8978065  Method and system to combine broadcast televis...
# 32       4915  8938000  Transcoding system using encoding history info...
# 33       7624  8947526  Video surveillance system having communication...
# 34      10451  8955009  Viewing of commercial break content during fas...
# 35      17370  8971416  Video decoder with vector processor and method...
# 36       9967  8952374                   Display and electronic apparatus
# 37       1954  8929435  Apparatus and method for encoding and decoding...
# 38      15433  8965172  Multi-screen video playback system and related...
# 39      10348  8953926                   Spline optic and lighting device
# 40      16560  8970734  Imaging apparatus having temporary recording m...
# 41      14006  8964854  Motion-compensated prediction of inter-layer r...
# 42       5941  8942572  Methods and systems for encoding and decoding ...
# 43      13575  8963747  Decoding apparatus, encoding apparatus, decodi...
# 44       4407  8937686                     Ultra low latency video fusion
# 45      13535  8963412  Display device and electronic apparatus having...
# 46       5501  8941298                                     Display device
# 47       1496  8929440  QP adaptive coefficients scanning and application
# 48      10732  8953675  Tile-based system and method for compressing v...
# 49      12157  8957491  Optical sensors for detecting relative motion ...
# 50      15712  8966346  Apparatus and method for processing a physical...
# 51      15015  8964077  Solid-state imaging device, method for driving...
# 52      17049  8970750  Image outputting apparatus, image outputting m...
#
#                                                 Claim  \
# 0   1. An information handling system comprising: ...
# 1   1. A method for generating a combined fingerpr...
# 2   1. A method, comprising: decoding a first enco...
# 3   1. A non-transitory computer-readable recordin...
# 4   1. A method, comprising: identifying an active...
# 5   1. A method operable on a computer that is cou...
# 6   1. A video processing system comprising: a vid...
# 7   1. A method of transmitting signaling informat...
# 8   1. A method of encoding video data, the method...
# 9   1. A display for displaying the progress of a ...
# 10  1. A method, comprising: receiving, in a proce...
# 11  1. A method of encoding video data, comprising...
# 12  1. A method for dynamically assigning a displa...
# 13  1. A method of operating a video system, the m...
# 14  1. A composition comprising: (a) mineral oil; ...
# 15  1. A video editing apparatus for connecting a ...
# 16  1. A method for reducing error propagation, co...
# 17  1. A method for encoding video data, said meth...
# 18  1. Apparatus for detecting insertion zones wit...
# 19  1. A method comprising: encoding video to be t...
# 20  1. A method comprising: formatting a message i...
# 21  1. A computer program product, the computer pr...
# 22  1. A video server, comprising: a memory device...
# 23  1. A method for filtering a video stream, the ...
# 24  1. A method of generating a stream, the method...
# 25  1. A system, comprising: a plurality of video ...
# 26  1. A computer implemented method of processing...
# 27  1. A method for segmenting a video, comprising...
# 28  1. Stream conversion apparatus for converting ...
# 29  1. A method for generating a physical layer (P...
# 30  1. A method comprising: in a 3-D video process...
# 31  1. An Internet television controller, comprisi...
# 32  1. Decoding apparatus for decoding an encoded ...
# 33  1. A system for controlling a motor in a video...
# 34  1. A method of providing content for a commerc...
# 35  1. A video decoder comprising: an entropy deco...
# 36  1. A display device comprising: a plurality of...
# 37  1. A method comprising the steps of: receiving...
# 38  1. A multi-screen video playback system for dy...
# 39  1. A light emitting device comprising; a. A li...
# 40  1. An imaging apparatus comprising: an imaging...
# 41  1. A method comprising: encoding base layer vi...
# 42  1. A method for use by a light sensor, the met...
# 43  1. A decoding apparatus comprising: a clipper ...
# 44  1. A method of processing video, the method co...
# 45  1. A display device comprising: a pixel includ...
# 46  1. A display device comprising: a plurality of...
# 47  1. An apparatus for coding video data, compris...
# 48  1. A computer-implemented method comprising: r...
# 49  1. An optical sensor, comprising: a photodetec...
# 50  1. A wireless device, comprising: a physical l...
# 51  1. A solid-state imaging device comprising: a ...
# 52  1. An image outputting apparatus, comprising: ...
#
#                                          cpc_subclass  \
# 0                                      G06F,G09G,H04N
# 1                                           G06K,H04N
# 2                                                H04N
# 3                                           G11B,H04N
# 4                                                H04N
# 5                                 G06K,G06Q,G06T,H04N
# 6                                           G06T,H04N
# 7                                                H04L
# 8                                                H04N
# 9                                           G08B,H04N
# 10                                G06F,G06K,G11B,H04N
# 11                                               H04N
# 12                                          G06F,H04L
# 13                                          G06K,H04N
# 14  A62D,B01F,C08J,C09K,C10M,C10N,C11D,C23G,F25B,G...
# 15                                          G11B,H04N
# 16                                          H03M,H04L
# 17                                               H04N
# 18                                     G06Q,G11B,H04N
# 19                                               H04N
# 20                                               H04L
# 21                                               H04N
# 22                                               H04N
# 23                                          G11B,H04N
# 24                                               H04N
# 25                                     G11B,H04H,H04N
# 26                                          G06T,H04N
# 27                                          G06K,H04N
# 28                                               H04N
# 29                                H04B,H04H,H04L,H04W
# 30                                               H04N
# 31                                               H04N
# 32                                               H04N
# 33                                G05B,G08B,H02H,H04N
# 34                                               H04N
# 35                                               H04N
# 36                                          G09G,H01L
# 37                                     H03M,H04L,H04N
# 38                                               H04N
# 39                           F21K,F21V,F21Y,G02B,H05B
# 40                                               H04N
# 41                                               H04N
# 42                                               H04B
# 43                                          G06T,H03M
# 44                                               H04N
# 45                                          G09G,H01L
# 46                                     G09G,H01L,H05B
# 47                                               H04N
# 48                                A63F,H04L,H04N,H04W
# 49                                     G02B,G06F,H01L
# 50                                          H03M,H04L
# 51                                          H01L,H04N
# 52                                G06F,G06T,H04N,Y02D
#
#                                      Lemmatized-Claim  LDA_topics  LDA_prob
# 0   handling first video processor first video out...          52  0.359647
# 1   generating combined fingerprint video executed...          52  0.333845
# 2   decoding first encoded video stream encoded vi...          52  0.320914
# 3   nontransitory computerreadable recording mediu...          52  0.315740
# 4   identifying active speaker video session detec...          52  0.294414
# 5   operable computer coupled memory video prescri...          52  0.280665
# 6   video processing video ingest module receiving...          52  0.280194
# 7   transmitting signaling path network encoding t...          52  0.270390
# 8   encoding video encoding header video block cod...          52  0.264121
# 9   display displaying progress recording process ...          52  0.262336
# 10  receiving processing gps carried user attached...          52  0.255384
# 11  encoding video receiving video encoding video ...          52  0.249052
# 12  dynamically assigning displayable realm name r...          52  0.248725
# 13  operating video video processor receiving vide...          52  0.242124
# 14  composition mineral oil b least weight one com...          52  0.241569
# 15  video editing connecting first first video con...          52  0.238652
# 16  reducing error propagation receiving frame sym...          52  0.232195
# 17  encoding video estimating displayed intensity ...          52  0.231417
# 18  detecting insertion zone within prerecorded vi...          52  0.230804
# 19  encoding video transmitted remote video commun...          52  0.229625
# 20  formatting message transport protocol header a...          52  0.228484
# 21  computer program product computer program prod...          52  0.228032
# 22  video server memory store first video signal f...          52  0.225263
# 23  filtering video stream receiving video stream ...          52  0.225046
# 24  generating stream generating first elementary ...          52  0.223719
# 25  video camera video camera capturing video stre...          52  0.218473
# 26  computer implemented processing video formed s...          52  0.212335
# 27  segmenting video segmenting video produce vide...          52  0.212106
# 28  stream conversion converting encoded stream re...          52  0.211408
# 29  generating physical layer pl frame transmissio...          52  0.211011
# 30                                   video processing          52  0.210213
# 31  internet television controller video controlle...          52  0.194389
# 32  decoding decoding encoded stream receiving rec...          52  0.192140
# 33    controlling motor video surveillance controller          52  0.190189
# 34  providing content commercial break fastforward...          52  0.184517
# 35  video decoder entropy decoding generates entro...          52  0.184168
# 36  display pixel substrate pixel pixel set subpix...          52  0.184031
# 37  step receiving set encoder processor set arran...          52  0.182534
# 38  multiscreen video playback dynamically generat...          52  0.175985
# 39  light emitting light source b exterior envelop...          52  0.175141
# 40  imaging imaging acquires captured image subjec...          52  0.174360
# 41  encoding base layer video produce least base l...          52  0.171807
# 42  use light sensor simultaneously receiving two ...          52  0.168740
# 43  decoding clipper clip piece encoded predetermi...          52  0.163661
# 44  processing video receiving first video signal ...          52  0.161309
# 45  display pixel subpixels subpixels emit light c...          52  0.158983
# 46  display subpixels display color white subpixel...          52  0.155575
# 47  coding video computer encoding andor decoding ...          52  0.138825
# 48  computerimplemented receiving server request p...          52  0.131680
# 49  optical sensor photodetector region slat photo...          52  0.128519
# 50  wireless physical layer convergence protocol p...          52  0.127505
# 51  solidstate imaging pixel array light responsiv...          52  0.108409
# 52  image outputting imaging circuit header produc...          52  0.104865

# %%
#calculate the similarity between the query and document in dataset with the Doc2Vec embedding

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.metrics.pairwise import cosine_similarity

# Convert the list of documents to a list of sentences
sentences = [doc.split() for doc in filter_topics_lda['Lemmatized-Claim'].tolist()]

# Create a list of TaggedDocument objects, where each TaggedDocument represents a single document in the corpus
# The words attribute of each TaggedDocument is set to a list of tokens for the corresponding document
# The tags attribute of each TaggedDocument is set to a list containing a single string, which is the index of the document in the corpus
tagged_data = [TaggedDocument(words=sentences[i], tags=[str(i)]) for i in range(len(sentences))]

# Train a Doc2Vec model on the tagged documents
# The vector_size parameter specifies the dimensionality of the document vectors
# The window parameter specifies the maximum distance between the predicted word and the context words within a sentence
# The min_count parameter specifies the minimum frequency of a word in the corpus to be included in the vocabulary
# The epochs parameter specifies the number of iterations over the corpus during training
model = Doc2Vec(tagged_data, vector_size=100, window=5, min_count=5, epochs=50)

# Infer the document vector for the new claim
# The split() method converts the string to a list of tokens
# The infer_vector() method calculates the document vector using the trained model
new_claim_vector = model.infer_vector(new_claim.split())

# Calculate the cosine similarity between the new claim and the documents in the corpus
# The infer_vector() method is called for each document in the corpus to calculate the document vectors
doc_vectors = [model.infer_vector(sentences[i]) for i in range(len(sentences))]
similarity_scores = cosine_similarity([new_claim_vector], doc_vectors)

# %%
# Add a new column to the dataframe to store the similarity scores
filter_topics_lda['cosin_similarity_Doc2vec'] = similarity_scores[0]
filter_topics_lda
# Out:
#     new_index       ID                                              Title  \
# 0        2529  8934755  System and method for managing multiple indepe...
# 1        7480  8947595  Fingerprinting to match videos having varying ...
# 2        1310  8930998  Method and system for providing a program guid...
# 3        6667  8942541  Recording medium and recording method reducing...
# 4        8854  8947493  System and method for alerting a participant i...
# 5       14762  8964036  System and method for capturing, storing, anal...
# 6        3147  8933961  Video processing system generating corrected g...
# 7       15203  8964981  Method and system for transmitting signaling i...
# 8        5106  8938009                Layered encoded bitstream structure
# 9         270  8929712                    Display for displaying progress
# 10        252  8929709  Automatic digital curation and tagging of acti...
# 11       4782  8937997  Scalable video coding/multiplexing compatible ...
# 12       5020  8938791  System and method to control display of a real...
# 13      16814  8970654  System and method for selecting portions of vi...
# 14      18747  8974690  Compositions containing chlorfluoroolefins or ...
# 15       2730  8934759   Video editing apparatus and video editing method
# 16       2065  8930795  Methods for slicing dynamically modulated symbols
# 17       1507  8929433  Systems, methods, and apparatus for improving ...
# 18        702  8929720  Apparatus and method for identifying insertion...
# 19       5734  8942293  Picture-in-picture processing for video telephony
# 20      12563  8958440  System and method for identifying upper layer ...
# 21      19474  8976872  Picture-in-picture processing for video telephony
# 22      18700  8977100  Video server and controlling method for video ...
# 23      19383  8977106  Methods and apparatus for filtering content in...
# 24       9722  8953019  Method and apparatus for generating stream and...
# 25      17097  8970666             Low scale production system and method
# 26      13808  8964835                    Feature-based video compression
# 27      15567  8965124             Spatio-temporal segmentation for video
# 28       3660  8934536  Transcoding system using encoding history info...
# 29       1513  8929400  Apparatus and method for support of communicat...
# 30       7241  8947503         Method and system for processing 3-D video
# 31      18851  8978065  Method and system to combine broadcast televis...
# 32       4915  8938000  Transcoding system using encoding history info...
# 33       7624  8947526  Video surveillance system having communication...
# 34      10451  8955009  Viewing of commercial break content during fas...
# 35      17370  8971416  Video decoder with vector processor and method...
# 36       9967  8952374                   Display and electronic apparatus
# 37       1954  8929435  Apparatus and method for encoding and decoding...
# 38      15433  8965172  Multi-screen video playback system and related...
# 39      10348  8953926                   Spline optic and lighting device
# 40      16560  8970734  Imaging apparatus having temporary recording m...
# 41      14006  8964854  Motion-compensated prediction of inter-layer r...
# 42       5941  8942572  Methods and systems for encoding and decoding ...
# 43      13575  8963747  Decoding apparatus, encoding apparatus, decodi...
# 44       4407  8937686                     Ultra low latency video fusion
# 45      13535  8963412  Display device and electronic apparatus having...
# 46       5501  8941298                                     Display device
# 47       1496  8929440  QP adaptive coefficients scanning and application
# 48      10732  8953675  Tile-based system and method for compressing v...
# 49      12157  8957491  Optical sensors for detecting relative motion ...
# 50      15712  8966346  Apparatus and method for processing a physical...
# 51      15015  8964077  Solid-state imaging device, method for driving...
# 52      17049  8970750  Image outputting apparatus, image outputting m...
#
#                                                 Claim  \
# 0   1. An information handling system comprising: ...
# 1   1. A method for generating a combined fingerpr...
# 2   1. A method, comprising: decoding a first enco...
# 3   1. A non-transitory computer-readable recordin...
# 4   1. A method, comprising: identifying an active...
# 5   1. A method operable on a computer that is cou...
# 6   1. A video processing system comprising: a vid...
# 7   1. A method of transmitting signaling informat...
# 8   1. A method of encoding video data, the method...
# 9   1. A display for displaying the progress of a ...
# 10  1. A method, comprising: receiving, in a proce...
# 11  1. A method of encoding video data, comprising...
# 12  1. A method for dynamically assigning a displa...
# 13  1. A method of operating a video system, the m...
# 14  1. A composition comprising: (a) mineral oil; ...
# 15  1. A video editing apparatus for connecting a ...
# 16  1. A method for reducing error propagation, co...
# 17  1. A method for encoding video data, said meth...
# 18  1. Apparatus for detecting insertion zones wit...
# 19  1. A method comprising: encoding video to be t...
# 20  1. A method comprising: formatting a message i...
# 21  1. A computer program product, the computer pr...
# 22  1. A video server, comprising: a memory device...
# 23  1. A method for filtering a video stream, the ...
# 24  1. A method of generating a stream, the method...
# 25  1. A system, comprising: a plurality of video ...
# 26  1. A computer implemented method of processing...
# 27  1. A method for segmenting a video, comprising...
# 28  1. Stream conversion apparatus for converting ...
# 29  1. A method for generating a physical layer (P...
# 30  1. A method comprising: in a 3-D video process...
# 31  1. An Internet television controller, comprisi...
# 32  1. Decoding apparatus for decoding an encoded ...
# 33  1. A system for controlling a motor in a video...
# 34  1. A method of providing content for a commerc...
# 35  1. A video decoder comprising: an entropy deco...
# 36  1. A display device comprising: a plurality of...
# 37  1. A method comprising the steps of: receiving...
# 38  1. A multi-screen video playback system for dy...
# 39  1. A light emitting device comprising; a. A li...
# 40  1. An imaging apparatus comprising: an imaging...
# 41  1. A method comprising: encoding base layer vi...
# 42  1. A method for use by a light sensor, the met...
# 43  1. A decoding apparatus comprising: a clipper ...
# 44  1. A method of processing video, the method co...
# 45  1. A display device comprising: a pixel includ...
# 46  1. A display device comprising: a plurality of...
# 47  1. An apparatus for coding video data, compris...
# 48  1. A computer-implemented method comprising: r...
# 49  1. An optical sensor, comprising: a photodetec...
# 50  1. A wireless device, comprising: a physical l...
# 51  1. A solid-state imaging device comprising: a ...
# 52  1. An image outputting apparatus, comprising: ...
#
#                                          cpc_subclass  \
# 0                                      G06F,G09G,H04N
# 1                                           G06K,H04N
# 2                                                H04N
# 3                                           G11B,H04N
# 4                                                H04N
# 5                                 G06K,G06Q,G06T,H04N
# 6                                           G06T,H04N
# 7                                                H04L
# 8                                                H04N
# 9                                           G08B,H04N
# 10                                G06F,G06K,G11B,H04N
# 11                                               H04N
# 12                                          G06F,H04L
# 13                                          G06K,H04N
# 14  A62D,B01F,C08J,C09K,C10M,C10N,C11D,C23G,F25B,G...
# 15                                          G11B,H04N
# 16                                          H03M,H04L
# 17                                               H04N
# 18                                     G06Q,G11B,H04N
# 19                                               H04N
# 20                                               H04L
# 21                                               H04N
# 22                                               H04N
# 23                                          G11B,H04N
# 24                                               H04N
# 25                                     G11B,H04H,H04N
# 26                                          G06T,H04N
# 27                                          G06K,H04N
# 28                                               H04N
# 29                                H04B,H04H,H04L,H04W
# 30                                               H04N
# 31                                               H04N
# 32                                               H04N
# 33                                G05B,G08B,H02H,H04N
# 34                                               H04N
# 35                                               H04N
# 36                                          G09G,H01L
# 37                                     H03M,H04L,H04N
# 38                                               H04N
# 39                           F21K,F21V,F21Y,G02B,H05B
# 40                                               H04N
# 41                                               H04N
# 42                                               H04B
# 43                                          G06T,H03M
# 44                                               H04N
# 45                                          G09G,H01L
# 46                                     G09G,H01L,H05B
# 47                                               H04N
# 48                                A63F,H04L,H04N,H04W
# 49                                     G02B,G06F,H01L
# 50                                          H03M,H04L
# 51                                          H01L,H04N
# 52                                G06F,G06T,H04N,Y02D
#
#                                      Lemmatized-Claim  LDA_topics  LDA_prob  \
# 0   handling first video processor first video out...          52  0.359647
# 1   generating combined fingerprint video executed...          52  0.333845
# 2   decoding first encoded video stream encoded vi...          52  0.320914
# 3   nontransitory computerreadable recording mediu...          52  0.315740
# 4   identifying active speaker video session detec...          52  0.294414
# 5   operable computer coupled memory video prescri...          52  0.280665
# 6   video processing video ingest module receiving...          52  0.280194
# 7   transmitting signaling path network encoding t...          52  0.270390
# 8   encoding video encoding header video block cod...          52  0.264121
# 9   display displaying progress recording process ...          52  0.262336
# 10  receiving processing gps carried user attached...          52  0.255384
# 11  encoding video receiving video encoding video ...          52  0.249052
# 12  dynamically assigning displayable realm name r...          52  0.248725
# 13  operating video video processor receiving vide...          52  0.242124
# 14  composition mineral oil b least weight one com...          52  0.241569
# 15  video editing connecting first first video con...          52  0.238652
# 16  reducing error propagation receiving frame sym...          52  0.232195
# 17  encoding video estimating displayed intensity ...          52  0.231417
# 18  detecting insertion zone within prerecorded vi...          52  0.230804
# 19  encoding video transmitted remote video commun...          52  0.229625
# 20  formatting message transport protocol header a...          52  0.228484
# 21  computer program product computer program prod...          52  0.228032
# 22  video server memory store first video signal f...          52  0.225263
# 23  filtering video stream receiving video stream ...          52  0.225046
# 24  generating stream generating first elementary ...          52  0.223719
# 25  video camera video camera capturing video stre...          52  0.218473
# 26  computer implemented processing video formed s...          52  0.212335
# 27  segmenting video segmenting video produce vide...          52  0.212106
# 28  stream conversion converting encoded stream re...          52  0.211408
# 29  generating physical layer pl frame transmissio...          52  0.211011
# 30                                   video processing          52  0.210213
# 31  internet television controller video controlle...          52  0.194389
# 32  decoding decoding encoded stream receiving rec...          52  0.192140
# 33    controlling motor video surveillance controller          52  0.190189
# 34  providing content commercial break fastforward...          52  0.184517
# 35  video decoder entropy decoding generates entro...          52  0.184168
# 36  display pixel substrate pixel pixel set subpix...          52  0.184031
# 37  step receiving set encoder processor set arran...          52  0.182534
# 38  multiscreen video playback dynamically generat...          52  0.175985
# 39  light emitting light source b exterior envelop...          52  0.175141
# 40  imaging imaging acquires captured image subjec...          52  0.174360
# 41  encoding base layer video produce least base l...          52  0.171807
# 42  use light sensor simultaneously receiving two ...          52  0.168740
# 43  decoding clipper clip piece encoded predetermi...          52  0.163661
# 44  processing video receiving first video signal ...          52  0.161309
# 45  display pixel subpixels subpixels emit light c...          52  0.158983
# 46  display subpixels display color white subpixel...          52  0.155575
# 47  coding video computer encoding andor decoding ...          52  0.138825
# 48  computerimplemented receiving server request p...          52  0.131680
# 49  optical sensor photodetector region slat photo...          52  0.128519
# 50  wireless physical layer convergence protocol p...          52  0.127505
# 51  solidstate imaging pixel array light responsiv...          52  0.108409
# 52  image outputting imaging circuit header produc...          52  0.104865
#
#     cosin_similarity_Doc2vec
# 0                   0.544543
# 1                   0.610705
# 2                  -0.110300
# 3                   0.056855
# 4                   0.345648
# 5                   0.303932
# 6                   0.150538
# 7                   0.219076
# 8                   0.358807
# 9                   0.044649
# 10                  0.093679
# 11                 -0.084844
# 12                  0.149966
# 13                  0.383449
# 14                  0.370621
# 15                  0.491411
# 16                  0.141984
# 17                  0.311398
# 18                  0.428840
# 19                  0.218864
# 20                  0.429719
# 21                  0.115552
# 22                  0.570059
# 23                 -0.035422
# 24                  0.217484
# 25                  0.013583
# 26                 -0.220063
# 27                  0.213160
# 28                 -0.041833
# 29                  0.312814
# 30                  0.462746
# 31                  0.583996
# 32                 -0.082873
# 33                  0.597025
# 34                 -0.190026
# 35                  0.180471
# 36                  0.122178
# 37                 -0.141142
# 38                  0.583015
# 39                  0.098881
# 40                  0.130803
# 41                 -0.039612
# 42                 -0.014075
# 43                  0.121755
# 44                  0.485739
# 45                  0.184711
# 46                  0.318185
# 47                  0.263913
# 48                  0.327912
# 49                  0.151218
# 50                  0.229194
# 51                  0.219090
# 52                 -0.079168

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the cosine similarity scores from the dataframe
cosine_scores = filter_topics_lda['cosin_similarity_Doc2vec']

# Plot a histogram of the cosine similarity scores
plt.figure(figsize=(10,6))
sns.histplot(cosine_scores, bins=20)
plt.title('Histogram of Cosine Similarity Scores for Claim')
plt.xlabel('Cosine Similarity Score with Doc2vec Embedding')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the cosine similarity scores from the dataframe
cosine_scores = filter_topics_lda['cosin_similarity_Doc2vec']
# Set the style of the plot
sns.set_style("whitegrid")

# Plot a histogram of the cosine similarity scores
plt.figure(figsize=(10,6))
sns.histplot(cosine_scores, bins=20, kde=True, color='blue')

# Set chart title and labels
plt.title('Distribution of Cosine Similarity Scores between Documents and Query for LDA on 20K Claims')
plt.xlabel('Cosine Similarity Score')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %%
#get the most similar doc in dataset to query

# %%
# Sort the filter_topics_lda dataframe by cosine similarity score in descending order
filter_topics_lda = filter_topics_lda.sort_values(by=['cosin_similarity_Doc2vec'], ascending=False)

# Get the document with the highest cosine similarity score
most_similar_doc = filter_topics_lda.iloc[0]['Claim']

most_similar_doc
# Out:
# '1. A method for generating a combined fingerprint of a video, the method executed by at least one computer system comprising a processor and a computer-readable storage medium, the method comprising: generating a first transformed video by applying a first aspect correction method to the video; generating a second transformed video by applying a second aspect correction method to the video; generating a first fingerprint using the first transformed video, the first fingerprint having a first half and a second half; generating a second fingerprint using the second transformed video, the second fingerprint having a first half and a second half; combining the first half of the first fingerprint with the second half of the second fingerprint to generate the combined fingerprint; and storing the combined fingerprint in the computer-readable storage medium.'

# %%
# Sort the filter_topics_lda dataframe by cosine similarity score in descending order
filter_topics_lda = filter_topics_lda.sort_values(by=['cosin_similarity_Doc2vec'], ascending=False)

# Get the document with the highest cosine similarity score
most_similar_doc = filter_topics_lda.iloc[0]['Lemmatized-Claim']

most_similar_doc
# Out:
# 'generating combined fingerprint video executed least one computer processor computerreadable storage medium generating first transformed video applying first correction video generating second transformed video applying second correction video generating first fingerprint using first transformed video first fingerprint first half second half generating second fingerprint using second transformed video second fingerprint first half second half combining first half first fingerprint second half second fingerprint generate combined fingerprint storing combined fingerprint computerreadable storage medium'

# %%
# Sort the filter_topics_lda dataframe by cosine similarity score in descending order
filter_topics_lda = filter_topics_lda.sort_values(by=['cosin_similarity_Doc2vec'], ascending=False)

# Get the document with the highest cosine similarity score
most_similar_doc = filter_topics_lda.iloc[0]['ID']

most_similar_doc
# Out:
# 8947595
