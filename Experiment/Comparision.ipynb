# %% [markdown]
# # Claim

# %%
import pandas as pd

# create a list of dictionaries with the data
data = [
    {'model': 'nmf', 'patent_count': 20000, 'C_V coherence': 0.45129103915852053, 'U_mass coherence':-4.372792189712559, 'C_npmi coherence':0.0009151738353764994},
    {'model': 'lda', 'patent_count': 20000, 'C_V coherence':0.48261153251985583, 'U_mass coherence':-8.371539604147335,'C_npmi coherence':-0.11532409454951423},
    {'model': 'bertopic', 'patent_count': 20000, 'C_V coherence':0.5414688111677558, 'U_mass coherence':-0.6866501216609453, 'C_npmi coherence':0.0173759289874694},
    {'model': 'nmf', 'patent_count': 30000, 'C_V coherence':0.4600950558320819, 'U_mass coherence':-4.3313751520747505, 'C_npmi coherence':0.009353560994548659},
    {'model': 'lda', 'patent_count': 30000, 'C_V coherence':0.4715362938434643, 'U_mass coherence':-7.405636344300677,'C_npmi coherence':-0.0847805026572984},
    {'model': 'bertopic', 'patent_count': 30000, 'C_V coherence':0.5592014471303033, 'U_mass coherence':-0.6048500228415797, 'C_npmi coherence':0.025993540686161956},
    {'model': 'nmf', 'patent_count': 50000, 'C_V coherence':0.5067258751253925, 'U_mass coherence':-3.6990778379805387, 'C_npmi coherence':0.0396539761676106},
    {'model': 'lda', 'patent_count': 50000, 'C_V coherence':0.4946286709523778, 'U_mass coherence':-5.770594924388985,'C_npmi coherence':-0.021556327107970636},
    {'model': 'bertopic', 'patent_count': 50000, 'C_V coherence': 0.5108191577385757, 'U_mass coherence':-0.6459861825176518,'C_npmi coherence':0.026827647722979978}
]

# create the DataFrame
df = pd.DataFrame(data)

# display the DataFrame
df = df.round(4)
df
# Out:
#       model  patent_count  C_V coherence  U_mass coherence  C_npmi coherence
# 0       nmf         20000         0.4513           -4.3728            0.0009
# 1       lda         20000         0.4826           -8.3715           -0.1153
# 2  bertopic         20000         0.5415           -0.6867            0.0174
# 3       nmf         30000         0.4601           -4.3314            0.0094
# 4       lda         30000         0.4715           -7.4056           -0.0848
# 5  bertopic         30000         0.5592           -0.6049            0.0260
# 6       nmf         50000         0.5067           -3.6991            0.0397
# 7       lda         50000         0.4946           -5.7706           -0.0216
# 8  bertopic         50000         0.5108           -0.6460            0.0268

# %%
import matplotlib.pyplot as plt

# Extract data
nmf_cv = [d['C_V coherence'] for d in data if d['model'] == 'nmf']
nmf_umass = [d['U_mass coherence'] for d in data if d['model'] == 'nmf']
nmf_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'nmf']

lda_cv = [d['C_V coherence'] for d in data if d['model'] == 'lda']
lda_umass = [d['U_mass coherence'] for d in data if d['model'] == 'lda']
lda_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'lda']

bert_cv = [d['C_V coherence'] for d in data if d['model'] == 'bertopic']
bert_umass = [d['U_mass coherence'] for d in data if d['model'] == 'bertopic']
bert_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'bertopic']

# Create the plots
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(8, 10), facecolor="none")

ax1.plot([20000, 30000, 50000], nmf_cv, '-o', label='NMF')
ax1.plot([20000, 30000, 50000], lda_cv, '-o', label='LDA')
ax1.plot([20000, 30000, 50000], bert_cv, '-o', label='BERTopic')
ax1.set_xlabel('Number of Patents')
ax1.set_ylabel('C_V Coherence')
ax1.legend()

ax2.plot([20000, 30000, 50000], nmf_umass, '-o', label='NMF')
ax2.plot([20000, 30000, 50000], lda_umass, '-o', label='LDA')
ax2.plot([20000, 30000, 50000], bert_umass, '-o', label='BERTopic')
ax2.set_xlabel('Number of Patents')
ax2.set_ylabel('U_mass Coherence')
ax2.legend()

ax3.plot([20000, 30000, 50000], nmf_npmi, '-o', label='NMF')
ax3.plot([20000, 30000, 50000], lda_npmi, '-o', label='LDA')
ax3.plot([20000, 30000, 50000], bert_npmi, '-o', label='BERTopic')
ax3.set_xlabel('Number of Patents')
ax3.set_ylabel('C_npmi Coherence')
ax3.legend()

plt.show()

# %% [markdown]
# # Claim

# %%
# quer: 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'
#text = "1. A communication apparatus for communicating with another apparatus in orthogonal frequency-division multiplexing wireless communication, the communication apparatus comprising: a modulator that modulates an input signal using a predetermined modulation scheme, and assigns the modulated input signal to subcarriers with frequency components orthogonal to each other, thereby generating a subcarrier modulation signal; an inserter that inserts a transmission-side data series in a signal for synthesis in such a way that elements in the signal for synthesis and elements in the transmission-side data series are alternately positioned, thereby generating first data, the signal for synthesis being generated by multiplying the subcarrier modulation signal by a predetermined signal amplitude coefficient, the transmission-side data series being generated by multiplying a data series which is a set of data whose quantity is equal to a number of the subcarriers and which has an autocorrelation property such that an autocorrelation value with a data series whose data has not been shifted is higher than an autocorrelation value with a data series whose data has been shifted by a predetermined series amplitude coefficient; a first transformer that performs an inverse fast Fourier transformation on the first data; a separator that separates an operation result from the first transformer into first half data and second half data having elements equal in quantity to elements of the first half data, and generates a baseband signal based on the first half data or the second half data; and a transmitter that generates a transmission signal from the baseband signal."


# tokenize the text and create a TF-IDF matrix
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform([text])

# get the vocabulary and IDF scores
vocab = tfidf_vectorizer.get_feature_names_out()
idf_scores = tfidf_vectorizer.idf_

# create a dictionary of words and their TF-IDF scores
word_scores = dict(zip(vocab, idf_scores))

# create the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white', colormap='Blues').generate_from_frequencies(word_scores)

# plot the word cloud
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

text = 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'

# tokenize the text and create a TF-IDF matrix
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform([text])

# get the vocabulary and IDF scores
vocab = tfidf_vectorizer.get_feature_names_out()
idf_scores = tfidf_vectorizer.idf_

# create a dictionary of words and their TF-IDF scores
word_scores = dict(zip(vocab, idf_scores))

# sort the words by their TF-IDF scores
sorted_words = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)

# print the top 10 keywords
for word, score in sorted_words[:10]:
    print(word)
# Out:
# alternately
# amplitude
# another
# assigns
# autocorrelation
# baseband
# based
# coefficient
# communicating
# communication

# %%
import scipy
import numpy as np
from sentence_transformers import SentenceTransformer

# load pre-trained BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# sample text for testing
text = 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'

# generate embeddings for each token in the text
tokens = text.split()
embeddings = model.encode(tokens)

# compute mean embedding for the entire text
embeddings_2d = np.array(embeddings).reshape(len(tokens), -1)
mean_embedding = np.mean(embeddings_2d, axis=0)

# compute cosine similarity between each token and the entire text
cosine_similarities = scipy.spatial.distance.cdist(embeddings_2d, [mean_embedding], "cosine").ravel()

# sort the tokens by their cosine similarity to the entire text
sorted_indices = np.argsort(cosine_similarities)

# print the top 5 most relevant keywords
top_keywords = [tokens[i] for i in sorted_indices[:5]]
print(top_keywords)
# Out:
# ['transmission', 'component', 'modulated', 'scheme', 'operation']

# %%
#This code uses a pre-trained BERT model to encode each sentence in a given text and then computes the cosine similarity between each sentence's embedding and the mean embedding of all sentences. It then sorts the sentences based on their cosine similarity scores and outputs the top 5 sentences with the highest scores, which can be considered the most relevant or important sentences in the text

# %%
# !pip install python-rake
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install rake-nltk
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from rake_nltk import Rake
from termcolor import colored
import textwrap

# initialize RAKE keyword extractor
r = Rake()

# define text to extract keywords from
#text = 'communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal'
text = "1. A communication apparatus for communicating with another apparatus in orthogonal frequency-division multiplexing wireless communication, the communication apparatus comprising: a modulator that modulates an input signal using a predetermined modulation scheme, and assigns the modulated input signal to subcarriers with frequency components orthogonal to each other, thereby generating a subcarrier modulation signal; an inserter that inserts a transmission-side data series in a signal for synthesis in such a way that elements in the signal for synthesis and elements in the transmission-side data series are alternately positioned, thereby generating first data, the signal for synthesis being generated by multiplying the subcarrier modulation signal by a predetermined signal amplitude coefficient, the transmission-side data series being generated by multiplying a data series which is a set of data whose quantity is equal to a number of the subcarriers and which has an autocorrelation property such that an autocorrelation value with a data series whose data has not been shifted is higher than an autocorrelation value with a data series whose data has been shifted by a predetermined series amplitude coefficient; a first transformer that performs an inverse fast Fourier transformation on the first data; a separator that separates an operation result from the first transformer into first half data and second half data having elements equal in quantity to elements of the first half data, and generates a baseband signal based on the first half data or the second half data; and a transmitter that generates a transmission signal from the baseband signal."
# extract keywords using RAKE
r.extract_keywords_from_text(text)

# get the top 10 keywords with the highest scores
keywords = r.get_ranked_phrases_with_scores()[:10]


# print the top 10 keywords
for score, keyword in keywords:
    print(f"{keyword} (score: {score})")
    
    
# # highlight top 10 keywords in the text with red color
# for score, keyword in keywords:
#     text = text.replace(keyword, colored(keyword, 'red'))

# define a color palette
color_palette = ['red', 'green', 'yellow', 'blue', 'magenta', 'cyan']

# highlight all keywords in the text with different colors based on their score
for i, (score, keyword) in enumerate(keywords):
    color_index = i % len(color_palette)
    text = text.replace(keyword, colored(keyword, color_palette[color_index]))

    
# wrap the text to a certain width and justify it
wrapped_text = textwrap.fill(text, width=80)
justified_text = textwrap.indent(wrapped_text, prefix='    ', predicate=lambda line: not line.startswith('    '))

# print the wrapped and justified text
print(justified_text)
# Out:
# inverse fast fourier transformation (score: 16.0)
# division multiplexing wireless communication (score: 15.0)
# predetermined series amplitude coefficient (score: 14.952380952380953)
# predetermined signal amplitude coefficient (score: 14.030303030303031)
# data series whose data (score: 13.327380952380953)
# data series whose data (score: 13.327380952380953)
# thereby generating first data (score: 11.901785714285715)
# predetermined modulation scheme (score: 9.666666666666666)
# side data series (score: 9.473214285714285)
# side data series (score: 9.473214285714285)
#     1. A communication apparatus for communicating with another apparatus in
#     orthogonal frequency-division multiplexing wireless communication, the
#     communication apparatus comprising: a modulator that modulates an input signal
#     using a predetermined modulation scheme, and assigns the modulated
#     input signal to subcarriers with frequency components orthogonal to each other,
# ...

# %%
import pandas as pd

models = ['NMF', 'LDA', 'BERTopic']
groups = ['20k', '30k', '50k']

probabilities = {
    'NMF': [0.39, 0.26,0.21],
    'LDA': [0.050, 0.079,0.085],
    'BERTopic': [0.63,0.62, 0.63]
}

topic_texts = {
    'NMF': [['signal', 'audio', 'digital', 'frequency', 'receiver'], ['signal', 'input', 'output', 'delay', 'control'], ['value', 'set', 'pixel', 'target', 'reference']],
    'LDA': [['communication', 'transmission', 'control', 'component', 'power'], ['time', 'location', 'number', 'determining', 'based'], ['value', 'number', 'determining', 'based', 'reference']],
    'BERTopic': [['rf','mixer','baseband', 'frequency','amplifier', 'modulated'], ['symbol','sequence','orthogonal frequency','orthogonal','orthogonal frequency division' ], ['antenna','transceiver', 'waveguide','chain', 'transmit']]
}

data = []
for model in models:
    for i, group in enumerate(groups):
        data.append({'Model': model, 'Group': group,'Probability': probabilities[model][i], 'Topic Text': topic_texts[model][i]})

df = pd.DataFrame(data)
df
# Out:
#       Model Group  Probability  \
# 0       NMF   20k        0.390
# 1       NMF   30k        0.260
# 2       NMF   50k        0.210
# 3       LDA   20k        0.050
# 4       LDA   30k        0.079
# 5       LDA   50k        0.085
# 6  BERTopic   20k        0.630
# 7  BERTopic   30k        0.620
# 8  BERTopic   50k        0.630
#
#                                           Topic Text
# 0      [signal, audio, digital, frequency, receiver]
# 1            [signal, input, output, delay, control]
# 2             [value, set, pixel, target, reference]
# 3  [communication, transmission, control, compone...
# 4       [time, location, number, determining, based]
# 5     [value, number, determining, based, reference]
# 6  [rf, mixer, baseband, frequency, amplifier, mo...
# 7  [symbol, sequence, orthogonal frequency, ortho...
# 8  [antenna, transceiver, waveguide, chain, trans...

# %%
#for 20K
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the keywords for each algorithm
lda_topics = ['communication', 'transmission', 'control', 'component', 'power']
nmf_topics = ['signal', 'audio', 'digital', 'frequency', 'receiver']
bert_topics = ['rf','mixer','baseband', 'frequency','amplifier', 'modulated']

# Create a WordCloud object for each algorithm
lda_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(lda_topics))
nmf_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(nmf_topics))
bert_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(bert_topics))


# Define the title for the plot
title = "WordCloud for Predicted Topics for 20K patent claim"

# Plot the word clouds
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(lda_cloud)
axes[0].set_title('LDA Topics')
axes[0].axis('off')
axes[1].imshow(nmf_cloud)
axes[1].set_title('NMF Topics')
axes[1].axis('off')
axes[2].imshow(bert_cloud)
axes[2].set_title('BERTopic Topics')
axes[2].axis('off')

# Add a main title to the plot
fig.suptitle(title, fontsize=14)

plt.show()

# %%
#for 30K
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the keywords for each algorithm
lda_topics = ['time', 'location', 'number', 'determining', 'based']
nmf_topics = ['signal', 'input', 'output', 'delay', 'control']
bert_topics = ['symbol','sequence','orthogonal frequency','orthogonal','orthogonal frequency division' ]

# Create a WordCloud object for each algorithm
lda_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(lda_topics))
nmf_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(nmf_topics))
bert_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(bert_topics))


# Define the title for the plot
title = "WordCloud for Predicted Topics for 30K patent claim"

# Plot the word clouds
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(lda_cloud)
axes[0].set_title('LDA Topics')
axes[0].axis('off')
axes[1].imshow(nmf_cloud)
axes[1].set_title('NMF Topics')
axes[1].axis('off')
axes[2].imshow(bert_cloud)
axes[2].set_title('BERTopic Topics')
axes[2].axis('off')

# Add a main title to the plot
fig.suptitle(title, fontsize=14)

plt.show()

# %%
#for 50K
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the keywords for each algorithm
lda_topics =['value', 'number', 'determining', 'based', 'reference']
nmf_topics = ['value', 'set', 'pixel', 'target', 'reference']
bert_topics =['antenna','transceiver', 'waveguide','chain', 'transmit']

# Create a WordCloud object for each algorithm
lda_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(lda_topics))
nmf_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(nmf_topics))
bert_cloud = WordCloud(width=800, height=800, background_color='white', stopwords=None).generate(' '.join(bert_topics))


# Define the title for the plot
title = "WordCloud for Predicted Topics for 50K patent claim"

# Plot the word clouds
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(lda_cloud)
axes[0].set_title('LDA Topics')
axes[0].axis('off')
axes[1].imshow(nmf_cloud)
axes[1].set_title('NMF Topics')
axes[1].axis('off')
axes[2].imshow(bert_cloud)
axes[2].set_title('BERTopic Topics')
axes[2].axis('off')

# Add a main title to the plot
fig.suptitle(title, fontsize=14)

plt.show()

# %%
#similarity between the query and predicted topics

# %%
#claim 20K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['inverse fast fourier transformation',
                            'division multiplexing wireless communication',
                            'predetermined series amplitude coefficient',
                            'predetermined signal amplitude coefficient',
                            'data series whose data',
                            'thereby generating first data',
                            'predetermined modulation scheme',
                            'side data series']
nmf_topic = ['signal', 'audio', 'digital', 'frequency', 'receiver', 'generate', 'rf', 'reference', 'input', 'received']
lda_topic = ['communication', 'transmission', 'control', 'component', 'power', 'transmitting', 'transmit', 'transmitted', 'radio', 'receiving']
bertopic_topic = ['antenna', 'wireless', 'wireless communication', 'band', 'frequency band','interference', 'white','one frequency', 'quality','operation mode']

    
# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.8471434
# LDA similarity: 0.8161794
# BERTopic similarity: 0.8389673

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim = 0.8471434
lda_sim = 0.8161794
bertopic_sim =0.8389673

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 20K patents Claim')
plt.legend()

# %%
#claim 30K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['inverse fast fourier transformation',
                            'division multiplexing wireless communication',
                            'predetermined series amplitude coefficient',
                            'predetermined signal amplitude coefficient',
                            'data series whose data',
                            'thereby generating first data',
                            'predetermined modulation scheme',
                            'side data series']
nmf_topic = ['signal', 'input', 'output', 'delay', 'control', 'generate', 'circuit', 'analog', 'receive', 'feedback']
lda_topic = ['signal', 'output', 'reference', 'frequency', 'input', 'generate','receive', 'generating', 'received', 'based']
bertopic_topic = ['interference','quality', 'wireless', 'noise' , 'wireless communication', 'antenna', 'stream', 'frequency band', 'band', 'estimating']

# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.8407343
# LDA similarity: 0.8331828
# BERTopic similarity: 0.8456593

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim = 0.8407343
lda_sim = 0.8331828
bertopic_sim =0.8456593

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 30K patents Claim')
plt.legend()

# %%
#claim 50K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['inverse fast fourier transformation',
                            'division multiplexing wireless communication',
                            'predetermined series amplitude coefficient',
                            'predetermined signal amplitude coefficient',
                            'data series whose data',
                            'thereby generating first data',
                            'predetermined modulation scheme',
                            'side data series']
nmf_topic = ['value', 'set', 'pixel', 'target', 'reference', 'color', 'parameter', 'based', 'current', 'determining']
lda_topic = ['value', 'number', 'determining', 'based', 'reference', 'time', 'n', 'current', 'threshold', 'predetermined']
bertopic_topic = ['wireless', 'wireless communication', 'first wireless', 'second wireless', 'band', 'interference', 'frequency band', 'quality','reception','antenna'] 

# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.80831814
# LDA similarity: 0.80689174
# BERTopic similarity: 0.8435685

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim =0.80831814
lda_sim = 0.80689174
bertopic_sim =0.8435685

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 50K patents Claim')
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the datasets and corresponding labels
datasets = ['20k', '30k', '50k']
nmf_sims = [0.8471434, 0.8407343, 0.80831814]
lda_sims = [0.8161794, 0.8331828, 0.80689174]
bertopic_sims = [0.8389673, 0.8456593,0.8435685]

# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 4))

# Set the bar width and position
bar_width = 0.25
r1 = np.arange(len(nmf_sims))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the bars
ax.barh(r1, nmf_sims, height=bar_width, label='NMF')
ax.barh(r2, lda_sims, height=bar_width, label='LDA')
ax.barh(r3, bertopic_sims, height=bar_width, label='BERTopic')

# Set the y-ticks and labels
ax.set_yticks([r + bar_width for r in range(len(nmf_sims))])
ax.set_yticklabels(datasets)

# Set the legend outside the plot area
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3)

# Set the axis labels
ax.set_xlabel('Cosine Similarity')
ax.set_ylabel('Different patent datasize')

# Set the title
ax.set_title('Measuring Similarity Between Query and Predicted Topics For Claims')

# Show the plot
plt.show()

# %% [markdown]
# # Abstract

# %%
import pandas as pd

# create a list of dictionaries with the data
data = [
    {'model': 'nmf', 'patent_count': 20000, 'C_V coherence':0.4272774413472316, 'U_mass coherence':-4.792768849718406, 'C_npmi coherence':-0.01750167594568079},
    {'model': 'lda', 'patent_count': 20000, 'C_V coherence':0.4634055941874869, 'U_mass coherence':-6.967650406062563,'C_npmi coherence': -0.07806451136970982},
    {'model': 'bertopic', 'patent_count': 20000, 'C_V coherence':0.5777476534453095, 'U_mass coherence':-0.7058345133753225, 'C_npmi coherence':0.021560398728263694},
    {'model': 'nmf', 'patent_count': 30000, 'C_V coherence':0.48609736553365473, 'U_mass coherence':-4.350545718319507, 'C_npmi coherence':0.019457772179269882},
    {'model': 'lda', 'patent_count': 30000, 'C_V coherence':0.4680821021596758, 'U_mass coherence':-6.24304885982448,'C_npmi coherence':-0.05143193333877656},
    {'model': 'bertopic', 'patent_count': 30000, 'C_V coherence':0.5373997204318021, 'U_mass coherence':-0.660433464124151, 'C_npmi coherence':0.013234695219338805},
    {'model': 'nmf', 'patent_count': 50000, 'C_V coherence':0.5086765377913532, 'U_mass coherence':-3.7103216024478765, 'C_npmi coherence':0.040271597693551875},
    {'model': 'lda', 'patent_count': 50000, 'C_V coherence':0.47285323195109663, 'U_mass coherence':-5.893789878955703,'C_npmi coherence':-0.03708827589619598},
    {'model': 'bertopic', 'patent_count': 50000, 'C_V coherence':0.4938432364671655, 'U_mass coherence': -0.7033401016638859,'C_npmi coherence': 0.008758899184116781}
]

# create the DataFrame
df = pd.DataFrame(data)

# display the DataFrame
df = df.round(4)
df
# Out:
#       model  patent_count  C_V coherence  U_mass coherence  C_npmi coherence
# 0       nmf         20000         0.4273           -4.7928           -0.0175
# 1       lda         20000         0.4634           -6.9677           -0.0781
# 2  bertopic         20000         0.5777           -0.7058            0.0216
# 3       nmf         30000         0.4861           -4.3505            0.0195
# 4       lda         30000         0.4681           -6.2430           -0.0514
# 5  bertopic         30000         0.5374           -0.6604            0.0132
# 6       nmf         50000         0.5087           -3.7103            0.0403
# 7       lda         50000         0.4729           -5.8938           -0.0371
# 8  bertopic         50000         0.4938           -0.7033            0.0088

# %%
import matplotlib.pyplot as plt

# Extract data
nmf_cv = [d['C_V coherence'] for d in data if d['model'] == 'nmf']
nmf_umass = [d['U_mass coherence'] for d in data if d['model'] == 'nmf']
nmf_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'nmf']

lda_cv = [d['C_V coherence'] for d in data if d['model'] == 'lda']
lda_umass = [d['U_mass coherence'] for d in data if d['model'] == 'lda']
lda_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'lda']

bert_cv = [d['C_V coherence'] for d in data if d['model'] == 'bertopic']
bert_umass = [d['U_mass coherence'] for d in data if d['model'] == 'bertopic']
bert_npmi = [d['C_npmi coherence'] for d in data if d['model'] == 'bertopic']

# Create the plots
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(8, 10), facecolor="none")

ax1.plot([20000, 30000, 50000], nmf_cv, '-o', label='NMF')
ax1.plot([20000, 30000, 50000], lda_cv, '-o', label='LDA')
ax1.plot([20000, 30000, 50000], bert_cv, '-o', label='BERTopic')
ax1.set_xlabel('Number of Patents')
ax1.set_ylabel('C_V Coherence')
ax1.legend()

ax2.plot([20000, 30000, 50000], nmf_umass, '-o', label='NMF')
ax2.plot([20000, 30000, 50000], lda_umass, '-o', label='LDA')
ax2.plot([20000, 30000, 50000], bert_umass, '-o', label='BERTopic')
ax2.set_xlabel('Number of Patents')
ax2.set_ylabel('U_mass Coherence')
ax2.legend()

ax3.plot([20000, 30000, 50000], nmf_npmi, '-o', label='NMF')
ax3.plot([20000, 30000, 50000], lda_npmi, '-o', label='LDA')
ax3.plot([20000, 30000, 50000], bert_npmi, '-o', label='BERTopic')
ax3.set_xlabel('Number of Patents')
ax3.set_ylabel('C_npmi Coherence')
ax3.legend()

plt.show()

# %% [markdown]
# # Abstract

# %%
import pandas as pd

models = ['NMF', 'LDA', 'BERTopic']
groups = ['20k', '30k', '50k']
topics = ['Topic 1']
probabilities = {
    'NMF': [0.36,0.52, 0.38],
    'LDA': [0.23,0.21, 0.25],
    'BERTopic': [0.61, 0.64, 0.64]
}

topic_texts = {
    'NMF': [['node', 'network', 'user', 'message', 'service'], ['network', 'server', 'connection', 'access', 'service'], ['network', 'channel', 'interface', 'port', 'access']],
    'LDA': [['signal', 'digital', 'output', 'gain', 'control'], ['node', 'link', 'bus', 'client', 'core'], ['value', 'time', 'detection', 'sample', 'reference']],
    'BERTopic': [['broadband','internet protocol','service provider','provider','telecommunication'], ['wireless communication', 'wireless', 'wireless network','priority','option'], ['access point','wireless communication', 'wireless network','access', 'communication path']]
}


data = []
for model in models:
    for i, group in enumerate(groups):
        data.append({'Model': model, 'Group': group, 'Topic': topics[0], 'Probability': probabilities[model][i], 'Topic Text': topic_texts[model][i]})

df = pd.DataFrame(data)
df
# Out:
#       Model Group    Topic  Probability  \
# 0       NMF   20k  Topic 1         0.36
# 1       NMF   30k  Topic 1         0.52
# 2       NMF   50k  Topic 1         0.38
# 3       LDA   20k  Topic 1         0.23
# 4       LDA   30k  Topic 1         0.21
# 5       LDA   50k  Topic 1         0.25
# 6  BERTopic   20k  Topic 1         0.61
# 7  BERTopic   30k  Topic 1         0.64
# 8  BERTopic   50k  Topic 1         0.64
#
#                                           Topic Text
# 0            [node, network, user, message, service]
# 1     [network, server, connection, access, service]
# 2        [network, channel, interface, port, access]
# 3           [signal, digital, output, gain, control]
# 4                    [node, link, bus, client, core]
# 5        [value, time, detection, sample, reference]
# 6  [broadband, internet protocol, service provide...
# 7  [wireless communication, wireless, wireless ne...
# 8  [access point, wireless communication, wireles...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = 'transmission provided transmitting received user terminal network destination user terminal executing communication using internet protocol transmission routing table storing relating destination address address network table storing static dynamic network selection unit selecting one network transmission transmits destination based static dynamic transmission enables transmission appropriate network selecting appropriate network based static dynamic network'
#text = 'a data transmission apparatus is provided for transmitting data received from a user terminal device through a plurality of networks to a destination the user terminal device executing communication using an internet protocol the data transmission apparatus includes a routing table storing information relating a destination address of the data and addresses of the plurality of networks an information table storing static and dynamic information about the plurality of networks and a selection unit selecting one or the plurality of networks through which the data transmission apparatus transmits the data to the destination based on the static and dynamic information the data transmission apparatus enables data transmission through the appropriate network by selecting the appropriate network based on the static and dynamic information about the plurality of networks'

# tokenize the text and create a TF-IDF matrix
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform([text])

# get the vocabulary and IDF scores
vocab = tfidf_vectorizer.get_feature_names_out()
idf_scores = tfidf_vectorizer.idf_

# create a dictionary of words and their TF-IDF scores
word_scores = dict(zip(vocab, idf_scores))

# create the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white', colormap='Blues').generate_from_frequencies(word_scores)

# plot the word cloud
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from rake_nltk import Rake
from termcolor import colored
import textwrap

# initialize RAKE keyword extractor
r = Rake()

# define text to extract keywords from
#text = 'transmission provided transmitting received user terminal network destination user terminal executing communication using internet protocol transmission routing table storing relating destination address address network table storing static dynamic network selection unit selecting one network transmission transmits destination based static dynamic transmission enables transmission appropriate network selecting appropriate network based static dynamic network'
text = 'a data transmission apparatus is provided for transmitting data received from a user terminal device through a plurality of networks to a destination the user terminal device executing communication using an internet protocol the data transmission apparatus includes a routing table storing information relating a destination address of the data and addresses of the plurality of networks an information table storing static and dynamic information about the plurality of networks and a selection unit selecting one or the plurality of networks through which the data transmission apparatus transmits the data to the destination based on the static and dynamic information the data transmission apparatus enables data transmission through the appropriate network by selecting the appropriate network based on the static and dynamic information about the plurality of networks'


# extract keywords using RAKE
r.extract_keywords_from_text(text)

# get the top 10 keywords with the highest scores
keywords = r.get_ranked_phrases_with_scores()[:10]


# print the top 10 keywords
for score, keyword in keywords:
    print(f"{keyword} (score: {score})")
    
    
# # highlight top 10 keywords in the text with red color
# for score, keyword in keywords:
#     text = text.replace(keyword, colored(keyword, 'red'))

# define a color palette
color_palette = ['red', 'green', 'yellow', 'blue', 'magenta', 'cyan']

# highlight all keywords in the text with different colors based on their score
for i, (score, keyword) in enumerate(keywords):
    color_index = i % len(color_palette)
    text = text.replace(keyword, colored(keyword, color_palette[color_index]))

    
# wrap the text to a certain width and justify it
wrapped_text = textwrap.fill(text, width=80)
justified_text = textwrap.indent(wrapped_text, prefix='    ', predicate=lambda line: not line.startswith('    '))

# print the wrapped and justified text
print(justified_text)
# Out:
# user terminal device executing communication using (score: 31.5)
# data transmission apparatus enables data transmission (score: 26.450000000000003)
# routing table storing information relating (score: 22.0)
# data transmission apparatus transmits (score: 16.35)
# data transmission apparatus includes (score: 16.35)
# selection unit selecting one (score: 14.5)
# information table storing static (score: 14.0)
# user terminal device (score: 13.5)
# data transmission apparatus (score: 12.35)
# transmitting data received (score: 9.5)
#     a data transmission apparatus is provided for transmitting data
#     received from a user terminal device through a plurality of
#     networks to a destination the user terminal device executing
#     communication using an internet protocol the data transmission
#     apparatus includes a routing table storing information relating
#     a destination address of the data and addresses of the plurality of networks an
# ...

# %%
#similarity between the query and predicted topics

# %%
#abstract 20K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['user terminal device executing communication using', 'routing table storing information relating',
                            'data transmission apparatus enables data transmission',
                            'routing table storing information relating',
                            'data transmission apparatus transmits',
                            'data transmission apparatus includes',
                            'selection unit selecting one',
                            'information table storing static',
                            'user terminal device',
                            'data transmission apparatus',
                            'transmitting data received']
nmf_topic = ['node', 'network', 'user', 'message', 'service', 'access', 'connection', 'mobile', 'communication', 'gateway']
lda_topic = ['Transmission', 'Received', 'Error', 'Radio', 'Based', 'Transmitted', 'Interference', 'Reception', 'base_station', 'Estimate']
bertopic_topic = ['signaling','translation','call','protocol','security', 'communication protocol', 'method system' , 'internet protocol', 'message']


# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.7841225
# LDA similarity: 0.7521994
# BERTopic similarity: 0.8349416

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim = 0.7841225
lda_sim = 0.7521994
bertopic_sim = 0.8349416

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 20K patents Abstract')
plt.legend()

# Show the plot
plt.show()

# %%
#abstract 30K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['user terminal device executing communication using', 'routing table storing information relating',
                            'data transmission apparatus enables data transmission',
                            'routing table storing information relating',
                            'data transmission apparatus transmits',
                            'data transmission apparatus includes',
                            'selection unit selecting one',
                            'information table storing static',
                            'user terminal device',
                            'data transmission apparatus',
                            'transmitting data received']

nmf_topic = ['network', 'server', 'connection', 'access', 'service', 'request', 'mobile', 'wireless', 'traffic', 'port']
lda_topic = ['network', 'packet', 'call','access','service','address', 'voice', 'telephone', 'routing', 'based']
bertopic_topic = ['wireless communication', 'wireless','first network','priority', 'second network','first terminal', 'protocol', 'controller may', 'communication network', 'positional']

# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.79043865
# LDA similarity: 0.76723176
# BERTopic similarity: 0.7937969

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim = 0.79043865
lda_sim =  0.76723176
bertopic_sim = 0.7937969

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 30K patents Abstract')
plt.legend()

# Show the plot
plt.show()

# %%
#abstract 50K
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Define the keywords and topics
query_extracted_keywords = ['user terminal device executing communication using', 'routing table storing information relating',
                            'data transmission apparatus enables data transmission',
                            'routing table storing information relating',
                            'data transmission apparatus transmits',
                            'data transmission apparatus includes',
                            'selection unit selecting one',
                            'information table storing static',
                            'user terminal device',
                            'data transmission apparatus',
                            'transmitting data received']
nmf_topic = ['network', 'channel', 'interface', 'port', 'access', 'service', 'address', 'core', 'protocol', 'connection']
lda_topic = ['value', 'time', 'detection', 'sample', 'reference', 'based', 'error', 'detected', 'detecting', 'predetermined']
bertopic_topic = ['mobile station','mobile', 'base station','station','mobile terminal', 'mobile communication', 'wireless', 'home', 'radio', 'cellular' ]
 
# Load the BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the keywords and topics
extracted_keywords_emb = model.encode(query_extracted_keywords)
nmf_topic_emb = model.encode(nmf_topic)
lda_topic_emb = model.encode(lda_topic)
bertopic_topic_emb = model.encode(bertopic_topic)

# Compute cosine similarity between extracted keywords and each topic
nmf_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), nmf_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
lda_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), lda_topic_emb.mean(axis=0).reshape(1, -1))[0][0]
bertopic_sim = cosine_similarity(extracted_keywords_emb.mean(axis=0).reshape(1, -1), bertopic_topic_emb.mean(axis=0).reshape(1, -1))[0][0]

print("NMF similarity:", nmf_sim)
print("LDA similarity:", lda_sim)
print("BERTopic similarity:", bertopic_sim)
# Out:
# NMF similarity: 0.76012635
# LDA similarity: 0.7325811
# BERTopic similarity: 0.72151005

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the similarity scores
nmf_sim = 0.76012635
lda_sim = 0.7325811
bertopic_sim = 0.72151005

# Create a list of similarity scores
sims = [nmf_sim, lda_sim, bertopic_sim]

# Create a list of algorithm names
algorithms = ['NMF', 'LDA', 'BERTopic']

# Set the Seaborn style to whitegrid
sns.set(style='whitegrid')

# Plot the scatter plot with different colors for each dot
sns.scatterplot(x=algorithms, y=sims, hue=algorithms, palette='bright', s=100)

# Add the score values next to each dot
for i in range(len(algorithms)):
    plt.annotate('{:.2f}'.format(sims[i]), xy=(algorithms[i], sims[i]), xytext=(20, 0), textcoords='offset points')

# Add labels, title and legend to the plot
plt.xlabel('Algorithms')
plt.ylabel('Similarity Scores')
plt.title('Comparison of Prediction of Topic Modeling Algorithms on 50K patents Abstract')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the datasets and corresponding labels
datasets = ['20k', '30k', '50k']
nmf_sims = [ 0.7841225, 0.79043865, 0.76012635]
lda_sims = [0.7521994, 0.76723176, 00.7325811]
bertopic_sims = [0.8349416, 0.7937969, 0.72151005]

# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 4))

# Set the bar width and position
bar_width = 0.25
r1 = np.arange(len(nmf_sims))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the bars
ax.barh(r1, nmf_sims, height=bar_width, label='NMF')
ax.barh(r2, lda_sims, height=bar_width, label='LDA')
ax.barh(r3, bertopic_sims, height=bar_width, label='BERTopic')

# Set the y-ticks and labels
ax.set_yticks([r + bar_width for r in range(len(nmf_sims))])
ax.set_yticklabels(datasets)

# Set the legend outside the plot area
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3)

# Set the axis labels
ax.set_xlabel('Cosine Similarity')
ax.set_ylabel('Different patent datasize')

# Set the title
ax.set_title('Measuring Similarity Between Query and Predicted Topics for Abstract')

# Show the plot
plt.show()


############## simililarity:

# %%
# similarity beween query and predicted doc in claim 20k

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and three documents
query = "communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal"
NMF = "antenna least one antenna one antenna downlead enabling processing analog signal transmitted received antenna one xy mount mount composed least three mechanical element first element base second element socalled lower box third element socalled upper box antenna fixed upper box component antenna downlead distributed first second third element composing xy mount orthomode transducer type junction upper box enabling separation component downlead two separate path first path called ascending path component amplifying processing signal transmitted antenna second path called descending path component processing amplifying signal received antenna component associated two path placed either side first second third element xy mount thus providing balancing"
LDA = "generating combined fingerprint video executed least one computer processor computerreadable storage medium generating first transformed video applying first correction video generating second transformed video applying second correction video generating first fingerprint using first transformed video first fingerprint first half second half generating second fingerprint using second transformed video second fingerprint first half second half combining first half first fingerprint second half second fingerprint generate combined fingerprint storing combined fingerprint computerreadable storage medium"
BERTopic = "wireless communication first communication performs wireless communication using first frequency band selected first frequency band second communication performs communication frequency hopping using second frequency band overlap first frequency band wirelesschannel control unit determines usable frequency band second frequency band usable frequency hopping based communication first frequency band extendedqualityinformation acquisition unit acquires communication quality extended frequency band frequency band first frequency band usable frequency band extended communication quality determination usable frequency band wirelesschannel control unit wirelesschannel control unit add frequency band determined used based extended communication quality usable frequency band extendedqualityinformation acquisition unit acquires extended communication quality every constant period determined based least one extended frequency band traffic amount second communication"

# Encode the query and documents using BERT embeddings
embeddings = model.encode([query, NMF, LDA, BERTopic])

# Calculate the pairwise cosine similarity between the embeddings
cosine_sim = cosine_similarity(embeddings)

# Create a dataframe from the cosine similarity matrix
df = pd.DataFrame(cosine_sim, columns=['Query', 'NMF', 'LDA', 'BERTopic'], index=['Query', 'NMF', 'LDA', 'BERTopic'])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='Blues', fmt='.2f')
plt.title('Similarity between Query and Retrieved Documents for Claim in 20K Patents', fontsize=16)
plt.show()

# Identify the document closest to the query
most_similar = cosine_sim[0,1:].argmax() + 1
print(f"The query is most similar to Document {most_similar}")
# Out:
# The query is most similar to Document 3

# %%
# similarity beween query and predicted doc in claim 50k

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and three documents
query = "communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal"

NMF = "communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator generates modulation signal dividing series equally number factorial equal greater number pattern expressed input signal generate subdata series series set autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted performing calculation multiplies predetermined amplitude coefficient unique number defined subdata series element subdata series rearranging subdata series applied calculation based rearrangement rule associated pattern expressed input signal one one synthesizing rearranged subdata series transformer performs inverse fast fourier transformation modulation signal calculator divide calculation result transformer equally number generate sub calculation result multiplies equalization coefficient defined sub calculation result element sub calculation result synthesizer generates baseband signal arranging sub calculation result applied calculation calculator arranged position corresponds position calculation result time divided equally calculator synthesizing arranged result transmitter generates transmission signal baseband signal transmit"
LDA = "induction generator radio switch magnet element induction coil coil core coil core ushaped first rest position second rest position case defined magnet element contact limb coil core flux direction reversal take place coil core whenever change take place first second rest position movement path magnet element predetermined movement first second rest position movement path magnet element predetermined cam control formed control profile engaging element guided along control profile induction generator first energy storage operatively connected magnet element store energy course forcing movement rest position reaching intermediate position defined along movement path magnetic force coil core suddenly decrease emits energy first energy storage magnet element order mechanically accelerate movement magnet element respective rest position leaving intermediate position"
BERTopic = "transceiver radiofrequency identification rfid transmitter transmitting carrier signal antenna receiver input terminal receiving wireless signal antenna input terminal noise canceller generating feedback current carrier signal feeding feedback current input terminal receiver adjusting feedback current signal strength noise wireless signal eliminate noise wireless signal noise canceller comprises multiphase generator generating pair basic signal predetermined phase relation carrier signal predetermined phase relation one phase relation programmable current generator generating feedback current pair basic signal feeding feedback signal input terminal receiver"

# Encode the query and documents using BERT embeddings
embeddings = model.encode([query, NMF, LDA, BERTopic])

# Calculate the pairwise cosine similarity between the embeddings
cosine_sim = cosine_similarity(embeddings)

# Create a dataframe from the cosine similarity matrix
df = pd.DataFrame(cosine_sim, columns=['Query', 'NMF', 'LDA', 'BERTopic'], index=['Query', 'NMF', 'LDA', 'BERTopic'])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='Blues', fmt='.2f')
plt.title('Similarity between Query and Retrieved Documents for Claim in 50K Patents', fontsize=16)
plt.show()

# Identify the document closest to the query
most_similar = cosine_sim[0,1:].argmax() + 1
print(f"The query is most similar to Document {most_similar}")
# Out:
# The query is most similar to Document 1

# %%
# claim similarity doc range

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the ranges of similarity for each algorithm and dataset
ranges = {
    'LDA 20k': (-0.2, 0.6),
    'NMF 20k': (0.93, 1),
    'BERTopic 20k': (0.65, 0.90),
    'LDA 50k': (-0.2, 0.3),
    'NMF 50k': (-0.2, 0.4),
    'BERTopic 50k': (0.5, 0.85)
}

# Define colors for each algorithm
colors = {'LDA 20k': 'C0', 'NMF 20k': 'C1', 'BERTopic 20k': 'C2',
          'LDA 50k': 'C0', 'NMF 50k': 'C1', 'BERTopic 50k': 'C2'}

# Create the plot
fig, ax = plt.subplots()

# Plot the ranges as horizontal lines with error bars
handles = []
for i, (alg, r) in enumerate(ranges.items()):
    color = colors[alg]
    error = (r[1] - r[0]) / 2
    if alg not in handles:
        handles.append(alg)
        ax.errorbar((r[0] + r[1]) / 2, i, xerr=error, color=color, fmt='o', capsize=10, label=alg)
    else:
        ax.errorbar((r[0] + r[1]) / 2, i, xerr=error, color=color, fmt='o', capsize=10)

# Set the y-axis labels
ax.set_yticks(range(len(ranges)))
ax.set_yticklabels(list(ranges.keys()))

# Set the x-axis label and limits
ax.set_xlabel('Degree of similarity')
ax.set_xlim([-1, 1])

# Set the grid
sns.set_style("whitegrid")

# Add a title
plt.title('Similarity Ranges for documents retrived by different Algorithms for Claim')

# Add a legend outside the chart
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
#claim documents similarity

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and documents for the two datasets
query = "communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator modulates input signal using predetermined modulation scheme assigns modulated input signal subcarriers frequency component orthogonal thereby generating subcarrier modulation signal inserter insert transmissionside series signal synthesis way element signal synthesis element transmissionside series alternately positioned thereby generating first signal synthesis generated multiplying subcarrier modulation signal predetermined signal amplitude coefficient transmissionside series generated multiplying series set whose quantity equal number subcarriers autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted predetermined series amplitude coefficient first transformer performs inverse fast fourier transformation first separator separate operation result first transformer first half second half element equal quantity element first half generates baseband signal based first half second half transmitter generates transmission signal baseband signal"

NMFs = ["antenna least one antenna one antenna downlead enabling processing analog signal transmitted received antenna one xy mount mount composed least three mechanical element first element base second element socalled lower box third element socalled upper box antenna fixed upper box component antenna downlead distributed first second third element composing xy mount orthomode transducer type junction upper box enabling separation component downlead two separate path first path called ascending path component amplifying processing signal transmitted antenna second path called descending path component processing amplifying signal received antenna component associated two path placed either side first second third element xy mount thus providing balancing",
       "communication communicating another orthogonal frequencydivision multiplexing wireless communication communication modulator generates modulation signal dividing series equally number factorial equal greater number pattern expressed input signal generate subdata series series set autocorrelation property autocorrelation value series whose shifted higher autocorrelation value series whose shifted performing calculation multiplies predetermined amplitude coefficient unique number defined subdata series element subdata series rearranging subdata series applied calculation based rearrangement rule associated pattern expressed input signal one one synthesizing rearranged subdata series transformer performs inverse fast fourier transformation modulation signal calculator divide calculation result transformer equally number generate sub calculation result multiplies equalization coefficient defined sub calculation result element sub calculation result synthesizer generates baseband signal arranging sub calculation result applied calculation calculator arranged position corresponds position calculation result time divided equally calculator synthesizing arranged result transmitter generates transmission signal baseband signal transmit"
        ]

LDAs = ["generating combined fingerprint video executed least one computer processor computerreadable storage medium generating first transformed video applying first correction video generating second transformed video applying second correction video generating first fingerprint using first transformed video first fingerprint first half second half generating second fingerprint using second transformed video second fingerprint first half second half combining first half first fingerprint second half second fingerprint generate combined fingerprint storing combined fingerprint computerreadable storage medium",
      "induction generator radio switch magnet element induction coil coil core coil core ushaped first rest position second rest position case defined magnet element contact limb coil core flux direction reversal take place coil core whenever change take place first second rest position movement path magnet element predetermined movement first second rest position movement path magnet element predetermined cam control formed control profile engaging element guided along control profile induction generator first energy storage operatively connected magnet element store energy course forcing movement rest position reaching intermediate position defined along movement path magnetic force coil core suddenly decrease emits energy first energy storage magnet element order mechanically accelerate movement magnet element respective rest position leaving intermediate position"
       ]

BERTopics = ["wireless communication first communication performs wireless communication using first frequency band selected first frequency band second communication performs communication frequency hopping using second frequency band overlap first frequency band wirelesschannel control unit determines usable frequency band second frequency band usable frequency hopping based communication first frequency band extendedqualityinformation acquisition unit acquires communication quality extended frequency band frequency band first frequency band usable frequency band extended communication quality determination usable frequency band wirelesschannel control unit wirelesschannel control unit add frequency band determined used based extended communication quality usable frequency band extendedqualityinformation acquisition unit acquires extended communication quality every constant period determined based least one extended frequency band traffic amount second communication",
             "transceiver radiofrequency identification rfid transmitter transmitting carrier signal antenna receiver input terminal receiving wireless signal antenna input terminal noise canceller generating feedback current carrier signal feeding feedback current input terminal receiver adjusting feedback current signal strength noise wireless signal eliminate noise wireless signal noise canceller comprises multiphase generator generating pair basic signal predetermined phase relation carrier signal predetermined phase relation one phase relation programmable current generator generating feedback current pair basic signal feeding feedback signal input terminal receiver" 
            ]

datasets = ["20k", "50k"]

# Concatenate the query and documents
documents = [query] + NMFs + LDAs + BERTopics

# Encode the queries and documents using BERT embeddings
embeddings = model.encode(documents)

# Calculate the pairwise cosine similarity between the embeddings
cosine_similarities = cosine_similarity(embeddings)

# Create dataframes from the cosine similarity matrices
df = pd.DataFrame(cosine_similarities, columns=['Query', 'NMF_20k', 'NMF_50k', 'LDA_20k', 'LDA_50k', 'BERTopic_20k','BERTopic_50k'])
df.index = ['Query', 'NMF_20k', 'NMF_50k', 'LDA_20k', 'LDA_50k', 'BERTopic_20k','BERTopic_50k']

# Create a heatmap
sns.heatmap(df, annot=True, cmap='Blues')
plt.title("Cosine Similarity of Query and Algorithms across Claim")
plt.show()

# %%
#Abstract

# %%
#similarity beween query and predicted doc in Abstract 20k

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and three documents
query = "transmission provided transmitting received user terminal network destination user terminal executing communication using internet protocol transmission routing table storing relating destination address address network table storing static dynamic network selection unit selecting one network transmission transmits destination based static dynamic transmission enables transmission appropriate network selecting appropriate network based static dynamic network"
NMF = "present directed video telephony"
LDA = "present relates test set testing service wireless telephone wireless network embodiment present wireless telephone modular implemented test set without hardwiring embodiment present modular wireless telephone implemented test set use video capturing controller read directly display modular wireless telephone deciphers displayed display modular wireless telephone"
BERTopic = "distributed network address translation security feature allow internet protocol security protocol ipsec used distributed network address translation distributed network address translation accomplished ipsec mapping local internet protocol ip address given local network ipsec security parameter index spi associated inbound ipsec security association sa terminates local network router allocates locally unique security value used ipsec spis router used distributed network address translation used local certificate authority may vouch identity local network device allowing local network device bind public key security name space combine global ip address router set locally unique port number used distributed network address translation router issue security certificate may authenticated higher certificate authority using security certificate local network may initiate termination point ipsec security association virtually network ip network like internet intranet may allow distributed network address translation security feature used mobile ip protocol internet protocol suite"

# Encode the query and documents using BERT embeddings
embeddings = model.encode([query, NMF, LDA, BERTopic])

# Calculate the pairwise cosine similarity between the embeddings
cosine_sim = cosine_similarity(embeddings)

# Create a dataframe from the cosine similarity matrix
df = pd.DataFrame(cosine_sim, columns=['Query', 'NMF', 'LDA', 'BERTopic'], index=['Query', 'NMF', 'LDA', 'BERTopic'])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='Blues', fmt='.2f')
plt.title('Similarity between Query and Retrieved Documents for Abstract in 20K Patents', fontsize=16)
plt.show()

# Identify the document closest to the query
most_similar = cosine_sim[0,1:].argmax() + 1
print(f"The query is most similar to Document {most_similar}")
# Out:
# The query is most similar to Document 3

# %%
#similarity beween query and predicted doc in Abstract 50k

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and three documents
query = "transmission provided transmitting received user terminal network destination user terminal executing communication using internet protocol transmission routing table storing relating destination address address network table storing static dynamic network selection unit selecting one network transmission transmits destination based static dynamic transmission enables transmission appropriate network selecting appropriate network based static dynamic network"
NMF = "operating member constructed supporting button member thin sheet member without integrally constructing button member therefore downsized slimmed key top button member individually surface treated assembly therefore user easily recognize kind button time operation operation mistake prevented"
LDA = "wire control communicates pole mounted push button station kind found traffic light controlled intersection via existing pair underground wire power signal transmitted enable visually impaired pedestrian receive audible tactile signal regarding flow vehicular traffic intersection wire control central control unit located traffic light control cabinet connected standard traffic signal light controller control unit wire output port connected respective pair push button station central control unit control interface wire output port provided power signal transmitted respective pair push button station depending upon entry pedestrian request illumination walk walk message"
BERTopic = "packet communication communication packet received gateway internet protocol ip destination address network access identifier nai gateway map received nai local network supported network address translator nat gateway convert destination address nat address local network gateway add port number allows nat identify target recipient mapping within gateway created maintained mobile station send registration request upon arrival within local network one registration request session initiation protocol sip registration"

# Encode the query and documents using BERT embeddings
embeddings = model.encode([query, NMF, LDA, BERTopic])

# Calculate the pairwise cosine similarity between the embeddings
cosine_sim = cosine_similarity(embeddings)

# Create a dataframe from the cosine similarity matrix
df = pd.DataFrame(cosine_sim, columns=['Query', 'NMF', 'LDA', 'BERTopic'], index=['Query', 'NMF', 'LDA', 'BERTopic'])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='Blues', fmt='.2f')
plt.title('Similarity between Query and Retrieved Documents for Abstract in 50K Patents', fontsize=16)
plt.show()

# Identify the document closest to the query
most_similar = cosine_sim[0,1:].argmax() + 1
print(f"The query is most similar to Document {most_similar}")
# Out:
# The query is most similar to Document 3

# %%
#Abstract topic similarity:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the ranges of similarity for each algorithm and dataset
ranges = {
    'LDA 20k': (-0.4, 0.8),
    'NMF 20k': (-0.02, 0.05),
    'BERTopic 20k': (0.55, 0.85),
    'LDA 50k': (-0.4, 0.4),
    'NMF 50k': (-0.1, 0.1),
    'BERTopic 50k': (0.3, 0.8)
}

# Define colors for each algorithm
colors = {'LDA 20k': 'C0', 'NMF 20k': 'C1', 'BERTopic 20k': 'C2',
          'LDA 50k': 'C0', 'NMF 50k': 'C1', 'BERTopic 50k': 'C2'}

# Create the plot
fig, ax = plt.subplots()

# Plot the ranges as horizontal lines with error bars
handles = []
for i, (alg, r) in enumerate(ranges.items()):
    color = colors[alg]
    error = (r[1] - r[0]) / 2
    if alg not in handles:
        handles.append(alg)
        ax.errorbar((r[0] + r[1]) / 2, i, xerr=error, color=color, fmt='o', capsize=10, label=alg)
    else:
        ax.errorbar((r[0] + r[1]) / 2, i, xerr=error, color=color, fmt='o', capsize=10)

# Set the y-axis labels
ax.set_yticks(range(len(ranges)))
ax.set_yticklabels(list(ranges.keys()))

# Set the x-axis label and limits
ax.set_xlabel('Degree of similarity')
ax.set_xlim([-1, 1])

# Set the grid
sns.set_style("whitegrid")

# Add a title
plt.title('Similarity Ranges for documents retrived by different Algorithms for Abstract')

# Add a legend outside the chart
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Define the query and documents for the two datasets
query = "transmission provided transmitting received user terminal network destination user terminal executing communication using internet protocol transmission routing table storing relating destination address address network table storing static dynamic network selection unit selecting one network transmission transmits destination based static dynamic transmission enables transmission appropriate network selecting appropriate network based static dynamic network"

NMFs = ["present directed video telephony", 
        "operating member constructed supporting button member thin sheet member without integrally constructing button member therefore downsized slimmed key top button member individually surface treated assembly therefore user easily recognize kind button time operation operation mistake prevented"
       ]

LDAs = ["present relates test set testing service wireless telephone wireless network embodiment present wireless telephone modular implemented test set without hardwiring embodiment present modular wireless telephone implemented test set use video capturing controller read directly display modular wireless telephone deciphers displayed display modular wireless telephone",
        "wire control communicates pole mounted push button station kind found traffic light controlled intersection via existing pair underground wire power signal transmitted enable visually impaired pedestrian receive audible tactile signal regarding flow vehicular traffic intersection wire control central control unit located traffic light control cabinet connected standard traffic signal light controller control unit wire output port connected respective pair push button station central control unit control interface wire output port provided power signal transmitted respective pair push button station depending upon entry pedestrian request illumination walk walk message"
       ]

BERTopics = ["distributed network address translation security feature allow internet protocol security protocol ipsec used distributed network address translation distributed network address translation accomplished ipsec mapping local internet protocol ip address given local network ipsec security parameter index spi associated inbound ipsec security association sa terminates local network router allocates locally unique security value used ipsec spis router used distributed network address translation used local certificate authority may vouch identity local network device allowing local network device bind public key security name space combine global ip address router set locally unique port number used distributed network address translation router issue security certificate may authenticated higher certificate authority using security certificate local network may initiate termination point ipsec security association virtually network ip network like internet intranet may allow distributed network address translation security feature used mobile ip protocol internet protocol suite",
             "packet communication communication packet received gateway internet protocol ip destination address network access identifier nai gateway map received nai local network supported network address translator nat gateway convert destination address nat address local network gateway add port number allows nat identify target recipient mapping within gateway created maintained mobile station send registration request upon arrival within local network one registration request session initiation protocol sip registration"
            ]

datasets = ["20k", "50k"]

# Concatenate the query and documents
documents = [query] + NMFs + LDAs + BERTopics

# Encode the queries and documents using BERT embeddings
embeddings = model.encode(documents)

# Calculate the pairwise cosine similarity between the embeddings
cosine_similarities = cosine_similarity(embeddings)

# Create dataframes from the cosine similarity matrices
df = pd.DataFrame(cosine_similarities, columns=['Query', 'NMF_20k', 'NMF_50k', 'LDA_20k', 'LDA_50k', 'BERTopic_20k','BERTopic_50k'])
df.index = ['Query', 'NMF_20k', 'NMF_50k', 'LDA_20k', 'LDA_50k', 'BERTopic_20k','BERTopic_50k']

# Create a heatmap
sns.heatmap(df, annot=True, cmap='Blues')
plt.title("Cosine Similarity of Query and Algorithms across Abstracts")
plt.show()
