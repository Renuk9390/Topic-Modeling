# %% [markdown]
# # Claim

# %%
import pandas as pd
dataframes = []

for filename in ['./dataset/2015.csv',
                 './dataset/2016.csv',
                 './dataset/2017.csv',
                 './dataset/2018.csv',
                 './dataset/2019.csv'
 
                ]:
    
    df = pd.read_csv(filename, error_bad_lines=False)
    dataframes.append(df)
    
df = pd.concat(dataframes, ignore_index=True)
df.to_csv('./dataset/df-claim.csv')
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_20536/2042145278.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filename, error_bad_lines=False)
# C:\Users\admin\AppData\Local\Temp/ipykernel_20536/2042145278.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filename, error_bad_lines=False)
# C:\Users\admin\AppData\Local\Temp/ipykernel_20536/2042145278.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filename, error_bad_lines=False)
# ...

# %%
# Read uspto dataset
import pandas as pd
import numpy as np
import nltk


df = pd.read_csv('./dataset/df-claim.csv')
#df_claim = pd.concat(df_chunks, ignore_index=True)
df_claim=df[["ID","Title","Claim","cpc_subclass"]]
df_claim= df_claim.dropna()
df_claim = df_claim.reset_index(drop=True)
df_claim.head()
# Out:
#         ID                                              Title  \
# 0  8927300  Method and compositions for the detection of p...
# 1  8930992                      TV social network advertising
# 2  8929358  Call flow system and method for use in a legac...
# 3  8925531                   Spark plug degradation detection
# 4  8927955                           Resistance change memory
#
#                                                Claim              cpc_subclass
# 0  1. A compound of the formula: wherein R is a s...  C07H,C07K,C12N,C12Q,G01N
# 1  1. An advertising method, comprising: displayi...                 G06Q,H04N
# 2  1. A method, comprising: receiving, from a mob...  H04L,H04M,H04Q,H04W,H05K
# 3  1. A method of controlling an engine cylinder ...            F02D,F02P,Y02T
# 4  1. A resistance change memory comprising: a fi...            B82Y,G11C,H01L

# %%
len(df_claim)
# Out:
# 1428600

# %%
df_claim_uspto = df_claim_uspto = df_claim[df_claim['cpc_subclass'].str.contains(r'\bA[\w]*|,[\s]*A[\w]*')]
df_claim_uspto
# Out:
#                ID                                              Title  \
# 5         8928484  System and method of biomechanical posture det...
# 6         8928653  Information processing system, information pro...
# 8         8926096  Conformable therapeutic shield for vision and ...
# 11        8926664                     Laminoplasty fixaction devices
# 21        8926515  Method and apparatus for continuously monitori...
# ...           ...                                                ...
# 1428570  10362937                             Cornea transplantation
# 1428575  10362875                    Easy folding cross brace design
# 1428589  10363129  Variable strength intraocular lens and method ...
# 1428594  10362949  Automatic extraction of disease-specific featu...
# 1428598  10363133  Methods and apparatus for engaging a valve pro...
#
#                                                      Claim  \
# 5        1. A method of providing postural feedback com...
# ...

# %%
df.to_csv('./dataset/df-claim-A.csv')

# %% [markdown]
# # Abstract

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import itertools
import wordcloud as wc
import matplotlib.ticker as ticker

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_2006 = pd.read_json('./dataset/AbstractDataset/2006_USPTO.json')
df_2007 = pd.read_json('./dataset/AbstractDataset/2007_USPTO.json')
df_2008 = pd.read_json('./dataset/AbstractDataset/2008_USPTO.json')
df_2009 = pd.read_json('./dataset/AbstractDataset/2009_USPTO.json')
df_2010 = pd.read_json('./dataset/AbstractDataset/2010_USPTO.json')
df_2011 = pd.read_json('./dataset/AbstractDataset/2011_USPTO.json')
df_2012 = pd.read_json('./dataset/AbstractDataset/2012_USPTO.json')
df_2013 = pd.read_json('./dataset/AbstractDataset/2013_USPTO.json')
df_2014 = pd.read_json('./dataset/AbstractDataset/2014_USPTO.json')
df_2015 = pd.read_json('./dataset/AbstractDataset/2015_USPTO.json')

# %%
df = pd.concat([df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015], axis=0, ignore_index=True)

# %%
df.to_csv('./dataset/AbstractDataset/df-Abstract.csv')

# %%
df = pd.read_csv('./dataset/AbstractDataset/df-Abstract.csv')
df = df.rename(columns={'No': 'ID', 'Title': 'Title', 'Abstract': 'Abstract', 'Subclass_labels': 'cpc_subclass'})
df_Abstract=df[["ID","Title","Abstract","cpc_subclass"]]
df_Abstract= df_Abstract.dropna()
df_Abstract = df_Abstract.reset_index(drop=True)
df_Abstract.head()
df_Abstract
# Out:
#                  ID                                              Title  \
# 0        US07072141  magnetic disc unit with range of gap between d...
# 1        US06981282        systems and methods for transformable suits
# 2        US06981283  gardening gloves with cushion insert to protec...
# 3        US06981284  hockey helmet comprising a lateral adjustment ...
# 4        US06981285                     toilet and method of operation
# ...             ...                                                ...
# 2000106  US08976203  wavelength conversion device and image display...
# 2000107  US08976510               cable assembly and electronic device
# 2000108  US08976819        circuit and method for metering electricity
# 2000109  US08977126  unified network management of hybrid fiber coa...
# 2000110  US08977434                    vehicle attitude control system
#
#                                                   Abstract  \
# ...

# %%
df_Abstract_uspto = df_Abstract[df_Abstract['cpc_subclass'].str.contains(r'\bA[\w]*|,[\s]*A[\w]*')]
df_Abstract_uspto
# Out:
#                  ID                                              Title  \
# 1        US06981282        systems and methods for transformable suits
# 2        US06981283  gardening gloves with cushion insert to protec...
# 3        US06981284  hockey helmet comprising a lateral adjustment ...
# 6        US06981287                                inflatable bed unit
# 7        US06981288                              structure of a pillow
# ...             ...                                                ...
# 2000081  US08975044  polynucleotides encoding for frizzled binding ...
# 2000091  US08975055  reduced fat foodstuffs and cooking oils and me...
# 2000093  US08975057  protein having glucosidase activity and uses t...
# 2000095  US08975059  polypeptides having endoglucanase activity and...
# 2000103  US08975274       compositions and methods for treating cancer
#
#                                                   Abstract  \
# ...
