# %%
import pandas as pd

df_claim = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %%
len(df_claim)
# Out:
# 31306

# %% [markdown]
# # preprocessing

# %%
def cleantext(df_claim): 
    
    df_claim['cleaned_claim_text'] = df_claim['first_claim'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
    
    # convert to lowercase
    df_claim['cleaned_claim_text'] = df_claim['cleaned_claim_text'].str.lower()
    
    #remove numbers
    df_claim['cleaned_claim_text'] =df_claim['cleaned_claim_text'].replace(r'\d+', '', regex = True)
        
    #remove_symbols
    df_claim['cleaned_claim_text']  = df_claim['cleaned_claim_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
    
    #remove punctuations 
    df_claim['cleaned_claim_text'] = df_claim['cleaned_claim_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
    
    #remove_URL(x):
    df_claim['cleaned_claim_text']  = df_claim['cleaned_claim_text'].replace(r'https.*$', "", regex = True)
    df_claim['cleaned_claim_text'] = df_claim['cleaned_claim_text'].replace("   ", " ", regex = True)
    df_claim['cleaned_claim_text'] = df_claim['cleaned_claim_text'].replace("  ", " ", regex = True)
   
    return df_claim

df_claim = cleantext(df_claim)
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_claim_text
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...

# %%
import nltk
from nltk.corpus import stopwords

# Load the stop words
nltk.download('stopwords')
english_stop_words = set(stopwords.words('english'))

# Define a set of patent-specific stop words 337
patent_stop_words = set([
                        'a', 'an', 'the', 'is', 'are', 'was', 'were', 'will', 'shall', 'may', 'can', 'could',
                        'of', 'in', 'on', 'at', 'by', 'with', 'for', 'to', 'from', 'as', 'and', 'or', 'not',
                        'this', 'that', 'these', 'those', 'such', 'which', 'where', 'when', 'who', 'whom',
                        'what', 'how', 'why', 'be', 'have', 'has', 'having', 'had', 'do', 'does', 'doing',
                        'done', 'but', 'however', 'although', 'unless', 'until', 'since', 'while', 'before',
                        'after', 'during', 'through', 'over', 'under', 'above', 'below', 'between', 'among',
                        'within', 'without', 'against', 'via', 'via', 'due', 'onto', 'per', 'each', 'any',
                        'some', 'many', 'few', 'all', 'most', 'no', 'yes', 'ok', 'okk', 'nope', 'nopes', 'nay',
                        'more', 'less', 'least', 'other', 'another', 'somehow', 'thus', 'therefore',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'therein', 'thereupon', 'therewith', 'thereto', 'wherefore', 'forthwith', 'hereby',
                        'herein', 'hereupon', 'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore',
                        'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore', 'therefrom', 'thereof',
                        'therein', 'thereon', 'thereto', 'whereby', 'thereafter', 'hereafter', 'whenever',
                        'wherever', 'until', 'since', 'whenever', 'wherever', 'until', 'since', 'whereas', 'whilst',
                        'whereas', 'whilst', 'beside', 'beyond', 'during', 'about', 'around', 'above', 'below', 'before',
                        'after', 'without', 'within', 'between', 'among', 'against', 'under', 'over', 'through',
                        'into', 'onto', 'upon', 'am', 'are', 'is', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
                        'had', 'having', 'do', 'does', 'did', 'doing', 'can', 'could', 'will', 'would', 'shall', 'should',
                        'may', 'might', 'must', 'ought', 'need', 'dare', 'used', 'use', 'using', 'uses', 'used', 'put',
                        'puts', 'putting', 'tell', 'tells', 'told', 'telling', 'ask', 'asks', 'asked', 'asking',
                        'make', 'makes', 'made', 'making', 'find', 'finds', 'found', 'finding', 'keep', 'keeps',
                        'kept', 'keeping', 'begin', 'begins', 'began', 'beginning', 'show', 'shows', 'showed',
                        'showing', 'say', 'says', 'said', 'saying', 'says', 'said', 'let', 'lets', 'letting', 'make',
                        'makes', 'made', 'making', 'put', 'puts', 'putting', 'seem', 'seems', 'seemed', 'seeming',
                        'need', 'needs', 'needed', 'needing', 'become', 'becomes', 'became', 'bec'])


# Merge the sets of stop words
stop_words = english_stop_words.union(patent_stop_words)

df_claim['cleaned_claim_without_Stopwprd'] = df_claim['cleaned_claim_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
df_claim.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_claim_without_Stopwprd
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df_claim["Lemmatized-Claim"] = df_claim["cleaned_claim_without_Stopwprd"].apply(lambda text: lemmatize_words(text))
df_claim.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Calculate the length of each record in both columns
df_claim['Length (cleaned)'] = df_claim['Lemmatized-Claim'].str.len()
df_claim['Length (original)'] = df_claim['first_claim'].str.len()

# Set a custom Seaborn style for a more appealing plot
sns.set_style("whitegrid")

# Create a figure with subplots for better readability
fig, ax = plt.subplots(figsize=(12, 6))

# Create line plots for both text lengths
sns.lineplot(data=df_claim[['Length (cleaned)', 'Length (original)']], ax=ax, palette=["red", "green"])
ax.set_xlabel('Record Index', fontsize=12)
ax.set_ylabel('Text Length', fontsize=12)
ax.set_title('Comparison of Text Lengths', fontsize=16)

# Customize the legend
ax.legend(['Length (cleaned_calim_text)', 'Length (first_claim)'], fontsize=10)

# Add a grid to the plot
sns.despine()
ax.grid(axis='y', linestyle='--', alpha=0.6)

# Display the plot
plt.tight_layout()
plt.show()

# %%
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim  Length (cleaned)  \
# 0  reality interactive responding system comprisi...               865
# 1  claimed data storage retrieval system nonconti...              1012
# 2  method computing system comprising obtaining i...              1003
# 3  claimed method providing networking communicat...               910
# 4  claimed method monitoring physiological condit...               951
#
#    Length (original)
# 0               1179
# 1               1331
# 2               1279
# 3               1260
# 4               1240

# %%
first_record = df_claim['Lemmatized-Claim'][1]
first_record
# Out:
# 'claimed data storage retrieval system noncontiguous medical device data system comprising medical device connectable computer network subject occasional gap connectivity computer network configured automatically repeatedly capture status information medical device send message containing status information computer network network connectivity log configured automatically record time medical device connects computer network b time medical device disconnect computer network data store configured automatically store digital medium data medium file provide requested portion stored medium file response provision request wherein provision request includes index relative end medium file corresponds requested portion medium server connectable computer network configured automatically receive message computer network store status information received message data store wherein status information consecutive received message stored contiguously data store notwithstanding occasional gap connectivity medical'

# %%
x = len(df_claim['Lemmatized-Claim'][1])
print(x)
# Out:
# 1012

# %%
# Check for NaN or null values in 'Lemmatized-Claim' column
has_nan_or_null = df_claim['Lemmatized-Claim'].isna().any()

if has_nan_or_null:
    print("The 'Lemmatized-Claim' column contains NaN or null values.")
else:
    print("The 'Lemmatized-Claim' column does not contain NaN or null values.")
# Out:
# The 'Lemmatized-Claim' column does not contain NaN or null values.

# %%
# Calculate the length of strings in the 'Lemmatized-Claim' column and find the minimum length
min_length = df_claim['Lemmatized-Claim'].str.len().min()

print(f"The shortest length in the 'Lemmatized-Claim' column is: {min_length}")
# Out:
# The shortest length in the 'Lemmatized-Claim' column is: 37

# %%
import torch
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from transformers.pipelines import pipeline
from sentence_transformers import SentenceTransformer

# Load the Sentence Transformers model
#sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
#sentence_model = SentenceTransformer("all-MiniLM-L6-v2", device=device)
sentence_model = SentenceTransformer("xlm-r-bert-base-nli-stsb-mean-tokens")

# Adjust UMAP hyperparameters
umap_model = UMAP(n_neighbors=3, 
                  n_components=3, 
                  min_dist=0.05, 
                  metric='cosine', 
                  random_state=100)  # Utilize all available CPU cores for UMAP preprocessing

# Adjust HDBSCAN hyperparameters
hdbscan_model = HDBSCAN( min_cluster_size=80,
                        min_samples=40, 
                        metric='euclidean', 
                        cluster_selection_method='eom', 
                        prediction_data=True)

# Adjust CountVectorizer hyperparameters
vectorizer_model = CountVectorizer(ngram_range=(1, 3))


# c-TF-IDF
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Run Model
topic_model = BERTopic(umap_model=umap_model,
                       embedding_model=sentence_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       ctfidf_model=ctfidf_model,
                       verbose=True)

# Replace 'df['first_claim']' with your data source for the first_claim column
topics, probabilities = topic_model.fit_transform(df_claim['Lemmatized-Claim'])
# Out:
# Batches:   0%|          | 0/979 [00:00<?, ?it/s]
# 2023-10-01 19:53:44,165 - BERTopic - Transformed documents to Embeddings
# 2023-10-01 19:53:51,903 - BERTopic - Reduced dimensionality
# 2023-10-01 19:53:53,600 - BERTopic - Clustered reduced embeddings

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document": df_claim['Lemmatized-Claim'],
                          "ID": range(len(df_claim['Lemmatized-Claim'])),
                          "Topic": topics})

documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence_c_nmpi = coherence_model.get_coherence()
print("c_npmi is: ",coherence_c_nmpi)
# Out:
# c_npmi is:  -0.06313159348245927

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_claim['Lemmatized-Claim'],
                          "ID": range(len(df_claim['Lemmatized-Claim'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_CV= coherence_model.get_coherence()
print("C_V is: ", coherence_CV)
# Out:
# C_V is:  0.42891611932861984

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

documents = pd.DataFrame({"Document":df_claim['Lemmatized-Claim'],
                          "ID": range(len(df_claim['Lemmatized-Claim'])),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence_u_mass= coherence_model.get_coherence()
print("u_mass is: ", coherence_u_mass)
# Out:
# u_mass is:  -0.6445754062244934

# %%
 topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  13814                     -1_device_medical_first_system
# 1       0   1991  0_canceled_canceled canceled_canceled canceled...
# 2       1   1197               1_glucose_food_insulin_blood glucose
# 3       2   1103      2_medication_drug_prescription_pharmaceutical
# 4       3   1009                  3_patient_care_healthcare_medical
# 5       4   1009              4_computer_healthcare_patient_medical
# 6       5    989           5_medical image_image_medical_image data
# 7       6    738      6_processor_one processor_patient_instruction
# 8       7    627     7_wireless_mobile_communication_medical device
# 9       8    495                8_radiation_light_beam_radiographic
# 10      9    477   9_health_health information_wellness_health data
# 11     10    472      10_one processor_processor_instruction_memory
# 12     11    470               11_health_health data_user_processor
# 13     12    464  12_biological_sample_biological information_bi...
# 14     13    440                       13_image_unit_object_display
# 15     14    439        14_ventilator_respiratory_fluid_ventilation
# 16     15    403  15_biological_physiological_biological extract...
# 17     16    378  16_surgical_surgical procedure_surgical instru...
# 18     17    372                  17_object_document_item_plurality
# 19     18    348     18_ultrasound_ultrasound image_ultrasonic_echo
# 20     19    303                  19_dental_tooth_teeth_orthodontic
# 21     20    287               20_exercise_workout_fitness_athletic
# 22     21    249                          21_cardiac_heart_ecg_beat
# 23     22    247                          22_cancer_tumor_cell_gene
# 24     23    246  23_physiological_signal_sensor_physiological s...
# 25     24    179  24_wireless_wireless communication_communicati...
# 26     25    177   25_medication_drug_prescription_medication claim
# 27     26    168       26_sleep_sleep stage_user sleep_sleeprelated
# 28     27    151     27_sensor_sensor data_wearable_wearable sensor
# 29     28    144      28_trial_clinical trial_clinical_investigator
# 30     29    141              29_animal_pet_veterinary_veterinarian
# 31     30    133  30_temperature_thermal_body temperature_therma...
# 32     31    129   31_coronary_coronary artery_physiological_artery
# 33     32    125   32_blood_pressure_blood pressure_blood treatment
# 34     33    122       33_first medical_second medical_second_first
# 35     34    112             34_payment_healthcare_provider_service
# 36     35    109                35_client_server_service_networking
# 37     36    108            36_bone_implant_fracture_bone structure
# 38     37    108              37_hygiene_cleaning_hand_hand hygiene
# 39     38    108               38_brain_brain wave_stimulus_emotion
# 40     39    102  39_image study_electronic processor configured...
# 41     40     97               40_cloud_web_cloud server_cloudbased
# 42     41     95                     41_genetic_cancer_gene_variant
# 43     42     94           42_medication_drug_pharmacy_prescription
# 44     43     94                   43_symptom_pain_disease_headache
# 45     44     82              44_image_evaluator_scan_dynamic image
# 46     45     81                 45_therapy_exercise_therapist_game
# 47     46     80  46_medical image_image_nodule_clinical image data
#
#                                        Representation  \
# 0   [device, medical, first, system, claim, claim ...
# 1   [canceled, canceled canceled, canceled cancele...
# 2   [glucose, food, insulin, blood glucose, meal, ...
# 3   [medication, drug, prescription, pharmaceutica...
# 4   [patient, care, healthcare, medical, treatment...
# 5   [computer, healthcare, patient, medical, provi...
# 6   [medical image, image, medical, image data, im...
# 7   [processor, one processor, patient, instructio...
# 8   [wireless, mobile, communication, medical devi...
# 9   [radiation, light, beam, radiographic, radioth...
# 10  [health, health information, wellness, health ...
# 11  [one processor, processor, instruction, memory...
# 12  [health, health data, user, processor, wellnes...
# 13  [biological, sample, biological information, b...
# 14  [image, unit, object, display, examination, im...
# 15  [ventilator, respiratory, fluid, ventilation, ...
# 16  [biological, physiological, biological extract...
# 17  [surgical, surgical procedure, surgical instru...
# 18  [object, document, item, plurality, informatio...
# 19  [ultrasound, ultrasound image, ultrasonic, ech...
# 20  [dental, tooth, teeth, orthodontic, appliance,...
# 21  [exercise, workout, fitness, athletic, exercis...
# 22  [cardiac, heart, ecg, beat, heart rate, signal...
# 23  [cancer, tumor, cell, gene, expression, sample...
# 24  [physiological, signal, sensor, physiological ...
# 25  [wireless, wireless communication, communicati...
# 26  [medication, drug, prescription, medication cl...
# 27  [sleep, sleep stage, user sleep, sleeprelated,...
# 28  [sensor, sensor data, wearable, wearable senso...
# 29  [trial, clinical trial, clinical, investigator...
# 30  [animal, pet, veterinary, veterinarian, cow, i...
# 31  [temperature, thermal, body temperature, therm...
# 32  [coronary, coronary artery, physiological, art...
# 33  [blood, pressure, blood pressure, blood treatm...
# 34  [first medical, second medical, second, first,...
# 35  [payment, healthcare, provider, service, healt...
# 36  [client, server, service, networking, service ...
# 37  [bone, implant, fracture, bone structure, cutt...
# 38  [hygiene, cleaning, hand, hand hygiene, toilet...
# 39  [brain, brain wave, stimulus, emotion, wave, s...
# 40  [image study, electronic processor configured,...
# 41  [cloud, web, cloud server, cloudbased, server,...
# 42  [genetic, cancer, gene, variant, genetic varia...
# 43  [medication, drug, pharmacy, prescription, dru...
# 44  [symptom, pain, disease, headache, pro, severi...
# 45  [image, evaluator, scan, dynamic image, proces...
# 46  [therapy, exercise, therapist, game, physical ...
# 47  [medical image, image, nodule, clinical image ...
#
#                                   Representative_Docs
# 0   [described various embodiment invention claime...
# 1   [canceled system recording delivery medication...
# 2   [system optimizing patient basal insulin dosag...
# 3   [method management distribution authorized med...
# 4   [claimed system providing user interface prese...
# 5   [system useful computer healthcare system crea...
# 6   [medical image system comprising image server ...
# 7   [claimed system comprising one processor nontr...
# 8   [method comprising receiving data medical devi...
# 9   [xray based imaging system comprising xray sou...
# 10  [system improve management individual health s...
# 11  [computer system configured communicate displa...
# 12  [computing system comprising one processor non...
# 13  [system allocating selecting biological cell t...
# 14  [claimed image management system comprising im...
# 15  [method comprising one computing device access...
# 16  [system determining plurality biological outco...
# 17  [claimed surgical visualization system surgica...
# 18  [system generating access control policy compr...
# 19  [claimed ultrasound diagnostic apparatus compr...
# 20  [claimed method processing dental aligner meth...
# 21  [exercise system configured provide two user o...
# 22  [claimed system evaluating degree blockage pat...
# 23  [gene panel personalized medicine gene panel c...
# 24  [system monitoring recording parameter subject...
# 25  [claim system monitoring repeating motion venu...
# 26  [claimed one computer storage medium storing c...
# 27  [claimed computersystemimplemented method comp...
# 28  [claimed computersystemimplemented method comp...
# 29  [claim trial operation service suite clinical ...
# 30  [claimed method providing animal related servi...
# 31  [device measure temperature device comprising ...
# 32  [claimed method identifying managing highrisk ...
# 33  [extracorporeal blood treatment system compris...
# 34  [claimed method selectively archiving medical ...
# 35  [claimed method comprising receiving customer ...
# 36  [service facilitating monitoring individual be...
# 37  [method creating patient specific instrumentat...
# 38  [proactive hand hygiene monitoring system empl...
# 39  [brain wave neurofeedback training computing s...
# 40  [claimed system automatically triaging image s...
# 41  [claim online system transmitting patient medi...
# 42  [nontransitory storage medium storing instruct...
# 43  [claim computing device communication implanta...
# 44  [claim method predictive diagnosis one autoimm...
# 45  [claimed image processing apparatus comprising...
# 46  [claimed system providing psychotherapy system...
# 47  [claimed tangible computerreadable storage med...

# %%
#adding topics and probs for eachdoc in dataset
df_claim['topics'] = topics
df_claim['prob'] = probabilities
df_claim_topic=df_claim[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob"]]
df_claim_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 1      What is claimed is: 1 . A data storage and ret...
# 2      1 . A method in a computing system, comprising...
# 3      What is claimed is: 1 . A method for providing...
# 4      What is claimed is: 1 . A method of monitoring...
# ...                                                  ...
# 31301  1 . A user authentication system comprising: a...
# 31302  What is claimed is: 1 . A diagnosis support ap...
# 31303  1 . A medical appointment scheduling system co...
# 31304  1 . A data processing, comprising a computer h...
# 31305  1 . A method comprising: a healthcare server o...
#
#                                         Lemmatized-Claim  \
# 0      reality interactive responding system comprisi...
# 1      claimed data storage retrieval system nonconti...
# 2      method computing system comprising obtaining i...
# 3      claimed method providing networking communicat...
# 4      claimed method monitoring physiological condit...
# ...                                                  ...
# 31301  user authentication system comprising pluralit...
# 31302  claimed diagnosis support apparatus diagnosis ...
# 31303  medical appointment scheduling system comprisi...
# 31304  data processing comprising computer processor ...
# 31305  method comprising healthcare server healthcare...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      -1  0.000000
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']      -1  0.000000
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']       4  0.978546
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']       7  1.000000
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']      31  1.000000
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']      -1  0.000000
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']      -1  0.000000
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      -1  0.000000
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']      -1  0.000000
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']       4  0.943660
#
# [31306 rows x 8 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_claim_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_claim_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_claim_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %%
test1 = df_claim_test.loc[0, 'first_claim']
test1
# Out:
# '1. A physiological monitoring device comprising:\nat least two LEDs, the at least two LEDs configured to emit light of at least two different wavelengths; at least one detector configured to detect at least a portion of the light emitted from the at least two LEDs after at least a portion of the light has been attenuated by tissue, the at least one detector configured to output at least one signal responsive to the detected light; a light block surrounding the at least one detector, the light block forming a cavity, the light block comprising a light-absorbing material, the light block including only one circular opening through which light is configured to pass, an area of the circular opening being smaller than a surface area of a facing surface of the at least one detector; and a processor configured to receive and process one or more signals responsive to the outputted at least one signal and determine a physiological parameter of a user responsive to the one or more signals. at least two LEDs, the at least two LEDs configured to emit light of at least two different wavelengths; at least one detector configured to detect at least a portion of the light emitted from the at least two LEDs after at least a portion of the light has been attenuated by tissue, the at least one detector configured to output at least one signal responsive to the detected light; a light block surrounding the at least one detector, the light block forming a cavity, the light block comprising a light-absorbing material, the light block including only one circular opening through which light is configured to pass, an area of the circular opening being smaller than a surface area of a facing surface of the at least one detector; and a processor configured to receive and process one or more signals responsive to the outputted at least one signal and determine a physiological parameter of a user responsive to the one or more signals.'

# %%
import numpy as np 

# Find topics
num_of_topics = 5
similar_topics, similarity = topic_model.find_topics(test1, top_n=num_of_topics); 

# Print results
print(f'The top {num_of_topics} similar topics are {similar_topics}, and the similarities are {np.round(similarity,2)}')

for idx, topic_idx in enumerate(similar_topics):
    topic = topic_model.get_topic(topic_idx)
    keywords = ' '.join(str(keyword) for keyword in topic[0])
    print(f"Topic {idx+1}: {keywords}")
# Out:
# The top 5 similar topics are [23, 8, 12, 21, 30], and the similarities are [0.75 0.74 0.71 0.7  0.69]
# Topic 1: physiological 0.3394172798427013
# Topic 2: radiation 0.37390708046305765
# Topic 3: biological 0.3538602062992372
# Topic 4: cardiac 0.3811497727312095
# Topic 5: temperature 0.5658747785998948

# %%
# filter_topics_filter = df_claim_topic[df_claim_topic['topics'] == 43]
# filter_topics_filter = filter_topics_filter.sort_values('prob', ascending=False)
# filter_topics_filter

# %%
# Define the range of topic IDs you want to retrieve documents for
selected_topic_range =[-1, 8, 0, 3, 6]  # Replace with your desired range of topic IDs

# Create an empty DataFrame to store the top 10 documents
top_10_documents_test1 = pd.DataFrame()

# Iterate through the selected topic IDs
for selected_topic_id in selected_topic_range:
    # Filter the dataset based on the current topic ID
    filtered_df = df_claim_topic[df_claim_topic['topics'] == selected_topic_id]
    
    # Sort the filtered dataset by similarity scores in descending order
    sorted_df = filtered_df.sort_values(by='prob', ascending=False)
    
    # Retrieve the top 10 documents for the current topic
    top_10_for_topic = sorted_df.head(10)
    
    # Append the top 10 documents for the current topic to the result DataFrame
    top_10_documents_test1 = top_10_documents_test1.append(top_10_for_topic)

# Display the top 10 documents for all selected topics
top_10_documents_test1
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 20823     US2013317382A1  System and Method for Providing and Aggregatin...
# 20825     US2013312498A1  Cardiovascular disease risk assessment and tre...
# 20829     US2013314535A1                     Dispensing verification device
# 20830     US2013317852A1                  Medical device information portal
# 20833     US2013317836A1  Systems and Methods for Time Management in a H...
# 20835     US2013317384A1  System and Method for Instructing a Behavior C...
# 20837     US2013325497A1  Clinical information display apparatus, clinic...
# 20841     US2013325491A1             Therapy Tracking And Management System
# 20842     US2013320079A1                        Anti-Counterfeiting Methods
# 15591     US2008068473A1  Studio booth contest using preselected chroma ...
# 19598     US2018358121A1  Communication system for dynamic checklists to...
# 19576     US2018350454A1        Determining an anonymized dose report image
# 19520     US2018342315A1  Method for 3d imaging of mechanical assemblies...
# 19465     US2018325476A1  Radiation imaging system, information processi...
# 19349     US2018304097A1  System and method for radiation therapy treatm...
# 19306     US2018296170A1  Ct apparatus, ct imaging method, and storage m...
# 19232     US2018286504A1  Challenge value icons for radiology report sel...
# 19203     US2018271469A1     Radiographic moving image processing apparatus
# 19184     US2018263502A1  Method and apparatus for non-contact fast vita...
# 31298     US2016249826A1  Method And System For Monitoring Physiological...
# 26009     US2022386951A1                    Autonomous drug delivery system
# 15615     US2008077031A1  System and method for remote expert-system med...
# 25933     US2022384058A1  Methods and apparatuses for using artificial i...
# 15543     US2008052313A1  Service Bus-Based Workflow Engine for Distribu...
# 15503     US2008038833A1  Manufacturing execution system for validation,...
# 15496     US2008037736A1  Medical information system having messaging fo...
# 15488     US2008033661A1  Method and apparatus for monitoring anesthesia...
# 25963     US2022381405A1                 Theragnostic Endoprosthetic Spacer
# 25985     US2022392631A1  Medical device with a data transfer system and...
# 14870     US2007150311A1  System for exchanging patient medical informat...
# 16079     US2008201174A1   Personalized medical adherence management system
# 14128     US2013106864A1  System, method, and software for displaying pa...
# 14926     US2007168223A1  Configurable clinical information system and m...
# 15075     US2007208598A1  Method of dispensing and tracking the giving o...
# 15202     US2007244724A1  Case based outcome prediction in a real-time m...
# 15227     US2007255596A1  Remote health application for the optimization...
# 2685      US2017147751A1  System and Methods for Narrative Patient Visit...
# 15466     US2008027751A1  Medical product reservation, distribution and ...
# 15580     US2008065422A1  Configurable User Interface System for Process...
# 31047     US2016196393A1  System and Method for Integrated Quantifiable ...
# 7623      US2021098123A1  Medical support apparatus, information process...
# 20729     US2013290005A1  Systems and methods for intelligent care trans...
# 7719      US2021118136A1  Artificial intelligence for personalized oncology
# 7728      US2021118557A1  System and method for providing model-based pr...
# 7744      US2021118547A1  Systems, devices, and methods for self-contain...
# 7745      US2021113279A1  Systems and methods for location sensor-based ...
# 7775      US2021125709A1  System and method to visualize and coordinate ...
# 7776      US2021125727A1  Machine Learning to Identify Locations of Brai...
# 14185     US2013124226A1  Method and Apparatus for Coordinating Healthca...
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 20823  We claim: 1 . A method for providing and aggre...
# 20825  What is claimed is: 1 . A therapeutic decision...
# 20829  1 . A dispensing verification device, comprisi...
# 20830  What is claimed is: 1 . A medical device infor...
# 20833  What is claimed is: 1 . A method comprising: r...
# 20835  We claim: 1 . A method for instructing a behav...
# 20837  What is claimed is: 1 . A clinical information...
# 20841  I claim: 1 . A computer implemented method for...
# 20842  We claim: 1 . A method against counterfeiting,...
# 15591  1 . A method of conducting a contest by produc...
# 19598  1 . A radiology workstation comprising: an ima...
# 19576  What is claimed is: 1 . A method for determini...
# 19520  1 . A method for quantitatively measuring the ...
# 19465  1 . A radiation imaging system comprising: a d...
# 19349  1 . A method for use in radiation therapy trea...
# 19306  1 . A CT apparatus comprising: a detection uni...
# 19232  1 . A radiology reading device comprising: a r...
# 19203  What is claimed is: 1 . A radiographic moving ...
# 19184  1 . A method of estimating a vibration rate of...
# 31298  1 .- 28 . (canceled) 29 . A method for monitor...
# 26009  1 . (canceled) 2 .- 24 . (canceled) 25 . An au...
# 15615  1 - 14 . (canceled) 15 . A medical device prog...
# 25933  1 - 11 . (canceled) 12 . A tangible, non-trans...
# 15543  1 . A distributed computing-implemented method...
# 15503  1 . A method of integrating a computer product...
# 15496  1 . (canceled) 2 . (canceled) 3 . (canceled) 4...
# 15488  1 - 14 . (canceled) 15 . A system for visually...
# 25963  What is claimed is: 1 . An endoprosthetic spac...
# 25985  1 .- 11 . (canceled) 12 . A medical device hav...
# 14870  1 . A system for exchanging patient medical in...
# 16079  1 . A method comprising: maintaining a patient...
# 14128  What is claimed is: 1 . A method, comprising t...
# 14926  1 . A method for providing functionality and d...
# 15075  1 . Apparatus comprising: a medical report, wh...
# 15202  1 . A method of monitoring a patient, comprisi...
# 15227  1 . A system for the scheduling of clinical vi...
# 2685   1 . A method for generating a narrative patien...
# 15466  1 . A method for providing a customer substant...
# 15580  1 . A user interface system for processing and...
# 31047  1 . An apparatus comprising: a processor parti...
# 7623   What is claimed is: 1 . A medical support appa...
# 20729  1 . A system comprising: a processor and a mem...
# 7719   What is claimed is: 1 . A system for personali...
# 7728   What is claimed is: 1 . A system for providing...
# 7744   1 . A computerized method for non-revealing mo...
# 7745   What is claimed is: 1 . A system, comprising: ...
# 7775   1 . An apparatus, comprising: at least one ele...
# 7776   What is claimed is: 1 . A computing system, th...
# 14185  1 . An apparatus for coordinating care of pati...
#
#                                         Lemmatized-Claim  \
# 0      reality interactive responding system comprisi...
# 20823  claim method providing aggregating bioelectric...
# 20825  claimed therapeutic decision diagram determine...
# 20829  dispensing verification device comprising came...
# 20830  claimed medical device information portal comp...
# 20833  claimed method comprising receiving computing ...
# 20835  claim method instructing behavior change user ...
# 20837  claimed clinical information display apparatus...
# 20841  claim computer implemented method tracking man...
# 20842  claim method counterfeiting method comprising ...
# 15591  method conducting contest producing area restr...
# 19598  radiology workstation comprising image renderi...
# 19576  claimed method determining anonymized dose rep...
# 19520  method quantitatively measuring individual pos...
# 19465  radiation imaging system comprising detector i...
# 19349  method radiation therapy treatment planning co...
# 19306  ct apparatus comprising detection unit configu...
# 19232  radiology reading device comprising radiology ...
# 19203  claimed radiographic moving image processing a...
# 19184  method estimating vibration rate target compri...
# 31298  canceled method monitoring subject engaged phy...
# 26009  canceled canceled automated first responder sy...
# 15615  canceled medical device programmer comprising ...
# 25933  canceled tangible nontransitory computerreadab...
# 15543  distributed computingimplemented method proces...
# 15503  method integrating computer product pharmaceut...
# 15496  canceled canceled canceled canceled canceled c...
# 15488  canceled system visually displaying pharmacoki...
# 25963  claimed endoprosthetic spacer administering th...
# 25985  canceled medical device data transfer system c...
# 14870  system exchanging patient medical information ...
# 16079  method comprising maintaining patient database...
# 14128  claimed method comprising step receiving one f...
# 14926  method providing functionality data patient pr...
# 15075  apparatus comprising medical report wherein me...
# 15202  method monitoring patient comprising step acqu...
# 15227  system scheduling clinical visit plurality rem...
# 2685   method generating narrative patient visit note...
# 15466  method providing customer substantially guaran...
# 15580  user interface system processing displaying pa...
# 31047  apparatus comprising processor particularly co...
# 7623   claimed medical support apparatus comprising p...
# 20729  system comprising processor memory store execu...
# 7719   claimed system personalized oncology comprisin...
# 7728   claimed system providing modelbased prediction...
# 7744   computerized method nonrevealing monitoring pr...
# 7745   claimed system comprising processor one comput...
# 7775   apparatus comprising one electronic processor ...
# 7776   claimed computing system computing system comp...
# 14185  apparatus coordinating care patient apparatus ...
#
#                         sub_classes         sub_class  topics  prob
# 0        ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      -1   0.0
# 20823     ['G16H20/30', 'A61B5/24']  ['G16H', 'A61B']      -1   0.0
# 20825  ['G16H10/60', 'G01N2800/32']  ['G16H', 'G01N']      -1   0.0
# 20829  ['G16H10/60', 'G07F17/0092']  ['G16H', 'G07F']      -1   0.0
# 20830    ['G06F19/00', 'G16H80/00']  ['G06F', 'G16H']      -1   0.0
# 20833    ['G06Q10/10', 'G16H40/20']  ['G06Q', 'G16H']      -1   0.0
# 20835    ['G16H20/70', 'A61B5/375']  ['G16H', 'A61B']      -1   0.0
# 20837    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']      -1   0.0
# 20841    ['G16H70/20', 'G16H40/63']  ['G16H', 'G16H']      -1   0.0
# 20842    ['G16H20/10', 'G16H20/10']  ['G16H', 'G16H']      -1   0.0
# 15591  ['G16H40/63', 'H04N1/00286']  ['G16H', 'H04N']       8   1.0
# 19598    ['G16H30/20', 'G16H30/20']  ['G16H', 'G16H']       8   1.0
# 19576    ['G16H15/00', 'G16H30/20']  ['G16H', 'G16H']       8   1.0
# 19520     ['G06T7/50', 'G16H30/40']  ['G06T', 'G16H']       8   1.0
# 19465     ['A61B6/00', 'G16H50/30']  ['A61B', 'G16H']       8   1.0
# 19349    ['G06F17/30', 'G16H20/40']  ['G06F', 'G16H']       8   1.0
# 19306     ['A61B6/03', 'G16H50/30']  ['A61B', 'G16H']       8   1.0
# 19232    ['G16H50/70', 'G16H40/20']  ['G16H', 'G16H']       8   1.0
# 19203     ['G06T7/00', 'G16H50/30']  ['G06T', 'G16H']       8   1.0
# 19184    ['G01S13/88', 'G16H50/30']  ['G01S', 'G16H']       8   1.0
# 31298   ['G16H20/30', 'A61B5/1118']  ['G16H', 'A61B']       0   1.0
# 26009    ['G16H20/17', 'G16H20/17']  ['G16H', 'G16H']       0   1.0
# 15615   ['A61B5/0452', 'G16H20/30']  ['A61B', 'G16H']       0   1.0
# 25933  ['G16H20/10', 'G06F18/2148']  ['G16H', 'G06F']       0   1.0
# 15543    ['G06F17/00', 'G16H30/20']  ['G06F', 'G16H']       0   1.0
# 15503    ['G01N30/02', 'G16H20/10']  ['G01N', 'G16H']       0   1.0
# 15496    ['G16H70/00', 'H04M3/533']  ['G16H', 'H04M']       0   1.0
# 15488    ['G16H20/17', 'A61M5/142']  ['G16H', 'A61M']       0   1.0
# 25963     ['F21K9/64', 'G16H40/63']  ['F21K', 'G16H']       0   1.0
# 25985  ['G16H40/67', 'H04L43/0823']  ['G16H', 'H04L']       0   1.0
# 14870    ['G16H10/60', 'G06Q10/10']  ['G16H', 'G06Q']       3   1.0
# 16079    ['G16H20/60', 'G16H20/10']  ['G16H', 'G16H']       3   1.0
# 14128    ['G06T11/20', 'G16H40/40']  ['G06T', 'G16H']       3   1.0
# 14926    ['G16H50/20', 'G16H50/20']  ['G16H', 'G16H']       3   1.0
# 15075    ['G16H15/00', 'G16H20/13']  ['G16H', 'G16H']       3   1.0
# 15202     ['A61B5/00', 'G16H40/63']  ['A61B', 'G16H']       3   1.0
# 15227    ['G16H40/20', 'G16H40/20']  ['G16H', 'G16H']       3   1.0
# 2685     ['G06F17/27', 'G16H10/60']  ['G06F', 'G16H']       3   1.0
# 15466    ['G16H20/13', 'G06Q10/10']  ['G16H', 'G06Q']       3   1.0
# 15580    ['G16H40/20', 'G16H40/20']  ['G16H', 'G16H']       3   1.0
# 31047     ['G16H30/20', 'A61B5/00']  ['G16H', 'A61B']       6   1.0
# 7623   ['G16H40/40', 'A61B1/00059']  ['G16H', 'A61B']       6   1.0
# 20729    ['G06Q50/22', 'G16H20/00']  ['G06Q', 'G16H']       6   1.0
# 7719     ['G16B40/00', 'G16H50/70']  ['G16B', 'G16H']       6   1.0
# 7728      ['G16H50/20', 'G06N7/01']  ['G16H', 'G06N']       6   1.0
# 7744     ['G16H50/50', 'H04W12/02']  ['G16H', 'H04W']       6   1.0
# 7745     ['A61B34/20', 'G16H20/40']  ['A61B', 'G16H']       6   1.0
# 7775     ['G16H40/20', 'G16H30/40']  ['G16H', 'G16H']       6   1.0
# 7776     ['G16H50/70', 'G16H50/70']  ['G16H', 'G16H']       6   1.0
# 14185    ['G16H10/60', 'G16H80/00']  ['G16H', 'G16H']       6   1.0

# %%
num_records = top_10_documents_test1.shape[0]
num_records
# Out:
# 50

# %%
# # Define a custom function to format the text
# def format_text(text):
#     # Remove brackets and single quotes, split by comma and strip whitespace
#     cleaned_text = ''.join(text).replace('[', '').replace(']', '').replace("'", '').split(',')
#     # Filter out empty strings and strip whitespace
#     cleaned_text = [item.strip() for item in cleaned_text if item.strip()]
#     # Join the cleaned text with commas and spaces
#     formatted_text = ', '.join(cleaned_text)
#     return formatted_text

# # Apply the custom function to the 'sub_classes' and 'sub_class' columns
# top_10_documents_test1['combined_class'] = top_10_documents_test1.apply(lambda x: format_text(x['sub_classes']) + ', ' + format_text(x['sub_class']), axis=1)

# # Display the resulting DataFrame with the 'combined' column
# print(top_10_documents_test1[['sub_classes', 'sub_class', 'combined_class']])

# %%
# # Get the class_codes from the first record of df_Abstract_test and convert it to a string, then split it by comma
# class_codes_value = df_Abstract_test['class_codes'].iloc[0]
# if pd.notna(class_codes_value):
#     target_sub_classes = str(class_codes_value).split(',')
# else:
#     target_sub_classes = []

# # Define a function to check for matching classes
# def has_matching_class(row):
#     # Extract the first 4 letters from each code in class_codes and combined_class
#     target_codes = [code[:4] for code in target_sub_classes]
#     combined_codes = [code[:4] for code in str(row['combined_class']).split(',')]

#     # Check if there are any common codes
#     return any(code in combined_codes for code in target_codes)

# # Apply the function to create a boolean mask
# top_10_documents_test1['has_matching_class'] = top_10_documents_test1.apply(has_matching_class, axis=1)

# top_10_documents_test1

# %%
# top_10_documents_test1.shape[0]

# %% [markdown]
# # list of 100 queries

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_claim_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Assuming you have a list of 100 queries in test
for query in df_claim_test['first_claim'][:num_samples_to_predict]:
    if isinstance(query, str):  # Check if the query is a string
        similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
        results.append((similar_topics, similarity))
    else:
        # Handle cases where 'query' is not a string (e.g., it's a float)
        print(f"Skipping non-string query: {query}")

# Now, the 'results' list contains the similar topics and similarities for each query
# You can access the results for a specific query like this:
for i, (similar_topics, similarity) in enumerate(results):
    print(f"Query {i + 1}: Similar Topics {similar_topics}, Similarity {similarity}")
# Out:
# Skipping non-string query: nan
# Skipping non-string query: nan
# Query 1: Similar Topics [23, 8, 12, 21, 30], Similarity [0.7460336, 0.7362931, 0.71009076, 0.70021033, 0.69143]
# Query 2: Similar Topics [8, 13, 23, 30, 24], Similarity [0.62646055, 0.60359156, 0.5989833, 0.5680598, 0.56789315]
# Query 3: Similar Topics [16, 36, 39, 46, 5], Similarity [0.78402436, 0.7215247, 0.7073066, 0.7011223, 0.6911143]
# Query 4: Similar Topics [10, 6, 15, 42, 11], Similarity [0.6965716, 0.6788354, 0.66583115, 0.64793926, 0.64761794]
# Query 5: Similar Topics [7, 0, -1, 43, 35], Similarity [0.72561085, 0.70707405, 0.7055948, 0.69520205, 0.6844642]
# Query 6: Similar Topics [23, 27, 24, 15, 45], Similarity [0.80900866, 0.80137444, 0.7525406, 0.7205435, 0.71791035]
# Query 7: Similar Topics [27, 10, 15, 44, 20], Similarity [0.81926227, 0.8012413, 0.78723, 0.7609329, 0.75703615]
# Query 8: Similar Topics [27, 20, 38, 45, 23], Similarity [0.6969273, 0.66740686, 0.63202167, 0.62153727, 0.61452365]
# Query 9: Similar Topics [16, 4, 3, 5, 39], Similarity [0.80361575, 0.76839304, 0.7604337, 0.7317424, 0.7177212]
# Query 10: Similar Topics [39, 46, 16, 22, 41], Similarity [0.7666693, 0.7528943, 0.74478143, 0.7232996, 0.7165631]
# Query 11: Similar Topics [22, 12, 41, 33, 8], Similarity [0.7842241, 0.67990077, 0.6530447, 0.5597595, 0.5592295]
# Query 12: Similar Topics [38, 27, 23, 43, 45], Similarity [0.7227632, 0.7123829, 0.6815976, 0.6796519, 0.6768588]
# Query 13: Similar Topics [23, 27, 45, 20, 15], Similarity [0.79534155, 0.793448, 0.7866523, 0.7822912, 0.78023744]
# Query 14: Similar Topics [26, 45, 6, 11, 10], Similarity [0.8184986, 0.65475243, 0.6517291, 0.648401, 0.64582145]
# Query 15: Similar Topics [27, 35, 45, 38, -1], Similarity [0.72987247, 0.710397, 0.69437546, 0.6847681, 0.68214256]
# Query 16: Similar Topics [1, 42, 11, 15, 6], Similarity [0.84752214, 0.68851846, 0.6785145, 0.65524447, 0.6471894]
# Query 17: Similar Topics [14, 1, 23, 30, 37], Similarity [0.7082153, 0.70406747, 0.6953821, 0.6926609, 0.6919693]
# Query 18: Similar Topics [1, 42, 25, 6, 11], Similarity [0.7408095, 0.7289077, 0.71493983, 0.6843238, 0.6804924]
# Query 19: Similar Topics [11, -1, 15, 42, 39], Similarity [0.7903341, 0.78212464, 0.7743945, 0.7674804, 0.76498044]
# Query 20: Similar Topics [3, 43, 9, 31, 33], Similarity [0.8222811, 0.79965997, 0.7768849, 0.77032936, 0.7689332]
# Query 21: Similar Topics [22, 12, 41, 46, 32], Similarity [0.8838946, 0.7634398, 0.7543438, 0.6576925, 0.64936936]
# Query 22: Similar Topics [19, 36, 22, 12, 18], Similarity [0.69517636, 0.6938175, 0.58404833, 0.58346874, 0.58059627]
# Query 23: Similar Topics [9, 11, 3, 34, 43], Similarity [0.84739995, 0.7363601, 0.7309078, 0.72913474, 0.70566905]
# Query 24: Similar Topics [20, 27, 23, 45, 21], Similarity [0.7879969, 0.7870603, 0.7839002, 0.7774302, 0.7709868]
# Query 25: Similar Topics [6, 25, 11, 45, 39], Similarity [0.8077128, 0.7991334, 0.78958476, 0.772146, 0.7701477]
# Query 26: Similar Topics [19, 36, 39, 16, 45], Similarity [0.76643467, 0.6043848, 0.564214, 0.5479775, 0.51301146]
# Query 27: Similar Topics [14, 31, 32, 21, 16], Similarity [0.7833992, 0.76016283, 0.7414859, 0.7251544, 0.70560163]
# Query 28: Similar Topics [4, 7, -1, 25, 46], Similarity [0.6592095, 0.6425653, 0.6384026, 0.6361382, 0.6354261]
# Query 29: Similar Topics [12, 22, 41, 15, 32], Similarity [0.8019059, 0.72158587, 0.68247104, 0.65060496, 0.6191993]
# Query 30: Similar Topics [3, 4, 0, -1, 6], Similarity [0.71378744, 0.71338004, 0.71196926, 0.7063962, 0.70414805]
# Query 31: Similar Topics [7, 16, 40, 4, 46], Similarity [0.7944651, 0.79088867, 0.7805172, 0.77325046, 0.7706523]
# Query 32: Similar Topics [14, 32, 37, 23, 30], Similarity [0.6998794, 0.6069691, 0.60351264, 0.58712655, 0.57169276]
# Query 33: Similar Topics [16, 36, 18, 5, 46], Similarity [0.7142733, 0.635275, 0.61204207, 0.6065526, 0.60301864]
# Query 34: Similar Topics [23, 1, 7, 24, 27], Similarity [0.73105377, 0.71002984, 0.7033497, 0.69792765, 0.6805879]
# Query 35: Similar Topics [24, 27, 7, 23, 8], Similarity [0.7261239, 0.7089727, 0.7068974, 0.70419204, 0.6645852]
# Query 36: Similar Topics [11, 4, 46, 16, 40], Similarity [0.7499795, 0.7309069, 0.729424, 0.7238618, 0.7122478]
# Query 37: Similar Topics [43, 2, 31, 28, 9], Similarity [0.78076404, 0.7786765, 0.7176273, 0.7135729, 0.7077583]
# Query 38: Similar Topics [6, 11, 42, 46, 15], Similarity [0.84265965, 0.82287824, 0.81640196, 0.81366146, 0.80366004]
# Query 39: Similar Topics [30, 26, 23, 11, 14], Similarity [0.72066927, 0.6526803, 0.62160563, 0.6166316, 0.5948764]
# Query 40: Similar Topics [8, 7, 30, 14, 23], Similarity [0.76631093, 0.7659202, 0.7640552, 0.75805724, 0.7579654]
# Query 41: Similar Topics [6, 25, 10, 4, 41], Similarity [0.83894724, 0.7775695, 0.77179694, 0.7613783, 0.76051664]
# Query 42: Similar Topics [19, 6, 41, 16, 39], Similarity [0.7602169, 0.65423715, 0.6424668, 0.6323384, 0.6309121]
# Query 43: Similar Topics [35, 24, 27, 17, 7], Similarity [0.7558477, 0.71085733, 0.67002004, 0.6442958, 0.6308178]
# Query 44: Similar Topics [31, 21, 43, 3, -1], Similarity [0.8322519, 0.8000571, 0.78445554, 0.7827327, 0.772438]
# Query 45: Similar Topics [6, 11, 1, 42, 25], Similarity [0.75290537, 0.7524123, 0.7508276, 0.74234945, 0.7090154]
# Query 46: Similar Topics [43, 3, 31, 9, 5], Similarity [0.8240482, 0.8016598, 0.77280784, 0.76415616, 0.75562537]
# Query 47: Similar Topics [1, 32, 23, 27, 11], Similarity [0.7682966, 0.66472137, 0.6514653, 0.6499509, 0.64831555]
# Query 48: Similar Topics [19, 36, 37, 16, 43], Similarity [0.809616, 0.5593711, 0.5288611, 0.51917803, 0.49353066]
# Query 49: Similar Topics [19, 36, 16, 39, 22], Similarity [0.8828396, 0.67978704, 0.61232275, 0.52953905, 0.51251364]
# Query 50: Similar Topics [10, 15, 11, 27, 0], Similarity [0.710881, 0.69346434, 0.6802138, 0.66278267, 0.66045517]
# Query 51: Similar Topics [40, 4, 11, 45, 25], Similarity [0.7730421, 0.7554998, 0.73635274, 0.7256384, 0.71578014]
# Query 52: Similar Topics [39, 46, 16, 41, -1], Similarity [0.80490196, 0.7751249, 0.7650121, 0.764623, 0.759001]
# Query 53: Similar Topics [15, 23, 39, 27, 45], Similarity [0.76877344, 0.75320804, 0.74172443, 0.73875034, 0.7248646]
# Query 54: Similar Topics [31, 21, 22, 43, 14], Similarity [0.737747, 0.7308289, 0.7153282, 0.6900908, 0.6758503]
# Query 55: Similar Topics [16, 46, 5, 39, 4], Similarity [0.7971259, 0.6897728, 0.667577, 0.6568357, 0.6494348]
# Query 56: Similar Topics [38, 17, 15, 44, 13], Similarity [0.7472031, 0.7091707, 0.6856085, 0.6794256, 0.6675451]
# Query 57: Similar Topics [19, 36, 16, 6, 41], Similarity [0.85614693, 0.6933117, 0.6611453, 0.658707, 0.63832724]
# Query 58: Similar Topics [7, 3, 40, 9, 33], Similarity [0.81397736, 0.79803056, 0.7540335, 0.74854547, 0.7457266]
# Query 59: Similar Topics [15, 27, 23, 10, 44], Similarity [0.79872334, 0.7980201, 0.79493475, 0.7532649, 0.7458999]
# Query 60: Similar Topics [16, 46, 25, 4, 6], Similarity [0.81902987, 0.77022207, 0.76511055, 0.7645601, 0.76429486]
# Query 61: Similar Topics [20, 45, 27, 38, 15], Similarity [0.7695013, 0.6803678, 0.6781684, 0.6404449, 0.6400687]
# Query 62: Similar Topics [11, 6, 10, 15, 42], Similarity [0.83200026, 0.8138875, 0.8038374, 0.7966859, 0.747327]
# Query 63: Similar Topics [23, 27, 24, 38, 8], Similarity [0.6650696, 0.644052, 0.63415396, 0.62244844, 0.5814563]
# Query 64: Similar Topics [23, 15, 11, 45, 27], Similarity [0.7833953, 0.776955, 0.75760543, 0.75055397, 0.75038683]
# Query 65: Similar Topics [24, 44, 27, 10, 15], Similarity [0.71367264, 0.6939246, 0.674317, 0.6630828, 0.65462863]
# Query 66: Similar Topics [44, 13, 27, 10, 39], Similarity [0.6668383, 0.6012139, 0.5967103, 0.59352756, 0.57612514]
# Query 67: Similar Topics [10, 27, 15, 44, 20], Similarity [0.80139613, 0.78154844, 0.7470962, 0.73862714, 0.7101333]
# Query 68: Similar Topics [24, 23, 27, 8, 7], Similarity [0.8014503, 0.78151166, 0.74138945, 0.69378716, 0.6898197]
# Query 69: Similar Topics [11, 9, 45, -1, 15], Similarity [0.8102258, 0.7915338, 0.76771235, 0.76233655, 0.7480465]
# Query 70: Similar Topics [21, 31, -1, 14, 43], Similarity [0.7852601, 0.7790948, 0.75696874, 0.74701315, 0.7329745]
# Query 71: Similar Topics [20, 27, 45, 23, 11], Similarity [0.69052607, 0.64010257, 0.6145631, 0.6071546, 0.59035987]
# Query 72: Similar Topics [25, 11, 42, 6, 1], Similarity [0.7350062, 0.71131444, 0.68191946, 0.67935, 0.6668118]
# Query 73: Similar Topics [1, 32, 37, 23, 30], Similarity [0.8022977, 0.74822557, 0.74133724, 0.7245034, 0.7174636]
# Query 74: Similar Topics [5, 22, 12, 31, -1], Similarity [0.7383322, 0.7191114, 0.70963573, 0.7075111, 0.7064053]
# Query 75: Similar Topics [14, 8, 30, 23, 21], Similarity [0.7678906, 0.73667216, 0.72684944, 0.70718145, 0.65897197]
# Query 76: Similar Topics [14, 23, 32, 21, 31], Similarity [0.76548696, 0.73086345, 0.7142565, 0.6930311, 0.6844734]
# Query 77: Similar Topics [1, 7, 11, 9, 23], Similarity [0.74765706, 0.73163146, 0.7191874, 0.690418, 0.68278617]
# Query 78: Similar Topics [16, 6, 46, 0, 36], Similarity [0.52562886, 0.51433665, 0.5113014, 0.5080646, 0.49926814]
# Query 79: Similar Topics [26, -1, 15, 6, 11], Similarity [0.6905294, 0.6369951, 0.6220561, 0.6069205, 0.60075355]
# Query 80: Similar Topics [27, 23, 45, 20, 15], Similarity [0.7641206, 0.6708108, 0.6540506, 0.6487956, 0.64186084]
# Query 81: Similar Topics [39, 31, 16, 28, 5], Similarity [0.6958209, 0.6865586, 0.68544745, 0.67535424, 0.67306423]
# Query 82: Similar Topics [7, 9, 40, 3, 11], Similarity [0.76749784, 0.7357756, 0.7338961, 0.69055176, 0.68808365]
# Query 83: Similar Topics [21, 23, 33, -1, 31], Similarity [0.68080276, 0.67041785, 0.66564703, 0.6629905, 0.65979767]
# Query 84: Similar Topics [27, 20, 45, 15, 11], Similarity [0.761179, 0.75259554, 0.7271886, 0.70719934, 0.7067821]
# Query 85: Similar Topics [41, 12, 15, 22, 44], Similarity [0.73271406, 0.71248436, 0.6608492, 0.6402787, 0.63645536]
# Query 86: Similar Topics [4, 6, 46, 25, 11], Similarity [0.8226125, 0.8114634, 0.7805395, 0.77409637, 0.76591194]
# Query 87: Similar Topics [7, 2, 42, 23, 37], Similarity [0.7878678, 0.75147593, 0.72900796, 0.72518814, 0.71172583]
# Query 88: Similar Topics [7, 5, 3, 33, 4], Similarity [0.82747173, 0.82072425, 0.8197876, 0.8148248, 0.7609737]
# Query 89: Similar Topics [16, 46, 39, 5, 4], Similarity [0.865633, 0.79967314, 0.7798146, 0.77735937, 0.7734339]
# Query 90: Similar Topics [5, 46, 31, 33, 3], Similarity [0.80407727, 0.7772697, 0.77206755, 0.768615, 0.75476515]
# Query 91: Similar Topics [11, 45, 9, 43, 4], Similarity [0.7032472, 0.6687159, 0.6684258, 0.6442927, 0.6223928]
# Query 92: Similar Topics [37, 30, 23, 0, 14], Similarity [0.7267996, 0.71152294, 0.70376414, 0.6907476, 0.67180747]
# Query 93: Similar Topics [0, 21, 31, -1, 8], Similarity [0.77721334, 0.76926124, 0.7691455, 0.7669473, 0.75820214]
# Query 94: Similar Topics [6, 46, 4, 42, 41], Similarity [0.8512205, 0.8325784, 0.7997912, 0.7971873, 0.7882494]
# Query 95: Similar Topics [35, 17, 10, 27, 44], Similarity [0.8008131, 0.78779733, 0.7710056, 0.71741086, 0.7079886]
# Query 96: Similar Topics [2, 42, 25, 31, 43], Similarity [0.8120571, 0.79436713, 0.78712076, 0.76775455, 0.7642306]
# Query 97: Similar Topics [-1, 15, 39, 11, 21], Similarity [0.774688, 0.765555, 0.76290023, 0.76219416, 0.76211315]
# Query 98: Similar Topics [40, 4, 3, 34, 33], Similarity [0.8384918, 0.8338944, 0.8292582, 0.7997043, 0.7689191]

# %%
# Assuming you want to predict topics for the first 100 samples in 'df_Abstract_test'
num_samples_to_predict = 100

num_of_topics = 5
results = []

# Create an empty DataFrame to store the results
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Assuming you have a list of 100 queries in 'df_Abstract_test'
for i, (query, publication_number, first_claim, class_codes) in enumerate(zip(df_claim_test['first_claim'][:num_samples_to_predict], 
                                                    df_claim_test['publication_numbers'][:num_samples_to_predict],
                                                    df_claim_test['first_claim'][:num_samples_to_predict],
                                                    df_claim_test['class_codes'][:num_samples_to_predict])):
    # Check if the 'first_claim' is a string before processing
    if isinstance(query, str):
        similar_topics, similarity = topic_model.find_topics(query, top_n=num_of_topics)
        results.append((similar_topics, similarity))
        
        # Store the results in the DataFrame
        result_df_q = result_df_q.append({
            'query_claim': query,
            'query_predicted_topics': similar_topics,
            'query_publication_numbers': publication_number,
            'query_class_codes': class_codes
        }, ignore_index=True)
    else:
        # Handle cases where 'query' is not a string (e.g., it's a nan value)
        print(f"Skipping non-string query: {query}")

result_df_q
# Out:
# Skipping non-string query: nan
# Skipping non-string query: nan
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 93           US20230017310A1
# 94           US20230091925A1
# 95           US20230010638A1
# 96           US20230009812A1
# 97           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 93  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 94  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 95  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 96  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 97  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                           query_claim query_predicted_topics
# 0   1. A physiological monitoring device comprisin...    [23, 8, 12, 21, 30]
# 1   1. A monitoring device, comprising:\na band co...    [8, 13, 23, 30, 24]
# 2   1-25. (canceled) 26. A method for guiding a fr...    [16, 36, 39, 46, 5]
# 3   1-184. (canceled) 185. A computer-implemented ...    [10, 6, 15, 42, 11]
# 4   1. (canceled) 2. A community based response sy...     [7, 0, -1, 43, 35]
# ..                                                ...                    ...
# 93  1. A system for storing medical information re...     [6, 46, 4, 42, 41]
# 94  1. A method for event notification in an inter...   [35, 17, 10, 27, 44]
# 95  1.-2. (canceled) 3. A method of managing an in...    [2, 42, 25, 31, 43]
# 96  1. (canceled) 2. A patient monitoring system c...   [-1, 15, 39, 11, 21]
# 97  1-27. (canceled) 28. A system to manage record...     [40, 4, 3, 34, 33]
#
# [98 rows x 4 columns]

# %%
# Check if the 'query_publication_numbers' field is unique
is_unique = result_df_q['query_publication_numbers'].nunique() == len(result_df_q)

if is_unique:
    print("The 'query_publication_numbers' field is unique.")
else:
    print("The 'query_publication_numbers' field is not unique.")
# Out:
# The 'query_publication_numbers' field is unique.

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'first_claim', 'Lemmatized-Claim', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_claim']
    predicted_topics = row['query_predicted_topics']
    
    for topic_id in predicted_topics:
        # Filter 'df_claim_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_claim_topic[df_claim_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'result_df' DataFrame
        for _, doc_row in topic_documents.iterrows():
            result_df = result_df.append({
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_claim': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'first_claim': doc_row['first_claim'],
                'Lemmatized-Claim': doc_row['Lemmatized-Claim'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }, ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 1        US2008221400A1  Method and system for measuring and ranking an...
# 2        US2019122125A1                                   Earpiece advisor
# 3        US2019000397A1  Physiological parameter signal fusion processi...
# 4        US2018368778A1  Systems and methods for linear-time clustering...
# ...                 ...                                                ...
# 4895     US2007251835A1  Subnetwork synchronization and variable transm...
# 4896     US2007233518A1                     Clinical examination apparatus
# 4897     US2013267795A1  Health-monitoring system with multiple health ...
# 4898     US2013179186A1  System and method for database synchronization...
# 4899     US2013080192A1               Identity matching of patient records
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method for monitorin...
# 1     1 . A method for sensing an individual&#39;s i...
# 2     What is claimed is: 1 . An earpiece comprising...
# 3     What is claimed is: 1 . A physiological parame...
# 4     1 . A method for identifying events of interes...
# ...                                                 ...
# 4895  1 . A medical device system comprising: a plur...
# 4896  1 . A clinical examination apparatus comprisin...
# 4897  What is claimed is: 1 . A patient monitoring s...
# 4898  What is claimed is: 1 . A data synchronization...
# 4899  1 . A system for matching a pair of patient re...
#
#                                        Lemmatized-Claim  \
# 0     claimed method monitoring one type arrhythmia ...
# 1     method sensing individual immersion experience...
# 2     claimed earpiece comprising earpiece housing o...
# 3     claimed physiological parameter signal fusion ...
# 4     method identifying event interest noisy physio...
# ...                                                 ...
# 4895  medical device system comprising plurality med...
# 4896  clinical examination apparatus comprising meas...
# 4897  claimed patient monitoring system comprising f...
# 4898  claimed data synchronization system synchroniz...
# 4899  system matching pair patient record belonging ...
#
#                        sub_classes         sub_class topics  prob  \
# 0        ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 1       ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 2       ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3      ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 4        ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# ...                            ...               ...    ...   ...
# 4895  ['G16H20/17', 'H04L61/5038']  ['G16H', 'H04L']     33   1.0
# 4896    ['G01N35/00', 'G16H40/63']  ['G01N', 'G16H']     33   1.0
# 4897    ['G16H40/67', 'A61B5/742']  ['G16H', 'A61B']     33   1.0
# 4898    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     33   1.0
# 4899    ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     33   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim query_predicted_topics
# 0     1. A physiological monitoring device comprisin...                   [23]
# 1     1. A physiological monitoring device comprisin...                   [23]
# 2     1. A physiological monitoring device comprisin...                   [23]
# 3     1. A physiological monitoring device comprisin...                   [23]
# 4     1. A physiological monitoring device comprisin...                   [23]
# ...                                                 ...                    ...
# 4895  1-27. (canceled) 28. A system to manage record...                   [33]
# 4896  1-27. (canceled) 28. A system to manage record...                   [33]
# 4897  1-27. (canceled) 28. A system to manage record...                   [33]
# 4898  1-27. (canceled) 28. A system to manage record...                   [33]
# 4899  1-27. (canceled) 28. A system to manage record...                   [33]
#
# [4900 rows x 12 columns]

# %%
result_df['query_class_codes'][0]
# Out:
# 'A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/7221,A61B5/14532,G16H40/00,A61B5/14546,G16H40/60,A61B5/68,A61B2562/08,H,A61B1/00,A61B2562/221,A61B5/7475,A61B2562/18,A61B5/746,A61B5/7405,H05K,G16H40/67,A61B,Y10,A61B5/6813,Y,A61B2562/185,G16H10/40,A61B5/6826,A61B5/02,A61B5/0002,A61B5/1455,A61B5/6832,A,A61B5/7235,A61B5/6801,A61B5/7278,G16H,A61B5/026,A61B5/742,A61B2562/22,A61B5/024,G16,A61B5/02416,A61B5/683,A61B5/0015,A61B5/6825,Y10S,A61B5/1495,A61B5/72,A61B5/0261,A61B2562/085,A61B2562/222,A61B5/7275,A61B5/00,A61B5/145,A61B5/74,G16H10/00,H05K999/99,A61B5/7246,Y10S439/909,A61B5/14552,A61B5/6838,A61B5/6815,A61B5/7271,H05K999/00,A61B5/02427,A61B5/0205,Y10S439/00,A61B5/0022,A61B5/6814,A61B2562/00,H05'

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 1        US2008221400A1  Method and system for measuring and ranking an...
# 2        US2019122125A1                                   Earpiece advisor
# 3        US2019000397A1  Physiological parameter signal fusion processi...
# 4        US2018368778A1  Systems and methods for linear-time clustering...
# ...                 ...                                                ...
# 4895     US2007251835A1  Subnetwork synchronization and variable transm...
# 4896     US2007233518A1                     Clinical examination apparatus
# 4897     US2013267795A1  Health-monitoring system with multiple health ...
# 4898     US2013179186A1  System and method for database synchronization...
# 4899     US2013080192A1               Identity matching of patient records
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method for monitorin...
# 1     1 . A method for sensing an individual&#39;s i...
# 2     What is claimed is: 1 . An earpiece comprising...
# 3     What is claimed is: 1 . A physiological parame...
# 4     1 . A method for identifying events of interes...
# ...                                                 ...
# 4895  1 . A medical device system comprising: a plur...
# 4896  1 . A clinical examination apparatus comprisin...
# 4897  What is claimed is: 1 . A patient monitoring s...
# 4898  What is claimed is: 1 . A data synchronization...
# 4899  1 . A system for matching a pair of patient re...
#
#                                        Lemmatized-Claim  \
# 0     claimed method monitoring one type arrhythmia ...
# 1     method sensing individual immersion experience...
# 2     claimed earpiece comprising earpiece housing o...
# 3     claimed physiological parameter signal fusion ...
# 4     method identifying event interest noisy physio...
# ...                                                 ...
# 4895  medical device system comprising plurality med...
# 4896  clinical examination apparatus comprising meas...
# 4897  claimed patient monitoring system comprising f...
# 4898  claimed data synchronization system synchroniz...
# 4899  system matching pair patient record belonging ...
#
#                        sub_classes         sub_class topics  prob  \
# 0        ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 1       ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 2       ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3      ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 4        ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# ...                            ...               ...    ...   ...
# 4895  ['G16H20/17', 'H04L61/5038']  ['G16H', 'H04L']     33   1.0
# 4896    ['G01N35/00', 'G16H40/63']  ['G01N', 'G16H']     33   1.0
# 4897    ['G16H40/67', 'A61B5/742']  ['G16H', 'A61B']     33   1.0
# 4898    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     33   1.0
# 4899    ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     33   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [23]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [23]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [23]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [23]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [23]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 4895                   [33]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896                   [33]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4897                   [33]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898                   [33]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4899                   [33]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [4900 rows x 13 columns]

# %%
# Create a new column to store the common code
import re 
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Custom extraction of values from sub_classes_str
    sub_classes = re.findall(r"'([^']*)'", sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 1        US2008221400A1  Method and system for measuring and ranking an...
# 2        US2019122125A1                                   Earpiece advisor
# 3        US2019000397A1  Physiological parameter signal fusion processi...
# 4        US2018368778A1  Systems and methods for linear-time clustering...
# ...                 ...                                                ...
# 4895     US2007251835A1  Subnetwork synchronization and variable transm...
# 4896     US2007233518A1                     Clinical examination apparatus
# 4897     US2013267795A1  Health-monitoring system with multiple health ...
# 4898     US2013179186A1  System and method for database synchronization...
# 4899     US2013080192A1               Identity matching of patient records
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method for monitorin...
# 1     1 . A method for sensing an individual&#39;s i...
# 2     What is claimed is: 1 . An earpiece comprising...
# 3     What is claimed is: 1 . A physiological parame...
# 4     1 . A method for identifying events of interes...
# ...                                                 ...
# 4895  1 . A medical device system comprising: a plur...
# 4896  1 . A clinical examination apparatus comprisin...
# 4897  What is claimed is: 1 . A patient monitoring s...
# 4898  What is claimed is: 1 . A data synchronization...
# 4899  1 . A system for matching a pair of patient re...
#
#                                        Lemmatized-Claim  \
# 0     claimed method monitoring one type arrhythmia ...
# 1     method sensing individual immersion experience...
# 2     claimed earpiece comprising earpiece housing o...
# 3     claimed physiological parameter signal fusion ...
# 4     method identifying event interest noisy physio...
# ...                                                 ...
# 4895  medical device system comprising plurality med...
# 4896  clinical examination apparatus comprising meas...
# 4897  claimed patient monitoring system comprising f...
# 4898  claimed data synchronization system synchroniz...
# 4899  system matching pair patient record belonging ...
#
#                        sub_classes         sub_class topics  prob  \
# 0        ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 1       ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 2       ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3      ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 4        ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# ...                            ...               ...    ...   ...
# 4895  ['G16H20/17', 'H04L61/5038']  ['G16H', 'H04L']     33   1.0
# 4896    ['G01N35/00', 'G16H40/63']  ['G01N', 'G16H']     33   1.0
# 4897    ['G16H40/67', 'A61B5/742']  ['G16H', 'A61B']     33   1.0
# 4898    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     33   1.0
# 4899    ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     33   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [23]
# 1                      [23]
# 2                      [23]
# 3                      [23]
# 4                      [23]
# ...                     ...
# 4895                   [33]
# 4896                   [33]
# 4897                   [33]
# 4898                   [33]
# 4899                   [33]
#
#                                        query_codes_G16H     exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...                  ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
# [4900 rows x 14 columns]

# %%
# result_df.sample(n=100)

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 1        US2008221400A1  Method and system for measuring and ranking an...
# 2        US2019122125A1                                   Earpiece advisor
# 3        US2019000397A1  Physiological parameter signal fusion processi...
# 4        US2018368778A1  Systems and methods for linear-time clustering...
# ...                 ...                                                ...
# 4895     US2007251835A1  Subnetwork synchronization and variable transm...
# 4896     US2007233518A1                     Clinical examination apparatus
# 4897     US2013267795A1  Health-monitoring system with multiple health ...
# 4898     US2013179186A1  System and method for database synchronization...
# 4899     US2013080192A1               Identity matching of patient records
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method for monitorin...
# 1     1 . A method for sensing an individual&#39;s i...
# 2     What is claimed is: 1 . An earpiece comprising...
# 3     What is claimed is: 1 . A physiological parame...
# 4     1 . A method for identifying events of interes...
# ...                                                 ...
# 4895  1 . A medical device system comprising: a plur...
# 4896  1 . A clinical examination apparatus comprisin...
# 4897  What is claimed is: 1 . A patient monitoring s...
# 4898  What is claimed is: 1 . A data synchronization...
# 4899  1 . A system for matching a pair of patient re...
#
#                                        Lemmatized-Claim  \
# 0     claimed method monitoring one type arrhythmia ...
# 1     method sensing individual immersion experience...
# 2     claimed earpiece comprising earpiece housing o...
# 3     claimed physiological parameter signal fusion ...
# 4     method identifying event interest noisy physio...
# ...                                                 ...
# 4895  medical device system comprising plurality med...
# 4896  clinical examination apparatus comprising meas...
# 4897  claimed patient monitoring system comprising f...
# 4898  claimed data synchronization system synchroniz...
# 4899  system matching pair patient record belonging ...
#
#                        sub_classes         sub_class topics  prob  \
# 0        ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 1       ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 2       ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3      ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 4        ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# ...                            ...               ...    ...   ...
# 4895  ['G16H20/17', 'H04L61/5038']  ['G16H', 'H04L']     33   1.0
# 4896    ['G01N35/00', 'G16H40/63']  ['G01N', 'G16H']     33   1.0
# 4897    ['G16H40/67', 'A61B5/742']  ['G16H', 'A61B']     33   1.0
# 4898    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     33   1.0
# 4899    ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     33   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [23]
# 1                      [23]
# 2                      [23]
# 3                      [23]
# 4                      [23]
# ...                     ...
# 4895                   [33]
# 4896                   [33]
# 4897                   [33]
# 4898                   [33]
# 4899                   [33]
#
#                                        query_codes_G16H     exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...                  ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
#       count_exact_match_top50
# 0                           6
# 1                           6
# 2                           6
# 3                           6
# 4                           6
# ...                       ...
# 4895                       22
# 4896                       22
# 4897                       22
# 4898                       22
# 4899                       22
#
# [4900 rows x 15 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 1        US2008221400A1  Method and system for measuring and ranking an...
# 2        US2019122125A1                                   Earpiece advisor
# 3        US2019000397A1  Physiological parameter signal fusion processi...
# 4        US2018368778A1  Systems and methods for linear-time clustering...
# ...                 ...                                                ...
# 4895     US2007251835A1  Subnetwork synchronization and variable transm...
# 4896     US2007233518A1                     Clinical examination apparatus
# 4897     US2013267795A1  Health-monitoring system with multiple health ...
# 4898     US2013179186A1  System and method for database synchronization...
# 4899     US2013080192A1               Identity matching of patient records
#
#                                             first_claim  \
# 0     What is claimed is: 1 . A method for monitorin...
# 1     1 . A method for sensing an individual&#39;s i...
# 2     What is claimed is: 1 . An earpiece comprising...
# 3     What is claimed is: 1 . A physiological parame...
# 4     1 . A method for identifying events of interes...
# ...                                                 ...
# 4895  1 . A medical device system comprising: a plur...
# 4896  1 . A clinical examination apparatus comprisin...
# 4897  What is claimed is: 1 . A patient monitoring s...
# 4898  What is claimed is: 1 . A data synchronization...
# 4899  1 . A system for matching a pair of patient re...
#
#                                        Lemmatized-Claim  \
# 0     claimed method monitoring one type arrhythmia ...
# 1     method sensing individual immersion experience...
# 2     claimed earpiece comprising earpiece housing o...
# 3     claimed physiological parameter signal fusion ...
# 4     method identifying event interest noisy physio...
# ...                                                 ...
# 4895  medical device system comprising plurality med...
# 4896  clinical examination apparatus comprising meas...
# 4897  claimed patient monitoring system comprising f...
# 4898  claimed data synchronization system synchroniz...
# 4899  system matching pair patient record belonging ...
#
#                        sub_classes         sub_class topics  prob  \
# 0        ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 1       ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 2       ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3      ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 4        ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# ...                            ...               ...    ...   ...
# 4895  ['G16H20/17', 'H04L61/5038']  ['G16H', 'H04L']     33   1.0
# 4896    ['G01N35/00', 'G16H40/63']  ['G01N', 'G16H']     33   1.0
# 4897    ['G16H40/67', 'A61B5/742']  ['G16H', 'A61B']     33   1.0
# 4898    ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     33   1.0
# 4899    ['G16H10/60', 'G16H50/20']  ['G16H', 'G16H']     33   1.0
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 4895           US20230138516A1
# 4896           US20230138516A1
# 4897           US20230138516A1
# 4898           US20230138516A1
# 4899           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 4895  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4896  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4897  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4898  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 4899  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 4895  1-27. (canceled) 28. A system to manage record...
# 4896  1-27. (canceled) 28. A system to manage record...
# 4897  1-27. (canceled) 28. A system to manage record...
# 4898  1-27. (canceled) 28. A system to manage record...
# 4899  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [23]
# 1                      [23]
# 2                      [23]
# 3                      [23]
# 4                      [23]
# ...                     ...
# 4895                   [33]
# 4896                   [33]
# 4897                   [33]
# 4898                   [33]
# 4899                   [33]
#
#                                        query_codes_G16H     exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                                                 ...                  ...
# 4895       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4896       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4897       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 4898       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 4899       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
#       count_exact_match_top50  RFR
# 0                           6  6.0
# 1                           6  6.0
# 2                           6  6.0
# 3                           6  6.0
# 4                           6  6.0
# ...                       ...  ...
# 4895                       22  2.0
# 4896                       22  2.0
# 4897                       22  2.0
# 4898                       22  2.0
# 4899                       22  2.0
#
# [4900 rows x 16 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_claim","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2020097777A1  Estimating sequential blood-sugar levels using...
# 1       US2014093148A1  System and method for determining the amount o...
# 2       US2014128834A1  Method, system and apparatus for calculating t...
# 3       US2014127651A1  Avatar having artificial intelligence for iden...
# 4       US2014128783A1  Isometric System, Method and Apparatus for Iso...
# ..                 ...                                                ...
# 485     US2008068473A1  Studio booth contest using preselected chroma ...
# 486     US2018358121A1  Communication system for dynamic checklists to...
# 487     US2018350454A1        Determining an anonymized dose report image
# 488     US2018342315A1  Method for 3d imaging of mechanical assemblies...
# 489     US2018325476A1  Radiation imaging system, information processi...
#
#                                            first_claim  \
# 0    What is claimed is: 1 . A method for predictin...
# 1    What is claimed is: 1 . A portable system for ...
# 2    What is claimed is: 1 . A method of setting a ...
# 3    What is claimed: 1 . A method, performed by on...
# 4    The invention claimed is: 1 . A method of trea...
# ..                                                 ...
# 485  1 . A method of conducting a contest by produc...
# 486  1 . A radiology workstation comprising: an ima...
# 487  What is claimed is: 1 . A method for determini...
# 488  1 . A method for quantitatively measuring the ...
# 489  1 . A radiation imaging system comprising: a d...
#
#                                       Lemmatized-Claim  \
# 0    claimed method predicting variation sequential...
# 1    claimed portable system determining amount vit...
# 2    claimed method setting dosage rapidacting insu...
# 3    claimed method performed one computing device ...
# 4    invention claimed method treating diabetes com...
# ..                                                 ...
# 485  method conducting contest producing area restr...
# 486  radiology workstation comprising image renderi...
# 487  claimed method determining anonymized dose rep...
# 488  method quantitatively measuring individual pos...
# 489  radiation imaging system comprising detector i...
#
#                       sub_classes         sub_class topics  prob  \
# 0       ['G06T7/00', 'G16H10/60']  ['G06T', 'G16H']      1   1.0
# 1       ['G06T7/00', 'G16H50/20']  ['G06T', 'G16H']      1   1.0
# 2      ['A61M5/172', 'G16H20/60']  ['A61M', 'G16H']      1   1.0
# 3      ['G06F19/00', 'G16H20/60']  ['G06F', 'G16H']      1   1.0
# 4    ['G16H20/30', 'A63B2225/20']  ['G16H', 'A63B']      1   1.0
# ..                            ...               ...    ...   ...
# 485  ['G16H40/63', 'H04N1/00286']  ['G16H', 'H04N']      8   1.0
# 486    ['G16H30/20', 'G16H30/20']  ['G16H', 'G16H']      8   1.0
# 487    ['G16H15/00', 'G16H30/20']  ['G16H', 'G16H']      8   1.0
# 488     ['G06T7/50', 'G16H30/40']  ['G06T', 'G16H']      8   1.0
# 489     ['A61B6/00', 'G16H50/30']  ['A61B', 'G16H']      8   1.0
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 485           US20230270344A1
# 486           US20230270344A1
# 487           US20230270344A1
# 488           US20230270344A1
# 489           US20230270344A1
#
#                                            query_claim  \
# 0    1. A continuous glucose monitoring system comp...
# 1    1. A continuous glucose monitoring system comp...
# 2    1. A continuous glucose monitoring system comp...
# 3    1. A continuous glucose monitoring system comp...
# 4    1. A continuous glucose monitoring system comp...
# ..                                                 ...
# 485  1. A monitoring device, comprising:\na band co...
# 486  1. A monitoring device, comprising:\na band co...
# 487  1. A monitoring device, comprising:\na band co...
# 488  1. A monitoring device, comprising:\na band co...
# 489  1. A monitoring device, comprising:\na band co...
#
#                                       query_codes_G16H exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# ..                                                 ...              ...
# 485  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H40/63
# 486  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 487  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
# 488  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H30/40
# 489  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
#
#      count_exact_match_top50  count_exact_match_top5
# 0                         14                       0
# 1                         14                       0
# 2                         14                       0
# 3                         14                       0
# 4                         14                       0
# ..                       ...                     ...
# 485                       26                       2
# 486                       26                       2
# 487                       26                       2
# 488                       26                       2
# 489                       26                       2
#
# [490 rows x 14 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230001090A1']
filtered_df
# Out:
#      publication_number                                              title  \
# 3800     US2020097777A1  Estimating sequential blood-sugar levels using...
# 3801     US2014093148A1  System and method for determining the amount o...
# 3802     US2014128834A1  Method, system and apparatus for calculating t...
# 3803     US2014127651A1  Avatar having artificial intelligence for iden...
# 3804     US2014128783A1  Isometric System, Method and Apparatus for Iso...
# 3805     US2014118138A1  Systems and methods for providing sensitive an...
# 3806     US2014121634A1  Method, system and apparatus for setting insul...
# 3807     US2014100859A1                    Diet planning system and method
# 3808     US2014095189A1       Systems and methods for response calibration
# 3809     US2014244181A1  System and method for estimating glucose in pl...
# 3810     US2020098458A1  Medical cannabis platform with physician and p...
# 3811     US2012041782A1     Medical Information Handling System and Method
# 3812     US2007255115A1           Remote diagnostic &amp; treatment system
# 3813     US2008027290A1  Base station for retrieving data from and prog...
# 3814     US2008091175A1                Web-enabled portable medical device
# 3815     US2008097913A1  Systems and methods for wireless processing an...
# 3816     US2008097552A1  Systems and methods for medical data interchan...
# 3817     US2008097909A1  Systems and methods for processing and transmi...
# 3818     US2008224852A1  Systems and methods for wireless processing an...
# 3819     US2009031020A1  Apparatus and method for monitoring use of res...
# 3820     US2016246931A1  Methods and systems for predicting health cond...
# 3821     US2022285022A1  Health monitoring system having a configurable...
# 3822     US2019180852A1  Remote health assertion verification and healt...
# 3823     US2019189285A1  Intelligent grouping of peers in motivational ...
# 3824     US2006004607A1  Personalized health history system with accomm...
# 3825     US2014156308A1  Automated Health Data Acquisition, Processing ...
# 3826     US2021090191A1  System and methods for estate planning predict...
# 3827     US2021090741A1  System and method for tracking end user behavi...
# 3828     US2010191544A1   Protocol Authoring for a Health Coaching Service
# 3829     US2021012900A1  Method for producing a one-number health score...
# 3830     US2016196404A1    Method, device, and system for improving health
# 3831     US2008005059A1  Framework for storage and transmission of medi...
# 3832     US2008154645A1  Health data generating method, health data gen...
# 3833     US2008162181A1            Method and Apparatus For Health Control
# 3834     US2008172299A1  Health reminders provided by product and servi...
# 3835     US2004010420A1  System for developing implementing and monitor...
# 3836     US2008197185A1  Method of promoting health and wellness throug...
# 3837     US2008215627A1                       Standardized health data hub
# 3838     US2003154107A1                                        Preventcare
# 3839     US2008243539A1  Method and System for Exchanging, Storing, and...
# 3840     US2020100693A1   Arrhythmia monitoring using photoplethysmography
# 3841     US2008221400A1  Method and system for measuring and ranking an...
# 3842     US2019122125A1                                   Earpiece advisor
# 3843     US2019000397A1  Physiological parameter signal fusion processi...
# 3844     US2018368778A1  Systems and methods for linear-time clustering...
# 3845     US2018333058A1  Method and system for acquiring and analyzing ...
# 3846     US2018336968A1  Degree-of-Distraction Estimation System based ...
# 3847     US2018317876A1  Programmable electronic stethoscope devices, a...
# 3848     US2018256106A1                           In-Ear Health Monitoring
# 3849     US2022151565A1            Signal quality index evaluation circuit
#
#                                             first_claim  \
# 3800  What is claimed is: 1 . A method for predictin...
# 3801  What is claimed is: 1 . A portable system for ...
# 3802  What is claimed is: 1 . A method of setting a ...
# 3803  What is claimed: 1 . A method, performed by on...
# 3804  The invention claimed is: 1 . A method of trea...
# 3805  What is claimed is: 1 . A method of activating...
# 3806  What is claimed is: 1 . A method of setting a ...
# 3807  1 ) A diet planning method, which is applied i...
# 3808  1 . A computer-implemented method for calibrat...
# 3809  1 . A plasma glucose estimation system compris...
# 3810  What is claimed is: 1 . A method for providing...
# 3811  I claim: 1 . A medical information system comp...
# 3812  1 . An apparatus comprising: a cellular teleph...
# 3813  1 . A system for retrieving information from a...
# 3814  1 . A portable, wearable, implantable, or semi...
# 3815  1 . A method comprising: receiving data wirele...
# 3816  1 . A method comprising: receiving data from a...
# 3817  1 . A method comprising: receiving data from a...
# 3818  1 . A method comprising: receiving data wirele...
# 3819  1 . A system for monitoring activity and use o...
# 3820  What is claimed is: 1 . A system for classifyi...
# 3821  1 . A computer-implemented method for obtainin...
# 3822  What is claimed is: 1 . A computing system imp...
# 3823  1 . A system configured to facilitate social r...
# 3824  1 . A computer-implemented method for providin...
# 3825  What is claimed is: 1 . A method for providing...
# 3826  1 . A system comprising: a client health monit...
# 3827  We claim: 1 . A computer method for determinin...
# 3828  1 . A method for authoring a protocol to coach...
# 3829  What is claimed is: \n     \n         1 . A co...
# 3830  1 . A method for improving health, comprising:...
# 3831  1 . A method to maintain a personal health rec...
# 3832  1 . A health data generating method for use in...
# 3833  1 . A method of health care financing, compris...
# 3834  1 . A method for providing a health reminder f...
# 3835  What is claimed is: 1 . A method of coordinati...
# 3836  1 . A method performed in connection with prom...
# 3837  1 . A method a managing health-related data co...
# 3838  I/we claim: 1 . A method of reducing long term...
# 3839  1 . A method for matching, comprising: receivi...
# 3840  What is claimed is: 1 . A method for monitorin...
# 3841  1 . A method for sensing an individual&#39;s i...
# 3842  What is claimed is: 1 . An earpiece comprising...
# 3843  What is claimed is: 1 . A physiological parame...
# 3844  1 . A method for identifying events of interes...
# 3845  1 . A method for monitoring physiological sign...
# 3846  1 . A system for estimating a degree of distra...
# 3847  1 . A digital electronic stethoscope, comprisi...
# 3848  What is claimed is: 1 . An in-ear health-monit...
# 3849  What is claimed is: 1 . A signal quality index...
#
#                                        Lemmatized-Claim  \
# 3800  claimed method predicting variation sequential...
# 3801  claimed portable system determining amount vit...
# 3802  claimed method setting dosage rapidacting insu...
# 3803  claimed method performed one computing device ...
# 3804  invention claimed method treating diabetes com...
# 3805  claimed method activating hypoglycemic indicat...
# 3806  claimed method setting dosage rapidacting insu...
# 3807  diet planning method applied diet planning sys...
# 3808  computerimplemented method calibrating user re...
# 3809  plasma glucose estimation system comprising se...
# 3810  claimed method providing networking communicat...
# 3811  claim medical information system comprising on...
# 3812  apparatus comprising cellular telephone cellul...
# 3813  system retrieving information programming medi...
# 3814  portable wearable implantable semiimplantable ...
# 3815  method comprising receiving data wirelessly pl...
# 3816  method comprising receiving data medical devic...
# 3817  method comprising receiving data plurality med...
# 3818  method comprising receiving data wirelessly me...
# 3819  system monitoring activity resource healthcare...
# 3820  claimed system classifying one human subject o...
# 3821  computerimplemented method obtaining healthrel...
# 3822  claimed computing system implementing health p...
# 3823  system configured facilitate social ranking gr...
# 3824  computerimplemented method providing personali...
# 3825  claimed method providing healthrelated informa...
# 3826  system comprising client health monitoring dev...
# 3827  claim computer method determining health welln...
# 3828  method authoring protocol coach user comprisin...
# 3829  claimed computerimplemented system producing o...
# 3830  method improving health comprising obtaining h...
# 3831  method maintain personal health record compris...
# 3832  health data generating method health data gene...
# 3833  method health care financing comprising calcul...
# 3834  method providing health reminder current poten...
# 3835  claimed method coordinating health management ...
# 3836  method performed connection promoting financia...
# 3837  method managing healthrelated data comprising ...
# 3838  iwe claim method reducing long term health car...
# 3839  method matching comprising receiving one healt...
# 3840  claimed method monitoring one type arrhythmia ...
# 3841  method sensing individual immersion experience...
# 3842  claimed earpiece comprising earpiece housing o...
# 3843  claimed physiological parameter signal fusion ...
# 3844  method identifying event interest noisy physio...
# 3845  method monitoring physiological signal compris...
# 3846  system estimating degree distraction based unc...
# 3847  digital electronic stethoscope comprising acou...
# 3848  claimed inear healthmonitoring audio device co...
# 3849  claimed signal quality index evaluation circui...
#
#                          sub_classes         sub_class topics  prob  \
# 3800       ['G06T7/00', 'G16H10/60']  ['G06T', 'G16H']      1   1.0
# 3801       ['G06T7/00', 'G16H50/20']  ['G06T', 'G16H']      1   1.0
# 3802      ['A61M5/172', 'G16H20/60']  ['A61M', 'G16H']      1   1.0
# 3803      ['G06F19/00', 'G16H20/60']  ['G06F', 'G16H']      1   1.0
# 3804    ['G16H20/30', 'A63B2225/20']  ['G16H', 'A63B']      1   1.0
# 3805      ['G08B21/02', 'G16H40/67']  ['G08B', 'G16H']      1   1.0
# 3806      ['G16H20/60', 'G16H20/60']  ['G16H', 'G16H']      1   1.0
# 3807      ['G06Q50/22', 'G16H20/60']  ['G06Q', 'G16H']      1   1.0
# 3808      ['H04L45/85', 'G16H10/20']  ['H04L', 'G16H']      1   1.0
# 3809      ['G16H20/17', 'G16B15/00']  ['G16H', 'G16B']      1   1.0
# 3810     ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']      7   1.0
# 3811      ['G06Q10/10', 'G16H40/20']  ['G06Q', 'G16H']      7   1.0
# 3812       ['A61B5/00', 'G16H10/60']  ['A61B', 'G16H']      7   1.0
# 3813       ['A61B5/00', 'G16H40/40']  ['A61B', 'G16H']      7   1.0
# 3814      ['G16H20/17', 'G16H40/67']  ['G16H', 'G16H']      7   1.0
# 3815      ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']      7   1.0
# 3816       ['A61N1/08', 'G16H40/63']  ['A61N', 'G16H']      7   1.0
# 3817      ['G06Q50/00', 'G16H40/67']  ['G06Q', 'G16H']      7   1.0
# 3818      ['G16H10/60', 'G16H40/67']  ['G16H', 'G16H']      7   1.0
# 3819     ['G06F15/173', 'G16H40/20']  ['G06F', 'G16H']      7   1.0
# 3820       ['G16H10/60', 'G06N7/01']  ['G16H', 'G06N']     11   1.0
# 3821      ['G16H40/67', 'G16H10/20']  ['G16H', 'G16H']     11   1.0
# 3822      ['G16H50/30', 'G16H10/60']  ['G16H', 'G16H']     11   1.0
# 3823      ['G16H20/00', 'G06Q50/01']  ['G16H', 'G06Q']     11   1.0
# 3824      ['G06F17/30', 'G16H15/00']  ['G06F', 'G16H']     11   1.0
# 3825      ['G16H50/30', 'G16H20/60']  ['G16H', 'G16H']     11   1.0
# 3826       ['G06N5/02', 'G16H10/60']  ['G06N', 'G16H']     11   1.0
# 3827      ['G16H50/30', 'H04W4/029']  ['G16H', 'H04W']     11   1.0
# 3828      ['G06Q50/00', 'G16H80/00']  ['G06Q', 'G16H']     11   1.0
# 3829      ['G16H10/60', 'G16H50/30']  ['G16H', 'G16H']     11   1.0
# 3830     ['G16H20/00', 'G06F19/322']  ['G16H', 'G06F']      9   1.0
# 3831      ['G06F17/30', 'G16H30/20']  ['G06F', 'G16H']      9   1.0
# 3832    ['G16H40/60', 'G01G23/3735']  ['G16H', 'G01G']      9   1.0
# 3833      ['G06Q40/08', 'G16H40/20']  ['G06Q', 'G16H']      9   1.0
# 3834      ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      9   1.0
# 3835      ['G16H50/20', 'G16H40/67']  ['G16H', 'G16H']      9   1.0
# 3836      ['G06F17/00', 'G16H10/60']  ['G06F', 'G16H']      9   1.0
# 3837      ['G06F17/30', 'G16H10/60']  ['G06F', 'G16H']      9   1.0
# 3838      ['G16H20/70', 'G06Q10/10']  ['G16H', 'G06Q']      9   1.0
# 3839      ['G06Q10/00', 'G16H40/20']  ['G06Q', 'G16H']      9   1.0
# 3840       ['A61B5/00', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 3841      ['G16H20/70', 'A61B5/369']  ['G16H', 'A61B']     23   1.0
# 3842      ['G16H20/00', 'G06N20/00']  ['G16H', 'G06N']     23   1.0
# 3843     ['G16H50/20', 'A61B5/7282']  ['G16H', 'A61B']     23   1.0
# 3844       ['A61B5/04', 'G16H50/20']  ['A61B', 'G16H']     23   1.0
# 3845      ['G16H40/67', 'A61B5/085']  ['G16H', 'A61B']     23   1.0
# 3846      ['G16H50/20', 'G16H40/63']  ['G16H', 'G16H']     23   1.0
# 3847       ['G16H40/63', 'A61B5/08']  ['G16H', 'A61B']     23   1.0
# 3848       ['A61F7/12', 'G16H40/67']  ['A61F', 'G16H']     23   1.0
# 3849  ['G16H50/70', 'A61B2560/0247']  ['G16H', 'A61B']     23   1.0
#
#      query_publication_numbers  \
# 3800           US20230001090A1
# 3801           US20230001090A1
# 3802           US20230001090A1
# 3803           US20230001090A1
# 3804           US20230001090A1
# 3805           US20230001090A1
# 3806           US20230001090A1
# 3807           US20230001090A1
# 3808           US20230001090A1
# 3809           US20230001090A1
# 3810           US20230001090A1
# 3811           US20230001090A1
# 3812           US20230001090A1
# 3813           US20230001090A1
# 3814           US20230001090A1
# 3815           US20230001090A1
# 3816           US20230001090A1
# 3817           US20230001090A1
# 3818           US20230001090A1
# 3819           US20230001090A1
# 3820           US20230001090A1
# 3821           US20230001090A1
# 3822           US20230001090A1
# 3823           US20230001090A1
# 3824           US20230001090A1
# 3825           US20230001090A1
# 3826           US20230001090A1
# 3827           US20230001090A1
# 3828           US20230001090A1
# 3829           US20230001090A1
# 3830           US20230001090A1
# 3831           US20230001090A1
# 3832           US20230001090A1
# 3833           US20230001090A1
# 3834           US20230001090A1
# 3835           US20230001090A1
# 3836           US20230001090A1
# 3837           US20230001090A1
# 3838           US20230001090A1
# 3839           US20230001090A1
# 3840           US20230001090A1
# 3841           US20230001090A1
# 3842           US20230001090A1
# 3843           US20230001090A1
# 3844           US20230001090A1
# 3845           US20230001090A1
# 3846           US20230001090A1
# 3847           US20230001090A1
# 3848           US20230001090A1
# 3849           US20230001090A1
#
#                                       query_class_codes  \
# 3800  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3801  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3802  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3803  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3804  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3805  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3806  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3807  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3808  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3809  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3810  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3811  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3812  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3813  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3814  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3815  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3816  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3817  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3818  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3819  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3820  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3821  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3822  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3823  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3824  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3825  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3826  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3827  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3828  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3829  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3830  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3831  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3832  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3833  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3834  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3835  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3836  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3837  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3838  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3839  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3840  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3841  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3842  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3843  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3844  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3845  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3846  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3847  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3848  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
# 3849  A61M5/142,A61,G08B,G08,G16H20/17,A61B5/4836,G,...
#
#                                             query_claim  \
# 3800  1. A continuous glucose monitoring system comp...
# 3801  1. A continuous glucose monitoring system comp...
# 3802  1. A continuous glucose monitoring system comp...
# 3803  1. A continuous glucose monitoring system comp...
# 3804  1. A continuous glucose monitoring system comp...
# 3805  1. A continuous glucose monitoring system comp...
# 3806  1. A continuous glucose monitoring system comp...
# 3807  1. A continuous glucose monitoring system comp...
# 3808  1. A continuous glucose monitoring system comp...
# 3809  1. A continuous glucose monitoring system comp...
# 3810  1. A continuous glucose monitoring system comp...
# 3811  1. A continuous glucose monitoring system comp...
# 3812  1. A continuous glucose monitoring system comp...
# 3813  1. A continuous glucose monitoring system comp...
# 3814  1. A continuous glucose monitoring system comp...
# 3815  1. A continuous glucose monitoring system comp...
# 3816  1. A continuous glucose monitoring system comp...
# 3817  1. A continuous glucose monitoring system comp...
# 3818  1. A continuous glucose monitoring system comp...
# 3819  1. A continuous glucose monitoring system comp...
# 3820  1. A continuous glucose monitoring system comp...
# 3821  1. A continuous glucose monitoring system comp...
# 3822  1. A continuous glucose monitoring system comp...
# 3823  1. A continuous glucose monitoring system comp...
# 3824  1. A continuous glucose monitoring system comp...
# 3825  1. A continuous glucose monitoring system comp...
# 3826  1. A continuous glucose monitoring system comp...
# 3827  1. A continuous glucose monitoring system comp...
# 3828  1. A continuous glucose monitoring system comp...
# 3829  1. A continuous glucose monitoring system comp...
# 3830  1. A continuous glucose monitoring system comp...
# 3831  1. A continuous glucose monitoring system comp...
# 3832  1. A continuous glucose monitoring system comp...
# 3833  1. A continuous glucose monitoring system comp...
# 3834  1. A continuous glucose monitoring system comp...
# 3835  1. A continuous glucose monitoring system comp...
# 3836  1. A continuous glucose monitoring system comp...
# 3837  1. A continuous glucose monitoring system comp...
# 3838  1. A continuous glucose monitoring system comp...
# 3839  1. A continuous glucose monitoring system comp...
# 3840  1. A continuous glucose monitoring system comp...
# 3841  1. A continuous glucose monitoring system comp...
# 3842  1. A continuous glucose monitoring system comp...
# 3843  1. A continuous glucose monitoring system comp...
# 3844  1. A continuous glucose monitoring system comp...
# 3845  1. A continuous glucose monitoring system comp...
# 3846  1. A continuous glucose monitoring system comp...
# 3847  1. A continuous glucose monitoring system comp...
# 3848  1. A continuous glucose monitoring system comp...
# 3849  1. A continuous glucose monitoring system comp...
#
#      query_predicted_topics  \
# 3800                    [1]
# 3801                    [1]
# 3802                    [1]
# 3803                    [1]
# 3804                    [1]
# 3805                    [1]
# 3806                    [1]
# 3807                    [1]
# 3808                    [1]
# 3809                    [1]
# 3810                    [7]
# 3811                    [7]
# 3812                    [7]
# 3813                    [7]
# 3814                    [7]
# 3815                    [7]
# 3816                    [7]
# 3817                    [7]
# 3818                    [7]
# 3819                    [7]
# 3820                   [11]
# 3821                   [11]
# 3822                   [11]
# 3823                   [11]
# 3824                   [11]
# 3825                   [11]
# 3826                   [11]
# 3827                   [11]
# 3828                   [11]
# 3829                   [11]
# 3830                    [9]
# 3831                    [9]
# 3832                    [9]
# 3833                    [9]
# 3834                    [9]
# 3835                    [9]
# 3836                    [9]
# 3837                    [9]
# 3838                    [9]
# 3839                    [9]
# 3840                   [23]
# 3841                   [23]
# 3842                   [23]
# 3843                   [23]
# 3844                   [23]
# 3845                   [23]
# 3846                   [23]
# 3847                   [23]
# 3848                   [23]
# 3849                   [23]
#
#                                        query_codes_G16H     exact_match_code  \
# 3800  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3801  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3802  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3803  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3804  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3805  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3806  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3807  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3808  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3809  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/17
# 3810  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3811  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3812  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3813  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3814  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...  G16H20/17,G16H40/67
# 3815  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3816  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3817  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3818  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3819  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3820  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3821  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3822  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3823  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/00
# 3824  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3825  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3826  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3827  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3828  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3829  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3830  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/00
# 3831  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3832  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/60
# 3833  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3834  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3835  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3836  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3837  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3838  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3839  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3840  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3841  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3842  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H20/00
# 3843  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3844  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3845  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3846  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3847  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3848  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...            G16H40/67
# 3849  G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
#
#       count_exact_match_top50  RFR
# 3800                       14  6.0
# 3801                       14  6.0
# 3802                       14  6.0
# 3803                       14  6.0
# 3804                       14  6.0
# 3805                       14  6.0
# 3806                       14  6.0
# 3807                       14  6.0
# 3808                       14  6.0
# 3809                       14  6.0
# 3810                       14  6.0
# 3811                       14  6.0
# 3812                       14  6.0
# 3813                       14  6.0
# 3814                       14  6.0
# 3815                       14  6.0
# 3816                       14  6.0
# 3817                       14  6.0
# 3818                       14  6.0
# 3819                       14  6.0
# 3820                       14  6.0
# 3821                       14  6.0
# 3822                       14  6.0
# 3823                       14  6.0
# 3824                       14  6.0
# 3825                       14  6.0
# 3826                       14  6.0
# 3827                       14  6.0
# 3828                       14  6.0
# 3829                       14  6.0
# 3830                       14  6.0
# 3831                       14  6.0
# 3832                       14  6.0
# 3833                       14  6.0
# 3834                       14  6.0
# 3835                       14  6.0
# 3836                       14  6.0
# 3837                       14  6.0
# 3838                       14  6.0
# 3839                       14  6.0
# 3840                       14  6.0
# 3841                       14  6.0
# 3842                       14  6.0
# 3843                       14  6.0
# 3844                       14  6.0
# 3845                       14  6.0
# 3846                       14  6.0
# 3847                       14  6.0
# 3848                       14  6.0
# 3849                       14  6.0

# %%
result_df.to_csv('BERTopic-Preprocessing.Claim-Tuning-SentenceTransformers.csv', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     0.0
# 1            US20230001263A1                     0.0
# 2            US20230005591A1                     2.0
# 3            US20230005611A1                     0.0
# 4            US20230009812A1                     0.0
# ..                       ...                     ...
# 93           US20230255518A1                     0.0
# 94           US20230259481A1                     0.0
# 95           US20230260617A1                     4.0
# 96           US20230264029A1                     1.0
# 97           US20230270344A1                     2.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 1.2755102040816326

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                     14.0
# 1            US20230001263A1                     22.0
# 2            US20230005591A1                     14.0
# 3            US20230005611A1                      6.0
# 4            US20230009812A1                     10.0
# ..                       ...                      ...
# 93           US20230255518A1                      7.0
# 94           US20230259481A1                     12.0
# 95           US20230260617A1                     21.0
# 96           US20230264029A1                     10.0
# 97           US20230270344A1                     26.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 12.540816326530612

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1   6.0
# 1            US20230001263A1   6.0
# 2            US20230005591A1   1.0
# 3            US20230005611A1   7.0
# 4            US20230009812A1  12.0
# ..                       ...   ...
# 93           US20230255518A1   8.0
# 94           US20230259481A1  10.0
# 95           US20230260617A1   2.0
# 96           US20230264029A1   1.0
# 97           US20230270344A1   1.0
#
# [98 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 5.135416666666667
