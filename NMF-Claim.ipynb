# %%
import pandas as pd

df_claim = pd.read_csv('final-dataset(A1-31306samples)-train-topicmodel.csv')
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths
# 0               123
# 1               142
# 2                81
# 3               148
# 4               110

# %% [markdown]
# # preprocessing

# %%
def cleantext(df_claim): 
    
    df_claim['cleaned_Claim_text'] = df_claim['first_claim'].replace(r'\'|\"|\,|\.|\?|\+|\-|\/|\=|\(|\)|\n|"', '', regex=True)
    
    # convert to lowercase
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].str.lower()
    
    #remove numbers
    df_claim['cleaned_Claim_text'] =df_claim['cleaned_Claim_text'].replace(r'\d+', '', regex = True)
        
    #remove_symbols
    df_claim['cleaned_Claim_text']  = df_claim['cleaned_Claim_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)
    
    #remove punctuations 
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)
    
    #remove_URL(x):
    df_claim['cleaned_Claim_text']  = df_claim['cleaned_Claim_text'].replace(r'https.*$', "", regex = True)
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace("   ", " ", regex = True)
    df_claim['cleaned_Claim_text'] = df_claim['cleaned_Claim_text'].replace("  ", " ", regex = True)
   
    return df_claim

df_claim = cleantext(df_claim)
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...

# %%
import nltk
from nltk.corpus import stopwords

# Load the stop words
nltk.download('stopwords')
english_stop_words = set(stopwords.words('english'))

# Define a set of patent-specific stop words 337
patent_stop_words = set([
                        'a', 'an', 'the', 'is', 'are', 'was', 'were', 'will', 'shall', 'may', 'can', 'could',
                        'of', 'in', 'on', 'at', 'by', 'with', 'for', 'to', 'from', 'as', 'and', 'or', 'not',
                        'this', 'that', 'these', 'those', 'such', 'which', 'where', 'when', 'who', 'whom',
                        'what', 'how', 'why', 'be', 'have', 'has', 'having', 'had', 'do', 'does', 'doing',
                        'done', 'but', 'however', 'although', 'unless', 'until', 'since', 'while', 'before',
                        'after', 'during', 'through', 'over', 'under', 'above', 'below', 'between', 'among',
                        'within', 'without', 'against', 'via', 'via', 'due', 'onto', 'per', 'each', 'any',
                        'some', 'many', 'few', 'all', 'most', 'no', 'yes', 'ok', 'okk', 'nope', 'nopes', 'nay',
                        'more', 'less', 'least', 'other', 'another', 'somehow', 'thus', 'therefore',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'otherwise', 'instead', 'again', 'further', 'furthermore', 'also', 'besides', 'moreover',
                        'hence', 'thus', 'therefore', 'accordingly', 'consequently', 'so', 'then', 'thereby',
                        'therein', 'thereupon', 'therewith', 'thereto', 'wherefore', 'forthwith', 'hereby',
                        'herein', 'hereupon', 'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore',
                        'herewith', 'hereto', 'whereupon', 'aforesaid', 'heretofore', 'therefrom', 'thereof',
                        'therein', 'thereon', 'thereto', 'whereby', 'thereafter', 'hereafter', 'whenever',
                        'wherever', 'until', 'since', 'whenever', 'wherever', 'until', 'since', 'whereas', 'whilst',
                        'whereas', 'whilst', 'beside', 'beyond', 'during', 'about', 'around', 'above', 'below', 'before',
                        'after', 'without', 'within', 'between', 'among', 'against', 'under', 'over', 'through',
                        'into', 'onto', 'upon', 'am', 'are', 'is', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
                        'had', 'having', 'do', 'does', 'did', 'doing', 'can', 'could', 'will', 'would', 'shall', 'should',
                        'may', 'might', 'must', 'ought', 'need', 'dare', 'used', 'use', 'using', 'uses', 'used', 'put',
                        'puts', 'putting', 'tell', 'tells', 'told', 'telling', 'ask', 'asks', 'asked', 'asking',
                        'make', 'makes', 'made', 'making', 'find', 'finds', 'found', 'finding', 'keep', 'keeps',
                        'kept', 'keeping', 'begin', 'begins', 'began', 'beginning', 'show', 'shows', 'showed',
                        'showing', 'say', 'says', 'said', 'saying', 'says', 'said', 'let', 'lets', 'letting', 'make',
                        'makes', 'made', 'making', 'put', 'puts', 'putting', 'seem', 'seems', 'seemed', 'seeming',
                        'need', 'needs', 'needed', 'needing', 'become', 'becomes', 'became', 'bec'])


# Merge the sets of stop words
stop_words = english_stop_words.union(patent_stop_words)

df_claim['cleaned_Claim_without_Stopwprd'] = df_claim['cleaned_Claim_text'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in stop_words]))
df_claim.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df_claim["Lemmatized-Claim"] = df_claim["cleaned_Claim_without_Stopwprd"].apply(lambda text: lemmatize_words(text))
df_claim.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
df_claim.head()
# Out:
#   publication_number country_code kind_code  \
# 0     US2020097067A1           US        A1
# 1     US2020098473A1           US        A1
# 2     US2020098451A1           US        A1
# 3     US2020098458A1           US        A1
# 4     US2020093988A1           US        A1
#
#                                                title  \
# 0  Artificial Intelligence System and Interactive...
# 1  Data Storage and Retrieval System for Non-Cont...
# 2  Hybrid analysis framework for prediction of ou...
# 3  Medical cannabis platform with physician and p...
# 4           Patient day planning systems and methods
#
#                                             abstract  \
# 0  A reality interactive responding system, compr...
# 1  A web-based interface enables medical personne...
# 2  A facility for predicting patient outcomes on ...
# 3  Through a physician&#39;s portal, a platform c...
# 4  Infusion systems, infusion devices, and relate...
#
#                                               claims  publication_date  \
# 0  1 . A reality interactive responding system, c...          20200326
# 1  What is claimed is: \n     \n         1 . A da...          20200326
# 2  1 . A method in a computing system, comprising...          20200326
# 3  What is claimed is: \n     \n         1 . A me...          20200326
# 4  What is claimed is: \n     \n         1 . A me...          20200326
#
#     ipc_code      cpc_code                                        first_claim  \
# 0  G06F9/448     G16H40/67  1 . A reality interactive responding system, c...
# 1  G16H40/67   H04L67/1097  What is claimed is: 1 . A data storage and ret...
# 2  G16H10/20     G16H10/20  1 . A method in a computing system, comprising...
# 3  G16H80/00    A61K36/185  What is claimed is: 1 . A method for providing...
# 4  G16H20/17  A61M2230/201  What is claimed is: 1 . A method of monitoring...
#
#    claim_lengths                    sub_classes         sub_class  \
# 0            200     ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']
# 1            200   ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']
# 2            200     ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']
# 3            200    ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']
# 4            200  ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']
#
#    abstract_lengths                                 cleaned_Claim_text  \
# 0               123   a reality interactive responding system compr...
# 1               142  what is claimed is a data storage and retrieva...
# 2                81   a method in a computing system comprising obt...
# 3               148  what is claimed is a method for providing netw...
# 4               110  what is claimed is a method of monitoring a ph...
#
#                       cleaned_Claim_without_Stopwprd  \
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...
#
#                                     Lemmatized-Claim
# 0  reality interactive responding system comprisi...
# 1  claimed data storage retrieval system nonconti...
# 2  method computing system comprising obtaining i...
# 3  claimed method providing networking communicat...
# 4  claimed method monitoring physiological condit...

# %%
first_record = df_claim['Lemmatized-Claim'][1]
first_record
# Out:
# 'claimed data storage retrieval system noncontiguous medical device data system comprising medical device connectable computer network subject occasional gap connectivity computer network configured automatically repeatedly capture status information medical device send message containing status information computer network network connectivity log configured automatically record time medical device connects computer network b time medical device disconnect computer network data store configured automatically store digital medium data medium file provide requested portion stored medium file response provision request wherein provision request includes index relative end medium file corresponds requested portion medium server connectable computer network configured automatically receive message computer network store status information received message data store wherein status information consecutive received message stored contiguously data store notwithstanding occasional gap connectivity medical'

# %%
import pandas as pd
from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.models.nmf import Nmf
from gensim.models.coherencemodel import CoherenceModel

# Tokenize the abstracts
docs = [doc.split() for doc in df_claim['Lemmatized-Claim']]

# Apply n-gram (1,3)
bigram_phrases = Phrases(docs, min_count=10)
trigram_phrases = Phrases(bigram_phrases[docs], min_count=10)
#quadgram_phraser = Phrases(trigram_phrases[bigram_phrases[docs]])
docs = [trigram_phrases[bigram_phrases[doc]] for doc in docs]

# Create the dictionary and document-term matrix
id2word = Dictionary(docs)
id2word.filter_extremes(no_below=10, no_above=0.4)
corpus = [id2word.doc2bow(doc) for doc in docs]

# Compute tf-idf scores
tfidf = TfidfModel(corpus)
tfidf_corpus = tfidf[corpus]

# Train the NMF model
num_topics = 30
nmf_model = Nmf(tfidf_corpus, num_topics=num_topics, random_state=42)

# Transform the corpus to get the topic distribution for each document
nmf_output = nmf_model[tfidf_corpus]

# Calculate coherence metrics
cm_cv = CoherenceModel(model=nmf_model, corpus=tfidf_corpus, texts=docs, dictionary=id2word, coherence='c_v')
coherence_cv = cm_cv.get_coherence()

cm_npmi = CoherenceModel(model=nmf_model, texts=docs, corpus=tfidf_corpus, dictionary=id2word, coherence='c_npmi')
coherence_npmi = cm_npmi.get_coherence()

cm_umass = CoherenceModel(model=nmf_model, corpus=tfidf_corpus, dictionary=id2word, coherence='u_mass')
coherence_umass = cm_umass.get_coherence()

# Print the coherence scores
print('C_v coherence:', coherence_cv)
print('c_npmi coherence:', coherence_npmi)
print('u_mass coherence:', coherence_umass)
# Out:
# C_v coherence: 0.3838686691822885
# c_npmi coherence: 0.012712960658397148
# u_mass coherence: -2.890108576822685

# %%
  for i in range(num_topics):
    print(f"Topic {i}:")
    topic_words = [id2word[int(word_id)] for word_id, _ in nmf_model.show_topic(i, topn=10)]
    print(topic_words)
# Out:
# Topic 0:
# ['service', 'terminal', 'message', 'device', 'element', 'service_provider', 'communication', 'request', 'display', 'input']
# Topic 1:
# ['treatment', 'task', 'parameter', 'value', 'biological', 'step', 'protocol', 'electronic', 'processing', 'according']
# Topic 2:
# ['medical', 'device', 'imaging', 'record', 'procedure', 'report', 'code', 'provider', 'condition', 'facility']
# Topic 3:
# ['medication', 'identifier', 'user', 'order', 'dispensing', 'profile', 'food', 'plurality', 'person', 'medicine']
# Topic 4:
# ['set', 'clinical', 'healthcare', 'value', 'attribute', 'object', 'plurality', 'candidate', 'biometric', 'feature']
# Topic 5:
# ['image', 'feature', 'position', 'threedimensional', 'pixel', 'reference', 'medical', 'digital', 'region_interest', 'first']
# Topic 6:
# ['content', 'model', 'procedure', 'training', 'clinical_trial', 'plurality', 'engine', 'organ', 'provider', 'rule']
# Topic 7:
# ['individual', 'event', 'information', 'care', 'parameter', 'population', 'wearable_sensor', 'group', 'disease', 'assessment']
# Topic 8:
# ['component', 'set', 'element', 'training', 'image', 'output', 'wearable_sensor', 'application', 'imaging', 'condition']
# Topic 9:
# ['unit', 'apparatus', 'control', 'information', 'configured', 'processing', 'storage', 'communication', 'device', 'according']
# Topic 10:
# ['sensor', 'event', 'motion', 'device', 'state', 'signal', 'movement', 'monitoring', 'wearable', 'body']
# Topic 11:
# ['first', 'second', 'parameter', 'model', 'signal', 'value', 'third', 'location', 'input', 'time']
# Topic 12:
# ['module', 'code', 'patient', 'configured', 'database', 'software', 'communication', 'computer', 'plurality', 'equipment']
# Topic 13:
# ['item', 'input', 'entity', 'diagnosis', 'query', 'apparatus', 'health_care', 'display', 'collection', 'sample']
# Topic 14:
# ['physiological', 'person', 'parameter', 'condition', 'monitoring', 'report', 'patient', 'signal', 'step', 'state']
# Topic 15:
# ['test', 'exercise', 'first', 'question', 'test_result', 'point', 'feature', 'result', 'testing', 'second']
# Topic 16:
# ['examination', 'object', 'apparatus', 'code', 'section', 'person', 'participant', 'signal', 'component', 'imaging']
# Topic 17:
# ['product', 'drug', 'device', 'member', 'participant', 'location', 'drug_delivery', 'transaction', 'mobile', 'consumer']
# Topic 18:
# ['subject', 'document', 'value', 'client', 'profile', 'location', 'plurality', 'condition', 'assessment', 'response']
# Topic 19:
# ['drug', 'sample', 'subject', 'computer', 'disease', 'characteristic', 'gene', 'cancer', 'group', 'communication']
# Topic 20:
# ['health', 'record', 'electronic', 'mobile', 'condition', 'personal_health', 'event', 'user', 'management', 'database']
# Topic 21:
# ['mean', 'information', 'server', 'computer', 'healthcare', 'network', 'database', 'study', 'record', 'access']
# Topic 22:
# ['patient', 'information', 'prescription', 'identification', 'care', 'clinical', 'medication', 'electronic', 'database', 'pharmacy']
# Topic 23:
# ['client', 'prescription', 'first', 'server', 'therapy', 'second', 'set', 'medication', 'dose', 'request']
# Topic 24:
# ['signal', 'region', 'target', 'ultrasound', 'tissue', 'diagnostic', 'circuit', 'motion', 'output', 'control']
# Topic 25:
# ['image', 'display', 'information', 'apparatus', 'imaging', 'processing', 'section', 'according', 'file', 'displayed']
# Topic 26:
# ['patient', 'computing_device', 'health', 'consumer', 'profile', 'monitoring', 'provider', 'treatment', 'disease', 'physician']
# Topic 27:
# ['measurement', 'state', 'value', 'feature', 'display', 'brain', 'measuring', 'device', 'electrode', 'area']
# Topic 28:
# ['activity', 'device', 'communication', 'electronic', 'mobile', 'server', 'application', 'container', 'user', 'module']
# Topic 29:
# ['user', 'information', 'frame', 'input', 'associated', 'user_interface', 'personal', 'profile', 'request', 'device']

# %%
# Get the most probable topic and its probability for each document
doc_topics = [sorted(nmf_model.get_document_topics(doc), key=lambda x: x[1], reverse=True) for doc in nmf_output]

# %%
# Create empty columns for topic number and probability
df_claim['topics'] = 0
df_claim['prob'] = 0.0

# Loop through each document and update the corresponding row in the dataframe   
for i, doc in enumerate(doc_topics):
    if len(doc) > 0:
        topic_num, topic_prob = doc[0]
        df_claim.at[i, 'topics'] = topic_num
        df_claim.at[i, 'prob'] = topic_prob

# %%
df_claim
# Out:
#       publication_number country_code kind_code  \
# 0         US2020097067A1           US        A1
# 1         US2020098473A1           US        A1
# 2         US2020098451A1           US        A1
# 3         US2020098458A1           US        A1
# 4         US2020093988A1           US        A1
# ...                  ...          ...       ...
# 31301     US2016253489A1           US        A1
# 31302     US2016253467A1           US        A1
# 31303     US2016253462A1           US        A1
# 31304     US2016249985A1           US        A1
# 31305     US2016253465A1           US        A1
#
#                                                    title  \
# 0      Artificial Intelligence System and Interactive...
# 1      Data Storage and Retrieval System for Non-Cont...
# 2      Hybrid analysis framework for prediction of ou...
# 3      Medical cannabis platform with physician and p...
# 4               Patient day planning systems and methods
# ...                                                  ...
# 31301                         User authentication system
# 31302  Diagnosis support apparatus and method, and no...
# 31303  Novel open-access scheduling system that optim...
# 31304  Interrelated point acquisition for navigated s...
# 31305             Next generation lifestream application
#
#                                                 abstract  \
# 0      A reality interactive responding system, compr...
# 1      A web-based interface enables medical personne...
# 2      A facility for predicting patient outcomes on ...
# 3      Through a physician&#39;s portal, a platform c...
# 4      Infusion systems, infusion devices, and relate...
# ...                                                  ...
# 31301  A user authentication system performs user rec...
# 31302  A diagnosis support apparatus for diagnosis of...
# 31303  A patient appointment schedule is generated fo...
# 31304  The present invention relates to a method for ...
# 31305  A method including a healthcare server of a he...
#
#                                                   claims  publication_date  \
# 0      1 . A reality interactive responding system, c...          20200326
# 1      What is claimed is: \n     \n         1 . A da...          20200326
# 2      1 . A method in a computing system, comprising...          20200326
# 3      What is claimed is: \n     \n         1 . A me...          20200326
# 4      What is claimed is: \n     \n         1 . A me...          20200326
# ...                                                  ...               ...
# 31301  1 . A user authentication system comprising:\n...          20160901
# 31302  What is claimed is: \n     \n         1 . A di...          20160901
# 31303  1 . A medical appointment scheduling system co...          20160901
# 31304  1 . A data processing, comprising a computer h...          20160901
# 31305  1 . A method comprising:\n a healthcare server...          20160901
#
#         ipc_code      cpc_code  \
# 0      G06F9/448     G16H40/67
# 1      G16H40/67   H04L67/1097
# 2      G16H10/20     G16H10/20
# 3      G16H80/00    A61K36/185
# 4      G16H20/17  A61M2230/201
# ...          ...           ...
# 31301  G16H10/60     G06F21/32
# 31302  G16H10/60     A61B5/743
# 31303  G16H40/20    G06F19/327
# 31304  G16H20/40    G06F19/324
# 31305  G16H40/67     G16H50/20
#
#                                              first_claim  claim_lengths  \
# 0      1 . A reality interactive responding system, c...            200
# 1      What is claimed is: 1 . A data storage and ret...            200
# 2      1 . A method in a computing system, comprising...            200
# 3      What is claimed is: 1 . A method for providing...            200
# 4      What is claimed is: 1 . A method of monitoring...            200
# ...                                                  ...            ...
# 31301  1 . A user authentication system comprising: a...            200
# 31302  What is claimed is: 1 . A diagnosis support ap...            200
# 31303  1 . A medical appointment scheduling system co...            200
# 31304  1 . A data processing, comprising a computer h...            200
# 31305  1 . A method comprising: a healthcare server o...            200
#
#                          sub_classes         sub_class  abstract_lengths  \
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']               123
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']               142
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']                81
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']               148
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']               110
# ...                              ...               ...               ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']               151
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']               139
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']               134
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']               200
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']               111
#
#                                       cleaned_Claim_text  \
# 0       a reality interactive responding system compr...
# 1      what is claimed is a data storage and retrieva...
# 2       a method in a computing system comprising obt...
# 3      what is claimed is a method for providing netw...
# 4      what is claimed is a method of monitoring a ph...
# ...                                                  ...
# 31301   a user authentication system comprising a plu...
# 31302  what is claimed is a diagnosis support apparat...
# 31303   a medical appointment scheduling system compr...
# 31304   a data processing comprising a computer havin...
# 31305   a method comprising a healthcare server of a ...
#
#                           cleaned_Claim_without_Stopwprd  \
# 0      reality interactive responding system comprisi...
# 1      claimed data storage retrieval system nonconti...
# 2      method computing system comprising obtaining i...
# 3      claimed method providing networking communicat...
# 4      claimed method monitoring physiological condit...
# ...                                                  ...
# 31301  user authentication system comprising pluralit...
# 31302  claimed diagnosis support apparatus diagnosis ...
# 31303  medical appointment scheduling system comprisi...
# 31304  data processing comprising computer processor ...
# 31305  method comprising healthcare server healthcare...
#
#                                         Lemmatized-Claim  topics      prob
# 0      reality interactive responding system comprisi...      24  0.169739
# 1      claimed data storage retrieval system nonconti...       0  0.188596
# 2      method computing system comprising obtaining i...      24  0.309068
# 3      claimed method providing networking communicat...      24  0.294943
# 4      claimed method monitoring physiological condit...       1  0.181485
# ...                                                  ...     ...       ...
# 31301  user authentication system comprising pluralit...       0  0.169809
# 31302  claimed diagnosis support apparatus diagnosis ...       6  0.204549
# 31303  medical appointment scheduling system comprisi...      24  0.369986
# 31304  data processing comprising computer processor ...      11  0.448988
# 31305  method comprising healthcare server healthcare...      14  0.293601
#
# [31306 rows x 19 columns]

# %%
df_Claim_topic=df_claim[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob"]]
df_Claim_topic
# Out:
#       publication_number                                              title  \
# 0         US2020097067A1  Artificial Intelligence System and Interactive...
# 1         US2020098473A1  Data Storage and Retrieval System for Non-Cont...
# 2         US2020098451A1  Hybrid analysis framework for prediction of ou...
# 3         US2020098458A1  Medical cannabis platform with physician and p...
# 4         US2020093988A1           Patient day planning systems and methods
# ...                  ...                                                ...
# 31301     US2016253489A1                         User authentication system
# 31302     US2016253467A1  Diagnosis support apparatus and method, and no...
# 31303     US2016253462A1  Novel open-access scheduling system that optim...
# 31304     US2016249985A1  Interrelated point acquisition for navigated s...
# 31305     US2016253465A1             Next generation lifestream application
#
#                                              first_claim  \
# 0      1 . A reality interactive responding system, c...
# 1      What is claimed is: 1 . A data storage and ret...
# 2      1 . A method in a computing system, comprising...
# 3      What is claimed is: 1 . A method for providing...
# 4      What is claimed is: 1 . A method of monitoring...
# ...                                                  ...
# 31301  1 . A user authentication system comprising: a...
# 31302  What is claimed is: 1 . A diagnosis support ap...
# 31303  1 . A medical appointment scheduling system co...
# 31304  1 . A data processing, comprising a computer h...
# 31305  1 . A method comprising: a healthcare server o...
#
#                                         Lemmatized-Claim  \
# 0      reality interactive responding system comprisi...
# 1      claimed data storage retrieval system nonconti...
# 2      method computing system comprising obtaining i...
# 3      claimed method providing networking communicat...
# 4      claimed method monitoring physiological condit...
# ...                                                  ...
# 31301  user authentication system comprising pluralit...
# 31302  claimed diagnosis support apparatus diagnosis ...
# 31303  medical appointment scheduling system comprisi...
# 31304  data processing comprising computer processor ...
# 31305  method comprising healthcare server healthcare...
#
#                          sub_classes         sub_class  topics      prob
# 0         ['G06F9/448', 'G16H40/67']  ['G06F', 'G16H']      24  0.169739
# 1       ['G16H40/67', 'H04L67/1097']  ['G16H', 'H04L']       0  0.188596
# 2         ['G16H10/20', 'G16H10/20']  ['G16H', 'G16H']      24  0.309068
# 3        ['G16H80/00', 'A61K36/185']  ['G16H', 'A61K']      24  0.294943
# 4      ['G16H20/17', 'A61M2230/201']  ['G16H', 'A61M']       1  0.181485
# ...                              ...               ...     ...       ...
# 31301     ['G16H10/60', 'G06F21/32']  ['G16H', 'G06F']       0  0.169809
# 31302     ['G16H10/60', 'A61B5/743']  ['G16H', 'A61B']       6  0.204549
# 31303    ['G16H40/20', 'G06F19/327']  ['G16H', 'G06F']      24  0.369986
# 31304    ['G16H20/40', 'G06F19/324']  ['G16H', 'G06F']      11  0.448988
# 31305     ['G16H40/67', 'G16H50/20']  ['G16H', 'G16H']      14  0.293601
#
# [31306 rows x 8 columns]

# %% [markdown]
# # prediction

# %%
import pandas as pd

df_Cliam_test = pd.read_csv('test-queries-USPTO(A1)-2023-G16H.csv')
df_Cliam_test.head()
# Out:
#   publication_numbers                                           abstract  \
# 0     US20230238130A1  A physiological sensor has light emitting sour...
# 1     US20230270344A1  A wearable monitoring device includes a band c...
# 2     US20230200909A1  A number of improvements are provided relating...
# 3     US20230218347A1  Embodiments include a system for determining c...
# 4     US20230063013A1  A community based response system for providin...
#
#                                          first_claim  \
# 0  1. A physiological monitoring device comprisin...
# 1  1. A monitoring device, comprising:\na band co...
# 2  1-25. (canceled) 26. A method for guiding a fr...
# 3  1-184. (canceled) 185. A computer-implemented ...
# 4  1. (canceled) 2. A community based response sy...
#
#                                          class_codes
# 0  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1  A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2  A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3  G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4  H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...

# %% [markdown]
# # test1

# %%
df_Cliam_test.iloc[0]
# Out:
# publication_numbers                                      US20230238130A1
# abstract               A physiological sensor has light emitting sour...
# first_claim            1. A physiological monitoring device comprisin...
# class_codes            A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# Name: 0, dtype: object

# %% [markdown]
# # list of 10 queries

# %%
num_samples_to_predict = 100
num_of_topics = 5
results = []

# Assuming you have a list of 10 queries in test
queries = df_Cliam_test['first_claim'][:num_samples_to_predict]

for query in queries:
    if isinstance(query, str):  # Check if the value is a string
        query_tokens = trigram_phrases[bigram_phrases[query.split()]]  # Preprocess the query text
        query_bow = id2word.doc2bow(query_tokens)  # Convert to bag of words
        query_topic_dist = nmf_model[query_bow]  # Get the topic distribution for the query
        top_topics = sorted(query_topic_dist, key=lambda x: x[1], reverse=True)[:num_of_topics]  # Get the top topics
        results.append(top_topics)
    else:
        results.append([])  # Append an empty list for non-string values

# Now, the 'results' list contains the top topics and their probabilities for each query
# You can access the results for a specific query like this:
for i, top_topics in enumerate(results):
    print(f"Query {i + 1}: Top {num_of_topics} Topics {top_topics}")
# Out:
# Query 1: Top 5 Topics [(24, 0.4619180649422502), (29, 0.1150010834548143), (14, 0.09201503890097538), (10, 0.07087911198776377), (9, 0.047350812400844516)]
# Query 2: Top 5 Topics [(0, 0.2309774667225527), (10, 0.14156611485129453), (14, 0.13916365847544593), (24, 0.1147707464305155), (4, 0.07042164614377874)]
# Query 3: Top 5 Topics [(22, 0.3824204405639803), (28, 0.10584555716504687), (1, 0.08869469839928698), (5, 0.08770013749980705), (20, 0.08504971664572508)]
# Query 4: Top 5 Topics [(19, 0.38025911985826605), (24, 0.1786723641582527), (5, 0.10947531833030619), (6, 0.06708826286097996), (0, 0.06354367304945507)]
# Query 5: Top 5 Topics [(0, 0.22119019748719215), (17, 0.16778236359664156), (29, 0.16388527334506592), (28, 0.11181917532125012), (11, 0.06666633361316836)]
# Query 6: Top 5 Topics [(10, 0.530816294025633), (11, 0.2545094479959276), (21, 0.09111179078212127), (25, 0.05325720118325487), (22, 0.04481302299388081)]
# Query 7: Top 5 Topics [(10, 0.36411806887089704), (21, 0.15988214451193622), (22, 0.14260500001019819), (17, 0.0812291228108242), (29, 0.0690649198868025)]
# Query 8: Top 5 Topics [(10, 0.39764637420416815), (11, 0.33187272950432595), (28, 0.07434432087109326), (5, 0.061096907021313325), (17, 0.04929589230467098)]
# Query 9: Top 5 Topics [(22, 0.6605189037067349), (26, 0.2972157835281283), (28, 0.042265312765136794)]
# Query 10: Top 5 Topics [(11, 0.45993760213958557), (5, 0.2504314658065884), (4, 0.09168247625653803), (26, 0.05523980261452857), (15, 0.0255861100954104)]
# Query 11: Top 5 Topics [(11, 0.6805984932878488), (19, 0.16390535142604862), (18, 0.13024551723137376), (15, 0.02065834052111291)]
# Query 12: Top 5 Topics [(24, 0.3720366139679209), (11, 0.30071037223803143), (28, 0.24367950582242875), (10, 0.07011130020306038)]
# Query 13: Top 5 Topics [(11, 0.22120754794289144), (8, 0.20499883554803966), (4, 0.14952965390679876), (14, 0.07600104449165357), (29, 0.07053597616135701)]
# Query 14: Top 5 Topics [(29, 0.3271624811878277), (20, 0.15516743565309865), (24, 0.09114395511588586), (25, 0.08900342072994115), (10, 0.08794488099695758)]
# Query 15: Top 5 Topics [(0, 0.21743712296741927), (21, 0.18678677989060866), (10, 0.12462765906597839), (14, 0.11837574449256617), (26, 0.10180548948501707)]
# Query 16: Top 5 Topics [(24, 0.5903583481516326), (27, 0.1808195071226286), (22, 0.05464747341519999), (14, 0.042770080263601434), (15, 0.037139508113308205)]
# Query 17: Top 5 Topics [(11, 0.7506874233177189), (10, 0.11624199534648), (9, 0.06804086510526137), (0, 0.03920034178847799), (23, 0.013428824534098433)]
# Query 18: Top 5 Topics [(29, 0.2548564680446573), (4, 0.197010415959561), (3, 0.1853251040567611), (1, 0.13904464113576268), (27, 0.0476032445421317)]
# Query 19: Top 5 Topics [(11, 0.4608603811062147), (28, 0.17683994176872328), (29, 0.14637725347194408), (4, 0.09119768356458993), (1, 0.054652017111725466)]
# Query 20: Top 5 Topics [(22, 0.2615900060915958), (26, 0.2361381608561618), (28, 0.1017679481277625), (17, 0.0564634050205393), (12, 0.05257623399368532)]
# Query 21: Top 5 Topics [(18, 0.37100383233535217), (24, 0.23627618176823884), (19, 0.169091811827528), (4, 0.08855004857405162), (6, 0.07253255666834407)]
# Query 22: Top 5 Topics [(11, 0.5215863735161322), (26, 0.13353417919690522), (22, 0.09163344978092788), (0, 0.07679388535142238), (6, 0.03361664167850865)]
# Query 23: Top 5 Topics [(29, 0.380939300521444), (20, 0.3530619403543128), (28, 0.08237784617914747), (26, 0.08235268096977047), (4, 0.06644332728280218)]
# Query 24: Top 5 Topics [(24, 0.22281410799654652), (29, 0.19580293275974983), (12, 0.18047713589026473), (4, 0.07844071474726856), (14, 0.07535661230598115)]
# Query 25: Top 5 Topics [(22, 0.12438537589477403), (9, 0.12147340594735438), (14, 0.10945925374926652), (10, 0.09873846214069859), (4, 0.09707569368360905)]
# Query 26: Top 5 Topics [(6, 0.4369733562659527), (5, 0.2448657137986523), (25, 0.09488146980509579), (12, 0.0832893745108077), (8, 0.05051631318046385)]
# Query 27: Top 5 Topics [(11, 0.7963600117263134), (10, 0.1964481141337246)]
# Query 28: Top 5 Topics [(11, 0.25979371072287755), (21, 0.24995919314244175), (2, 0.17804417765499014), (22, 0.08545859166961113), (29, 0.07344241662804825)]
# Query 29: Top 5 Topics [(15, 0.31105869853031803), (19, 0.2381876479581033), (6, 0.1872185768029061), (4, 0.07166156777045157), (5, 0.05572486289254711)]
# Query 30: Top 5 Topics [(28, 0.2141928763990018), (11, 0.17011342026703447), (1, 0.1360312800967335), (17, 0.1289576937708972), (10, 0.11523786543598744)]
# Query 31: Top 5 Topics [(2, 0.5251011657399979), (4, 0.1517273554362574), (12, 0.07241993634288427), (10, 0.04656326523993013), (5, 0.045870993027023424)]
# Query 32: Top 5 Topics [(10, 0.40023473184877434), (24, 0.15121796536037743), (9, 0.12821477229197695), (17, 0.09790299004062931), (5, 0.09326080079840185)]
# Query 33: Top 5 Topics [(8, 0.3158123536897479), (4, 0.31027356257725147), (11, 0.2769008866683766), (23, 0.06240312580092372), (9, 0.015841862236452082)]
# Query 34: Top 5 Topics [(10, 0.28805640576404024), (11, 0.22040533138919094), (29, 0.0979932269226183), (28, 0.08153495078733002), (8, 0.06980755569020548)]
# Query 35: Top 5 Topics [(10, 0.46851684117076264), (2, 0.16090245871954878), (0, 0.11424732142278696), (28, 0.09134464742648972), (19, 0.0512661928125124)]
# Query 36: Top 5 Topics [(2, 0.24797425987728228), (6, 0.22959680160219095), (29, 0.1773918376705881), (25, 0.11378037600084263), (22, 0.08129645154650554)]
# Query 37: Top 5 Topics [(19, 0.5097486058345183), (26, 0.21155107190124042), (17, 0.0829230138105089), (14, 0.07024364238379885), (23, 0.05717965995646502)]
# Query 38: Top 5 Topics [(11, 0.5920979102935666), (7, 0.14639607268800026), (2, 0.0996190449260432), (28, 0.04532996110676918), (21, 0.033492466401349875)]
# Query 39: Top 5 Topics [(10, 0.25196253104732663), (28, 0.2068467684170188), (0, 0.13666864429443276), (17, 0.12579992227591028), (9, 0.08687783439691905)]
# Query 40: Top 5 Topics [(1, 0.4153783718732183), (11, 0.18361259041383524), (24, 0.09426492422657318), (28, 0.08833891203638007), (0, 0.07997368902030756)]
# Query 41: Top 5 Topics [(22, 0.3790883030107394), (0, 0.1654237246036532), (28, 0.1571434365909695), (26, 0.14072344492105104), (17, 0.06701072546230559)]
# Query 42: Top 5 Topics [(22, 0.34962321885610015), (5, 0.28080791233519453), (26, 0.23048572822419347), (25, 0.12123462950847876), (1, 0.01784851107603303)]
# Query 43: Top 5 Topics [(11, 0.38379207792427894), (26, 0.21587983884084178), (21, 0.1114592430862094), (28, 0.1045874976737937), (0, 0.056556867141160684)]
# Query 44: Top 5 Topics [(24, 0.32090801103486544), (4, 0.30639913401437185), (8, 0.2520577062729032), (22, 0.04810242495182697), (6, 0.02384163805069623)]
# Query 45: Top 5 Topics [(4, 0.1983789679231033), (8, 0.15216099122780402), (26, 0.14814261770849957), (10, 0.07264183643488153), (23, 0.06135115863675677)]
# Query 46: Top 5 Topics [(26, 0.26176752555295874), (15, 0.23737685920953325), (20, 0.1784313829790381), (6, 0.09418288002794048), (10, 0.08709755342016752)]
# Query 47: Top 5 Topics [(10, 0.2558594855221442), (28, 0.134216954604774), (0, 0.1149825718667149), (17, 0.09039787419186644), (9, 0.0569337784063287)]
# Query 48: Top 5 Topics [(22, 0.3786934239021528), (26, 0.26025331517345823), (25, 0.23668367621158953), (5, 0.07997622864723632), (14, 0.019068732649241325)]
# Query 49: Top 5 Topics [(6, 0.4610498943296962), (26, 0.1092964772855543), (4, 0.10741856418372617), (1, 0.08965368240035967), (5, 0.06629958844620612)]
# Query 50: Top 5 Topics [(16, 0.18133877484581382), (6, 0.16571257255819952), (4, 0.10784434451626371), (1, 0.09761706754321298), (24, 0.08824649476438172)]
# Query 51: Top 5 Topics [(26, 0.4083584475992355), (22, 0.24846468131835095), (11, 0.11490803536058763), (10, 0.09505153511420086), (14, 0.067976611711561)]
# Query 52: Top 5 Topics [(4, 0.29018659868730495), (8, 0.18355116239345357), (19, 0.11153836071793818), (24, 0.09552009246631402), (26, 0.0779480905350887)]
# Query 53: Top 5 Topics [(24, 0.3468632310179335), (4, 0.2970206620902895), (8, 0.2662379939093792), (29, 0.03859469436125462), (23, 0.02888813919580499)]
# Query 54: Top 5 Topics [(11, 0.33424427356281516), (21, 0.19791956424697568), (22, 0.12194027128961087), (29, 0.11365576379578951), (25, 0.06076055172717407)]
# Query 55: Top 5 Topics [(11, 0.7263928979168178), (0, 0.15137757852580913), (9, 0.06638440341464988), (19, 0.02338456915964969), (23, 0.014490331163075966)]
# Query 56: Top 5 Topics [(6, 0.8638985096334505), (10, 0.03999856730487545), (27, 0.030395176327462445), (29, 0.025300769929752782), (26, 0.02460008758457065)]
# Query 57: Top 5 Topics [(24, 0.25420902354950564), (26, 0.18848557343619443), (6, 0.11566215696901844), (5, 0.0974386333914767), (4, 0.08492435268923028)]
# Query 58: Top 5 Topics [(22, 0.5406243199721972), (26, 0.14569103826201987), (14, 0.09946227144001672), (28, 0.09200968435566069), (17, 0.03243608858125336)]
# Query 59: Top 5 Topics [(9, 0.2405359033101898), (4, 0.1578669138752543), (10, 0.1075671654902581), (1, 0.1055365714511237), (6, 0.09088865797141517)]
# Query 60: Top 5 Topics [(6, 0.45052905568820845), (26, 0.10110372401395303), (22, 0.09232896366733145), (19, 0.07481154644465855), (8, 0.050759577107701924)]
# Query 61: Top 5 Topics [(28, 0.7121694996204543), (26, 0.16450607610588888), (14, 0.05093223258111996), (21, 0.03724389443874098), (4, 0.020573767373612037)]
# Query 62: Top 5 Topics [(8, 0.36959345449922754), (29, 0.25414969514910696), (20, 0.17799389073660163), (26, 0.041640105323308745), (9, 0.04021627258375955)]
# Query 63: Top 5 Topics [(11, 0.7851006148544759), (20, 0.09263782451826907), (21, 0.039968290320806815), (10, 0.02571845204545728), (23, 0.024132515910800147)]
# Query 64: Top 5 Topics [(29, 0.31661415454837755), (10, 0.24114688038174897), (14, 0.17303267114189055), (6, 0.09696500165907156), (25, 0.05808905403106705)]
# Query 65: Top 5 Topics [(6, 0.3274140659126455), (10, 0.29990245106042873), (12, 0.18467963520210104), (28, 0.09969840933659865), (17, 0.03441262046730731)]
# Query 66: Top 5 Topics [(11, 0.36196888540977984), (10, 0.3198729729600626), (5, 0.2272966873877909), (25, 0.05348404430253859), (23, 0.03577292884958464)]
# Query 67: Top 5 Topics []
# Query 68: Top 5 Topics [(28, 0.7116901387755812), (4, 0.1269803543103448), (1, 0.054356079239468065), (27, 0.022100566416983717), (29, 0.018773928788231805)]
# Query 69: Top 5 Topics [(24, 0.3839864833722614), (11, 0.33744772517415605), (21, 0.06351901179146473), (0, 0.036701383590213486), (29, 0.03606694313523937)]
# Query 70: Top 5 Topics [(14, 0.2854808236493429), (20, 0.19763415358082398), (10, 0.1496655322213308), (25, 0.10880117527049062), (29, 0.062386738126833104)]
# Query 71: Top 5 Topics [(21, 0.27316046959302154), (22, 0.1660892452180465), (29, 0.12688258144762377), (17, 0.08084766271132802), (25, 0.05293400399233426)]
# Query 72: Top 5 Topics [(7, 0.4973283013055026), (10, 0.2515848161991112), (12, 0.11705046383531185), (28, 0.050688554057688025), (11, 0.045950022529534146)]
# Query 73: Top 5 Topics [(29, 0.6839171960807015), (27, 0.14350681409059088), (14, 0.08653641706572403), (10, 0.0659300834030314), (1, 0.013742394870370503)]
# Query 74: Top 5 Topics []
# Query 75: Top 5 Topics [(10, 0.8381596749447301), (9, 0.08620920950352463), (25, 0.04471049510589812)]
# Query 76: Top 5 Topics [(2, 0.4610531560883762), (9, 0.19092327631920003), (10, 0.15985069098935656), (25, 0.044342078851383616), (29, 0.03997000759203854)]
# Query 77: Top 5 Topics [(28, 0.3024056257704931), (22, 0.2134571181754353), (26, 0.08743850786416096), (24, 0.08011324467895391), (19, 0.07531559333992582)]
# Query 78: Top 5 Topics [(5, 0.4565473019584984), (25, 0.1463089431885073), (10, 0.12719420877508353), (19, 0.047418643259939317), (0, 0.04736327788039365)]
# Query 79: Top 5 Topics [(29, 0.20576464091053984), (9, 0.17651248296469763), (2, 0.1516148177598765), (10, 0.12732010631418478), (28, 0.11962542526220094)]
# Query 80: Top 5 Topics [(28, 0.38356051642300415), (0, 0.2551306696482673), (17, 0.22999805009816243), (2, 0.06834658117041191), (27, 0.027747172069245096)]
# Query 81: Top 5 Topics [(4, 0.18828760552861573), (29, 0.18368461871436945), (9, 0.18346370302297102), (10, 0.08476195319948181), (26, 0.07710770405854403)]
# Query 82: Top 5 Topics [(11, 0.8082845318307832), (10, 0.11597686411681915), (4, 0.07069679293127103)]
# Query 83: Top 5 Topics [(22, 0.6361677705449708), (26, 0.22710924514241568), (5, 0.06880799620156491), (14, 0.0310330304572938), (24, 0.021253136213625783)]
# Query 84: Top 5 Topics [(29, 0.273280735941854), (20, 0.20926236391055572), (28, 0.17925036993658236), (17, 0.12175182112188847), (0, 0.12065564914473474)]
# Query 85: Top 5 Topics [(11, 0.28382616349858786), (24, 0.27215467278324573), (21, 0.1149550591849504), (14, 0.08686528028431222), (8, 0.04737472827195888)]
# Query 86: Top 5 Topics [(28, 0.7236468247297704), (29, 0.1894388543017591), (10, 0.030543055586760907), (4, 0.02951877167840773), (11, 0.0133715321779241)]
# Query 87: Top 5 Topics [(4, 0.2161125539224584), (24, 0.17639336511814), (9, 0.09432454752477716), (6, 0.08655174681015784), (19, 0.0847167079775347)]
# Query 88: Top 5 Topics [(21, 0.18960175759259187), (2, 0.17361432796188261), (29, 0.13728720483205548), (23, 0.10375358042627403), (12, 0.09039904135524439)]
# Query 89: Top 5 Topics [(22, 0.24257993056466132), (10, 0.21994968623395747), (8, 0.11837719584908113), (12, 0.10659631156388279), (17, 0.09201306709338357)]
# Query 90: Top 5 Topics [(0, 0.32231733906071347), (2, 0.2160425468207018), (28, 0.18371860281649155), (17, 0.1202958814290751), (4, 0.0576848551010663)]
# Query 91: Top 5 Topics [(6, 0.31448316573527313), (28, 0.1379021549462936), (0, 0.09560088441111593), (17, 0.09248253157087469), (22, 0.06902655307695132)]
# Query 92: Top 5 Topics [(5, 0.5183280412468605), (2, 0.31152053541554314), (25, 0.17015142333759642)]
# Query 93: Top 5 Topics [(29, 0.2913322056293027), (28, 0.28653366656888235), (11, 0.28146833408475597), (20, 0.13456396371181076)]
# Query 94: Top 5 Topics [(14, 0.24028126438663447), (10, 0.23755370400611497), (11, 0.21133641216002058), (27, 0.1600789044642043), (29, 0.14253716461152216)]
# Query 95: Top 5 Topics [(4, 0.1934167223358669), (24, 0.14982937590070658), (6, 0.0948552720568966), (2, 0.08164973884045743), (10, 0.07932601030340526)]
# Query 96: Top 5 Topics [(22, 0.22459515786763723), (26, 0.14977802500365456), (2, 0.09940619231854678), (0, 0.09553522072413168), (5, 0.08911683244775351)]
# Query 97: Top 5 Topics [(11, 0.42397632994685425), (10, 0.17111059250352073), (21, 0.11762748322598962), (7, 0.08412932083031979), (23, 0.0671216576041863)]
# Query 98: Top 5 Topics [(11, 0.6275090402747386), (22, 0.2079281809417632), (2, 0.10372437286176109), (21, 0.02534605744235099), (5, 0.017281804524486927)]
# Query 99: Top 5 Topics [(11, 0.44300973913055147), (10, 0.32104111473857627), (4, 0.12460760436111205), (14, 0.034619503586640024), (26, 0.02000522344315425)]
# Query 100: Top 5 Topics [(26, 0.33981893009605135), (11, 0.21688333428372655), (22, 0.13572095182141192), (23, 0.09511624226860592), (29, 0.0939133277104795)]

# %%
# Create a new DataFrame to store the predicted topics
result_df_q = pd.DataFrame(columns=['query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Populate the new DataFrame with the predicted topics
for i, top_topics in enumerate(results):
    query_publication_numbers = df_Cliam_test['publication_numbers'].iloc[i]
    query_class_codes = df_Cliam_test['class_codes'].iloc[i]
    query_claim = df_Cliam_test['first_claim'].iloc[i]
    predicted_topics = [topic_id for topic_id, _ in top_topics]
    
    # Append the data to the new DataFrame
    new_row = {'query_publication_numbers': query_publication_numbers,
               'query_class_codes': query_class_codes,
               'query_claim': query_claim,
               'query_predicted_topics': predicted_topics}
    
    result_df_q = pd.concat([result_df_q, pd.DataFrame([new_row])], ignore_index=True)

# Now, predicted_topics_df contains the desired structure of predicted topics for each query
result_df_q
# Out:
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230270344A1
# 2            US20230200909A1
# 3            US20230218347A1
# 4            US20230063013A1
# ..                       ...
# 95           US20230017310A1
# 96           US20230091925A1
# 97           US20230010638A1
# 98           US20230009812A1
# 99           US20230138516A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/02405,A61B5/01,A61B5/16,A61B5/02055,A61B...
# 2   A61B17/17,A61B2090/061,A61B90/06,A61B2090/365,...
# 3   G06V10/46,G06V20/698,G06T2207/20112,G06T7/13,A...
# 4   H04M1/72418,G08B,G08,G08B25/016,G,H04W4/023,G1...
# ..                                                ...
# 95  G06Q10/10,G,G06F,G06F16/90,G06F16/95,G16H30/20...
# 96  H04L41/5061,G,G06,G06F,H04L67/00,H,H04,G06F16/...
# 97  A61M5/142,A61,Y10S128/00,G06T2219/2016,G06F8/6...
# 98  A61B5/14551,A61,G,A61B5/021,A61B5/746,A61B,A61...
# 99  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                           query_claim query_predicted_topics
# 0   1. A physiological monitoring device comprisin...    [24, 29, 14, 10, 9]
# 1   1. A monitoring device, comprising:\na band co...     [0, 10, 14, 24, 4]
# 2   1-25. (canceled) 26. A method for guiding a fr...     [22, 28, 1, 5, 20]
# 3   1-184. (canceled) 185. A computer-implemented ...      [19, 24, 5, 6, 0]
# 4   1. (canceled) 2. A community based response sy...    [0, 17, 29, 28, 11]
# ..                                                ...                    ...
# 95  1. A system for storing medical information re...      [22, 26, 2, 0, 5]
# 96  1. A method for event notification in an inter...    [11, 10, 21, 7, 23]
# 97  1.-2. (canceled) 3. A method of managing an in...     [11, 22, 2, 21, 5]
# 98  1. (canceled) 2. A patient monitoring system c...    [11, 10, 4, 14, 26]
# 99  1-27. (canceled) 28. A system to manage record...   [26, 11, 22, 23, 29]
#
# [100 rows x 4 columns]

# %%
import pandas as pd

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=['publication_number', 'title', 'first_claim', 'Lemmatized-Claim', 'sub_classes', 'sub_class', 'topics', 'prob', 'query_publication_numbers', 'query_class_codes', 'query_claim', 'query_predicted_topics'])

# Define the number of documents to retrieve for each topic
num_of_documents_to_retrieve = 10

for i, row in result_df_q.iterrows():
    query = row['query_claim']
    predicted_topics = row['query_predicted_topics']
    
    rows_to_append = []  # Create a list to store rows to be appended
    
    for topic_id in predicted_topics:
        # Filter 'df_Abstract_topic' to get the top 'num_of_documents_to_retrieve' documents for the current topic_id
        topic_documents = df_Claim_topic[df_Claim_topic['topics'] == topic_id]
        
        # Sort the documents by probability in descending order
        topic_documents = topic_documents.sort_values(by='prob', ascending=False).head(num_of_documents_to_retrieve)
        
        # Append the results to the 'rows_to_append' list
        for _, doc_row in topic_documents.iterrows():
            new_row = {
                'query_publication_numbers': row['query_publication_numbers'],
                'query_class_codes': row['query_class_codes'],
                'query_claim': query,
                'query_predicted_topics': [topic_id],  # Assign the current topic_id as a list
                'publication_number': doc_row['publication_number'],
                'title': doc_row['title'],
                'first_claim': doc_row['first_claim'],
                'Lemmatized-Claim': doc_row['Lemmatized-Claim'],
                'sub_classes': doc_row['sub_classes'],
                'sub_class': doc_row['sub_class'],
                'topics': doc_row['topics'],
                'prob': doc_row['prob']
            }
            rows_to_append.append(new_row)
    
    # Use pd.concat to append rows to result_df
    result_df = pd.concat([result_df, pd.DataFrame(rows_to_append)], ignore_index=True)

# Now, 'result_df' contains the top 10 most probable documents for each predicted topic list for each query
result_df
# Out:
#      publication_number                                              title  \
# 0        US2012271647A1  Method for improved adherence to medication th...
# 1        US2008132799A1  Method of physiological data analysis and meas...
# 2        US2022199254A1  Universal health machine for the automatic ass...
# 3        US2019096520A1                         Personalized patient model
# 4        US2021280323A1  Customizable communication platform with longi...
# ...                 ...                                                ...
# 2987     US2011021952A1  Event-based health activity tracking with icon...
# 2988     US2003220821A1  System and method for managing and reconciling...
# 2989     US2008040157A1  Methods and systems for storing and providing ...
# 2990     US2014188508A1  Method of automated electronic health record s...
# 2991     US2021090081A1              Tokenized healthcare service payments
#
#                                             first_claim  \
# 0     1 . A method for managing medication adherence...
# 1     1 . A method of analyzing patient physiologica...
# 2     1 . A method for automatically determining an ...
# 3     What is claimed is: 1 . A method for calculati...
# 4     What is claimed is: 1 . A method, comprising: ...
# ...                                                 ...
# 2987  1 . A method of tracking health activities pre...
# 2988  What is claimed is: 1 . A method of managing a...
# 2989  1 . A method for storing and providing informa...
# 2990  What is claimed is: 1 . A method of automated ...
# 2991  What is claimed is: 1 . A computer-implemented...
#
#                                        Lemmatized-Claim  \
# 0     method managing medication adherence patient c...
# 1     method analyzing patient physiological data co...
# 2     method automatically determining assessment pa...
# 3     claimed method calculating personalized patien...
# 4     claimed method comprising linking patient devi...
# ...                                                 ...
# 2987  method tracking health activity prescribed per...
# 2988  claimed method managing asynchronous patient d...
# 2989  method storing providing information related c...
# 2990  claimed method automated electronic health rec...
# 2991  claimed computerimplemented method expediting ...
#
#                       sub_classes         sub_class topics      prob  \
# 0      ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1      ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2      ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3      ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4      ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# ...                           ...               ...    ...       ...
# 2987   ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 2988   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 2989   ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 2990   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 2991  ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 2987           US20230138516A1
# 2988           US20230138516A1
# 2989           US20230138516A1
# 2990           US20230138516A1
# 2991           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 2987  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2988  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2989  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2990  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2991  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim query_predicted_topics
# 0     1. A physiological monitoring device comprisin...                   [24]
# 1     1. A physiological monitoring device comprisin...                   [24]
# 2     1. A physiological monitoring device comprisin...                   [24]
# 3     1. A physiological monitoring device comprisin...                   [24]
# 4     1. A physiological monitoring device comprisin...                   [24]
# ...                                                 ...                    ...
# 2987  1-27. (canceled) 28. A system to manage record...                   [29]
# 2988  1-27. (canceled) 28. A system to manage record...                   [29]
# 2989  1-27. (canceled) 28. A system to manage record...                   [29]
# 2990  1-27. (canceled) 28. A system to manage record...                   [29]
# 2991  1-27. (canceled) 28. A system to manage record...                   [29]
#
# [2992 rows x 12 columns]

# %%
# Add a new column to store the filtered codes
result_df['query_codes_G16H'] = ''

# Define a function to extract codes starting with 'G61H' from the class codes
def extract_G16H_codes(class_codes):
    codes = class_codes.split(',')
    return ','.join([code for code in codes if code.startswith('G16H')])

# Iterate through rows and update the 'query_codes_G61H' column
for index, row in result_df.iterrows():
    class_codes = row['query_class_codes']
    filtered_codes = extract_G16H_codes(class_codes)
    result_df.at[index, 'query_codes_G16H'] = filtered_codes

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2012271647A1  Method for improved adherence to medication th...
# 1        US2008132799A1  Method of physiological data analysis and meas...
# 2        US2022199254A1  Universal health machine for the automatic ass...
# 3        US2019096520A1                         Personalized patient model
# 4        US2021280323A1  Customizable communication platform with longi...
# ...                 ...                                                ...
# 2987     US2011021952A1  Event-based health activity tracking with icon...
# 2988     US2003220821A1  System and method for managing and reconciling...
# 2989     US2008040157A1  Methods and systems for storing and providing ...
# 2990     US2014188508A1  Method of automated electronic health record s...
# 2991     US2021090081A1              Tokenized healthcare service payments
#
#                                             first_claim  \
# 0     1 . A method for managing medication adherence...
# 1     1 . A method of analyzing patient physiologica...
# 2     1 . A method for automatically determining an ...
# 3     What is claimed is: 1 . A method for calculati...
# 4     What is claimed is: 1 . A method, comprising: ...
# ...                                                 ...
# 2987  1 . A method of tracking health activities pre...
# 2988  What is claimed is: 1 . A method of managing a...
# 2989  1 . A method for storing and providing informa...
# 2990  What is claimed is: 1 . A method of automated ...
# 2991  What is claimed is: 1 . A computer-implemented...
#
#                                        Lemmatized-Claim  \
# 0     method managing medication adherence patient c...
# 1     method analyzing patient physiological data co...
# 2     method automatically determining assessment pa...
# 3     claimed method calculating personalized patien...
# 4     claimed method comprising linking patient devi...
# ...                                                 ...
# 2987  method tracking health activity prescribed per...
# 2988  claimed method managing asynchronous patient d...
# 2989  method storing providing information related c...
# 2990  claimed method automated electronic health rec...
# 2991  claimed computerimplemented method expediting ...
#
#                       sub_classes         sub_class topics      prob  \
# 0      ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1      ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2      ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3      ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4      ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# ...                           ...               ...    ...       ...
# 2987   ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 2988   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 2989   ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 2990   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 2991  ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 2987           US20230138516A1
# 2988           US20230138516A1
# 2989           US20230138516A1
# 2990           US20230138516A1
# 2991           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 2987  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2988  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2989  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2990  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2991  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 2987  1-27. (canceled) 28. A system to manage record...
# 2988  1-27. (canceled) 28. A system to manage record...
# 2989  1-27. (canceled) 28. A system to manage record...
# 2990  1-27. (canceled) 28. A system to manage record...
# 2991  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics                                   query_codes_G16H
# 0                      [24]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1                      [24]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2                      [24]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3                      [24]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4                      [24]  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# ...                     ...                                                ...
# 2987                   [29]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2988                   [29]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2989                   [29]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2990                   [29]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2991                   [29]       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
#
# [2992 rows x 13 columns]

# %%
import ast


# Create a new column to store the common code
result_df['exact_match_code'] = ''

# Iterate through rows and compare 'sub_classes' and 'query_codes_G16H'
for index, row in result_df.iterrows():
    sub_classes_str = row['sub_classes']  # Data format in this field "['A61B5/00', 'G16H40/67']"
    query_codes_G16H = row['query_codes_G16H']  # Data format in this field 'G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H'
    
    # Convert the sub_classes string to a list
    sub_classes = ast.literal_eval(sub_classes_str)
    
    # Split the codes into lists
    sub_class_list = [code.strip() for code in sub_classes]
    query_codes_list = query_codes_G16H.split(',')
    
    # Check for common codes
    exact_match_code = [code for code in sub_class_list if code in query_codes_list]
    
    # Join the common codes into a single string
    exact_match_code_str = ','.join(exact_match_code)
    
    # Update the 'exact_match_code' column with the exact_match_code
    result_df.at[index, 'exact_match_code'] = exact_match_code_str
    
    # Debugging statements
    #print(f'Row {index}: sub_classes={sub_classes}, query_codes_G16H={query_codes_G16H}, common_codes={common_codes_str}')

# Display the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2012271647A1  Method for improved adherence to medication th...
# 1        US2008132799A1  Method of physiological data analysis and meas...
# 2        US2022199254A1  Universal health machine for the automatic ass...
# 3        US2019096520A1                         Personalized patient model
# 4        US2021280323A1  Customizable communication platform with longi...
# ...                 ...                                                ...
# 2987     US2011021952A1  Event-based health activity tracking with icon...
# 2988     US2003220821A1  System and method for managing and reconciling...
# 2989     US2008040157A1  Methods and systems for storing and providing ...
# 2990     US2014188508A1  Method of automated electronic health record s...
# 2991     US2021090081A1              Tokenized healthcare service payments
#
#                                             first_claim  \
# 0     1 . A method for managing medication adherence...
# 1     1 . A method of analyzing patient physiologica...
# 2     1 . A method for automatically determining an ...
# 3     What is claimed is: 1 . A method for calculati...
# 4     What is claimed is: 1 . A method, comprising: ...
# ...                                                 ...
# 2987  1 . A method of tracking health activities pre...
# 2988  What is claimed is: 1 . A method of managing a...
# 2989  1 . A method for storing and providing informa...
# 2990  What is claimed is: 1 . A method of automated ...
# 2991  What is claimed is: 1 . A computer-implemented...
#
#                                        Lemmatized-Claim  \
# 0     method managing medication adherence patient c...
# 1     method analyzing patient physiological data co...
# 2     method automatically determining assessment pa...
# 3     claimed method calculating personalized patien...
# 4     claimed method comprising linking patient devi...
# ...                                                 ...
# 2987  method tracking health activity prescribed per...
# 2988  claimed method managing asynchronous patient d...
# 2989  method storing providing information related c...
# 2990  claimed method automated electronic health rec...
# 2991  claimed computerimplemented method expediting ...
#
#                       sub_classes         sub_class topics      prob  \
# 0      ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1      ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2      ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3      ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4      ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# ...                           ...               ...    ...       ...
# 2987   ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 2988   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 2989   ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 2990   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 2991  ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 2987           US20230138516A1
# 2988           US20230138516A1
# 2989           US20230138516A1
# 2990           US20230138516A1
# 2991           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 2987  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2988  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2989  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2990  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2991  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 2987  1-27. (canceled) 28. A system to manage record...
# 2988  1-27. (canceled) 28. A system to manage record...
# 2989  1-27. (canceled) 28. A system to manage record...
# 2990  1-27. (canceled) 28. A system to manage record...
# 2991  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [24]
# 1                      [24]
# 2                      [24]
# 3                      [24]
# 4                      [24]
# ...                     ...
# 2987                   [29]
# 2988                   [29]
# 2989                   [29]
# 2990                   [29]
# 2991                   [29]
#
#                                        query_codes_G16H     exact_match_code
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# ...                                                 ...                  ...
# 2987       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2988       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2989       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
# 2990       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2991       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
# [2992 rows x 14 columns]

# %%
# Calculate the count of 'exact_match_code' for each group and assign it to all rows within the group
result_df['count_exact_match_top50'] = result_df.groupby('query_publication_numbers')['exact_match_code'].transform(lambda x: x[x != ''].count())
result_df
# Out:
#      publication_number                                              title  \
# 0        US2012271647A1  Method for improved adherence to medication th...
# 1        US2008132799A1  Method of physiological data analysis and meas...
# 2        US2022199254A1  Universal health machine for the automatic ass...
# 3        US2019096520A1                         Personalized patient model
# 4        US2021280323A1  Customizable communication platform with longi...
# ...                 ...                                                ...
# 2987     US2011021952A1  Event-based health activity tracking with icon...
# 2988     US2003220821A1  System and method for managing and reconciling...
# 2989     US2008040157A1  Methods and systems for storing and providing ...
# 2990     US2014188508A1  Method of automated electronic health record s...
# 2991     US2021090081A1              Tokenized healthcare service payments
#
#                                             first_claim  \
# 0     1 . A method for managing medication adherence...
# 1     1 . A method of analyzing patient physiologica...
# 2     1 . A method for automatically determining an ...
# 3     What is claimed is: 1 . A method for calculati...
# 4     What is claimed is: 1 . A method, comprising: ...
# ...                                                 ...
# 2987  1 . A method of tracking health activities pre...
# 2988  What is claimed is: 1 . A method of managing a...
# 2989  1 . A method for storing and providing informa...
# 2990  What is claimed is: 1 . A method of automated ...
# 2991  What is claimed is: 1 . A computer-implemented...
#
#                                        Lemmatized-Claim  \
# 0     method managing medication adherence patient c...
# 1     method analyzing patient physiological data co...
# 2     method automatically determining assessment pa...
# 3     claimed method calculating personalized patien...
# 4     claimed method comprising linking patient devi...
# ...                                                 ...
# 2987  method tracking health activity prescribed per...
# 2988  claimed method managing asynchronous patient d...
# 2989  method storing providing information related c...
# 2990  claimed method automated electronic health rec...
# 2991  claimed computerimplemented method expediting ...
#
#                       sub_classes         sub_class topics      prob  \
# 0      ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1      ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2      ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3      ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4      ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# ...                           ...               ...    ...       ...
# 2987   ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 2988   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 2989   ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 2990   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 2991  ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 2987           US20230138516A1
# 2988           US20230138516A1
# 2989           US20230138516A1
# 2990           US20230138516A1
# 2991           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 2987  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2988  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2989  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2990  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2991  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 2987  1-27. (canceled) 28. A system to manage record...
# 2988  1-27. (canceled) 28. A system to manage record...
# 2989  1-27. (canceled) 28. A system to manage record...
# 2990  1-27. (canceled) 28. A system to manage record...
# 2991  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [24]
# 1                      [24]
# 2                      [24]
# 3                      [24]
# 4                      [24]
# ...                     ...
# 2987                   [29]
# 2988                   [29]
# 2989                   [29]
# 2990                   [29]
# 2991                   [29]
#
#                                        query_codes_G16H     exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# ...                                                 ...                  ...
# 2987       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2988       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2989       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
# 2990       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2991       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
#       count_exact_match_top50
# 0                           3
# 1                           3
# 2                           3
# 3                           3
# 4                           3
# ...                       ...
# 2987                        9
# 2988                        9
# 2989                        9
# 2990                        9
# 2991                        9
#
# [2992 rows x 15 columns]

# %%
import pandas as pd


# Initialize RFR as NaN
result_df['RFR'] = float('nan')

# Create a dictionary to store the first occurrence index for each group
first_occurrence_indices = {}

# Iterate through the DataFrame
for index, row in result_df.iterrows():
    query_pub_num = row['query_publication_numbers']
    exact_match_code = row['exact_match_code']

    # Check if the exact_match_code is not empty and it's the first occurrence within the group
    if exact_match_code != '' and not pd.isna(exact_match_code) and query_pub_num not in first_occurrence_indices:
        first_occurrence_indices[query_pub_num] = index

# Calculate RFR for each group based on the first occurrence within each group
for query_pub_num, first_occurrence_index in first_occurrence_indices.items():
    group_indices = result_df[result_df['query_publication_numbers'] == query_pub_num].index
    result_df.loc[group_indices, 'RFR'] = first_occurrence_index - group_indices[0] + 1

# Print the updated DataFrame
result_df
# Out:
#      publication_number                                              title  \
# 0        US2012271647A1  Method for improved adherence to medication th...
# 1        US2008132799A1  Method of physiological data analysis and meas...
# 2        US2022199254A1  Universal health machine for the automatic ass...
# 3        US2019096520A1                         Personalized patient model
# 4        US2021280323A1  Customizable communication platform with longi...
# ...                 ...                                                ...
# 2987     US2011021952A1  Event-based health activity tracking with icon...
# 2988     US2003220821A1  System and method for managing and reconciling...
# 2989     US2008040157A1  Methods and systems for storing and providing ...
# 2990     US2014188508A1  Method of automated electronic health record s...
# 2991     US2021090081A1              Tokenized healthcare service payments
#
#                                             first_claim  \
# 0     1 . A method for managing medication adherence...
# 1     1 . A method of analyzing patient physiologica...
# 2     1 . A method for automatically determining an ...
# 3     What is claimed is: 1 . A method for calculati...
# 4     What is claimed is: 1 . A method, comprising: ...
# ...                                                 ...
# 2987  1 . A method of tracking health activities pre...
# 2988  What is claimed is: 1 . A method of managing a...
# 2989  1 . A method for storing and providing informa...
# 2990  What is claimed is: 1 . A method of automated ...
# 2991  What is claimed is: 1 . A computer-implemented...
#
#                                        Lemmatized-Claim  \
# 0     method managing medication adherence patient c...
# 1     method analyzing patient physiological data co...
# 2     method automatically determining assessment pa...
# 3     claimed method calculating personalized patien...
# 4     claimed method comprising linking patient devi...
# ...                                                 ...
# 2987  method tracking health activity prescribed per...
# 2988  claimed method managing asynchronous patient d...
# 2989  method storing providing information related c...
# 2990  claimed method automated electronic health rec...
# 2991  claimed computerimplemented method expediting ...
#
#                       sub_classes         sub_class topics      prob  \
# 0      ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1      ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2      ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3      ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4      ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# ...                           ...               ...    ...       ...
# 2987   ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 2988   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 2989   ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 2990   ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 2991  ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
#
#      query_publication_numbers  \
# 0              US20230238130A1
# 1              US20230238130A1
# 2              US20230238130A1
# 3              US20230238130A1
# 4              US20230238130A1
# ...                        ...
# 2987           US20230138516A1
# 2988           US20230138516A1
# 2989           US20230138516A1
# 2990           US20230138516A1
# 2991           US20230138516A1
#
#                                       query_class_codes  \
# 0     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4     A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# ...                                                 ...
# 2987  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2988  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2989  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2990  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
# 2991  G16H,G16H10/00,G06Q10/1093,G06Q10/10,G16,G06Q1...
#
#                                             query_claim  \
# 0     1. A physiological monitoring device comprisin...
# 1     1. A physiological monitoring device comprisin...
# 2     1. A physiological monitoring device comprisin...
# 3     1. A physiological monitoring device comprisin...
# 4     1. A physiological monitoring device comprisin...
# ...                                                 ...
# 2987  1-27. (canceled) 28. A system to manage record...
# 2988  1-27. (canceled) 28. A system to manage record...
# 2989  1-27. (canceled) 28. A system to manage record...
# 2990  1-27. (canceled) 28. A system to manage record...
# 2991  1-27. (canceled) 28. A system to manage record...
#
#      query_predicted_topics  \
# 0                      [24]
# 1                      [24]
# 2                      [24]
# 3                      [24]
# 4                      [24]
# ...                     ...
# 2987                   [29]
# 2988                   [29]
# 2989                   [29]
# 2990                   [29]
# 2991                   [29]
#
#                                        query_codes_G16H     exact_match_code  \
# 0     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4     G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...            G16H40/67
# ...                                                 ...                  ...
# 2987       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60
# 2988       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2989       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
# 2990       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60  G16H10/60,G16H10/60
# 2991       G16H,G16H10/00,G16H40/20,G16H40/00,G16H10/60            G16H10/60
#
#       count_exact_match_top50  RFR
# 0                           3  5.0
# 1                           3  5.0
# 2                           3  5.0
# 3                           3  5.0
# 4                           3  5.0
# ...                       ...  ...
# 2987                        9  7.0
# 2988                        9  7.0
# 2989                        9  7.0
# 2990                        9  7.0
# 2991                        9  7.0
#
# [2992 rows x 16 columns]

# %%
# Filter the DataFrame to keep only the top 5 records within each group
result_df_filter_top5 = result_df.groupby('query_publication_numbers').apply(lambda x: x.head(5)).reset_index(drop=True)

# Count the occurrences of count_exact_match if it has data
result_df_filter_top5['count_exact_match_count'] = result_df_filter_top5['exact_match_code'].apply(lambda x: 1 if x != '' else 0)

# Calculate the total count for each group
result_df_filter_top5['count_exact_match_top5'] = result_df_filter_top5.groupby('query_publication_numbers')['count_exact_match_count'].transform('sum')
df_top5=result_df_filter_top5[["publication_number","title","first_claim", "Lemmatized-Claim","sub_classes","sub_class","topics","prob", "query_publication_numbers","query_claim","query_codes_G16H","exact_match_code","count_exact_match_top50","count_exact_match_top5"]]
df_top5
# Out:
#     publication_number                                              title  \
# 0       US2015154355A1  Health examination data displaying method, ins...
# 1       US2021375409A1  Systems and methods for blockchain-based healt...
# 2       US2020372179A1    A method and apparatus for securing health data
# 3       US2016093010A1  Multi-payer clinical documentation e-learning ...
# 4       US2019267118A1         Person-centered health record architecture
# ..                 ...                                                ...
# 485     US2012221348A1  Identifying a deviation during clinical pathwa...
# 486     US2022051780A1  System, Mobile Application and Process for an ...
# 487     US2021330546A1  System, application, and process for exercise ...
# 488     US2020038709A1      Real-Time Augmented Reality Activity Feedback
# 489     US2016210711A1                Employee Wellness Management System
#
#                                            first_claim  \
# 0    What is claimed is: 1 . A method to display he...
# 1    1 . A system comprising: a health data storage...
# 2    1 . A method of securing health data for trans...
# 3    1 . A method for educating at least one health...
# 4    What is claimed is: 1 . A method for providing...
# ..                                                 ...
# 485  1 . A system for identifying a deviation durin...
# 486  What is claimed is: 1 . A method for operating...
# 487  What is claimed is: 1 . A method for recommend...
# 488  1 . A method for real-time augmented reality (...
# 489  What is claimed is: 1 . A method for managing ...
#
#                                       Lemmatized-Claim  \
# 0    claimed method display health examination data...
# 1    system comprising health data storage configur...
# 2    method securing health data transport originat...
# 3    method educating one health professional medic...
# 4    claimed method providing health record archite...
# ..                                                 ...
# 485  system identifying deviation clinical pathway ...
# 486  claimed method operating compressive recovery ...
# 487  claimed method recommending recovery activity ...
# 488  method realtime augmented reality ar activity ...
# 489  claimed method managing wellness employee meth...
#
#                         sub_classes         sub_class topics      prob  \
# 0        ['G16H10/60', 'G16H15/00']  ['G16H', 'G16H']     29  0.490027
# 1        ['G06F21/62', 'G16H10/60']  ['G06F', 'G16H']     29  0.441707
# 2    ['G16H10/60', 'G06F2221/0711']  ['G16H', 'G06F']     29  0.423498
# 3        ['G16H50/70', 'G06Q50/22']  ['G16H', 'G06Q']     29  0.412818
# 4        ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.409711
# ..                              ...               ...    ...       ...
# 485      ['G16H70/20', 'G16H40/67']  ['G16H', 'G16H']      0  0.521324
# 486       ['G06N5/04', 'G16H20/30']  ['G06N', 'G16H']      0  0.510558
# 487      ['A61H23/00', 'G16H50/20']  ['A61H', 'G16H']      0  0.486829
# 488      ['A63B24/00', 'G16H20/30']  ['A63B', 'G16H']      0  0.471750
# 489    ['G16H20/60', 'G06Q10/1057']  ['G16H', 'G06Q']      0  0.452873
#
#     query_publication_numbers  \
# 0             US20230001090A1
# 1             US20230001090A1
# 2             US20230001090A1
# 3             US20230001090A1
# 4             US20230001090A1
# ..                        ...
# 485           US20230270344A1
# 486           US20230270344A1
# 487           US20230270344A1
# 488           US20230270344A1
# 489           US20230270344A1
#
#                                            query_claim  \
# 0    1. A continuous glucose monitoring system comp...
# 1    1. A continuous glucose monitoring system comp...
# 2    1. A continuous glucose monitoring system comp...
# 3    1. A continuous glucose monitoring system comp...
# 4    1. A continuous glucose monitoring system comp...
# ..                                                 ...
# 485  1. A monitoring device, comprising:\na band co...
# 486  1. A monitoring device, comprising:\na band co...
# 487  1. A monitoring device, comprising:\na band co...
# 488  1. A monitoring device, comprising:\na band co...
# 489  1. A monitoring device, comprising:\na band co...
#
#                                       query_codes_G16H exact_match_code  \
# 0    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 1    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 2    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 3    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# 4    G16H20/17,G16H40/00,G16H40/60,G16H40/67,G16H20...
# ..                                                 ...              ...
# 485  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H40/67
# 486  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H20/30
# 487  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H50/20
# 488  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...        G16H20/30
# 489  G16H40/00,G16H40/67,G16H20/30,G16H30/40,G16H30...
#
#      count_exact_match_top50  count_exact_match_top5
# 0                          2                       0
# 1                          2                       0
# 2                          2                       0
# 3                          2                       0
# 4                          2                       0
# ..                       ...                     ...
# 485                       19                       4
# 486                       19                       4
# 487                       19                       4
# 488                       19                       4
# 489                       19                       4
#
# [490 rows x 14 columns]

# %%
filtered_df = result_df[result_df['query_publication_numbers'] == 'US20230238130A1']
filtered_df
# Out:
#    publication_number                                              title  \
# 0      US2012271647A1  Method for improved adherence to medication th...
# 1      US2008132799A1  Method of physiological data analysis and meas...
# 2      US2022199254A1  Universal health machine for the automatic ass...
# 3      US2019096520A1                         Personalized patient model
# 4      US2021280323A1  Customizable communication platform with longi...
# 5      US2022130539A1  Method and system for dynamically generating p...
# 6      US2022130515A1  Method and system for dynamically generating g...
# 7      US2004078239A1  Integrated patient care method, apparatus, and...
# 8      US2013325496A1                        System for preventing fraud
# 9      US2022157417A1  System, method and user interface for recorded...
# 10     US2015154355A1  Health examination data displaying method, ins...
# 11     US2021375409A1  Systems and methods for blockchain-based healt...
# 12     US2020372179A1    A method and apparatus for securing health data
# 13     US2016093010A1  Multi-payer clinical documentation e-learning ...
# 14     US2019267118A1         Person-centered health record architecture
# 15     US2011021952A1  Event-based health activity tracking with icon...
# 16     US2003220821A1  System and method for managing and reconciling...
# 17     US2008040157A1  Methods and systems for storing and providing ...
# 18     US2014188508A1  Method of automated electronic health record s...
# 19     US2021090081A1              Tokenized healthcare service payments
# 20     US2020243167A1  Predicting clinical trial eligibility based on...
# 21     US2014129256A1  System and method for identifying healthcare f...
# 22     US2013070608A1  Identifying Related Network Traffic Data for M...
# 23     US2017038961A1                                   Image navigation
# 24     US2013166318A1  System and techniques for cost estimation of m...
# 25     US2013197932A1  System and Method for Healthcare Decision Support
# 26     US2020286596A1  Generating and managing clinical studies using...
# 27     US2020097552A1  Synonym determination device and synonym deter...
# 28     US2012316895A1              Generating Cross-Channel Medical Data
# 29     US2017286456A1  Dynamic ontology schema generation and asset m...
# 30     US2005003470A1  Glucose measuring device for use in personal a...
# 31     US2005222870A1  Web-based data submission for nursing quality ...
# 32     US2005216311A1  Communications system and a method of processi...
# 33     US2019164645A1  Medical information system, medical apparatus,...
# 34     US2014039914A1           System and method for promoting wellness
# 35     US2011046469A1  Glucose Measuring Device for Use In Personal A...
# 36     US2014172452A1                 System for processing medical data
# 37     US2014214440A1            Risk model for a care management system
# 38     US2010217099A1  Methods and Apparatus for Assessing Physiologi...
# 39     US2018174677A1        Autism therapy management system and method
# 40     US2011279477A1       Medical Image Processing and Handling System
# 41     US2014016846A1  Systems and methods for performing image type ...
# 42     US2015141733A1  Automatic plan optimization for changing patie...
# 43     US2019122361A1  Determination and visualization of damage to a...
# 44     US2020202519A1  Vulnerable plaque identification method, appli...
# 45     US2022207306A1  System and method for diagnosing a disease usi...
# 46     US2008117225A1   System and Method for Geometric Image Annotation
# 47     US2013335418A1  Analysis of food items captured in digital images
# 48     US2007177780A1  Enhanced navigational tools for comparing medi...
# 49     US2010053208A1      System and method of contouring a target area
#
#                                           first_claim  \
# 0   1 . A method for managing medication adherence...
# 1   1 . A method of analyzing patient physiologica...
# 2   1 . A method for automatically determining an ...
# 3   What is claimed is: 1 . A method for calculati...
# 4   What is claimed is: 1 . A method, comprising: ...
# 5   What is claimed is: 1 . A computing system imp...
# 6   What is claimed is: 1 . A computing system imp...
# 7   What is claimed is: 1 . A method for tracking ...
# 8   What is claimed is: 1 . A system for preventin...
# 9   What is claimed is: 1 . A computer-implemented...
# 10  What is claimed is: 1 . A method to display he...
# 11  1 . A system comprising: a health data storage...
# 12  1 . A method of securing health data for trans...
# 13  1 . A method for educating at least one health...
# 14  What is claimed is: 1 . A method for providing...
# 15  1 . A method of tracking health activities pre...
# 16  What is claimed is: 1 . A method of managing a...
# 17  1 . A method for storing and providing informa...
# 18  What is claimed is: 1 . A method of automated ...
# 19  What is claimed is: 1 . A computer-implemented...
# 20  What is claimed is: 1 . A computer-implemented...
# 21  1 . A method comprising: for each medical enti...
# 22  What is claimed is: 1 . A method of identifyin...
# 23  What is claimed is: 1 . (canceled) 2 . A metho...
# 24  1 . A computer-implemented method of processin...
# 25  1 . A method for building a healthcare rule en...
# 26  1 . A computer-implemented method of generatin...
# 27  What is claimed is: 1 . A synonym determinatio...
# 28  1 . A computer-implemented method comprising: ...
# 29  1 : A method comprising: storing a data model ...
# 30  1 . A data communication system, comprising: a...
# 31  1 . A system operated over an electronic netwo...
# 32  1 . A communications system for the processing...
# 33  What is claimed is: 1 . A medical information ...
# 34  What is claimed is: 1 . A method for promoting...
# 35  1 - 20 . (canceled) 21 . An analyte monitoring...
# 36  1 . System for processing medical data compris...
# 37  1 . A non-transitory electronic device readabl...
# 38  1 . A method of assessing a physiological cond...
# 39  1 . A method for using a computing device to a...
# 40  1 . An image processing device, comprising: an...
# 41  What is claimed is: 1 . A method for determini...
# 42  1 . A therapy planning system for generating a...
# 43  1 . System for determining and visualizing dam...
# 44  1 . A vulnerable plaque identification method,...
# 45  What is claimed is: 1 . A system for diagnosin...
# 46  1 . A method of geometrical annotation, compri...
# 47  1 . A smart device for analyzing food items ca...
# 48  1 . A navigational tool to facilitate the comp...
# 49  1 . A method of contouring an image, the metho...
#
#                                      Lemmatized-Claim  \
# 0   method managing medication adherence patient c...
# 1   method analyzing patient physiological data co...
# 2   method automatically determining assessment pa...
# 3   claimed method calculating personalized patien...
# 4   claimed method comprising linking patient devi...
# 5   claimed computing system implemented method co...
# 6   claimed computing system implemented method co...
# 7   claimed method tracking patient data method co...
# 8   claimed system preventing fraud comprising mem...
# 9   claimed computerimplemented method presenting ...
# 10  claimed method display health examination data...
# 11  system comprising health data storage configur...
# 12  method securing health data transport originat...
# 13  method educating one health professional medic...
# 14  claimed method providing health record archite...
# 15  method tracking health activity prescribed per...
# 16  claimed method managing asynchronous patient d...
# 17  method storing providing information related c...
# 18  claimed method automated electronic health rec...
# 19  claimed computerimplemented method expediting ...
# 20  claimed computerimplemented method comprising ...
# 21  method comprising medical entity record medica...
# 22  claimed method identifying related network tra...
# 23  claimed canceled method navigating data item m...
# 24  computerimplemented method processing medical ...
# 25  method building healthcare rule engine method ...
# 26  computerimplemented method generating managing...
# 27  claimed synonym determination device wherein s...
# 28  computerimplemented method comprising receivin...
# 29  method comprising storing data model metadata ...
# 30  data communication system comprising data netw...
# 31  system operated electronic network surveying n...
# 32  communication system processing medical data c...
# 33  claimed medical information system comprising ...
# 34  claimed method promoting wellness comprising c...
# 35  canceled analyte monitoring system comprising ...
# 36  system processing medical data comprising cent...
# 37  nontransitory electronic device readable mediu...
# 38  method assessing physiological condition subje...
# 39  method computing device automatically conduct ...
# 40  image processing device comprising electronic ...
# 41  claimed method determining image information i...
# 42  therapy planning system generating optimal tre...
# 43  system determining visualizing damage anatomic...
# 44  vulnerable plaque identification method applic...
# 45  claimed system diagnosing disease image classi...
# 46  method geometrical annotation comprising acqui...
# 47  smart device analyzing food item captured two ...
# 48  navigational tool facilitate comparison two te...
# 49  method contouring image method comprising acqu...
#
#                         sub_classes         sub_class topics      prob  \
# 0        ['G16H80/00', 'G06Q10/10']  ['G16H', 'G06Q']     24  0.549093
# 1        ['A61B5/366', 'G16H50/70']  ['A61B', 'G16H']     24  0.545203
# 2        ['G16H10/60', 'G06N3/045']  ['G16H', 'G06N']     24  0.543169
# 3        ['G16H30/20', 'G16H50/50']  ['G16H', 'G16H']     24  0.541534
# 4        ['G16H40/67', 'G16H20/00']  ['G16H', 'G16H']     24  0.537068
# 5      ['G16H50/50', 'A61M2230/42']  ['G16H', 'A61M']     24  0.530496
# 6    ['G16H50/20', 'A61M2021/0027']  ['G16H', 'A61M']     24  0.530426
# 7        ['G06Q10/10', 'G16H10/60']  ['G06Q', 'G16H']     24  0.527439
# 8        ['G16H20/10', 'G06Q10/08']  ['G16H', 'G06Q']     24  0.527420
# 9        ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     24  0.523036
# 10       ['G16H10/60', 'G16H15/00']  ['G16H', 'G16H']     29  0.490027
# 11       ['G06F21/62', 'G16H10/60']  ['G06F', 'G16H']     29  0.441707
# 12   ['G16H10/60', 'G06F2221/0711']  ['G16H', 'G06F']     29  0.423498
# 13       ['G16H50/70', 'G06Q50/22']  ['G16H', 'G06Q']     29  0.412818
# 14       ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.409711
# 15       ['G16H20/30', 'G16H20/30']  ['G16H', 'G16H']     29  0.409642
# 16       ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.406767
# 17       ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     29  0.406766
# 18       ['G16H10/60', 'G16H10/60']  ['G16H', 'G16H']     29  0.405024
# 19      ['G16H10/60', 'G06Q20/401']  ['G16H', 'G06Q']     29  0.394376
# 20        ['G16H10/60', 'G06N7/01']  ['G16H', 'G06N']     14  0.408045
# 21       ['G06Q40/08', 'G16H40/20']  ['G06Q', 'G16H']     14  0.396582
# 22       ['G16H10/60', 'Y02D30/50']  ['G16H', 'Y02D']     14  0.392341
# 23     ['G16H30/20', 'G06F3/04883']  ['G16H', 'G06F']     14  0.390303
# 24       ['G16H40/20', 'G06Q10/10']  ['G16H', 'G06Q']     14  0.388222
# 25       ['G16H40/20', 'G16H40/20']  ['G16H', 'G16H']     14  0.387090
# 26       ['G06F16/28', 'G16H10/60']  ['G06F', 'G16H']     14  0.386631
# 27        ['G06K9/00', 'G16H70/40']  ['G06K', 'G16H']     14  0.385562
# 28       ['G06Q50/00', 'G16H10/60']  ['G06Q', 'G16H']     14  0.385108
# 29       ['G06F17/30', 'G16H10/20']  ['G06F', 'G16H']     14  0.384537
# 30   ['G16H10/60', 'A61B2562/0295']  ['G16H', 'A61B']     10  0.325974
# 31       ['G06F17/30', 'G16H40/20']  ['G06F', 'G16H']     10  0.321440
# 32       ['G16H80/00', 'G16H40/20']  ['G16H', 'G16H']     10  0.321049
# 33       ['H04L29/06', 'G16H40/40']  ['H04L', 'G16H']     10  0.308726
# 34       ['G06F19/00', 'G16H20/60']  ['G06F', 'G16H']     10  0.304677
# 35   ['G16H10/60', 'A61B2562/0295']  ['G16H', 'A61B']     10  0.303060
# 36       ['G06F19/00', 'G16H40/67']  ['G06F', 'G16H']     10  0.297560
# 37       ['G06F19/00', 'G16H10/20']  ['G06F', 'G16H']     10  0.290267
# 38        ['A61B5/00', 'G16H40/67']  ['A61B', 'G16H']     10  0.288786
# 39      ['G16H20/70', 'A61B5/4848']  ['G16H', 'A61B']     10  0.288489
# 40       ['G16H30/40', 'G16H40/20']  ['G16H', 'G16H']      9  0.236793
# 41        ['G06K9/78', 'G16H30/40']  ['G06K', 'G16H']      9  0.233115
# 42      ['G16H20/40', 'A61N5/1045']  ['G16H', 'A61N']      9  0.233081
# 43        ['A61B6/00', 'G16H50/30']  ['A61B', 'G16H']      9  0.232541
# 44  ['G16H30/40', 'G06T2207/20084']  ['G16H', 'G06T']      9  0.231992
# 45      ['G16H30/20', 'G06F18/213']  ['G16H', 'G06F']      9  0.230420
# 46      ['G16H30/20', 'A61B6/5223']  ['G16H', 'A61B']      9  0.230308
# 47       ['G16H20/60', 'G06T15/08']  ['G16H', 'G06T']      9  0.229849
# 48     ['G16H30/40', 'G06V2201/03']  ['G16H', 'G06V']      9  0.229481
# 49     ['G16H20/40', 'G06T2210/41']  ['G16H', 'G06T']      9  0.228291
#
#    query_publication_numbers  \
# 0            US20230238130A1
# 1            US20230238130A1
# 2            US20230238130A1
# 3            US20230238130A1
# 4            US20230238130A1
# 5            US20230238130A1
# 6            US20230238130A1
# 7            US20230238130A1
# 8            US20230238130A1
# 9            US20230238130A1
# 10           US20230238130A1
# 11           US20230238130A1
# 12           US20230238130A1
# 13           US20230238130A1
# 14           US20230238130A1
# 15           US20230238130A1
# 16           US20230238130A1
# 17           US20230238130A1
# 18           US20230238130A1
# 19           US20230238130A1
# 20           US20230238130A1
# 21           US20230238130A1
# 22           US20230238130A1
# 23           US20230238130A1
# 24           US20230238130A1
# 25           US20230238130A1
# 26           US20230238130A1
# 27           US20230238130A1
# 28           US20230238130A1
# 29           US20230238130A1
# 30           US20230238130A1
# 31           US20230238130A1
# 32           US20230238130A1
# 33           US20230238130A1
# 34           US20230238130A1
# 35           US20230238130A1
# 36           US20230238130A1
# 37           US20230238130A1
# 38           US20230238130A1
# 39           US20230238130A1
# 40           US20230238130A1
# 41           US20230238130A1
# 42           US20230238130A1
# 43           US20230238130A1
# 44           US20230238130A1
# 45           US20230238130A1
# 46           US20230238130A1
# 47           US20230238130A1
# 48           US20230238130A1
# 49           US20230238130A1
#
#                                     query_class_codes  \
# 0   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 1   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 2   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 3   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 4   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 5   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 6   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 7   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 8   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 9   A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 10  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 11  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 12  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 13  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 14  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 15  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 16  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 17  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 18  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 19  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 20  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 21  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 22  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 23  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 24  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 25  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 26  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 27  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 28  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 29  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 30  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 31  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 32  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 33  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 34  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 35  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 36  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 37  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 38  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 39  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 40  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 41  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 42  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 43  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 44  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 45  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 46  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 47  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 48  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
# 49  A61B5/14551,A61,A61B5/0295,A61B5/6829,G,A61B5/...
#
#                                           query_claim query_predicted_topics  \
# 0   1. A physiological monitoring device comprisin...                   [24]
# 1   1. A physiological monitoring device comprisin...                   [24]
# 2   1. A physiological monitoring device comprisin...                   [24]
# 3   1. A physiological monitoring device comprisin...                   [24]
# 4   1. A physiological monitoring device comprisin...                   [24]
# 5   1. A physiological monitoring device comprisin...                   [24]
# 6   1. A physiological monitoring device comprisin...                   [24]
# 7   1. A physiological monitoring device comprisin...                   [24]
# 8   1. A physiological monitoring device comprisin...                   [24]
# 9   1. A physiological monitoring device comprisin...                   [24]
# 10  1. A physiological monitoring device comprisin...                   [29]
# 11  1. A physiological monitoring device comprisin...                   [29]
# 12  1. A physiological monitoring device comprisin...                   [29]
# 13  1. A physiological monitoring device comprisin...                   [29]
# 14  1. A physiological monitoring device comprisin...                   [29]
# 15  1. A physiological monitoring device comprisin...                   [29]
# 16  1. A physiological monitoring device comprisin...                   [29]
# 17  1. A physiological monitoring device comprisin...                   [29]
# 18  1. A physiological monitoring device comprisin...                   [29]
# 19  1. A physiological monitoring device comprisin...                   [29]
# 20  1. A physiological monitoring device comprisin...                   [14]
# 21  1. A physiological monitoring device comprisin...                   [14]
# 22  1. A physiological monitoring device comprisin...                   [14]
# 23  1. A physiological monitoring device comprisin...                   [14]
# 24  1. A physiological monitoring device comprisin...                   [14]
# 25  1. A physiological monitoring device comprisin...                   [14]
# 26  1. A physiological monitoring device comprisin...                   [14]
# 27  1. A physiological monitoring device comprisin...                   [14]
# 28  1. A physiological monitoring device comprisin...                   [14]
# 29  1. A physiological monitoring device comprisin...                   [14]
# 30  1. A physiological monitoring device comprisin...                   [10]
# 31  1. A physiological monitoring device comprisin...                   [10]
# 32  1. A physiological monitoring device comprisin...                   [10]
# 33  1. A physiological monitoring device comprisin...                   [10]
# 34  1. A physiological monitoring device comprisin...                   [10]
# 35  1. A physiological monitoring device comprisin...                   [10]
# 36  1. A physiological monitoring device comprisin...                   [10]
# 37  1. A physiological monitoring device comprisin...                   [10]
# 38  1. A physiological monitoring device comprisin...                   [10]
# 39  1. A physiological monitoring device comprisin...                   [10]
# 40  1. A physiological monitoring device comprisin...                    [9]
# 41  1. A physiological monitoring device comprisin...                    [9]
# 42  1. A physiological monitoring device comprisin...                    [9]
# 43  1. A physiological monitoring device comprisin...                    [9]
# 44  1. A physiological monitoring device comprisin...                    [9]
# 45  1. A physiological monitoring device comprisin...                    [9]
# 46  1. A physiological monitoring device comprisin...                    [9]
# 47  1. A physiological monitoring device comprisin...                    [9]
# 48  1. A physiological monitoring device comprisin...                    [9]
# 49  1. A physiological monitoring device comprisin...                    [9]
#
#                                      query_codes_G16H exact_match_code  \
# 0   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 1   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 2   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 3   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 4   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 5   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 6   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 7   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 8   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 9   G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 10  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 11  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 12  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 13  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 14  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 15  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 16  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 17  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 18  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 19  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 20  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 21  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 22  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 23  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 24  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 25  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 26  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 27  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 28  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 29  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 30  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 31  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 32  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 33  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 34  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 35  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 36  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 37  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 38  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...        G16H40/67
# 39  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 40  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 41  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 42  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 43  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 44  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 45  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 46  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 47  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 48  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
# 49  G16H40/00,G16H40/60,G16H40/67,G16H10/40,G16H,G...
#
#     count_exact_match_top50  RFR
# 0                         3  5.0
# 1                         3  5.0
# 2                         3  5.0
# 3                         3  5.0
# 4                         3  5.0
# 5                         3  5.0
# 6                         3  5.0
# 7                         3  5.0
# 8                         3  5.0
# 9                         3  5.0
# 10                        3  5.0
# 11                        3  5.0
# 12                        3  5.0
# 13                        3  5.0
# 14                        3  5.0
# 15                        3  5.0
# 16                        3  5.0
# 17                        3  5.0
# 18                        3  5.0
# 19                        3  5.0
# 20                        3  5.0
# 21                        3  5.0
# 22                        3  5.0
# 23                        3  5.0
# 24                        3  5.0
# 25                        3  5.0
# 26                        3  5.0
# 27                        3  5.0
# 28                        3  5.0
# 29                        3  5.0
# 30                        3  5.0
# 31                        3  5.0
# 32                        3  5.0
# 33                        3  5.0
# 34                        3  5.0
# 35                        3  5.0
# 36                        3  5.0
# 37                        3  5.0
# 38                        3  5.0
# 39                        3  5.0
# 40                        3  5.0
# 41                        3  5.0
# 42                        3  5.0
# 43                        3  5.0
# 44                        3  5.0
# 45                        3  5.0
# 46                        3  5.0
# 47                        3  5.0
# 48                        3  5.0
# 49                        3  5.0

# %%
result_df.to_csv('NMF-Claim.csv', index=False)

# %%
average_count_exact_match_top5 = df_top5.groupby('query_publication_numbers')['count_exact_match_top5'].mean().reset_index()
average_count_exact_match_top5
# Out:
#    query_publication_numbers  count_exact_match_top5
# 0            US20230001090A1                     0.0
# 1            US20230001263A1                     0.0
# 2            US20230005591A1                     0.0
# 3            US20230005611A1                     1.0
# 4            US20230009812A1                     0.0
# ..                       ...                     ...
# 93           US20230255518A1                     0.0
# 94           US20230259481A1                     0.0
# 95           US20230260617A1                     2.0
# 96           US20230264029A1                     0.0
# 97           US20230270344A1                     4.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top5 = average_count_exact_match_top5['count_exact_match_top5'].mean()
print("Average of count_exact_match_top5:", average_count_exact_match_top5)
# Out:
# Average of count_exact_match_top5: 0.7857142857142857

# %%
average_count_exact_match_top50 = result_df.groupby('query_publication_numbers')['count_exact_match_top50'].mean().reset_index()
average_count_exact_match_top50
# Out:
#    query_publication_numbers  count_exact_match_top50
# 0            US20230001090A1                      2.0
# 1            US20230001263A1                      4.0
# 2            US20230005591A1                      4.0
# 3            US20230005611A1                      4.0
# 4            US20230009812A1                      4.0
# ..                       ...                      ...
# 93           US20230255518A1                      6.0
# 94           US20230259481A1                      3.0
# 95           US20230260617A1                      5.0
# 96           US20230264029A1                      3.0
# 97           US20230270344A1                     19.0
#
# [98 rows x 2 columns]

# %%
average_count_exact_match_top50 = average_count_exact_match_top50['count_exact_match_top50'].mean()
print("Average of count_exact_match_top50:", average_count_exact_match_top50)
# Out:
# Average of count_exact_match_top50: 5.214285714285714

# %%
avg_RFR =  result_df.groupby('query_publication_numbers')['RFR'].mean().reset_index()
avg_RFR
# Out:
#    query_publication_numbers   RFR
# 0            US20230001090A1  27.0
# 1            US20230001263A1  13.0
# 2            US20230005591A1   7.0
# 3            US20230005611A1   3.0
# 4            US20230009812A1   8.0
# ..                       ...   ...
# 93           US20230255518A1  13.0
# 94           US20230259481A1  18.0
# 95           US20230260617A1   4.0
# 96           US20230264029A1   7.0
# 97           US20230270344A1   1.0
#
# [98 rows x 2 columns]

# %%
avg_RFR = avg_RFR['RFR'].mean()
print("Average of RFR:", avg_RFR)
# Out:
# Average of RFR: 7.588888888888889
